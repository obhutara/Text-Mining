# %% [markdown]
# # L5: Information extraction

# %% [markdown]
# # Omkar Bhutra (omkbh878)

# %% [markdown]
# Information extraction (IE) is the task of identifying named entities and semantic relations between these entities in text data. In this lab we will focus on two sub-tasks in IE, **named entity recognition** (identifying mentions of entities) and **entity linking** (matching these mentions to entities in a knowledge base).

# %% [markdown]
# We start by loading spaCy:

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# The data that we will be using has been tokenized following the conventions of the [Penn Treebank](ftp://ftp.cis.upenn.edu/pub/treebank/public_html/tokenization.html), and we need to prevent spaCy from using its own tokenizer on top of this. We therefore override spaCy&rsquo;s tokenizer with one that simply splits on space.

# %%
from spacy.tokens import Doc

class WhitespaceTokenizer(object):
    def __init__(self, vocab):
        self.vocab = vocab

    def __call__(self, text):
        return Doc(self.vocab, words=text.split(" "))

nlp.tokenizer = WhitespaceTokenizer(nlp.vocab)

# %% [markdown]
# ## Data set

# %% [markdown]
# The main data set for this lab is a collection of news wire articles in which mentions of named entities have been annotated with page names from the [English Wikipedia](https://en.wikipedia.org/wiki/). The next code cell loads the training and the development parts of the data into Pandas data frames.

# %%
import bz2
import csv
import pandas as pd

with bz2.open("ner-train.tsv.bz2", 'rt',encoding='utf8') as source:
    df_train = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

with bz2.open("ner-dev.tsv.bz2", 'rt',encoding='utf8') as source:
    df_dev = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Each row in these two data frames corresponds to one mention of a named entity and has five columns:
#
# 1. a unique identifier for the sentence containing the entity mention
# 2. the pre-tokenized sentence, with tokens separated by spaces
# 3. the start position of the token span containing the entity mention
# 4. the end position of the token span (exclusive, as in Python list indexing)
# 5. the entity label; either a Wikipedia page name or the generic label `--NME--`
#
# The following cell prints the first five samples from the training data:

# %%
df_train.head()
# Out:
#   sentence_id                                          sentence  beg  end  \
# 0    0000-000  EU rejects German call to boycott British lamb .    0    1
# 1    0000-000  EU rejects German call to boycott British lamb .    2    3
# 2    0000-000  EU rejects German call to boycott British lamb .    6    7
# 3    0000-001                                   Peter Blackburn    0    2
# 4    0000-002                               BRUSSELS 1996-08-22    0    1
#
#             label
# 0         --NME--
# 1         Germany
# 2  United_Kingdom
# 3         --NME--
# 4        Brussels

# %% [markdown]
# In this sample, we see that the first sentence is annotated with three entity mentions:
#
# * the span 0–1 &lsquo;EU&rsquo; is annotated as a mention but only labelled with the generic `--NME--`
# * the span 2–3 &lsquo;German&rsquo; is annotated with the page [Germany](http://en.wikipedia.org/wiki/Germany)
# * the span 6–7 &lsquo;British&rsquo; is annotated with the page [United_Kingdom](http://en.wikipedia.org/wiki/United_Kingdom)

# %% [markdown]
# ## Problem 1: Evaluation measures

# %% [markdown]
# To warm up, we ask you to write code to print the three measures that you will be using for evaluation:

# %%
import numpy as np
def evaluation_report(gold, pred):
    """Print precision, recall, and F1 score.
    
    Args:
        gold: The set with the gold-standard values.
        pred: The set with the predicted values.
    
    Returns:
        Nothing, but prints the precision, recall, and F1 values computed
        based on the specified sets.
    """
    # TODO: Replace the next line with your own code
    
    precision = len(gold.intersection(pred))*100/len(pred)
    recall = len(gold.intersection(pred))*100/len(gold)
    f1_score = 2 * (precision*recall)/(precision + recall)
    
    print("Precision score is",precision,"%")
    print("Recall score is",recall,"%")
    print("f1 score is",f1_score,"%")
    pass

# %% [markdown]
# To test your code, you can run the following cell:

# %%
evaluation_report(set(range(3)), set(range(5)))
# Out:
# Precision score is 60.0 %
# Recall score is 100.0 %
# f1 score is 75.0 %

# %% [markdown]
# This should give you a precision of 60%, a recall of 100%, and an F1-value of 75%.

# %% [markdown]
# ## Problem 2: Span recognition

# %% [markdown]
# One of the first tasks that an information extraction system has to solve is to locate and classify (mentions of) named entities, such as persons and organizations. Here we will tackle the simpler task of recognizing **spans** of tokens that contain an entity mention, without the actual entity label.
#
# The English language model in spaCy features a full-fledged [named entity recognizer](https://spacy.io/usage/linguistic-features#named-entities) that identifies a variety of entities, and can be updated with new entity types by the user. Your task in this problem is to evaluate the performance of this component when predicting entity spans in the development data.
#
# Start by implementing a generator function that yields the gold-standard spans in a given data frame.
#
# **Hint:** The Pandas method [`itertuples()`](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.itertuples.html) is useful when iterating over the rows in a DataFrame.

# %%
def gold_spans(df):
    """Yield the gold-standard mention spans in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        triples consisting of the sentence id, start position, and end
        position of each span.
    """
    # TODO: Replace the next line with your own code
    for _,sentence_id, _, beg, end, *_ in df.itertuples():   
        yield(sentence_id,beg,end)

# %% [markdown]
# To test your code, you can count the spans yielded by your function. When called on the development data, you should get a total of 5,917 unique triples. The first triple and the last triple should be
#
#     ('0946-000', 2, 3)
#     ('1161-010', 1, 3)

# %%
spans_dev_gold = set(gold_spans(df_dev))
print(len(spans_dev_gold))
# Out:
# 5917

# %%
spans_dev_gold1 = list(gold_spans(df_dev))
print(spans_dev_gold1[0])
print(spans_dev_gold1[5916])
# Out:
# ('0946-000', 2, 3)
# ('1161-010', 1, 3)

# %% [markdown]
# Your next task is to write code that calls spaCy to predict the named entities in the development data, and to evaluate the accuracy of these predictions in terms of precision, recall, and F1. Print these scores using the function that you wrote for Problem&nbsp;1.

# %%
# TODO: Write code here to run and evaluate the spaCy NER on the development data
def spans(data):
    for i in data.sentence_id.unique():
        sentence = data[data.sentence_id == i].sentence.values[0]
        doc = nlp(sentence)
        for ent in doc.ents:
            yield (i, ent.start, ent.end)
evaluation_report(spans_dev_gold, set(spans(df_dev)))
# Out:
# Precision score is 52.94499221587961 %
# Recall score is 68.97076221057968 %
# f1 score is 59.904587155963306 %

# %% [markdown]
# ## Problem 3: Error analysis

# %% [markdown]
# As you were able to see in Problem&nbsp;2, the span accuracy of the named entity recognizer is far from perfect. In particular, only slightly more than half of the predicted spans are correct according to the gold standard. Your next task is to analyse this result in more detail.
#
# Write code that prints the false positives and the false negatives from the automatic prediction. Have a look at the output. What are your observations? How could you improve the result? Discuss these questions in a short text.

# %%
# TODO: Write code here to do your analysis
print("The number of false negatives are",len(spans_dev_gold - set(spans(df_dev))))
#print("The false negatives are",list(spans_dev_gold - set(spans(df_dev))))
def false_pos(gold, pred, df):
    for i in gold:
        if i not in pred:
            print(i)
            print(df[df['sentence_id'] == i[0]]['sentence'].values[0].split(' ')[i[1]:i[2]])
false_pos(spans_dev_gold, spans(df_dev), df_dev)
# Out:
# The number of false negatives are 1836
# ('0969-002', 9, 10)
# ['French']
# ('1128-013', 7, 8)
# ['Swiss']
# ('1130-003', 6, 8)
# ['Bertillon', '166']
# ('1077-006', 0, 1)
# ['England']
# ('1090-014', 0, 1)
# ['Seles']
# ('1031-008', 25, 26)
# ['Pirelli']
# ('0949-006', 23, 24)
# ['Hoddle']
# ('1160-018', 4, 5)
# ['Collins']
# ('0957-018', 26, 28)
# ['Alex', 'Corretja']
# ('1009-003', 25, 26)
# ['U.S.']
# ('1054-008', 6, 7)
# ['Rabobank']
# ('1064-002', 1, 2)
# ['Wallaby']
# ('1135-013', 0, 2)
# ['Suu', 'Kyi']
# ('1156-009', 11, 12)
# ['Burundi']
# ('1146-004', 12, 13)
# ['Aziz']
# ('0959-013', 2, 3)
# ['PITTSBURGH']
# ('0966-143', 4, 5)
# ['Britain']
# ('0965-006', 0, 1)
# ['Jamaica']
# ('1152-014', 9, 10)
# ['F-14']
# ('0962-011', 3, 5)
# ['Brian', 'Henninger']
# ('1159-000', 7, 8)
# ['Belgium']
# ('1060-020', 5, 6)
# ['Spain']
# ('1100-002', 1, 3)
# ['Tom', 'Johnson']
# ('1057-002', 18, 19)
# ['Edgbaston']
# ('1134-007', 0, 1)
# ['Ramos']
# ('1074-002', 0, 1)
# ['Mauritania']
# ('0990-005', 7, 8)
# ['Yeltsin']
# ('1142-005', 9, 11)
# ['Faik', 'Nerweyi']
# ('1123-004', 0, 1)
# ['Ssangbangwool']
# ('1149-001', 0, 1)
# ['DETROIT']
# ('1005-006', 19, 21)
# ['South', 'Korean']
# ('1056-017', 24, 26)
# ['Thorsten', 'Rund']
# ('1134-002', 2, 4)
# ['Fidel', 'Ramos']
# ('0972-026', 0, 2)
# ['A.', 'Gurusinha']
# ('1068-034', 3, 4)
# ['Hartlepool']
# ('1011-017', 7, 8)
# ['Missouri']
# ('1067-008', 5, 6)
# ['Clydebank']
# ('1127-019', 11, 13)
# ['Nurbika', 'Mamatuyeva']
# ('1114-004', 0, 1)
# ['Romania']
# ('0966-047', 4, 5)
# ['Kenya']
# ('0966-156', 1, 3)
# ['Louise', 'McPaul']
# ('1011-002', 0, 1)
# ['CHICAGO']
# ('1056-046', 0, 2)
# ['Lucy', 'Tyler-Sharman']
# ('1111-008', 5, 7)
# ['Beryll', 'Remblance']
# ('1103-016', 36, 38)
# ['Abdullah', 'Ercan']
# ('1099-018', 11, 13)
# ['Colin', 'Calderwood']
# ('1145-003', 16, 17)
# ['al-Daih']
# ('1037-002', 28, 29)
# ['China']
# ('1022-007', 21, 22)
# ['C$']
# ('0956-007', 2, 3)
# ['Samsung']
# ('0958-039', 0, 1)
# ['HOUSTON']
# ('0949-004', 16, 17)
# ['Moldova']
# ('1061-019', 0, 1)
# ['Currie']
# ('1133-004', 24, 26)
# ['Communist', 'Party']
# ('1068-025', 0, 1)
# ['Shrewsbury']
# ('1070-015', 7, 10)
# ['Reynard', 'Ford', 'Cosworth']
# ('1150-000', 3, 5)
# ['New', 'Hampshire']
# ('1152-018', 18, 19)
# ['U.S.']
# ('1008-014', 5, 7)
# ['Commerce', 'Department']
# ('1157-002', 19, 20)
# ['Iraq']
# ('1152-011', 26, 27)
# ['Iran']
# ('1065-006', 0, 2)
# ['Greenock', 'Morton']
# ('1121-000', 7, 8)
# ['Iraq']
# ('1056-014', 1, 3)
# ['Tatian', 'Stiajkina']
# ('0966-125', 1, 3)
# ['Stefka', 'Kostadinova']
# ('0946-004', 29, 30)
# ['England']
# ('1128-002', 17, 18)
# ['Hachette']
# ('1075-002', 4, 5)
# ['Benin']
# ('1154-009', 11, 12)
# ['Moslem']
# ('1076-038', 0, 4)
# ['Buducnost', '(', 'V', ')']
# ('1045-003', 8, 9)
# ['U.N.']
# ('1049-003', 22, 23)
# ['Norwich']
# ('1009-013', 16, 17)
# ['Mexico']
# ('1046-008', 31, 32)
# ['Real']
# ('1099-015', 0, 1)
# ['Austrian']
# ('1142-012', 4, 5)
# ['KDP']
# ('0962-010', 16, 18)
# ['Tim', 'Simpson']
# ('1143-004', 25, 26)
# ['Sikhin']
# ('1128-006', 5, 6)
# ['Hachette']
# ('0966-101', 4, 5)
# ['Canada']
# ('1152-018', 1, 3)
# ['Carl', 'Vinson']
# ('0984-005', 0, 1)
# ['BRITAIN']
# ('1065-014', 0, 1)
# ['Stirling']
# ('1023-013', 1, 4)
# ['New', 'York', 'Newsdesk']
# ('1056-047', 0, 2)
# ['Antonella', 'Bellutti']
# ('0984-011', 5, 6)
# ['LIFFE']
# ('1093-000', 2, 3)
# ['U.S.']
# ('1067-018', 2, 4)
# ['East', 'Stirling']
# ('0957-006', 5, 6)
# ['Croatia']
# ('0981-014', 12, 14)
# ['John', 'Casesa']
# ('1108-004', 8, 9)
# ['Miller']
# ('1096-013', 3, 5)
# ['Delino', 'DeShields']
# ('1066-066', 0, 1)
# ['Lincoln']
# ('0968-004', 5, 6)
# ['Edwards']
# ('0963-011', 0, 1)
# ['Henke']
# ('1152-004', 24, 25)
# ['Enterprise']
# ('1016-001', 0, 1)
# ['BONN']
# ('1160-010', 24, 25)
# ['IRA']
# ('0966-037', 4, 5)
# ['Cuba']
# ('1096-012', 32, 36)
# ['(', 'Jerry', ')', 'Koosman']
# ('0963-003', 15, 17)
# ['Duffy', 'Waldorf']
# ('1012-002', 16, 18)
# ['Louis', 'Farrakhan']
# ('1120-002', 1, 2)
# ['Iraqi']
# ('1068-014', 7, 8)
# ['Bolton']
# ('0972-000', 4, 6)
# ['SRI', 'LANKA']
# ('1118-002', 33, 34)
# ['Scotland']
# ('0982-001', 0, 1)
# ['LONDON']
# ('1094-040', 0, 2)
# ['ST', 'LOUIS']
# ('1037-002', 0, 1)
# ['Swedish']
# ('1072-019', 59, 61)
# ['Glenn', 'Taylor']
# ('1069-011', 4, 5)
# ['Worcestershire']
# ('1156-010', 20, 21)
# ['Hutu']
# ('0981-001', 0, 2)
# ['FARMINGTON', 'HILLS']
# ('1095-009', 3, 4)
# ['CALIFORNIA']
# ('0966-025', 1, 3)
# ['Falk', 'Balzer']
# ('0966-105', 1, 3)
# ['Marc', 'Blume']
# ('1058-003', 0, 1)
# ['Rodriguez']
# ('0949-002', 5, 7)
# ['Alan', 'Shearer']
# ('1042-000', 5, 6)
# ['China']
# ('1055-004', 3, 5)
# ['Moin', 'Khan']
# ('1059-002', 20, 21)
# ['Surrey']
# ('1010-002', 2, 4)
# ['Joseph', 'Bernardin']
# ('1121-005', 19, 20)
# ['Arbil']
# ('0947-010', 20, 21)
# ['Hampshire']
# ('1101-000', 2, 3)
# ['FRANCE']
# ('1058-017', 16, 18)
# ['Darryl', 'Strawberry']
# ('1152-018', 22, 23)
# ['Gulf']
# ('1094-041', 0, 1)
# ['CHICAGO']
# ('0957-033', 26, 27)
# ['Sweden']
# ('1128-002', 21, 22)
# ['Polish']
# ('1034-001', 0, 2)
# ['THE', 'HAGUE']
# ('1030-032', 2, 4)
# ['Wall', 'Street']
# ('1144-000', 0, 1)
# ['KPD']
# ('1031-013', 37, 40)
# ['Marco', 'Tonchetti', 'Provera']
# ('0966-081', 4, 5)
# ['U.S.']
# ('1075-002', 0, 1)
# ['Mauritania']
# ('1016-015', 12, 14)
# ['Shimon', 'Peres']
# ('1054-005', 4, 5)
# ['Germany']
# ('1008-008', 6, 7)
# ['Midwest']
# ('1058-036', 29, 32)
# ['Kansas', 'City', 'Royals']
# ('0951-004', 2, 4)
# ['Cosmin', 'Contra']
# ('1064-005', 28, 29)
# ['Gloucester']
# ('0973-002', 11, 13)
# ['Sri', 'Lanka']
# ('1095-010', 2, 3)
# ['Boston']
# ('0966-079', 4, 5)
# ['Kenya']
# ('1025-010', 13, 14)
# ['Israel']
# ('1064-002', 9, 10)
# ['English']
# ('1103-007', 38, 40)
# ['David', 'Elleray']
# ('1116-023', 2, 6)
# ['James', 'Alfred', 'Van', 'Allen']
# ('1045-007', 21, 22)
# ['Israeli']
# ('0953-012', 0, 1)
# ['Duran']
# ('1059-000', 4, 5)
# ['KENT']
# ('1030-040', 1, 2)
# ['Tokyo']
# ('1006-011', 0, 1)
# ['Tripoli-based']
# ('1143-004', 21, 22)
# ['Hizbollah']
# ('1095-006', 2, 3)
# ['TORONTO']
# ('1065-037', 0, 2)
# ['Ross', 'County']
# ('1007-012', 2, 3)
# ['Dole']
# ('1146-006', 7, 8)
# ['Saddam']
# ('1076-014', 0, 1)
# ['Partizan']
# ('1072-000', 6, 8)
# ['ALL', 'BLACK']
# ('1141-007', 11, 12)
# ['Guangdong']
# ('1147-002', 0, 2)
# ['United', 'Nations']
# ('1125-003', 12, 13)
# ['RDR']
# ('1103-016', 22, 24)
# ['Recep', 'Cetin']
# ('1094-014', 0, 1)
# ['CHICAGO']
# ('1096-027', 6, 8)
# ['David', 'Segui']
# ('0958-013', 0, 1)
# ['CLEVELAND']
# ('1068-038', 0, 1)
# ['Wigan']
# ('1125-012', 14, 15)
# ['Tanzania']
# ('1098-001', 0, 1)
# ['DUBLIN']
# ('1035-009', 0, 1)
# ['Russia']
# ('0982-005', 4, 6)
# ['London', 'Newsroom']
# ('1095-010', 0, 1)
# ['OAKLAND']
# ('0946-004', 11, 13)
# ['Grace', 'Road']
# ('1069-006', 5, 6)
# ['Durham']
# ('1058-018', 0, 1)
# ['Pettite']
# ('1006-011', 6, 7)
# ['Gaddafi']
# ('1116-007', 13, 15)
# ['Charles', 'VI']
# ('1027-016', 19, 20)
# ['Jerusalem']
# ('1094-018', 0, 2)
# ['WESTERN', 'DIVISION']
# ('1007-012', 0, 1)
# ['Clinton']
# ('1068-001', 0, 1)
# ['LONDON']
# ('1140-005', 8, 9)
# ['Chinese']
# ('1140-000', 0, 2)
# ['Hong', 'Kong']
# ('0960-007', 31, 33)
# ['Leander', 'Paes']
# ('1137-002', 18, 19)
# ['South']
# ('0966-002', 4, 7)
# ['Berlin', 'Grand', 'Prix']
# ('1142-009', 7, 8)
# ['KDP']
# ('0975-000', 1, 2)
# ['COMELF']
# ('1077-002', 0, 1)
# ['England']
# ('0948-036', 9, 10)
# ['Manchester']
# ('0966-109', 1, 3)
# ['Sammy', 'Langat']
# ('1078-007', 0, 1)
# ['Alba']
# ('1146-005', 14, 15)
# ['U.S.']
# ('1089-012', 14, 15)
# ['Parnevik']
# ('1101-003', 12, 14)
# ['Aime', 'Jacquet']
# ('1096-015', 0, 2)
# ['Darren', 'Dreifort']
# ('0991-000', 0, 1)
# ['Lebed']
# ('1096-001', 0, 1)
# ['CINCINNATI']
# ('1155-011', 6, 7)
# ['Banisadr']
# ('1101-012', 65, 68)
# ['Alberto', 'Garcia', 'Aspe']
# ('0989-000', 0, 1)
# ['Chad']
# ('0974-011', 6, 8)
# ['Upul', 'Chandana']
# ('0954-003', 6, 8)
# ['Dan', 'Jenson']
# ('1060-019', 4, 6)
# ['South', 'Africa']
# ('1116-017', 12, 13)
# ['Boxer']
# ('1006-004', 44, 45)
# ['Scotland']
# ('1035-009', 2, 3)
# ['Interfax']
# ('1160-018', 16, 17)
# ['Jordan']
# ('1137-008', 33, 34)
# ['Korean']
# ('0960-010', 27, 28)
# ['Washington']
# ('0963-006', 15, 16)
# ['Woods']
# ('0985-004', 10, 11)
# ['WBC']
# ('1152-014', 50, 52)
# ['United', 'States']
# ('1035-010', 36, 37)
# ['Finland']
# ('0958-005', 0, 4)
# ['AMERICAN', 'LEAGUE', 'EASTERN', 'DIVISION']
# ('1146-001', 0, 1)
# ['BAGHDAD']
# ('1116-010', 0, 1)
# ['Napoleon']
# ('1025-009', 18, 19)
# ['Israeli']
# ('1045-006', 42, 45)
# ['Palestinian', 'Liberation', 'Organisation']
# ('1128-007', 2, 3)
# ['Ruch']
# ('1062-003', 25, 27)
# ['John', 'Robinson']
# ('1116-016', 6, 8)
# ['Boxer', 'Rising']
# ('1036-011', 17, 18)
# ['Onarheim']
# ('1134-007', 20, 21)
# ['Philippine']
# ('1054-016', 1, 3)
# ['Rolf', 'Sorensen']
# ('0999-003', 22, 24)
# ['Valery', 'Ivankov']
# ('1017-007', 36, 38)
# ['Francois', 'Cabrera']
# ('1076-015', 0, 4)
# ['Mladost', '(', 'L', ')']
# ('1089-001', 2, 3)
# ['Wisconsin']
# ('1017-003', 10, 11)
# ['Saint-Bernard']
# ('1083-002', 4, 5)
# ['Dinamo']
# ('1160-010', 0, 1)
# ['Jordan']
# ('1059-005', 0, 1)
# ['Derbyshire']
# ('0966-076', 1, 3)
# ['Tegla', 'Loroupe']
# ('1111-004', 1, 3)
# ['Miss', 'Stamper']
# ('1143-003', 45, 46)
# ['UNIFIL']
# ('1130-005', 9, 14)
# ['In', 'the', 'Year', 'of', 'January']
# ('0959-005', 0, 1)
# ['DETROIT']
# ('1069-006', 1, 2)
# ['Chester-le-Street']
# ('1105-001', 0, 1)
# ['MADRID']
# ('1072-019', 51, 53)
# ['Josh', 'Kronfeld']
# ('1066-061', 0, 1)
# ['Cardiff']
# ('0990-002', 23, 25)
# ['Alexander', 'Lebed']
# ('1072-011', 25, 26)
# ['Springboks']
# ('1103-006', 25, 26)
# ['Belgian']
# ('0949-006', 14, 15)
# ['Alan']
# ('1033-008', 5, 6)
# ['Chechen']
# ('1095-013', 2, 3)
# ['Atlanta']
# ('0966-148', 4, 5)
# ['Norway']
# ('1016-009', 18, 20)
# ['West', 'Bank']
# ('0966-155', 1, 3)
# ['Heli', 'Rantanen']
# ('0947-006', 0, 1)
# ['Chester-le-Street']
# ('1016-013', 5, 6)
# ['Bonn']
# ('1146-005', 50, 51)
# ['Talabani']
# ('1097-020', 24, 25)
# ['Krajicek']
# ('1097-000', 2, 3)
# ['EDBERG']
# ('1136-000', 0, 2)
# ['Dow', 'Chemical']
# ('1024-000', 3, 6)
# ['Homegate', 'Hospitality', 'Inc']
# ('1044-000', 3, 4)
# ['Nablus']
# ('1035-010', 23, 24)
# ['OSCE']
# ('0991-003', 16, 18)
# ['Russian', 'Federation']
# ('1048-000', 2, 3)
# ['ISRAEL']
# ('1089-001', 0, 1)
# ['MILWAUKEE']
# ('1056-026', 4, 5)
# ['Canada']
# ('1127-015', 0, 1)
# ['Urus-Martan']
# ('1066-022', 0, 1)
# ['Oxford']
# ('1056-006', 4, 5)
# ['Italy']
# ('1068-030', 0, 1)
# ['Colchester']
# ('1072-019', 31, 33)
# ['Glen', 'Osborne']
# ('0966-110', 1, 3)
# ['Nico', 'Motchebon']
# ('0960-005', 8, 9)
# ['Rios']
# ('1036-002', 0, 1)
# ['LONGYEAR']
# ('1157-001', 0, 1)
# ['BRUSSELS']
# ('0959-001', 0, 2)
# ['NEW', 'YORK']
# ('0995-002', 2, 3)
# ['Tajikistan']
# ('0951-001', 0, 1)
# ['BUCHAREST']
# ('1019-002', 22, 23)
# ['Groningen']
# ('1033-009', 24, 25)
# ['Russia']
# ('0947-003', 4, 5)
# ['Somerset']
# ('1044-004', 15, 16)
# ['Arafat']
# ('1106-000', 4, 5)
# ['TURKEY']
# ('1004-002', 3, 5)
# ['Norodom', 'Sihanouk']
# ('1155-007', 0, 1)
# ['Iran']
# ('1142-009', 1, 2)
# ['U.N.']
# ('1141-007', 3, 4)
# ['Guangzhou']
# ('0947-006', 2, 3)
# ['Glamorgan']
# ('1058-026', 10, 12)
# ['American', 'League']
# ('0984-004', 14, 15)
# ['LIFFE']
# ('0986-004', 3, 5)
# ['Norwich', 'City']
# ('0966-006', 1, 3)
# ['Aliuska', 'Lopez']
# ('1050-002', 1, 4)
# ['Republic', 'of', 'Ireland']
# ('1125-012', 6, 7)
# ['Hutu']
# ('0992-003', 1, 2)
# ['Bosnian']
# ('0966-111', 1, 3)
# ['David', 'Kiptoo']
# ('0997-000', 3, 4)
# ['Naina']
# ('0966-078', 1, 3)
# ['Pauline', 'Konga']
# ('1083-002', 0, 1)
# ['Benetton']
# ('0957-016', 11, 13)
# ['Czech', 'Republic']
# ('0968-000', 4, 5)
# ['EDWARDS']
# ('1014-010', 51, 55)
# ['League', 'of', 'Women', 'Voters']
# ('1068-030', 2, 3)
# ['Hereford']
# ('1127-022', 0, 1)
# ['Mamatuyev']
# ('1076-005', 2, 6)
# ['Proleter', '(', 'Z', ')']
# ('0957-010', 0, 2)
# ['Guy', 'Forget']
# ('1044-002', 2, 4)
# ['Yasser', 'Arafat']
# ('1156-008', 13, 15)
# ['Pierre', 'Buyoya']
# ('1131-003', 30, 31)
# ['U.S.']
# ('1036-007', 13, 15)
# ['Stig', 'Onarheim']
# ('0964-003', 9, 10)
# ['Russia']
# ('1126-005', 16, 17)
# ['Mahala']
# ('1022-007', 5, 6)
# ['Canada']
# ('1054-014', 1, 3)
# ['Johan', 'Capiot']
# ('1139-001', 0, 1)
# ['BEIJING']
# ('0948-043', 3, 4)
# ['Somerset']
# ('1103-020', 7, 9)
# ['Van', 'Moer']
# ('1057-002', 0, 1)
# ['Pakistan']
# ('1069-012', 1, 3)
# ['The', 'Oval']
# ('0947-010', 0, 1)
# ['Portsmouth']
# ('1076-042', 0, 4)
# ['Zeleznik', '(', 'B', ')']
# ('1016-013', 1, 2)
# ['Levy']
# ('0963-023', 18, 22)
# ['World', 'Series', 'of', 'Golf']
# ('1006-002', 0, 1)
# ['TRIPOLI']
# ('1007-025', 24, 25)
# ['Clintons']
# ('1068-034', 0, 2)
# ['Leyton', 'Orient']
# ('0948-014', 4, 5)
# ['London']
# ('1138-011', 31, 32)
# ['Western']
# ('0991-003', 20, 22)
# ['Chechen', 'Republic']
# ('1048-000', 6, 7)
# ['EUROPEAN']
# ('1091-003', 23, 25)
# ['Martina', 'Hingis']
# ('1128-002', 1, 2)
# ['Polish']
# ('1066-020', 0, 1)
# ['Reading']
# ('1157-004', 25, 26)
# ['Arbil']
# ('1090-017', 14, 17)
# ['Mary', 'Joe', 'Fernandez']
# ('1009-001', 0, 2)
# ['Maggie', 'McNeil']
# ('1068-028', 2, 3)
# ['Scunthorpe']
# ('1139-002', 5, 7)
# ['Wang', 'Donghai']
# ('1050-003', 22, 24)
# ['Ian', 'Harte']
# ('0966-108', 1, 3)
# ['Norberto', 'Tellez']
# ('0946-001', 0, 1)
# ['LONDON']
# ('0963-002', 0, 2)
# ['Nolan', 'Henke']
# ('0958-025', 0, 1)
# ['CHICAGO']
# ('0966-030', 1, 3)
# ['Frankie', 'Fredericks']
# ('1022-003', 23, 25)
# ['Jim', 'Webber']
# ('1030-027', 1, 3)
# ['Commerce', 'Department']
# ('1025-008', 15, 16)
# ['Arab']
# ('1131-003', 0, 1)
# ['Albright']
# ('1157-004', 5, 7)
# ['Iraqi', 'Kurd']
# ('1128-006', 23, 25)
# ['Jacques', 'Chirac']
# ('1116-022', 25, 30)
# ['Anne', 'of', 'a', 'Thousand', 'Days']
# ('1128-011', 12, 13)
# ['Kaczmarek']
# ('0986-007', 1, 3)
# ['Dublin', 'Newsroom']
# ('1128-007', 10, 11)
# ['Poland']
# ('1051-005', 1, 4)
# ['Miguel', 'Angel', 'Jimenez']
# ('1019-012', 7, 8)
# ['Germany']
# ('0986-006', 10, 11)
# ['Harte']
# ('1034-000', 0, 1)
# ['Dutch']
# ('0947-003', 0, 1)
# ['Leicester']
# ('0960-039', 21, 22)
# ['Rios']
# ('1057-002', 6, 7)
# ['England']
# ('1135-002', 0, 1)
# ['RANGOON']
# ('0997-002', 14, 15)
# ['Interfax']
# ('1137-002', 24, 25)
# ['Seoul']
# ('0962-011', 6, 8)
# ['Tiger', 'Woods']
# ('1094-021', 0, 1)
# ['OAKLAND']
# ('0950-001', 0, 1)
# ['BELGRADE']
# ('1108-002', 12, 14)
# ['Nate', 'Miller']
# ('0963-017', 23, 25)
# ['PGA', 'Tour']
# ('1146-007', 13, 14)
# ['Arbil']
# ('1116-027', 10, 12)
# ['Hermann', 'Goering']
# ('0980-000', 9, 10)
# ['NAPM']
# ('1073-007', 8, 10)
# ['Walter', 'Little']
# ('0966-036', 4, 5)
# ['Denmark']
# ('1076-001', 0, 1)
# ['BELGRADE']
# ('1069-010', 5, 7)
# ['K.', 'Spiring']
# ('1096-024', 8, 9)
# ['Atlanta']
# ('1065-020', 0, 1)
# ['Stenhousemuir']
# ('0991-002', 0, 1)
# ['Russian']
# ('1059-005', 8, 9)
# ['Surrey']
# ('1066-001', 0, 1)
# ['LONDON']
# ('1156-002', 0, 1)
# ['Italian']
# ('1006-005', 21, 22)
# ['Tripoli']
# ('0966-097', 4, 5)
# ['Germany']
# ('1075-002', 7, 10)
# ['African', 'Nations', 'Cup']
# ('1125-000', 0, 1)
# ['Rwandan']
# ('1077-003', 0, 1)
# ['Ince']
# ('1100-002', 6, 7)
# ['IBF']
# ('1003-003', 14, 15)
# ['Surinamese-born']
# ('1111-006', 4, 6)
# ['Warren', "O'Connor"]
# ('1033-009', 2, 3)
# ['Chechnya']
# ('0953-003', 7, 8)
# ['Mexican']
# ('1054-006', 4, 5)
# ['Italy']
# ('1026-003', 22, 23)
# ['Cairo']
# ('1032-001', 0, 1)
# ['AMSTERDAM']
# ('1125-006', 0, 1)
# ['U.N.']
# ('1036-024', 4, 5)
# ['Ukrainian']
# ('1027-007', 10, 11)
# ['Jewish']
# ('1058-017', 0, 2)
# ['New', 'York']
# ('1016-011', 13, 14)
# ['German-Israeli']
# ('1114-002', 10, 11)
# ['European']
# ('1044-004', 28, 29)
# ['Moslems']
# ('1054-010', 4, 5)
# ['Russia']
# ('1096-032', 9, 10)
# ['Mets']
# ('1147-003', 1, 2)
# ['KDP']
# ('1096-020', 5, 7)
# ['Ryne', 'Sandberg']
# ('1056-022', 1, 3)
# ['Michelle', 'Ferris']
# ('1033-003', 15, 16)
# ['OSCE']
# ('1090-005', 17, 18)
# ['Japan']
# ('1146-000', 0, 1)
# ['Iraq']
# ('1095-007', 0, 1)
# ['MILWAUKEE']
# ('0966-049', 1, 3)
# ['Marko', 'Koers']
# ('0968-000', 2, 3)
# ['HARRISON']
# ('1112-008', 23, 25)
# ['Euro', '96']
# ('0966-127', 4, 5)
# ['Germany']
# ('1090-008', 32, 35)
# ['Billie', 'Jean', 'King']
# ('0984-015', 21, 22)
# ['BOJ']
# ('1019-002', 11, 13)
# ['Nicole', 'Nichterwitz']
# ('1156-010', 10, 11)
# ['Burundi']
# ('1071-000', 7, 9)
# ['WORLD', 'CUP']
# ('1128-011', 8, 9)
# ['Ruch']
# ('0972-020', 9, 10)
# ['Dharmasena']
# ('1025-006', 3, 5)
# ['West', 'Bank']
# ('0962-008', 7, 9)
# ['Jesper', 'Parnevik']
# ('0949-003', 5, 6)
# ['Newcastle']
# ('1033-009', 0, 1)
# ['Cotti']
# ('0989-002', 6, 8)
# ["N'Djamena", 'University']
# ('1039-009', 0, 2)
# ['JAKARTA', 'POST']
# ('1058-009', 29, 30)
# ['Cleveland']
# ('1030-007', 6, 7)
# ['Brent']
# ('1117-004', 7, 8)
# ['Holland']
# ('0993-003', 15, 16)
# ['Batajnica']
# ('1054-006', 6, 7)
# ['Polti']
# ('1087-018', 14, 15)
# ['Scotland']
# ('1125-008', 14, 15)
# ['Rwanda']
# ('1011-012', 18, 20)
# ['Norwest', 'Corp.']
# ('1116-038', 23, 24)
# ['American']
# ('0957-020', 9, 11)
# ['Pete', 'Sampras']
# ('1133-003', 29, 31)
# ['Strike', 'Hard']
# ('0958-048', 0, 2)
# ['SAN', 'FRANCISCO']
# ('1156-003', 21, 23)
# ['Howard', 'Wolpe']
# ('1116-014', 10, 13)
# ['Trades', 'Disputes', 'Act']
# ('0959-008', 0, 1)
# ['SEATTLE']
# ('0992-006', 6, 7)
# ['Bosnia']
# ('1013-003', 8, 9)
# ['Gulf']
# ('1095-007', 2, 3)
# ['Minnesota']
# ('1059-005', 12, 13)
# ['Warwickshire']
# ('1120-007', 14, 15)
# ['Iraq']
# ('1058-039', 0, 2)
# ['Kansas', 'City']
# ('0968-003', 1, 5)
# ['International', 'Amateur', 'Athletic', 'Federation']
# ('1008-023', 8, 9)
# ['CNBC']
# ('0957-010', 8, 10)
# ['Felix', 'Mantilla']
# ('1030-036', 19, 20)
# ['Iraq']
# ('1160-000', 5, 6)
# ['Venice']
# ('0986-002', 3, 5)
# ['Mick', 'McCarthy']
# ('1069-004', 14, 16)
# ['P.', 'Tufnell']
# ('0978-002', 0, 4)
# ['Jones', 'Medical', 'Industries', 'Inc']
# ('0980-013', 20, 22)
# ['Federal', 'Reserve']
# ('1007-028', 59, 60)
# ['Geraghty']
# ('1027-015', 12, 13)
# ['Jamil']
# ('0959-000', 2, 4)
# ['MAJOR', 'LEAGUE']
# ('1022-007', 13, 14)
# ['C$']
# ('1058-044', 13, 15)
# ['Dave', 'Nilsson']
# ('1133-011', 0, 1)
# ['Wang']
# ('1011-013', 5, 6)
# ['Norwest']
# ('1058-026', 1, 2)
# ['Orioles']
# ('1091-003', 39, 40)
# ['Austria']
# ('1096-021', 0, 1)
# ['Foster']
# ('1099-004', 0, 1)
# ['Scotland']
# ('1101-008', 33, 35)
# ['Osvaldo', 'Sanchez']
# ('1124-010', 35, 36)
# ['Afrikaans']
# ('1125-006', 28, 29)
# ['Zairean']
# ('1160-004', 4, 6)
# ['Liam', 'Neeson']
# ('1055-006', 0, 2)
# ['M.', 'Atherton']
# ('0995-010', 27, 28)
# ['Islamic']
# ('0947-006', 20, 21)
# ['Durham']
# ('0957-015', 11, 12)
# ['France']
# ('1087-018', 0, 1)
# ['Eyles']
# ('0968-004', 43, 44)
# ['Milan']
# ('0972-005', 0, 2)
# ['M.', 'Waugh']
# ('1140-001', 0, 2)
# ['HONG', 'KONG']
# ('0948-022', 7, 9)
# ['The', 'Oval']
# ('1146-002', 16, 17)
# ['Iraq']
# ('1146-000', 4, 5)
# ['Baghdad']
# ('0957-030', 5, 6)
# ['U.S.']
# ('1056-016', 8, 10)
# ['Andrea', 'Collinelli']
# ('1039-001', 6, 7)
# ['Indonesian']
# ('1095-009', 0, 2)
# ['New', 'York']
# ('0997-006', 5, 6)
# ['Moscow']
# ('1155-011', 3, 4)
# ['Germany']
# ('1052-004', 3, 6)
# ['Jan', 'Allan', 'Mueller']
# ('1005-004', 1, 3)
# ['Southeast', 'Asian']
# ('0952-005', 4, 5)
# ['Rotor']
# ('1007-033', 1, 4)
# ['Standard', '&', 'Poor']
# ('1092-004', 7, 9)
# ['Germany', 'France']
# ('1133-011', 6, 7)
# ['China']
# ('1152-000', 5, 6)
# ['Gulf']
# ('1039-001', 19, 20)
# ['Jakarta']
# ('1116-016', 22, 24)
# ['Peking', 'Protocol']
# ('1097-001', 0, 2)
# ['Richard', 'Finn']
# ('1059-006', 26, 27)
# ['Australian']
# ('0957-019', 13, 15)
# ['Barbara', 'Rittner']
# ('1029-002', 0, 1)
# ['WASHINGTON']
# ('1125-003', 16, 17)
# ['U.N.']
# ('0997-002', 19, 21)
# ['Sergei', 'Yastrzhembsky']
# ('0966-076', 4, 5)
# ['Kenya']
# ('1073-007', 0, 2)
# ['New', 'Zealand']
# ('0997-002', 2, 4)
# ['Boris', 'Yeltsin']
# ('1091-001', 0, 2)
# ['NEW', 'YORK']
# ('0961-005', 14, 15)
# ['Philadelphia']
# ('1094-031', 0, 4)
# ['NATIONAL', 'LEAGUE', 'EASTERN', 'DIVISION']
# ('1000-016', 5, 7)
# ['Laszlo', 'Sebesvari']
# ('0968-000', 8, 9)
# ['SARAJEVO']
# ('1070-016', 8, 10)
# ['Reynard', 'Honda']
# ('1073-005', 2, 4)
# ['Henry', 'Honiball']
# ('0999-004', 4, 5)
# ['Ivankov']
# ('0964-002', 31, 32)
# ['Brazilian']
# ('1096-040', 10, 11)
# ['Rockies']
# ('1007-022', 8, 10)
# ['Dow', 'Jones']
# ('1049-002', 15, 16)
# ['Liechtenstein']
# ('1152-013', 0, 1)
# ['U.S.']
# ('1136-006', 14, 15)
# ['Tianjin']
# ('0984-018', 0, 2)
# ['NSW', 'Treasury']
# ('0985-003', 6, 7)
# ['Bruno']
# ('1103-009', 28, 29)
# ['Turkey']
# ('1134-005', 0, 1)
# ['Jakarta']
# ('1068-026', 4, 5)
# ['Wrexham']
# ('1106-006', 0, 1)
# ['Belgium']
# ('1116-006', 7, 8)
# ['Orleans']
# ('1153-001', 0, 1)
# ['BRUSSELS']
# ('1063-003', 2, 4)
# ['Sergei', 'Rebrov']
# ('1044-002', 7, 9)
# ['West', 'Bank']
# ('0959-009', 0, 2)
# ['National', 'League']
# ('1011-005', 17, 18)
# ['Commerce']
# ('1057-004', 0, 1)
# ['Pakistan']
# ('1076-028', 0, 1)
# ['Rudar']
# ('1145-002', 10, 11)
# ['Bahraini']
# ('1066-033', 0, 1)
# ['Bury']
# ('1061-000', 5, 6)
# ['SCOTTISH']
# ('1031-007', 29, 30)
# ['Italian']
# ('1067-013', 0, 1)
# ['Dumbarton']
# ('1012-000', 0, 1)
# ['U.S.']
# ('0966-005', 4, 5)
# ['Sweden']
# ('1099-004', 4, 5)
# ['Belarus']
# ('1050-002', 16, 17)
# ['European']
# ('1027-007', 2, 3)
# ['Arafat']
# ('1016-011', 5, 6)
# ['Kinkel']
# ('1056-026', 1, 3)
# ['Tanya', 'Dubnicoff']
# ('1101-003', 16, 18)
# ['Euro', '96']
# ('0981-006', 24, 27)
# ['Johnson', 'Controls', 'Inc']
# ('1080-001', 0, 1)
# ['BUCHAREST']
# ('0960-025', 13, 14)
# ['Tarango']
# ('1068-031', 0, 1)
# ['Doncaster']
# ('1016-009', 10, 11)
# ['Israel']
# ('1013-006', 1, 5)
# ['New', 'York', 'Energy', 'Desk']
# ('1095-015', 0, 1)
# ['Florida']
# ('1078-000', 2, 5)
# ['TROFEJ', 'BEOGRAD', 'TOURNAMENT']
# ('1160-007', 9, 10)
# ['British']
# ('0962-009', 13, 15)
# ['Willie', 'Wood']
# ('1061-006', 3, 4)
# ['Bristol']
# ('1031-015', 0, 2)
# ['CITIC', 'Pacific']
# ('1038-007', 8, 10)
# ['Hong', 'Kong']
# ('0980-019', 38, 39)
# ['Eurodollars']
# ('1008-019', 4, 8)
# ['Federal', 'Open', 'Market', 'Committee']
# ('1139-002', 9, 11)
# ['New', 'York-based']
# ('1033-003', 32, 33)
# ['Russian']
# ('1010-006', 4, 5)
# ['Chicago']
# ('1121-003', 1, 2)
# ['London-based']
# ('1054-001', 0, 1)
# ['LANDGRAAF']
# ('0961-001', 0, 1)
# ['PHILADELPHIA']
# ('0966-149', 1, 3)
# ['Carlos', 'Calado']
# ('1158-003', 5, 6)
# ['Belgian']
# ('0951-000', 2, 3)
# ['ROMANIA']
# ('1010-017', 44, 45)
# ['Bernardin']
# ('1064-003', 17, 18)
# ['Saracens']
# ('1082-002', 13, 14)
# ['European']
# ('1054-023', 5, 6)
# ['Netherlands']
# ('1055-022', 0, 2)
# ['Saeed', 'Anwar']
# ('0978-002', 25, 26)
# ['Jones']
# ('1101-012', 16, 18)
# ['Pavel', 'Pardo']
# ('1132-007', 14, 15)
# ['EPR']
# ('1152-014', 46, 47)
# ['U.S.']
# ('1027-014', 15, 16)
# ['al-Aqsa']
# ('1000-018', 6, 7)
# ['Kecskemet']
# ('1058-030', 0, 2)
# ['Danny', 'Tartabull']
# ('1067-013', 2, 3)
# ['Brechin']
# ('1020-000', 0, 1)
# ['Indian']
# ('1089-026', 30, 31)
# ['Kraft']
# ('1039-015', 9, 13)
# ['PT', 'Timor', 'Putra', 'Nasional']
# ('0957-009', 9, 11)
# ['Czech', 'Republic']
# ('1039-018', 21, 23)
# ['Megawati', 'Sukarnoputri']
# ('1114-002', 0, 1)
# ['Romania']
# ('1017-006', 17, 20)
# ['Charles', 'de', 'Gaulle']
# ('1096-030', 0, 1)
# ['Montreal']
# ('0968-004', 33, 34)
# ['Balkans']
# ('1129-001', 0, 1)
# ['MOSCOW']
# ('0946-009', 2, 3)
# ['Oval']
# ('1068-031', 2, 3)
# ['Darlington']
# ('1056-009', 4, 5)
# ['Britain']
# ('0958-055', 0, 2)
# ['SAN', 'FRANCISCO']
# ('1090-015', 7, 9)
# ['U.S.', 'Open']
# ('1016-010', 17, 18)
# ['German']
# ('1127-014', 22, 23)
# ['Dudayeva']
# ('0965-011', 18, 20)
# ['Jesse', 'Owens']
# ('1008-020', 2, 3)
# ['FOMC']
# ('1108-005', 0, 1)
# ['Miller']
# ('1049-002', 19, 20)
# ['Alpine']
# ('1054-001', 2, 3)
# ['Netherlands']
# ('0949-002', 12, 13)
# ['England']
# ('0951-000', 4, 5)
# ['LITHUANIA']
# ('1009-013', 14, 15)
# ['Michoacan']
# ('1016-012', 9, 10)
# ['Israeli']
# ('1094-025', 2, 3)
# ['SEATTLE']
# ('1058-013', 3, 5)
# ['Jim', 'Thome']
# ('1126-005', 0, 1)
# ['Marriner']
# ('1034-002', 1, 2)
# ['Dutch']
# ('1128-003', 0, 2)
# ['Zycie', 'Warszawy']
# ('0986-000', 2, 3)
# ['McCarthy']
# ('1106-001', 0, 1)
# ['BRUSSELS']
# ('1031-006', 16, 18)
# ['Far', 'Eastern']
# ('1152-014', 32, 33)
# ['F-15']
# ('1017-003', 21, 23)
# ['Air', 'France']
# ('1055-026', 0, 1)
# ['Inzamam-ul-Haq']
# ('1125-008', 0, 1)
# ['Zairean']
# ('1056-032', 4, 5)
# ['Lithuania']
# ('1065-036', 0, 2)
# ['East', 'Stirling']
# ('0960-009', 18, 20)
# ['Todd', 'Martin']
# ('0966-026', 4, 5)
# ['U.S.']
# ('1159-004', 38, 39)
# ['Legeard']
# ('1085-002', 0, 1)
# ['Belarus']
# ('1156-002', 11, 13)
# ['Julius', 'Nyerere']
# ('1058-027', 3, 5)
# ['Kevin', 'Tapani']
# ('0966-108', 4, 5)
# ['Cuba']
# ('1016-009', 14, 15)
# ['Jewish']
# ('1055-001', 0, 1)
# ['BIRMINGHAM']
# ('1069-017', 27, 29)
# ['K.', 'Evans']
# ('1160-007', 21, 22)
# ['Jordan']
# ('1116-014', 4, 7)
# ['House', 'of', 'Lords']
# ('0966-042', 1, 3)
# ['Valentina', 'Fedyushina']
# ('0972-006', 0, 2)
# ['M.', 'Slater']
# ('1127-008', 18, 19)
# ['Russian']
# ('0986-002', 12, 13)
# ['Liechtenstein']
# ('1084-000', 4, 5)
# ['LATVIA']
# ('1133-004', 33, 35)
# ['Deng', 'Xiaoping']
# ('1033-001', 0, 1)
# ['BONN']
# ('1128-000', 5, 6)
# ['Ruch']
# ('1092-002', 16, 18)
# ['U.S.', 'Open']
# ('1039-006', 0, 1)
# ['KOMPAS']
# ('1097-004', 21, 22)
# ['German']
# ('1143-003', 10, 11)
# ['Israel']
# ('0995-006', 15, 16)
# ['Tavildara']
# ('1084-002', 10, 11)
# ['European']
# ('1012-006', 7, 8)
# ['Farrakhan']
# ('1135-015', 20, 21)
# ['SLORC']
# ('0966-041', 1, 3)
# ['Irina', 'Korzhanenko']
# ('1072-012', 18, 20)
# ['Pieter', 'Hendriks']
# ('1154-001', 0, 1)
# ['PARIS']
# ('1012-008', 1, 3)
# ['Treasury', 'Department']
# ('1058-027', 1, 2)
# ['Toronto']
# ('0994-017', 13, 15)
# ['Zenon', 'Poznyak']
# ('1152-014', 34, 35)
# ['F-16']
# ('1059-006', 18, 19)
# ['Australian']
# ('0981-006', 7, 8)
# ['Ontario-based']
# ('1118-007', 7, 8)
# ['Scottish']
# ('1055-026', 2, 3)
# ['Thorpe']
# ('1090-008', 27, 28)
# ['Cup']
# ('0947-001', 0, 1)
# ['LONDON']
# ('0962-009', 22, 24)
# ['Brian', 'Claar']
# ('1030-039', 4, 6)
# ['FTSE', '100']
# ('0952-006', 12, 13)
# ['Volgograd']
# ('1016-009', 0, 1)
# ['Erdmann']
# ('0976-000', 0, 1)
# ['POLISH']
# ('1022-015', 1, 2)
# ['U.S.']
# ('1116-004', 2, 4)
# ['Henry', 'VIII']
# ('1150-005', 25, 28)
# ['Rochester', 'Fire', 'Department']
# ('1149-012', 25, 26)
# ['Dewey']
# ('1033-006', 3, 4)
# ['Chechnya']
# ('0965-003', 8, 10)
# ['Donovan', 'Bailey']
# ('1061-019', 2, 5)
# ['Heriot', "'s", 'F.P.']
# ('1035-002', 20, 21)
# ['Nagorno-Karabakh']
# ('0996-004', 1, 5)
# ['Federal', 'Republic', 'of', 'Yugoslavia']
# ('1011-007', 4, 7)
# ['Commerce', 'Bancshares', 'Inc.']
# ('0988-000', 0, 2)
# ['East', 'Dries']
# ('1074-003', 2, 3)
# ['Mauritania']
# ('1090-018', 26, 28)
# ['Conchita', 'Martinez']
# ('1032-003', 14, 15)
# ['EOE']
# ('0979-011', 23, 25)
# ['Labor', 'Day']
# ('1099-018', 34, 36)
# ['Gary', 'McAllister']
# ('1141-006', 0, 1)
# ['Wuhan']
# ('1077-003', 16, 17)
# ['England']
# ('0981-016', 0, 1)
# ['Magna']
# ('1022-014', 10, 11)
# ['C$']
# ('1146-005', 23, 24)
# ['Baghdad']
# ('1138-006', 0, 1)
# ['Wang']
# ('0964-000', 11, 12)
# ['FIFA']
# ('1055-026', 4, 5)
# ['Croft']
# ('1025-012', 0, 1)
# ['Syria']
# ('0955-012', 0, 1)
# ['Suwan']
# ('0984-008', 0, 1)
# ['FRANCE']
# ('1056-037', 3, 4)
# ['France']
# ('1057-007', 28, 30)
# ['Mushtaq', 'Ahmed']
# ('0966-146', 4, 5)
# ['U.S.']
# ('0981-015', 3, 4)
# ['Magna']
# ('1147-001', 0, 1)
# ['BAGHDAD']
# ('0966-113', 4, 5)
# ['Norway']
# ('0965-001', 0, 2)
# ['Adrian', 'Warner']
# ('1072-018', 5, 7)
# ['Andre', 'Joubert']
# ('1156-002', 18, 19)
# ['Burundi']
# ('1103-011', 15, 16)
# ['Belgium']
# ('1025-003', 26, 27)
# ['Arab']
# ('1121-003', 9, 10)
# ['Iraqi']
# ('1103-007', 36, 37)
# ['English']
# ('1161-004', 12, 14)
# ['Shakil', 'Rizvi']
# ('1143-003', 14, 15)
# ['Syria']
# ('0966-057', 4, 5)
# ['Belarus']
# ('1032-002', 7, 8)
# ['Dutch']
# ('1033-003', 0, 2)
# ['Flavio', 'Cotti']
# ('1018-001', 0, 1)
# ['BERLIN']
# ('1101-012', 83, 85)
# ['Enrique', 'Alfaro']
# ('1152-011', 21, 22)
# ['Baghdad']
# ('1087-018', 11, 13)
# ['Peter', 'Nicol']
# ('1049-004', 5, 6)
# ['Ireland']
# ('0962-009', 7, 8)
# ['Canada']
# ('0966-006', 4, 5)
# ['Cuba']
# ('1011-023', 16, 17)
# ['NationsBank']
# ('1030-032', 17, 18)
# ['Clinton']
# ('1128-013', 18, 19)
# ['UWP-Hachette']
# ('0955-011', 0, 1)
# ['Pohang']
# ('1160-002', 2, 3)
# ['Italy']
# ('0958-031', 0, 4)
# ['NATIONAL', 'LEAGUE', 'EASTERN', 'DIVISION']
# ('1011-012', 10, 11)
# ['Missouri']
# ('1059-004', 0, 1)
# ['Kent']
# ('1072-019', 56, 58)
# ['Michael', 'Jones']
# ('1068-010', 0, 2)
# ['Port', 'Vale']
# ('1066-032', 0, 1)
# ['Brentford']
# ('1087-015', 4, 7)
# ['Professional', 'Squash', 'Association']
# ('1000-014', 11, 13)
# ['Czech', 'Republic']
# ('1039-018', 14, 17)
# ['Indonesian', 'Democratic', 'Party']
# ('1036-027', 10, 11)
# ['Longyear']
# ('0963-023', 0, 2)
# ['Phil', 'Mickelson']
# ('1058-042', 18, 19)
# ['Brewers']
# ('1131-005', 14, 15)
# ['Chile']
# ('0977-008', 0, 1)
# ['Canada']
# ('0948-004', 8, 13)
# ['Test', 'and', 'County', 'Cricket', 'Board']
# ('1027-023', 1, 3)
# ['Mustafa', 'Hoshiyeh']
# ('1123-001', 0, 1)
# ['SEOUL']
# ('1014-010', 32, 36)
# ['Commission', 'on', 'Presidential', 'Debates']
# ('0948-018', 3, 4)
# ['Worcestershire']
# ('0966-061', 4, 5)
# ['Germany']
# ('0961-000', 1, 3)
# ['AMERICAN', 'FOOTBALL-RANDALL']
# ('1115-004', 6, 8)
# ['Bernard', 'Ingram']
# ('1091-004', 14, 16)
# ['Pablo', 'Campana']
# ('1138-006', 4, 5)
# ['Hangzhou']
# ('1027-007', 30, 31)
# ['Arabs']
# ('0984-006', 4, 6)
# ['U.S.', 'Treasuries']
# ('0966-051', 4, 5)
# ['Britain']
# ('1011-009', 0, 4)
# ['Roosevelt', 'Financial', 'Group', 'Inc']
# ('1042-003', 5, 6)
# ['Huize']
# ('1139-002', 0, 1)
# ['Chinese']
# ('1156-002', 3, 5)
# ['Lamberto', 'Dini']
# ('1080-000', 4, 5)
# ['LITHUANIA']
# ('1054-007', 1, 3)
# ['Tristan', 'Hoffman']
# ('1069-017', 19, 21)
# ['C.', 'Hooper']
# ('1055-028', 3, 4)
# ['Knight']
# ('0954-004', 10, 12)
# ['Chris', 'Walker']
# ('0990-014', 15, 16)
# ['Lebed']
# ('1067-018', 0, 1)
# ['Arbroath']
# ('0985-002', 14, 15)
# ['Britain']
# ('0983-002', 35, 36)
# ['Britain']
# ('0996-004', 12, 13)
# ['Yugoslavia']
# ('0972-035', 4, 5)
# ['Dharmasena']
# ('1055-025', 0, 2)
# ['Ijaz', 'Ahmed']
# ('1103-017', 2, 5)
# ['Wilfried', 'Van', 'Moer']
# ('1011-012', 12, 13)
# ['Minneapolis-based']
# ('1026-000', 0, 1)
# ['Egypt']
# ('0972-037', 6, 8)
# ['M.', 'Waugh']
# ('1091-004', 17, 18)
# ['Ecuador']
# ('0990-014', 22, 23)
# ['Chechnya']
# ('1110-002', 14, 16)
# ['James', 'Heath']
# ('1033-007', 0, 1)
# ['Pro-Moscow']
# ('1084-002', 2, 3)
# ['Latvia']
# ('0947-011', 10, 12)
# ['J.', 'Adams']
# ('0947-012', 7, 9)
# ['J.', 'Russell']
# ('1072-004', 10, 12)
# ['New', 'Zealand']
# ('0966-085', 1, 3)
# ['Sven', 'Nylander']
# ('0967-002', 5, 6)
# ['Belgian']
# ('1101-012', 4, 6)
# ['Osvaldo', 'Sanchez']
# ('1092-004', 0, 2)
# ['United', 'States']
# ('1137-010', 15, 16)
# ['South']
# ('1045-009', 12, 13)
# ['Jerusalem']
# ('1056-008', 4, 5)
# ['Australia']
# ('1055-027', 5, 6)
# ['Hollioake']
# ('1093-002', 1, 3)
# ['United', 'States']
# ('0968-001', 0, 2)
# ['MONTE', 'CARLO']
# ('0966-010', 4, 5)
# ['Jamaica']
# ('1161-007', 5, 6)
# ['IDLC']
# ('0957-019', 29, 31)
# ['Gabriela', 'Sabatini']
# ('1097-012', 31, 32)
# ['Wimbledon']
# ('1151-001', 0, 1)
# ['DALLAS']
# ('1061-021', 2, 3)
# ['Stirling']
# ('1120-005', 17, 18)
# ['Amman']
# ('0965-011', 27, 28)
# ['Olympics']
# ('0952-006', 4, 5)
# ['Alania']
# ('1080-000', 2, 3)
# ['ROMANIA']
# ('1131-001', 0, 1)
# ['SANTIAGO']
# ('0963-003', 18, 20)
# ['Jesper', 'Parnevik']
# ('1080-002', 2, 3)
# ['Lithuania']
# ('0980-015', 5, 6)
# ['Fed']
# ('0994-003', 2, 3)
# ['Belarus']
# ('0966-055', 4, 5)
# ['U.S.']
# ('1092-001', 0, 2)
# ['NEW', 'YORK']
# ('0996-004', 14, 15)
# ['Poles']
# ('1142-006', 12, 13)
# ['Iranian']
# ('1002-001', 2, 3)
# ['Colombia']
# ('0961-004', 2, 4)
# ['Pro', 'Bowl']
# ('1066-012', 0, 1)
# ['Wolverhampton']
# ('1022-011', 14, 15)
# ['Webber']
# ('0949-005', 0, 1)
# ['Shearer']
# ('1030-031', 8, 9)
# ['Clinton']
# ('1051-002', 8, 10)
# ['British', 'Masters']
# ('1072-006', 22, 24)
# ['Andre', 'Venter']
# ('1099-018', 26, 28)
# ['Alistair', 'McCoist']
# ('1124-003', 15, 16)
# ['Pretoria']
# ('0974-002', 0, 1)
# ['Australia']
# ('1025-011', 36, 37)
# ['Israel']
# ('0946-012', 8, 10)
# ['Chris', 'Adams']
# ('1108-002', 26, 27)
# ['WBA']
# ('1054-006', 1, 3)
# ['Giovanni', 'Lombardi']
# ('1140-005', 0, 1)
# ['Chen']
# ('0967-005', 0, 2)
# ['Roberto', 'Bisconti']
# ('0966-077', 1, 3)
# ['Gunhild', 'Halle']
# ('0972-002', 10, 11)
# ['Australia']
# ('1055-031', 4, 5)
# ['Gough']
# ('0987-002', 6, 7)
# ['Nigeria']
# ('1116-027', 3, 6)
# ['World', 'War', 'Two']
# ('1051-001', 2, 3)
# ['England']
# ('1078-007', 8, 9)
# ['Yugoslavia']
# ('1069-015', 11, 13)
# ['R.', 'Kettleborough']
# ('1056-022', 4, 5)
# ['Australia']
# ('1057-007', 11, 13)
# ['Salim', 'Malik']
# ('1116-035', 2, 3)
# ['British']
# ('1115-008', 0, 1)
# ['Ingram']
# ('1119-007', 7, 8)
# ['French']
# ('0957-013', 6, 8)
# ['David', 'Nainkin']
# ('0998-003', 0, 1)
# ['Lebed']
# ('1002-001', 0, 1)
# ['BOGOTA']
# ('1051-009', 32, 34)
# ['Klas', 'Eriksson']
# ('1056-016', 28, 30)
# ['Nikolai', 'Kouznetsov']
# ('1087-017', 6, 9)
# ['Hong', 'Kong', 'Open']
# ('1057-006', 0, 1)
# ['England']
# ('1057-006', 14, 16)
# ['Graham', 'Thorpe']
# ('0970-000', 2, 3)
# ['MILAN']
# ('1035-002', 2, 3)
# ['Armenia']
# ('1032-003', 4, 5)
# ['FTO']
# ('1109-007', 2, 3)
# ['Giovanni']
# ('1055-024', 4, 5)
# ['Mullally']
# ('1049-005', 11, 12)
# ['Eschen']
# ('1012-008', 8, 9)
# ['U.S.']
# ('1033-013', 17, 18)
# ['Cotti']
# ('1069-013', 33, 35)
# ['D.', 'Bicknell']
# ('1119-006', 34, 35)
# ['Iraqi']
# ('0972-001', 0, 1)
# ['COLOMBO']
# ('0948-044', 6, 8)
# ['Trent', 'Bridge']
# ('0998-002', 0, 1)
# ['Russian']
# ('1067-011', 2, 3)
# ['Berwick']
# ('1135-004', 43, 44)
# ['Rangoon']
# ('0955-013', 0, 1)
# ['Ulsan']
# ('1126-005', 14, 15)
# ['Tuzla']
# ('1006-003', 20, 22)
# ['Muammar', 'Gaddafi']
# ('1072-018', 100, 102)
# ['Dawie', 'Theron']
# ('0993-002', 4, 6)
# ['Aerodrom', 'Beograd']
# ('0949-003', 29, 30)
# ['European']
# ('0994-017', 1, 3)
# ['United', 'States']
# ('1065-017', 0, 1)
# ['Livingston']
# ('1046-002', 6, 8)
# ['Roberto', 'Carlos']
# ('0957-020', 12, 13)
# ['U.S.']
# ('1133-003', 16, 17)
# ['Wang']
# ('1059-006', 6, 7)
# ['Surrey']
# ('0990-007', 6, 8)
# ['Aslan', 'Maskhadov']
# ('1118-007', 19, 20)
# ['Scotland']
# ('1056-024', 1, 3)
# ['Olga', 'Slioussareva']
# ('1116-006', 2, 3)
# ['French']
# ('1116-037', 11, 12)
# ['Kazakhstan']
# ('1127-008', 21, 23)
# ['Alexander', 'Lebed']
# ('0964-002', 21, 22)
# ['FIFA']
# ('0997-004', 22, 23)
# ['Yeltsin']
# ('1077-003', 11, 12)
# ['Chisinau']
# ('1146-007', 17, 18)
# ['Iraqi']
# ('1060-005', 1, 3)
# ['Ian', 'Woosnam']
# ('1063-000', 2, 3)
# ['UKRAINE']
# ('1014-009', 21, 22)
# ['Dole']
# ('1127-008', 0, 1)
# ['Russian']
# ('0997-002', 7, 8)
# ['Naina']
# ('1096-003', 12, 14)
# ['National', 'League']
# ('0995-016', 22, 23)
# ['Tajik']
# ('1006-000', 0, 1)
# ['Tripoli']
# ('1031-013', 8, 9)
# ['China']
# ('1010-016', 12, 13)
# ['Chicago']
# ('0957-033', 23, 25)
# ['Stefan', 'Edberg']
# ('1076-017', 0, 1)
# ['Becej']
# ('1118-000', 0, 3)
# ['Scottish', 'Labour', 'Party']
# ('1015-003', 24, 25)
# ['Newfoundland']
# ('1109-007', 0, 1)
# ['Brazil']
# ('1059-004', 29, 31)
# ['Tunbridge', 'Wells']
# ('1090-000', 2, 3)
# ['SPAIN']
# ('1017-006', 5, 6)
# ['CFDT']
# ('1110-002', 1, 3)
# ['Nate', 'Miller']
# ('0962-004', 1, 6)
# ['Brown', 'Deer', 'Park', 'Golf', 'Course']
# ('1067-011', 0, 1)
# ['Ayr']
# ('1050-002', 5, 6)
# ['Liechtenstein']
# ('1138-002', 6, 8)
# ['Wang', 'Donghai']
# ('1054-004', 1, 2)
# ['Roermond']
# ('0957-019', 10, 11)
# ['U.S.']
# ('1056-032', 1, 3)
# ['Rita', 'Razmaite']
# ('1033-010', 6, 7)
# ['Chechnya']
# ('1043-000', 0, 1)
# ['Singapore']
# ('1054-020', 1, 3)
# ['Erik', 'Dekker']
# ('1056-040', 9, 11)
# ['Czech', 'Republic']
# ('0946-015', 2, 3)
# ['Kent']
# ('1004-008', 5, 7)
# ['Hun', 'Sen']
# ('1118-007', 21, 22)
# ['Labour']
# ('0984-006', 12, 14)
# ['Chicago', 'PMI']
# ('1160-016', 9, 10)
# ['Dublin']
# ('1098-002', 6, 7)
# ['WBO']
# ('1036-014', 0, 1)
# ['Longyear']
# ('1058-027', 19, 21)
# ['Frank', 'Thomas']
# ('0974-009', 6, 9)
# ['Aravinda', 'de', 'Silva']
# ('1057-007', 16, 18)
# ['Wasim', 'Akram']
# ('1036-017', 9, 10)
# ['Barentsburg']
# ('1088-000', 2, 5)
# ['HONG', 'KONG', 'OPEN']
# ('1045-003', 7, 8)
# ['Palestinian']
# ('0954-004', 2, 4)
# ['Peter', 'Nicol']
# ('1035-001', 0, 1)
# ['BONN']
# ('1150-001', 2, 3)
# ['N.H.']
# ('1133-013', 16, 17)
# ['Wang']
# ('1008-002', 0, 1)
# ['WASHINGTON']
# ('0971-002', 3, 4)
# ['Australia']
# ('0966-121', 1, 3)
# ['Jean', 'Galfione']
# ('1138-002', 14, 18)
# ['Human', 'Rights', 'in', 'China']
# ('1031-005', 15, 16)
# ['Wuxi']
# ('0966-041', 4, 5)
# ['Russia']
# ('1015-003', 26, 27)
# ['Canada']
# ('0957-012', 0, 2)
# ['Alexander', 'Volkov']
# ('1090-000', 4, 5)
# ['U.S.']
# ('1096-041', 13, 15)
# ['Donne', 'Wall']
# ('0981-006', 10, 12)
# ['North', 'American']
# ('1101-012', 71, 73)
# ['Ramon', 'Ramirez']
# ('1072-019', 36, 38)
# ['Andrew', 'Mehrtens']
# ('0960-010', 8, 10)
# ['New', 'Haven']
# ('1045-010', 13, 16)
# ['Burj', 'al-Laqlaq', 'Society']
# ('1066-068', 0, 1)
# ['Exeter']
# ('1155-010', 7, 8)
# ['Tehran']
# ('1058-005', 13, 15)
# ['Mickey', 'Rivers']
# ('0957-019', 21, 23)
# ['Asa', 'Carlsson']
# ('1056-028', 4, 6)
# ['New', 'Zealand']
# ('0999-003', 3, 5)
# ['Olga', 'Lavrentyeva']
# ('1098-002', 0, 1)
# ['Britain']
# ('1095-018', 2, 3)
# ['PITTSBURGH']
# ('0966-158', 4, 5)
# ['Belarus']
# ('1064-005', 5, 6)
# ['Harlequins']
# ('1125-008', 3, 6)
# ['Kengo', 'wa', 'Dondo']
# ('1062-000', 7, 9)
# ['WORLD', 'CUP']
# ('0966-024', 4, 5)
# ['Cuba']
# ('1119-002', 11, 12)
# ['Kurdish']
# ('1009-000', 5, 6)
# ['U.S']
# ('0958-041', 0, 1)
# ['CINCINNATI']
# ('1030-008', 0, 1)
# ['FTSE']
# ('1058-011', 24, 26)
# ['American', 'League']
# ('1119-000', 2, 3)
# ['Iraq']
# ('0972-028', 0, 2)
# ['A.', 'Ranatunga']
# ('1049-003', 6, 8)
# ['Mick', 'McCarthy']
# ('1037-003', 0, 1)
# ['Ericsson']
# ('1035-002', 4, 5)
# ['Azerbaijan']
# ('1097-004', 7, 8)
# ['Open']
# ('1156-004', 2, 3)
# ['Nyerere']
# ('0966-005', 1, 3)
# ['Ludmila', 'Engquist']
# ('1065-024', 0, 1)
# ['Clyde']
# ('1119-006', 21, 22)
# ['British']
# ('0953-004', 26, 27)
# ['Duran']
# ('1003-003', 36, 37)
# ['Moengo']
# ('1011-006', 2, 5)
# ['Mercantile', 'Bancorp', 'Inc.']
# ('0958-053', 3, 4)
# ['PHILADELPHIA']
# ('1055-018', 6, 8)
# ['Waqar', 'Younis']
# ('1069-015', 19, 21)
# ['P.', 'Such']
# ('1011-003', 7, 11)
# ['Boatmen', "'s", 'Bancshares', 'Inc.']
# ('1148-002', 7, 8)
# ['Tunisian']
# ('1031-012', 6, 7)
# ['Unicom']
# ('0966-107', 4, 5)
# ['Denmark']
# ('1024-008', 2, 7)
# ['Bear', 'Stearns', '&', 'Co', 'Inc']
# ('0966-023', 1, 3)
# ['Florian', 'Schwarthoff']
# ('1093-004', 14, 16)
# ['Eric', 'Wynalda']
# ('1093-004', 0, 1)
# ['U.S.']
# ('1096-025', 3, 5)
# ['Scott', 'Sanders']
# ('1070-008', 7, 10)
# ['Lola', 'Ford', 'Cosworth']
# ('0991-006', 17, 18)
# ['Chechnya']
# ('0972-035', 8, 9)
# ['Muralitharan']
# ('1006-004', 14, 16)
# ['United', 'Nations']
# ('1061-003', 0, 1)
# ['Welsh']
# ('1090-002', 0, 2)
# ['NEW', 'YORK']
# ('1066-024', 0, 2)
# ['West', 'Bromwich']
# ('0968-004', 0, 2)
# ['Atlanta', 'Games']
# ('1035-003', 20, 22)
# ['Zhirayr', 'Liparityan']
# ('1063-002', 11, 13)
# ['World', 'Cup']
# ('0984-020', 0, 1)
# ['DNIB']
# ('1150-003', 3, 4)
# ['Rochester']
# ('1099-018', 20, 22)
# ['Duncan', 'Ferguson']
# ('1036-030', 16, 17)
# ['Russia']
# ('1151-002', 6, 7)
# ['Dallas']
# ('1150-006', 2, 3)
# ['Boston']
# ('0986-006', 18, 19)
# ['Quinn']
# ('0947-008', 0, 1)
# ['London']
# ('1065-001', 0, 1)
# ['LONDON']
# ('1057-006', 32, 34)
# ['Dean', 'Headley']
# ('0985-004', 14, 16)
# ['Mike', 'Tyson']
# ('1069-005', 0, 1)
# ['Middlesex']
# ('1128-006', 19, 20)
# ['Ruch']
# ('0966-135', 1, 3)
# ['Bob', 'Kennedy']
# ('1054-008', 1, 3)
# ['Erik', 'Breukink']
# ('1054-007', 6, 7)
# ['TVM']
# ('1133-006', 15, 16)
# ['Xiao']
# ('0948-041', 6, 7)
# ['Headingley']
# ('1098-002', 12, 13)
# ['Mexico']
# ('0997-004', 14, 15)
# ['Russian']
# ('1045-008', 28, 29)
# ['Israeli']
# ('0966-032', 1, 3)
# ['Ato', 'Boldon']
# ('1043-003', 27, 28)
# ['CNB']
# ('1006-009', 20, 23)
# ['Samer', 'Ammar', 'Soliman']
# ('1058-024', 0, 1)
# ['Baltimore']
# ('1116-011', 8, 10)
# ['Pedro', 'I']
# ('0962-009', 19, 21)
# ['Steve', 'Stricker']
# ('1014-009', 13, 14)
# ['Dole']
# ('1009-007', 1, 3)
# ['Agriculture', 'Department']
# ('1123-003', 0, 1)
# ['OB']
# ('1033-000', 4, 5)
# ['Chechnya']
# ('1081-001', 0, 1)
# ['YEREVAN']
# ('1014-003', 1, 2)
# ['Dole']
# ('0950-004', 6, 7)
# ['Dinamo']
# ('0990-002', 10, 12)
# ['Boris', 'Yeltsin']
# ('0963-017', 0, 1)
# ['Henke']
# ('1077-004', 0, 1)
# ['Gascoigne']
# ('1061-013', 2, 4)
# ['Ebbw', 'Vale']
# ('1152-017', 3, 4)
# ['Marines']
# ('1134-001', 0, 1)
# ['MANILA']
# ('1094-029', 0, 1)
# ['BOSTON']
# ('1120-006', 17, 18)
# ['London']
# ('1094-052', 3, 5)
# ['NEW', 'YORK']
# ('0947-008', 6, 7)
# ['Warwickshire']
# ('1133-014', 21, 22)
# ['Xiao']
# ('0962-011', 0, 2)
# ['Mike', 'Hulbert']
# ('1124-006', 0, 1)
# ['Viljoen']
# ('1096-026', 0, 1)
# ['Sanders']
# ('1155-000', 3, 4)
# ['German']
# ('0968-002', 0, 1)
# ['Olympic']
# ('1035-010', 15, 22)
# ['Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('0966-143', 1, 3)
# ['Jonathan', 'Edwards']
# ('1134-002', 30, 31)
# ['Moslem']
# ('1101-011', 26, 28)
# ['Marcel', 'Desailly']
# ('1039-017', 0, 1)
# ['REPUBLIKA']
# ('1057-007', 8, 10)
# ['Ijaz', 'Ahmed']
# ('0972-037', 3, 4)
# ['Gillespie']
# ('1090-018', 8, 9)
# ['King']
# ('1153-002', 1, 2)
# ['Belgian']
# ('0994-003', 20, 21)
# ['Soviet']
# ('1119-008', 14, 16)
# ['Foreign', 'Office']
# ('1123-003', 2, 3)
# ['Samsung']
# ('1056-043', 0, 2)
# ['Marion', 'Clignet']
# ('1049-005', 18, 20)
# ['Jack', 'Charlton']
# ('1121-003', 29, 30)
# ['Arbil']
# ('1072-018', 42, 46)
# ['Joost', 'van', 'der', 'Westhuizen']
# ('0949-005', 22, 23)
# ['Blackburn']
# ('1005-005', 25, 26)
# ['Indonesian-origin']
# ('1038-004', 0, 2)
# ['Hong', 'Kong']
# ('1146-005', 20, 22)
# ['Iraqi', 'Kurds']
# ('1012-008', 4, 5)
# ['Libya']
# ('1099-018', 8, 10)
# ['Thomas', 'Boyd']
# ('0949-010', 2, 4)
# ['Euro', '96']
# ('1155-012', 15, 17)
# ['Der', 'Spiegel']
# ('0946-014', 9, 11)
# ['Paul', 'Johnson']
# ('0953-013', 10, 12)
# ['Atlantic', 'City']
# ('1069-005', 4, 5)
# ['Hampshire']
# ('0996-006', 5, 7)
# ['Slobodan', 'Milosevic']
# ('1065-022', 0, 1)
# ['Stranraer']
# ('0986-001', 0, 1)
# ['DUBLIN']
# ('0958-046', 0, 2)
# ['LOS', 'ANGELES']
# ('0952-003', 20, 22)
# ['Lada', 'Togliatti']
# ('0961-003', 8, 10)
# ['Philadelphia', 'Eagles']
# ('1137-004', 2, 3)
# ['Kim']
# ('1065-030', 0, 1)
# ['Cowdenbeath']
# ('1056-037', 0, 2)
# ['Florian', 'Rousseau']
# ('1016-009', 5, 7)
# ['European', 'Union']
# ('0984-017', 18, 20)
# ['Labour', 'Day']
# ('0948-000', 3, 4)
# ['ASHES']
# ('1031-012', 0, 1)
# ['China']
# ('1007-019', 0, 1)
# ['Johnson']
# ('0957-017', 7, 9)
# ['Irina', 'Spirlea']
# ('0960-029', 10, 11)
# ['Rios']
# ('0964-002', 18, 20)
# ['Real', 'Madrid']
# ('1124-006', 40, 43)
# ['African', 'National', 'Congress']
# ('1046-010', 21, 22)
# ['Brazil']
# ('1075-000', 2, 3)
# ['MAURITANIA']
# ('1056-030', 4, 5)
# ['Britain']
# ('1058-011', 0, 2)
# ['Roger', 'Pavlik']
# ('1079-005', 5, 6)
# ['Dinamo']
# ('1138-005', 20, 23)
# ['1966-76', 'Cultural', 'Revolution']
# ('1130-004', 30, 31)
# ['pre-Castro']
# ('0963-001', 0, 1)
# ['MILWAUKEE']
# ('1073-002', 0, 2)
# ['South', 'Africa']
# ('1011-011', 2, 3)
# ['Commerce']
# ('1120-000', 1, 2)
# ['Iraqis']
# ('1095-020', 0, 2)
# ['ST', 'LOUIS']
# ('1017-006', 9, 10)
# ['CGT']
# ('1096-019', 6, 7)
# ['Cubs']
# ('1039-015', 20, 21)
# ['Suharto']
# ('1098-002', 14, 16)
# ['Manuel', 'Medina']
# ('1094-022', 0, 1)
# ['CALIFORNIA']
# ('0948-046', 6, 8)
# ['The', 'Oval']
# ('1065-033', 0, 3)
# ['Queen', "'s", 'Park']
# ('1155-010', 17, 18)
# ['Iranian']
# ('1033-007', 3, 4)
# ['Chechnya']
# ('0949-004', 2, 3)
# ['Platt']
# ('1061-010', 0, 1)
# ['Saracens']
# ('1068-013', 6, 8)
# ['Manchester', 'City']
# ('1056-020', 4, 5)
# ['France']
# ('0957-019', 16, 17)
# ['Germany']
# ('1159-007', 28, 29)
# ['Belgium']
# ('1058-040', 3, 5)
# ['Marc', 'Newfield']
# ('1111-009', 2, 4)
# ['Richard', 'Hannon']
# ('0975-005', 9, 10)
# ['Bistrita']
# ('1000-014', 8, 9)
# ['Poland']
# ('1109-003', 0, 1)
# ['Brazil']
# ('1116-005', 14, 15)
# ['Europe']
# ('1058-031', 27, 28)
# ['Athetlics']
# ('1065-025', 0, 1)
# ['Dumbarton']
# ('0947-004', 5, 7)
# ['P.', 'Simmons']
# ('1031-013', 26, 27)
# ['Asia']
# ('0963-001', 2, 3)
# ['Wisconsin']
# ('0984-010', 16, 17)
# ['Treasuries']
# ('1011-011', 0, 1)
# ['Mercantile']
# ('1066-054', 0, 1)
# ['Walsall']
# ('1086-002', 10, 11)
# ['European']
# ('0992-008', 1, 8)
# ['Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('0993-003', 24, 25)
# ['Tanjug']
# ('0966-037', 1, 3)
# ['Ivan', 'Garcia']
# ('0966-129', 4, 5)
# ['Norway']
# ('1065-032', 0, 1)
# ['Alloa']
# ('1055-004', 0, 2)
# ['N.', 'Knight']
# ('1160-004', 14, 16)
# ['Michael', 'Collins']
# ('0967-005', 7, 8)
# ['Euro']
# ('1119-001', 0, 1)
# ['LONDON']
# ('0974-003', 4, 6)
# ['Sri', 'Lanka']
# ('1046-009', 3, 4)
# ['Deportivo']
# ('0948-017', 3, 4)
# ['Northampton']
# ('0972-008', 5, 6)
# ['Chandana']
# ('1069-017', 16, 17)
# ['Kent']
# ('1135-010', 12, 13)
# ['NLD']
# ('0966-164', 19, 21)
# ['Florian', 'Schwarthoff']
# ('0980-003', 2, 3)
# ['Chicago']
# ('1027-009', 18, 19)
# ['Moslem']
# ('0997-004', 6, 7)
# ['Yeltsin']
# ('1148-005', 5, 6)
# ['France']
# ('1041-000', 0, 2)
# ['Apic', 'Yamada']
# ('1094-024', 3, 4)
# ['DETROIT']
# ('0957-006', 11, 12)
# ['Australia']
# ('1054-023', 1, 4)
# ['Maarten', 'den', 'Bakker']
# ('1147-006', 7, 8)
# ['Iraqi']
# ('1055-029', 0, 2)
# ['Mushtaq', 'Ahmed']
# ('1085-002', 10, 12)
# ['World', 'Cup']
# ('1011-004', 6, 7)
# ['Midwest']
# ('0948-044', 9, 10)
# ['Nottingham']
# ('1066-069', 0, 2)
# ['Cambridge', 'United']
# ('1005-005', 3, 4)
# ['Australian']
# ('1073-004', 13, 15)
# ['Andre', 'Joubert']
# ('1076-026', 2, 6)
# ['Mladost', '(', 'BJ', ')']
# ('1147-000', 8, 9)
# ['Arbil']
# ('1089-025', 0, 2)
# ['Steve', 'Stricker']
# ('0966-061', 1, 3)
# ['Michael', 'Moellenbeck']
# ('1007-025', 18, 19)
# ['Whitewater']
# ('0948-031', 3, 4)
# ['Leicestershire']
# ('0996-008', 0, 1)
# ['Poland']
# ('1003-003', 45, 46)
# ['Paramaribo']
# ('1051-010', 8, 10)
# ['Adam', 'Hunter']
# ('0980-016', 3, 4)
# ['Fed']
# ('0963-017', 32, 34)
# ['BellSouth', 'Classic']
# ('1035-003', 18, 19)
# ['Armenian']
# ('1054-005', 1, 3)
# ['Olaf', 'Ludwig']
# ('1103-015', 44, 46)
# ['Enzo', 'Scifo']
# ('1019-000', 1, 2)
# ['German']
# ('1059-002', 2, 3)
# ['Kent']
# ('0956-018', 0, 1)
# ['Samsung']
# ('0967-003', 6, 7)
# ['Swiss']
# ('1157-004', 28, 29)
# ['Iraq']
# ('1115-008', 24, 25)
# ['Orr']
# ('0995-006', 0, 1)
# ['Sherbatov']
# ('0997-006', 7, 10)
# ['Central', 'Clinical', 'Hospital']
# ('0952-001', 0, 1)
# ['MOSCOW']
# ('1045-008', 22, 23)
# ['U.N.']
# ('0962-008', 10, 11)
# ['Sweden']
# ('0978-001', 0, 2)
# ['ST.', 'LOUIS']
# ('1086-000', 2, 3)
# ['ENGLAND']
# ('1132-002', 12, 13)
# ['Mexican']
# ('1136-005', 0, 1)
# ['Tianjin']
# ('1068-033', 0, 1)
# ['Hull']
# ('1102-002', 2, 3)
# ['Mexico']
# ('1139-004', 4, 5)
# ['Wang']
# ('0994-004', 4, 5)
# ['Belarus']
# ('1017-004', 5, 6)
# ['African']
# ('1111-000', 3, 5)
# ['TATTERSALLS', 'BREEDERS']
# ('1130-005', 62, 64)
# ['Soul', 'Alone']
# ('0965-005', 21, 22)
# ['American']
# ('1064-007', 47, 48)
# ['Bristol']
# ('1103-011', 13, 14)
# ['France']
# ('0980-014', 8, 9)
# ['U.S.']
# ('1002-000', 4, 5)
# ['Colombian']
# ('1152-011', 9, 10)
# ['Arbil']
# ('0958-001', 0, 2)
# ['NEW', 'YORK']
# ('1106-006', 2, 4)
# ['Marc', 'Degryse']
# ('1009-015', 35, 36)
# ['Mexico']
# ('1133-006', 22, 24)
# ['Amnesty', 'International']
# ('1157-004', 13, 16)
# ['Kurdistan', 'Democratic', 'Party']
# ('1009-017', 1, 2)
# ['U.S.']
# ('1029-017', 4, 6)
# ['Labour', 'Department']
# ('0966-009', 1, 3)
# ['Julie', 'Baumann']
# ('1089-007', 0, 2)
# ['Tiger', 'Woods']
# ('0997-008', 2, 3)
# ['Yeltsin']
# ('0974-007', 20, 22)
# ['Glenn', 'McGrath']
# ('0947-004', 10, 11)
# ['Leicestershire']
# ('0965-004', 6, 7)
# ['Olympic']
# ('1131-004', 11, 13)
# ['United', 'States']
# ('1116-021', 0, 1)
# ['British']
# ('1133-006', 29, 30)
# ['China']
# ('0958-051', 0, 1)
# ['FLORIDA']
# ('1011-012', 22, 23)
# ['KeyCorp']
# ('0972-002', 4, 7)
# ['Singer', 'World', 'Series']
# ('1037-003', 16, 17)
# ['GPTA']
# ('1011-020', 33, 34)
# ['Ancell']
# ('0966-052', 1, 3)
# ['Marcus', "O'Sullivan"]
# ('0949-005', 24, 25)
# ['Southampton']
# ('1089-008', 14, 17)
# ['U.S.', 'Amateur', 'Championship']
# ('1036-014', 3, 4)
# ['Norwegian']
# ('1109-001', 0, 1)
# ['AMSTERDAM']
# ('1055-012', 3, 5)
# ['Waqar', 'Younis']
# ('1099-018', 2, 4)
# ['Andrew', 'Goram']
# ('1076-007', 0, 1)
# ['Borac']
# ('1056-038', 9, 10)
# ['U.S.']
# ('1066-064', 0, 1)
# ['Scarborough']
# ('1126-010', 24, 25)
# ['NATO']
# ('1156-003', 15, 16)
# ['U.S.']
# ('1129-004', 8, 9)
# ['Kalashnikov']
# ('1055-002', 8, 9)
# ['England']
# ('1128-014', 0, 1)
# ['Kaczmarek']
# ('1033-002', 22, 23)
# ['Chechnya']
# ('1152-005', 34, 36)
# ['Doug', 'Kennett']
# ('1055-004', 6, 8)
# ['Saqlain', 'Mushtaq']
# ('0966-050', 1, 3)
# ['Isaac', 'Viciosa']
# ('1007-018', 19, 20)
# ['Treasury']
# ('1131-000', 0, 1)
# ['U.N.']
# ('0954-003', 3, 4)
# ['Australia']
# ('1160-015', 3, 5)
# ['Harry', 'Boland']
# ('1004-001', 0, 2)
# ['PHNOM', 'PENH']
# ('1059-005', 5, 6)
# ['Worcestershire']
# ('1126-007', 10, 11)
# ['Bosnian']
# ('0974-007', 11, 13)
# ['Damien', 'Flemming']
# ('1116-031', 10, 12)
# ['Cape', 'Town']
# ('1120-007', 7, 8)
# ['Britain']
# ('0957-024', 0, 2)
# ['Hendrik', 'Dreekmann']
# ('1026-007', 12, 13)
# ["Gama'a"]
# ('1046-004', 30, 31)
# ['Donato']
# ('1076-007', 2, 6)
# ['Mladost', '(', 'L', ')']
# ('1050-003', 14, 16)
# ['Niall', 'Quinn']
# ('1007-016', 19, 20)
# ['Democrat']
# ('1063-002', 14, 15)
# ['European']
# ('1072-018', 37, 39)
# ['Henry', 'Honiball']
# ('1052-000', 6, 8)
# ['WORLD', 'CUP']
# ('1072-019', 26, 28)
# ['Frank', 'Bunce']
# ('1090-005', 15, 16)
# ['France']
# ('1086-002', 2, 3)
# ['Moldova']
# ('0948-023', 0, 1)
# ['London']
# ('1111-003', 3, 5)
# ['The', 'Curragh']
# ('1096-041', 25, 27)
# ['Houston', 'Astros']
# ('0963-002', 20, 23)
# ['Greater', 'Milwaukee', 'Open']
# ('1054-008', 4, 5)
# ['Netherlands']
# ('0947-011', 23, 25)
# ['T.', 'Moody']
# ('1139-000', 4, 6)
# ['Wang', 'Donghai']
# ('1141-003', 2, 3)
# ['Wuhan']
# ('1131-000', 2, 3)
# ['Albright']
# ('1125-012', 5, 6)
# ['Rwandan']
# ('0966-032', 4, 5)
# ['Trinidad']
# ('1155-010', 27, 28)
# ['Kurdish']
# ('0965-003', 4, 5)
# ['Olympic']
# ('1056-017', 8, 10)
# ['Jean-Michel', 'Monin']
# ('1013-002', 22, 25)
# ['Offshore', 'Data', 'Services']
# ('1072-012', 5, 6)
# ['Joubert']
# ('1103-016', 27, 29)
# ['Ogun', 'Temizkanoglu']
# ('1083-000', 2, 3)
# ['BENETTON']
# ('1066-074', 0, 1)
# ['Brighton']
# ('0969-003', 27, 28)
# ['Guingamp']
# ('1148-005', 13, 14)
# ['France']
# ('1137-000', 3, 5)
# ['S.', 'Korea']
# ('0965-002', 0, 1)
# ['BERLIN']
# ('0997-005', 1, 3)
# ['Naina', 'Yeltsin']
# ('1103-003', 4, 7)
# ['1998', 'World', 'Cup']
# ('1141-008', 0, 1)
# ['Guangzhou']
# ('1160-022', 31, 32)
# ['Britain']
# ('1125-010', 0, 1)
# ['RDR']
# ('1069-001', 0, 1)
# ['LONDON']
# ('1086-002', 0, 1)
# ['England']
# ('0947-012', 21, 23)
# ['A.', 'Smith']
# ('0946-002', 12, 13)
# ['Leicestershire']
# ('1054-020', 4, 5)
# ['Netherlands']
# ('0990-006', 3, 4)
# ['Yeltsin']
# ('1056-029', 1, 3)
# ['Mira', 'Kasslin']
# ('1003-007', 12, 14)
# ['Desi', 'Bouterse']
# ('0994-004', 11, 12)
# ['Reuters']
# ('0966-119', 4, 5)
# ['Germany']
# ('0966-014', 1, 3)
# ['Carla', 'Sacramento']
# ('1033-010', 30, 31)
# ['OSCE']
# ('1052-002', 3, 5)
# ['Faroe', 'Islands']
# ('0958-044', 0, 2)
# ['WESTERN', 'DIVISION']
# ('1068-006', 2, 3)
# ['Portsmouth']
# ('1132-002', 15, 16)
# ['Michoacan']
# ('1127-022', 5, 6)
# ['Lisa']
# ('1095-011', 2, 3)
# ['SEATTLE']
# ('0986-004', 0, 2)
# ['Keith', "O'Neill"]
# ('1103-010', 32, 34)
# ['De', 'Wilde']
# ('1083-000', 4, 5)
# ['DINAMO']
# ('1146-005', 0, 1)
# ['Aziz']
# ('0957-018', 35, 36)
# ['Switzerland']
# ('1044-001', 0, 1)
# ['NABLUS']
# ('1037-006', 1, 2)
# ['Stockholm']
# ('1054-024', 1, 2)
# ['Andersson']
# ('0966-043', 4, 5)
# ['Germany']
# ('1097-020', 10, 11)
# ['Edberg']
# ('1046-004', 26, 27)
# ['Brazilian-born']
# ('0980-009', 4, 6)
# ['Federal', 'Reserve']
# ('1160-014', 11, 12)
# ['Oscar']
# ('1119-003', 3, 4)
# ['Iraqi']
# ('1107-000', 2, 3)
# ['AUSTRIA']
# ('0958-018', 0, 2)
# ['WESTERN', 'DIVISION']
# ('0946-010', 7, 9)
# ['Mark', 'Butcher']
# ('1099-008', 14, 16)
# ['Andreas', 'Heraf']
# ('0966-161', 19, 21)
# ['Linford', 'Christie']
# ('1099-011', 0, 2)
# ['SK', 'Rapid']
# ('1088-002', 43, 45)
# ['Peter', 'Nicol']
# ('0995-011', 22, 24)
# ['United', 'Nations-sponsored']
# ('1146-006', 31, 32)
# ['Iraqi']
# ('1057-003', 18, 20)
# ...
# ('1046-001', 3, 4)
# ['Spain']
# ('0958-026', 2, 3)
# ['MILWAUKEE']
# ('1054-017', 1, 3)
# ['Lance', 'Armstrong']
# ('1101-012', 40, 41)
# ['Gomez']
# ('1099-003', 3, 5)
# ['World', 'Cup']
# ('1007-024', 11, 12)
# ['Dole']
# ('1055-022', 5, 6)
# ['Gough']
# ('0957-033', 9, 11)
# ['Todd', 'Martin']
# ('0948-039', 3, 4)
# ['Glamorgan']
# ('1009-010', 21, 22)
# ['U.S.']
# ('1057-000', 2, 3)
# ['PAKISTAN']
# ('1058-035', 3, 4)
# ['Boston']
# ('1138-007', 19, 21)
# ['Cultural', 'Revolution']
# ('1054-019', 1, 3)
# ['Marco', 'Lietti']
# ('0952-002', 30, 31)
# ['Rotor']
# ('1096-002', 21, 23)
# ['Florida', 'Marlins']
# ('1056-017', 18, 20)
# ['Guido', 'Fulst']
# ('1120-001', 0, 1)
# ['LONDON']
# ('0966-039', 1, 3)
# ['Astrid', 'Kumbernuss']
# ('0975-002', 4, 5)
# ['Comelf']
# ('1125-001', 0, 1)
# ['NAIROBI']
# ('1043-000', 2, 3)
# ['Thai']
# ('1031-004', 39, 40)
# ['Jiangsu']
# ('1142-001', 0, 1)
# ['ISTANBUL']
# ('1007-016', 13, 15)
# ['White', 'House']
# ('1055-038', 2, 3)
# ['Irani']
# ('0974-007', 17, 19)
# ['Stuart', 'Law']
# ('1127-000', 0, 1)
# ['Chechens']
# ('0966-164', 22, 23)
# ['Germany']
# ('1138-003', 10, 11)
# ['Zhejiang']
# ('1011-006', 0, 2)
# ['St.', 'Louis-based']
# ('1152-014', 5, 8)
# ['F', '/', 'A-18']
# ('0974-000', 2, 3)
# ['AUSTRALIA']
# ('1150-001', 0, 1)
# ['ROCHESTER']
# ('1103-006', 27, 30)
# ['Filip', 'De', 'Wilde']
# ('1031-003', 25, 26)
# ['Chinese']
# ('0956-002', 2, 4)
# ['South', 'Korean']
# ('1060-012', 4, 5)
# ['Australia']
# ('0946-007', 5, 6)
# ['England']
# ('1099-005', 0, 1)
# ['Austria']
# ('1022-013', 19, 21)
# ['Labour', 'Day']
# ('1099-007', 17, 19)
# ['Michael', 'Konsel']
# ('1055-022', 3, 4)
# ['Stewart']
# ('1096-025', 1, 2)
# ['Montreal']
# ('1056-023', 1, 3)
# ['Magali', 'Faure']
# ('1012-008', 38, 39)
# ['Lockerbie']
# ('1135-025', 17, 19)
# ['Suu', 'Kyi']
# ('1148-005', 2, 3)
# ['Tunisia']
# ('0981-003', 2, 6)
# ['Douglas', '&', 'Lomason', 'Co']
# ('1060-004', 2, 3)
# ['British']
# ('1055-027', 3, 4)
# ['Stewart']
# ('1096-002', 2, 3)
# ['ERA']
# ('1027-014', 4, 6)
# ['Abu', 'Ammar']
# ('0972-005', 5, 6)
# ['Jayasuriya']
# ('1017-001', 0, 1)
# ['PARIS']
# ('1116-037', 13, 14)
# ['Uzbekistan']
# ('1090-003', 37, 39)
# ['U.S.', 'Open']
# ('1012-008', 19, 20)
# ['Tripoli']
# ('1103-006', 10, 12)
# ['Sergen', 'Yalcin']
# ('0996-006', 3, 4)
# ['Serbian']
# ('1073-004', 5, 9)
# ['Joost', 'van', 'der', 'Westhuizen']
# ('0960-040', 7, 8)
# ['Tarango']
# ('0984-012', 0, 2)
# ['UNITED', 'STATES']
# ('0990-006', 0, 1)
# ['Lebed']
# ('1054-003', 8, 12)
# ['Tour', 'of', 'the', 'Netherlands']
# ('0978-002', 11, 14)
# ['Daniels', 'Pharmaceuticals', 'Inc']
# ('1027-011', 3, 6)
# ['Arab', 'East', 'Jerusalem']
# ('1014-003', 17, 19)
# ['Scott', 'Reed']
# ('0983-000', 0, 1)
# ['Iraqi']
# ('1127-012', 12, 14)
# ['Mubatik', 'Dagayeva']
# ('0961-007', 10, 11)
# ['NFL']
# ('1152-007', 31, 32)
# ['Iraq']
# ('1135-000', 0, 1)
# ['Burma']
# ('1092-004', 13, 14)
# ['Belgium']
# ('1037-000', 6, 7)
# ['China']
# ('1054-011', 4, 5)
# ['Italy']
# ('1045-003', 18, 19)
# ['Germany']
# ('1156-004', 14, 16)
# ['Great', 'Lakes']
# ('1008-001', 0, 2)
# ['Glenn', 'Somerville']
# ('1135-008', 1, 2)
# ['Burmese']
# ('1135-025', 6, 12)
# ['James', 'Leander', '(', 'Leo', ')', 'Nichols']
# ('1128-000', 0, 1)
# ['Polish']
# ('0975-002', 0, 1)
# ['Romanian']
# ('0964-002', 4, 6)
# ['Deportivo', 'Coruna']
# ('1097-008', 12, 13)
# ['Edberg']
# ('1046-005', 12, 14)
# ['Luis', 'Milla']
# ('1056-010', 1, 3)
# ['Natalia', 'Karimova']
# ('0949-003', 37, 39)
# ['David', 'Platt']
# ('1007-010', 6, 7)
# ['Dole']
# ('1035-009', 15, 16)
# ['Germany']
# ('1058-022', 1, 2)
# ['Seattle']
# ('0957-013', 0, 2)
# ['Jonas', 'Bjorkman']
# ('0966-117', 1, 3)
# ['Igor', 'Trandenkov']
# ('0966-164', 10, 11)
# ['Germany']
# ('1146-003', 13, 15)
# ['Massoud', 'Barzani']
# ('1161-005', 1, 3)
# ['Khurshid', 'Alam']
# ('1025-008', 28, 29)
# ['Damascus']
# ('1099-007', 0, 1)
# ['Everton']
# ('1003-003', 10, 12)
# ['Freddy', 'Pinas']
# ('1156-008', 28, 29)
# ['Buyoya']
# ('1010-020', 0, 1)
# ['Bernardin']
# ('1028-002', 8, 9)
# ['MI']
# ('0991-007', 29, 30)
# ['Chechnya']
# ('1091-003', 17, 18)
# ['Belarus']
# ('1093-004', 2, 4)
# ['Joe-Max', 'Moore']
# ('1103-015', 30, 32)
# ['Gunther', 'Schepens']
# ('1054-011', 6, 7)
# ['Aki']
# ('0966-015', 1, 3)
# ['Yekaterina', 'Podkopayeva']
# ('1027-025', 27, 28)
# ['Qalandia']
# ('1097-012', 27, 28)
# ['Edberg']
# ('1127-004', 20, 21)
# ['Urus-Martan']
# ('1135-023', 34, 36)
# ['Suu', 'Kyi']
# ('1125-004', 2, 3)
# ['RDR']
# ('1069-012', 7, 8)
# ['Surrey']
# ('1096-043', 0, 1)
# ['Wall']
# ('1133-006', 18, 19)
# ['Manila']
# ('1142-002', 0, 1)
# ['Iranian']
# ('1025-000', 0, 1)
# ['Syria']
# ('1056-007', 1, 3)
# ['Marion', 'Clignet']
# ('1086-001', 0, 1)
# ['CHISINAU']
# ('1014-004', 41, 43)
# ['Peter', 'Knight']
# ('0994-005', 37, 38)
# ['Sharetsky']
# ('1152-010', 1, 2)
# ['U.S.']
# ('1066-071', 0, 1)
# ['Chester']
# ('0966-050', 4, 5)
# ['Spain']
# ('1116-037', 17, 18)
# ['Tajikistan']
# ('1158-002', 7, 8)
# ['Kalashnikov']
# ('0966-101', 1, 3)
# ['Donovan', 'Bailey']
# ('1135-014', 6, 7)
# ['NLD']
# ('1066-070', 0, 1)
# ['Darlington']
# ('1055-030', 0, 2)
# ['Saqlain', 'Mushtaq']
# ('1116-038', 18, 19)
# ['Berlin']
# ('1056-034', 21, 23)
# ['Philippe', 'Ermenault']
# ('0992-001', 0, 1)
# ['SARAJEVO']
# ('1067-006', 2, 4)
# ['St', 'Mirren']
# ('1087-001', 0, 2)
# ['HONG', 'KONG']
# ('0965-000', 2, 3)
# ['MITCHELL']
# ('1121-006', 11, 12)
# ['Kurdish']
# ('1011-010', 13, 14)
# ['Weber']
# ('0969-000', 5, 6)
# ['NICE']
# ('1056-034', 0, 1)
# ['Italy']
# ('1079-001', 0, 1)
# ['BELGRADE']
# ('0972-014', 3, 4)
# ['Chandana']
# ('1045-006', 39, 40)
# ['Israel']
# ('1143-006', 23, 24)
# ['Israel']
# ('1101-012', 29, 30)
# ['Becerril']
# ('1009-011', 24, 27)
# ['World', 'Trade', 'Organisation']
# ('1073-000', 3, 5)
# ['SOUTH', 'AFRICA']
# ('1022-012', 18, 19)
# ['Canadian']
# ('1128-004', 26, 27)
# ['Warsaw']
# ('0987-005', 5, 6)
# ['Uyo']
# ('1018-000', 0, 1)
# ['German']
# ('1073-009', 2, 3)
# ['Mehrtens']
# ('1061-013', 0, 1)
# ['Dunvant']
# ('1011-012', 13, 17)
# ['First', 'Bank', 'System', 'Inc.']
# ('1160-010', 6, 9)
# ['The', 'Crying', 'Game']
# ('1069-007', 5, 6)
# ['Durham']
# ('1031-002', 0, 1)
# ['MILAN']
# ('1007-018', 15, 17)
# ['Wall', 'Street']
# ('1025-000', 2, 3)
# ['Israel']
# ('0984-008', 15, 16)
# ['U.S.']
# ('1043-004', 0, 1)
# ['Singapore']
# ('1155-014', 9, 11)
# ['Ali', 'Fallahiyan']
# ('1045-010', 0, 1)
# ['Canada']
# ('1056-047', 9, 11)
# ['Rasa', 'Mazeikyte']
# ('1072-015', 32, 33)
# ['Springboks']
# ('1116-018', 6, 8)
# ['Elia', 'Kazanjoglus']
# ('1101-012', 52, 55)
# ['Raul', 'Rodrigo', 'Lara']
# ('1011-006', 31, 33)
# ['Boatmen', "'s"]
# ('1089-000', 2, 3)
# ['PARNEVIK']
# ('0966-100', 1, 3)
# ['Michael', 'Green']
# ('1003-000', 4, 5)
# ['Surinam']
# ('1128-002', 15, 16)
# ['France']
# ('0984-019', 0, 1)
# ['DNIB']
# ('1138-003', 2, 3)
# ['Hangzhou']
# ('1096-000', 2, 4)
# ['KEVIN', 'BROWN']
# ('1096-022', 21, 23)
# ['Andruw', 'Jones']
# ('1009-004', 20, 22)
# ['Paul', 'Drazek']
# ('1008-010', 28, 30)
# ['Lynn', 'Reaser']
# ('1121-007', 32, 33)
# ['Iraq']
# ('1030-004', 0, 2)
# ['NY', 'Dow']
# ('1101-011', 31, 33)
# ['Franck', 'Leboeuf']
# ('1135-005', 0, 2)
# ['Suu', 'Kyi']
# ('1037-000', 0, 1)
# ['Ericsson']
# ('1022-012', 28, 29)
# ['GMT']
# ('1090-004', 0, 1)
# ['Spain']
# ('1051-009', 1, 3)
# ['Colin', 'Montgomerie']
# ('0960-014', 32, 33)
# ["O'Brien"]
# ('0962-010', 4, 6)
# ['Payne', 'Stewart']
# ('1015-002', 20, 22)
# ['RMS', 'Titanic']
# ('0985-000', 0, 1)
# ['Boxing-Bruno']
# ('1034-002', 34, 35)
# ['Amsterdam']
# ('1087-002', 1, 2)
# ['Australian']
# ('1137-004', 0, 1)
# ['Li']
# ('1036-030', 0, 1)
# ['Barentsburg']
# ('1068-019', 0, 1)
# ['Bury']
# ('1051-003', 11, 14)
# ['Miguel', 'Angel', 'Martin']
# ('1054-007', 4, 5)
# ['Netherlands']
# ('1122-003', 6, 9)
# ['British', 'Broadcasting', 'Corporation']
# ('0956-005', 2, 3)
# ['Hyundai']
# ('0986-006', 2, 3)
# ['Breen']
# ('0949-010', 0, 1)
# ['Shearer']
# ('1076-030', 0, 1)
# ['Sutjeska']
# ('1089-003', 0, 1)
# ['Parnevik']
# ('1011-016', 6, 7)
# ['Missouri']
# ('1056-027', 4, 5)
# ['Germany']
# ('0972-029', 0, 2)
# ['H.', 'Tillekeratne']
# ('1096-036', 23, 24)
# ['Cardinals']
# ('1015-008', 25, 26)
# ['Purcell']
# ('1049-005', 37, 38)
# ['European']
# ('1095-000', 2, 4)
# ['MAJOR', 'LEAGUE']
# ('0968-004', 17, 18)
# ['Sarajevo']
# ('1094-002', 0, 3)
# ['Major', 'League', 'Baseball']
# ('1072-018', 76, 79)
# ['Fritz', 'van', 'Heerden']
# ('0948-011', 0, 1)
# ['Scotland']
# ('1154-003', 29, 30)
# ['Staoueli']
# ('1013-002', 8, 10)
# ['U.S.', 'Gulf']
# ('1037-003', 10, 15)
# ['Guangdong', 'Post', 'and', 'Telecommunications', 'Administration']
# ('0966-085', 4, 5)
# ['Sweden']
# ('1131-006', 19, 21)
# ['Latin', 'American']
# ('1031-004', 0, 1)
# ['Pirelli']
# ('0957-033', 29, 31)
# ['Bernd', 'Karbacher']
# ('1112-004', 18, 19)
# ['European']
# ('0949-003', 20, 22)
# ['Tony', 'Adams']
# ('1089-004', 0, 1)
# ['Parnevik']
# ('0969-003', 0, 1)
# ['Baratelli']
# ('1064-000', 7, 8)
# ['DWYER']
# ('1096-002', 25, 27)
# ['Cincinnati', 'Reds']
# ('1070-011', 7, 9)
# ['Reynard', 'Honda']
# ('1150-006', 13, 16)
# ['Lilac', 'Falls', 'Motel']
# ('1057-007', 34, 35)
# ['Ata-ur-Rehman']
# ('0966-019', 1, 3)
# ['Sara', 'Thorsett']
# ('1077-003', 8, 9)
# ['Republican']
# ('1067-012', 2, 5)
# ['Queen', 'of', 'South']
# ('1031-000', 0, 1)
# ['Pirelli']
# ('1127-006', 10, 12)
# ['Dzhokhar', 'Dudayev']
# ('1096-036', 4, 6)
# ['Tom', 'Pagnozzi']
# ('0949-004', 0, 1)
# ['Adams']
# ('1126-007', 0, 1)
# ['Moslems']
# ('0974-007', 29, 31)
# ['Darren', 'Lehmann']
# ('1124-010', 20, 22)
# ['Northern', 'Cape']
# ('1126-004', 17, 19)
# ['Max', 'Marriner']
# ('1099-000', 4, 5)
# ['SCOTLAND']
# ('1010-021', 20, 22)
# ['American', 'Catholics']
# ('1136-002', 23, 24)
# ['China']
# ('0967-002', 0, 1)
# ['UEFA']
# ('1054-017', 6, 7)
# ['Motorola']
# ('1058-040', 29, 31)
# ['Minnesota', 'Twins']
# ('1013-004', 6, 7)
# ['European']
# ('1068-022', 2, 3)
# ['Rotherham']
# ('1031-008', 15, 16)
# ['Chinese']
# ('0958-015', 0, 1)
# ['MINNESOTA']
# ('1031-003', 5, 6)
# ['Pirelli']
# ('1025-003', 4, 5)
# ['Israeli']
# ('1156-000', 6, 7)
# ['Nyerere']
# ('1016-002', 1, 2)
# ['German']
# ('1056-014', 4, 5)
# ['Ukraine']
# ('1077-000', 2, 3)
# ['INCE']
# ('1006-004', 38, 40)
# ['Pan', 'Am']
# ('1097-019', 0, 1)
# ['Edberg']
# ('1009-012', 27, 28)
# ['American']
# ('1124-000', 0, 2)
# ['S.', 'African']
# ('1066-036', 0, 1)
# ['Shrewsbury']
# ('0981-000', 0, 3)
# ['Douglas', '&', 'Lomason']
# ('1138-010', 0, 1)
# ['Wang']
# ('1069-015', 6, 7)
# ['Yorkshire']
# ('1097-016', 0, 1)
# ['Edberg']
# ('1038-005', 37, 38)
# ['Tsang']
# ('1143-004', 9, 10)
# ['Israel']
# ('1128-006', 21, 22)
# ['French']
# ('1049-004', 19, 20)
# ['Irish']
# ('1103-000', 5, 6)
# ['TURKEY']
# ('0966-162', 10, 11)
# ['Nigeria']
# ('1070-015', 4, 5)
# ['Brazil']
# ('1160-007', 28, 30)
# ['Warner', 'Bros']
# ('1101-003', 34, 35)
# ['Chelsea']
# ('1025-005', 0, 1)
# ['Palestinian']
# ('0972-013', 0, 2)
# ['J.', 'Gillespie']
# ('1116-037', 25, 26)
# ['Russian']
# ('0972-040', 4, 5)
# ['India']
# ('1058-043', 0, 2)
# ['Matt', 'Lawton']
# ('1027-010', 1, 2)
# ['Israeli']
# ('1069-004', 0, 1)
# ['Middlesex']
# ('1099-000', 2, 3)
# ['AUSTRIA']
# ('0984-019', 14, 15)
# ['European']
# ('1076-009', 0, 1)
# ['Buducnost']
# ('1007-017', 0, 2)
# ['George', 'Bush']
# ('1030-017', 17, 19)
# ['Ralph', 'Bloch']
# ('1103-016', 0, 1)
# ['Turkey']
# ('1000-001', 0, 2)
# ['Emese', 'Bartha']
# ('1000-005', 0, 1)
# ['Cofinec']
# ('0996-002', 4, 6)
# ['Dariusz', 'Rosati']
# ('1061-017', 0, 1)
# ['Scottish']
# ('1025-011', 7, 8)
# ['Netanyahu']
# ('1112-003', 33, 35)
# ['Sueddeutsche', 'Zeitung']
# ('0948-001', 0, 1)
# ['LONDON']
# ('1156-000', 4, 5)
# ['Burundi']
# ('1157-003', 5, 6)
# ['Reuters']
# ('0952-004', 5, 7)
# ['Manchester', 'United']
# ('0965-013', 4, 6)
# ['American', 'Olympic']
# ('1066-040', 0, 1)
# ['Bournemouth']
# ('1052-000', 2, 3)
# ['SLOVAKIA']
# ('1008-023', 14, 16)
# ['Lawrence', 'Lindsey']
# ('1008-003', 10, 11)
# ['Midwest']
# ('1015-003', 42, 44)
# ['Reagan', 'Communications']
# ('0984-013', 2, 3)
# ['Treasury']
# ('1054-013', 1, 3)
# ['Michael', 'Andersson']
# ('1058-003', 16, 17)
# ['Texas']
# ('1136-002', 6, 8)
# ['United', 'States']
# ('0966-105', 4, 5)
# ['Germany']
# ('1142-010', 9, 10)
# ['U.S.']
# ('1125-006', 32, 33)
# ['Goma']
# ('1086-000', 4, 5)
# ['MOLDOVA']
# ('1028-011', 3, 6)
# ['Michigan', 'National', 'Bank']
# ('1055-017', 4, 6)
# ['A.', 'Mullally']
# ('1093-005', 0, 2)
# ['El', 'Salvador']
# ('0966-069', 1, 3)
# ['Irina', 'Privalova']
# ('0966-131', 1, 3)
# ['Yelena', 'Gulyayeva']
# ('1029-014', 21, 23)
# ['Wall', 'Street']
# ('1036-023', 0, 1)
# ['Barentsburg']
# ('1115-003', 0, 3)
# ['The', 'Sunday', 'Telegraph']
# ('1156-000', 2, 3)
# ['Dini']
# ('0948-029', 7, 8)
# ['Edgbaston']
# ('1060-016', 4, 6)
# ['New', 'Zealand']
# ('1062-002', 11, 13)
# ['World', 'Cup']
# ('1120-002', 19, 20)
# ['Sudanese']
# ('1096-041', 3, 5)
# ['Sean', 'Berry']
# ('1046-009', 17, 19)
# ['Mauro', 'Silva']
# ('1056-006', 1, 3)
# ['Antonella', 'Bellutti']
# ('1107-000', 8, 10)
# ['WORLD', 'CUP']
# ('0966-154', 1, 3)
# ['Isel', 'Lopez']
# ('1142-012', 8, 9)
# ['Baghdad']
# ('0990-002', 31, 32)
# ['Interfax']
# ('0994-002', 0, 1)
# ['MINSK']
# ('1096-036', 26, 28)
# ['Colorado', 'Rockies']
# ('1113-000', 2, 4)
# ['GERMAN', 'CUP']
# ('1116-006', 20, 21)
# ['French']
# ('1072-008', 12, 14)
# ['Walter', 'Little']
# ('1096-013', 34, 35)
# ['Phillies']
# ('1053-003', 7, 9)
# ['N.', 'Knight']
# ('1027-010', 5, 6)
# ['Jerusalem']
# ('1058-014', 5, 7)
# ['White', 'Sox']
# ('0966-164', 4, 5)
# ['Sweden']
# ('1094-030', 0, 2)
# ['NEW', 'YORK']
# ('1013-004', 8, 9)
# ['Mediterranean']
# ('1135-027', 16, 17)
# ['Burma']
# ('0966-104', 4, 5)
# ['Norway']
# ('1060-022', 5, 6)
# ['Spain']
# ('1054-011', 1, 3)
# ['Luca', 'Pavanello']
# ('0957-008', 0, 2)
# ['Mark', 'Philippoussis']
# ('1056-043', 11, 13)
# ['Jane', 'Quigley']
# ('1070-013', 8, 10)
# ['Penske', 'Mercedes-Benz']
# ('1073-001', 0, 1)
# ['JOHANNESBURG']
# ('1156-000', 0, 1)
# ['Italy']
# ('0947-000', 2, 5)
# ['ENGLISH', 'COUNTY', 'CHAMPIONSHIP']
# ('1065-012', 0, 1)
# ['Clydebank']
# ('1137-003', 19, 23)
# ['North', 'Korean', 'Red', 'Cross']
# ('1064-005', 2, 3)
# ['French']
# ('0966-111', 4, 5)
# ['Kenya']
# ('0958-034', 0, 1)
# ['MONTREAL']
# ('1055-027', 0, 2)
# ['Salim', 'Malik']
# ('1094-033', 0, 1)
# ['ATLANTA']
# ('1116-034', 0, 1)
# ['Iraq']
# ('1065-031', 0, 1)
# ['Arbroath']
# ('1027-016', 3, 4)
# ['Jordan']
# ('1019-002', 0, 1)
# ['Dutch']
# ('1149-005', 35, 37)
# ['East', 'Coast']
# ('1155-005', 14, 15)
# ['Tehran']
# ('1054-014', 4, 5)
# ['Belgium']
# ('1046-001', 0, 2)
# ['LA', 'CORUNA']
# ('0951-005', 2, 4)
# ['Danius', 'Gleveckas']
# ('1057-007', 2, 4)
# ['Aamir', 'Sohail']
# ('1158-005', 19, 20)
# ['Uzi']
# ('1009-011', 0, 1)
# ['Mexican']
# ('1103-020', 2, 3)
# ['Belgium']
# ('1112-001', 0, 1)
# ['BONN']
# ('1145-003', 7, 8)
# ["Shul'ala"]
# ('0957-012', 3, 4)
# ['Russia']
# ('1128-010', 8, 9)
# ['Ruch']
# ('0958-020', 0, 1)
# ['SEATTLE']
# ('1031-003', 13, 14)
# ['China']
# ('1004-007', 11, 12)
# ['KNP']
# ('1156-006', 9, 12)
# ['Artisans', 'for', 'Peace']
# ('1138-010', 21, 23)
# ['Tiananmen', 'Square']
# ('0960-006', 5, 6)
# ['Chilean']
# ('1118-002', 16, 17)
# ['Scottish']
# ('0963-024', 0, 2)
# ['Mark', 'Brooks']
# ('1128-009', 14, 15)
# ['Polish']
# ('1064-003', 40, 41)
# ['London']
# ('1052-000', 4, 5)
# ['FAROES']
# ('1055-003', 0, 1)
# ['England']
# ('1101-011', 48, 50)
# ['Didier', 'Deschamps']
# ('0999-006', 2, 3)
# ['Levrentyeva']
# ('1036-009', 19, 20)
# ['Longyear']
# ('1161-007', 10, 12)
# ['Chittagong', 'Cement']
# ('1101-008', 3, 4)
# ['Ouedec']
# ('1142-002', 16, 17)
# ['Baghdad']
# ('0986-003', 0, 1)
# ['Birmingham']
# ('0958-008', 0, 1)
# ['BALTIMORE']
# ('0966-023', 4, 5)
# ['Germany']
# ('1069-018', 3, 4)
# ['Gloucestershire']
# ('0966-134', 4, 5)
# ['Kenya']
# ('1068-011', 2, 3)
# ['Stoke']
# ('0966-092', 1, 3)
# ['Fatima', 'Yusuf']
# ('1142-010', 19, 20)
# ['Iraqi']
# ('1058-043', 8, 10)
# ['Mike', 'Fetters']
# ('1054-014', 6, 7)
# ['Collstrop']
# ('1018-006', 20, 21)
# ['Reuters']
# ('1158-005', 17, 18)
# ['Kalashnikov']
# ('1108-004', 0, 1)
# ['Heath']
# ('1056-034', 5, 7)
# ['Cristiano', 'Citto']
# ('1054-021', 1, 2)
# ['Ludwig']
# ('1135-013', 10, 11)
# ['Burma']
# ('1023-000', 1, 4)
# ['Computer', 'Systems', 'Inc']
# ('1066-037', 0, 1)
# ['Blackpool']
# ('1115-003', 26, 27)
# ['Irish']
# ('0956-017', 0, 1)
# ['Hyundai']
# ('1066-028', 0, 1)
# ['Southend']
# ('1055-037', 5, 6)
# ['Mullally']
# ('1077-006', 2, 3)
# ['Moldova']
# ('1058-013', 7, 8)
# ['Cleveland']
# ('0966-135', 4, 5)
# ['U.S.']
# ('1103-016', 32, 34)
# ['Alpay', 'Ozalan']
# ('1096-037', 0, 1)
# ['Benes']
# ('1094-036', 0, 2)
# ['NEW', 'YORK']
# ('0957-033', 15, 17)
# ['Andrea', 'Gaudenzi']
# ('0999-006', 0, 1)
# ['Interfax']
# ('1115-004', 2, 3)
# ['Thatcher']
# ('0959-013', 0, 1)
# ['Atlanta']
# ('1034-007', 1, 4)
# ['Air', 'Cargo', 'Newsroom']
# ('1070-000', 6, 7)
# ['VANCOUVER']
# ('1094-048', 0, 2)
# ['SAN', 'FRANCISCO']
# ('1010-002', 10, 12)
# ['Roman', 'Catholic']
# ('1069-018', 1, 2)
# ['Bristol']
# ('1123-012', 0, 1)
# ['Lotte']
# ('1058-036', 15, 17)
# ['Tony', 'Clark']
# ('1068-011', 0, 1)
# ['Reading']
# ('1138-005', 6, 7)
# ['Wang']
# ('1069-013', 0, 1)
# ['Warwickshire']
# ('1060-012', 1, 3)
# ['Wayne', 'Riley']
# ('1146-005', 2, 3)
# ['Iraq']
# ('0963-017', 13, 15)
# ['Andrew', 'Magee']
# ('0957-033', 18, 19)
# ['Italy']
# ('1000-014', 6, 7)
# ['Hungary']
# ('0957-015', 2, 4)
# ['Lindsay', 'Davenport']
# ('1144-004', 11, 12)
# ['Saladdin']
# ('1130-006', 17, 18)
# ['America']
# ('1116-003', 3, 5)
# ['Elizabeth', 'I']
# ('1089-002', 0, 2)
# ['Jesper', 'Parnevik']

# %%
print("The number of false positives are",len(set(spans(df_dev))-spans_dev_gold))
#print("The false positives are",set(set(spans(df_dev))-spans_dev_gold))
def false_neg(gold, pred, df):
    for i in pred:
        if i not in gold:
            print(i)
            print(df[df['sentence_id'] == i[0]]['sentence'].values[0].split(' ')[i[1]:i[2]])
false_neg(spans_dev_gold, spans(df_dev), df_dev)
# Out:
# The number of false positives are 3627
# ('0946-002', 6, 7)
# ['four']
# ('0946-002', 8, 9)
# ['38']
# ('0946-002', 10, 11)
# ['Friday']
# ('0946-002', 19, 20)
# ['39']
# ('0946-002', 22, 24)
# ['two', 'days']
# ('0946-004', 5, 6)
# ['83']
# ('0946-004', 7, 10)
# ['the', 'opening', 'morning']
# ('0946-004', 17, 18)
# ['first']
# ('0946-004', 20, 21)
# ['94']
# ('0946-004', 27, 28)
# ['296']
# ('0946-004', 34, 35)
# ['three']
# ('0946-004', 36, 37)
# ['83']
# ('0946-005', 2, 3)
# ['213']
# ('0946-005', 11, 12)
# ['second']
# ('0946-005', 22, 23)
# ['174']
# ('0946-006', 26, 29)
# ['Yorkshire', 'at', 'Headingley']
# ('0946-007', 7, 8)
# ['one-day']
# ('0946-007', 11, 12)
# ['158']
# ('0946-007', 13, 20)
# ['his', 'first', 'championship', 'century', 'of', 'the', 'season']
# ('0946-007', 24, 25)
# ['372']
# ('0946-007', 28, 29)
# ['first']
# ('0946-007', 32, 33)
# ['82']
# ('0946-008', 20, 21)
# ['four']
# ('0946-008', 22, 23)
# ['24']
# ('0946-008', 24, 25)
# ['48']
# ('0946-008', 31, 32)
# ['119']
# ('0946-008', 33, 34)
# ['five']
# ('0946-009', 24, 25)
# ['four']
# ('0946-009', 26, 27)
# ['45']
# ('0946-009', 28, 29)
# ['Thursday']
# ('0946-009', 30, 31)
# ['80']
# ('0946-009', 34, 35)
# ['Friday']
# ('0946-010', 11, 12)
# ['70']
# ('0946-010', 16, 17)
# ['429']
# ('0946-010', 18, 19)
# ['seven']
# ('0946-010', 23, 24)
# ['234']
# ('0946-011', 7, 8)
# ['first']
# ('0946-011', 11, 12)
# ['1936']
# ('0946-011', 16, 17)
# ['133']
# ('0946-011', 18, 19)
# ['five']
# ('0946-011', 21, 22)
# ['second']
# ('0946-011', 25, 26)
# ['100']
# ('0946-012', 4, 5)
# ['six']
# ('0946-012', 6, 7)
# ['82']
# ('0946-012', 11, 12)
# ['123']
# ('0946-012', 17, 18)
# ['109']
# ('0946-012', 22, 23)
# ['471']
# ('0946-012', 25, 26)
# ['first']
# ('0946-012', 29, 30)
# ['233']
# ('0946-013', 5, 8)
# ['the', 'opening', 'day']
# ('0946-013', 26, 27)
# ['214']
# ('0946-014', 7, 8)
# ['84']
# ('0946-014', 18, 19)
# ['four']
# ('0946-014', 20, 21)
# ['55']
# ('0946-015', 5, 6)
# ['108']
# ('0946-015', 7, 8)
# ['three']
# ('0947-000', 0, 6)
# ['CRICKET', '-', 'ENGLISH', 'COUNTY', 'CHAMPIONSHIP', 'SCORES']
# ('0947-002', 12, 13)
# ['Friday']
# ('0947-003', 9, 10)
# ['39']
# ('0947-004', 1, 2)
# ['83']
# ('0947-004', 3, 4)
# ['174']
# ('0947-004', 5, 8)
# ['P.', 'Simmons', '4-38']
# ('0947-004', 11, 12)
# ['296']
# ('0947-005', 1, 2)
# ['22']
# ('0947-005', 5, 6)
# ['4']
# ('0947-006', 3, 4)
# ['259']
# ('0947-006', 5, 6)
# ['207']
# ('0947-006', 7, 10)
# ['A.', 'Dale', '69']
# ('0947-006', 11, 14)
# ['H.', 'Morris', '69']
# ('0947-006', 15, 16)
# ['D.']
# ('0947-006', 17, 18)
# ['4-43']
# ('0947-006', 20, 22)
# ['Durham', '114']
# ('0947-006', 28, 29)
# ['81-3']
# ('0947-007', 3, 5)
# ['Nottinghamshire', '214']
# ('0947-007', 6, 9)
# ['P.', 'Johnson', '84']
# ('0947-007', 10, 13)
# ['M.', 'McCague', '4-55']
# ('0947-007', 15, 17)
# ['Kent', '108-3']
# ('0947-008', 3, 4)
# ['Oval']
# ('0947-008', 7, 8)
# ['195']
# ('0947-008', 9, 11)
# ['Surrey', '429-7']
# ('0947-008', 22, 25)
# ['G.', 'Kersey', '63']
# ('0947-008', 26, 29)
# ['J.', 'Ratcliffe', '63']
# ('0947-008', 30, 31)
# ['D.']
# ('0947-009', 3, 4)
# ['363']
# ('0947-009', 5, 8)
# ['W.', 'Athey', '111']
# ('0947-009', 11, 12)
# ['52']
# ('0947-009', 13, 16)
# ['I.', 'Austin', '4-37']
# ('0947-009', 18, 20)
# ['Lancashire', '197-8']
# ('0947-009', 23, 24)
# ['54']
# ('0947-010', 2, 4)
# ['Middlesex', '199']
# ('0947-010', 5, 6)
# ['426']
# ('0947-010', 15, 18)
# ['M.', 'Gatting', '83']
# ('0947-010', 21, 22)
# ['232']
# ('0947-010', 23, 24)
# ['109-5']
# ('0947-011', 3, 4)
# ['238']
# ('0947-011', 5, 6)
# ['133-5']
# ('0947-011', 8, 9)
# ['471']
# ('0947-011', 10, 13)
# ['J.', 'Adams', '123']
# ('0947-011', 15, 16)
# ['109']
# ('0947-011', 19, 22)
# ['K.', 'Barnett', '87']
# ('0947-011', 23, 26)
# ['T.', 'Moody', '6-82']
# ('0947-012', 3, 4)
# ['183']
# ('0947-012', 5, 6)
# ['185-6']
# ('0947-012', 15, 16)
# ['190']
# ('0947-012', 17, 20)
# ['K.', 'Curran', '52']
# ('0948-004', 2, 6)
# ['May', '13', 'next', 'year']
# ('0948-004', 7, 13)
# ['the', 'Test', 'and', 'County', 'Cricket', 'Board']
# ('0948-006', 4, 5)
# ['three']
# ('0948-010', 6, 9)
# ['the', 'Minor', 'Counties']
# ('0948-014', 0, 2)
# ['May', '13']
# ('0948-015', 0, 2)
# ['May', '14']
# ('0948-016', 0, 2)
# ['May', '15']
# ('0948-016', 5, 6)
# ['Norfolk']
# ('0948-017', 0, 2)
# ['May', '17']
# ('0948-018', 0, 2)
# ['May', '18']
# ('0948-019', 0, 2)
# ['May', '20']
# ('0948-020', 0, 2)
# ['May', '22']
# ('0948-020', 2, 3)
# ['First']
# ('0948-022', 0, 2)
# ['May', '24']
# ('0948-022', 2, 3)
# ['Second']
# ('0948-022', 8, 9)
# ['Oval']
# ('0948-024', 0, 2)
# ['May', '25']
# ('0948-024', 2, 3)
# ['Third']
# ('0948-025', 9, 10)
# ['three']
# ('0948-027', 0, 5)
# ['May', '31', '-', 'June', '2']
# ('0948-027', 8, 10)
# ['three', 'days']
# ('0948-029', 0, 1)
# ['June']
# ('0948-029', 2, 3)
# ['First']
# ('0948-031', 0, 1)
# ['June']
# ('0948-031', 5, 7)
# ['three', 'days']
# ('0948-032', 0, 1)
# ['June']
# ('0948-032', 2, 3)
# ['Second']
# ('0948-033', 0, 1)
# ['June']
# ('0948-033', 3, 4)
# ['British']
# ('0948-033', 9, 11)
# ['three', 'days']
# ('0948-034', 0, 2)
# ['June', '28-30']
# ('0948-034', 5, 7)
# ['three', 'days']
# ('0948-036', 0, 1)
# ['July']
# ('0948-036', 2, 3)
# ['Third']
# ('0948-037', 0, 2)
# ['July', '9']
# ('0948-038', 0, 2)
# ['July', '12']
# ('0948-039', 0, 2)
# ['July', '16-18']
# ('0948-039', 5, 7)
# ['three', 'days']
# ('0948-040', 0, 2)
# ['July', '19-21']
# ('0948-040', 5, 7)
# ['three', 'days']
# ('0948-041', 0, 2)
# ['July', '24-28']
# ('0948-041', 2, 3)
# ['Fourth']
# ('0948-043', 0, 1)
# ['August']
# ('0948-043', 5, 7)
# ['four', 'days']
# ('0948-044', 0, 1)
# ['August']
# ('0948-044', 2, 3)
# ['Fifth']
# ('0948-045', 0, 2)
# ['August', '16-18']
# ('0948-045', 5, 7)
# ['three', 'days']
# ('0948-046', 0, 1)
# ['August']
# ('0948-046', 2, 3)
# ['Sixth']
# ('0948-046', 7, 8)
# ['Oval']
# ('0949-002', 15, 16)
# ['Friday']
# ('0949-003', 1, 2)
# ['26-year-old']
# ('0949-003', 7, 10)
# ['15', 'million', 'pounds']
# ('0949-003', 12, 15)
# ['$', '23.4', 'million']
# ('0949-003', 32, 33)
# ['June']
# ('0949-004', 18, 19)
# ['Sunday']
# ('0949-007', 3, 6)
# ['three', 'or', 'four']
# ('0949-010', 16, 17)
# ['Friday']
# ('0951-002', 6, 7)
# ['1-1']
# ('0951-002', 15, 16)
# ['Friday']
# ('0951-004', 11, 12)
# ['75th']
# ('0951-005', 0, 4)
# ['Lithuania', '-', 'Danius', 'Gleveckas']
# ('0951-005', 5, 6)
# ['13rd']
# ('0952-002', 1, 2)
# ['Volgograd']
# ('0952-002', 23, 24)
# ['1-0']
# ('0952-002', 27, 28)
# ['Saturday']
# ('0952-003', 15, 16)
# ['Friday']
# ('0952-003', 26, 28)
# ['September', '3']
# ('0952-004', 9, 12)
# ['last', 'year', "'s"]
# ('0952-004', 18, 19)
# ['1,000']
# ('0952-005', 9, 10)
# ['11']
# ('0952-006', 1, 2)
# ['three']
# ('0952-006', 6, 7)
# ['two']
# ('0952-006', 23, 24)
# ['two']
# ('0953-000', 0, 4)
# ['BOXING', '-', 'PANAMA', "'S"]
# ('0953-002', 3, 4)
# ['Roberto']
# ('0953-002', 9, 10)
# ['Duran']
# ('0953-002', 15, 16)
# ['Saturday']
# ('0953-003', 2, 3)
# ['45']
# ('0953-003', 11, 12)
# ['30']
# ('0953-004', 5, 6)
# ['first']
# ('0953-004', 10, 12)
# ['10', 'years']
# ('0953-011', 3, 4)
# ['Saturday']
# ('0953-011', 11, 12)
# ['one']
# ('0953-011', 20, 23)
# ['Panamanian', 'Boxing', 'Association']
# ('0953-012', 6, 8)
# ['three', 'decades']
# ('0953-012', 14, 15)
# ['10-round']
# ('0953-012', 22, 25)
# ['Puerto', 'Rico', "'s"]
# ('0953-013', 13, 14)
# ['June']
# ('0954-002', 3, 7)
# ['the', 'Hong', 'Kong', 'Open']
# ('0954-002', 8, 9)
# ['Friday']
# ('0954-002', 16, 17)
# ['1']
# ('0954-002', 30, 32)
# ['15-6', '15-7']
# ('0954-004', 0, 1)
# ['4']
# ('0954-004', 8, 9)
# ['7']
# ('0954-004', 15, 16)
# ['15-8']
# ('0954-004', 17, 19)
# ['13-15', '15-9']
# ('0954-005', 0, 1)
# ['2']
# ('0954-005', 14, 15)
# ['15-9']
# ('0955-004', 0, 2)
# ['Pohang', '3']
# ('0955-004', 6, 7)
# ['1-0']
# ('0955-005', 0, 4)
# ['Puchon', '2', 'Chonbuk', '1']
# ('0955-005', 6, 7)
# ['1-1']
# ('0955-009', 4, 5)
# ['6']
# ('0955-009', 5, 6)
# ['1']
# ('0955-010', 0, 2)
# ['Chonan', '3']
# ('0955-011', 0, 2)
# ['Pohang', '2']
# ('0955-012', 1, 3)
# ['1', '3']
# ('0955-012', 4, 5)
# ['7']
# ('0955-012', 5, 6)
# ['3']
# ('0955-013', 1, 2)
# ['1']
# ('0955-013', 3, 4)
# ['2']
# ('0955-013', 4, 5)
# ['8']
# ('0955-014', 3, 4)
# ['1']
# ('0955-016', 2, 3)
# ['2']
# ('0955-017', 3, 4)
# ['3']
# ('0956-005', 3, 4)
# ['2']
# ('0956-006', 1, 3)
# ['6', 'Lotte']
# ('0956-007', 0, 2)
# ['Haitai', '2']
# ('0956-008', 3, 4)
# ['3']
# ('0956-009', 1, 2)
# ['6']
# ('0956-010', 10, 11)
# ['two']
# ('0956-014', 0, 2)
# ['Haitai', '64']
# ('0956-015', 1, 2)
# ['59']
# ('0956-015', 5, 7)
# ['5', '1/2']
# ('0956-016', 1, 2)
# ['58']
# ('0956-017', 1, 2)
# ['57']
# ('0956-017', 5, 7)
# ['6', '1/2']
# ('0956-019', 5, 7)
# ['14', '1/2']
# ('0956-020', 5, 6)
# ['17']
# ('0956-021', 1, 2)
# ['42']
# ('0956-021', 5, 7)
# ['20', '1/2']
# ('0957-000', 0, 4)
# ['TENNIS', '-', 'FRIDAY', "'S"]
# ('0957-000', 7, 8)
# ['U.S.']
# ('0957-002', 8, 12)
# ['the', 'National', 'Tennis', 'Centre']
# ('0957-002', 13, 14)
# ['Friday']
# ('0957-006', 0, 1)
# ['4']
# ('0957-006', 17, 18)
# ['6-3']
# ('0957-007', 11, 12)
# ['6-3']
# ('0957-008', 11, 12)
# ['6']
# ('0957-009', 9, 10)
# ['Czech']
# ('0957-009', 12, 13)
# ['6']
# ('0957-010', 6, 7)
# ['17']
# ('0957-012', 11, 12)
# ['1-6']
# ('0957-012', 14, 15)
# ['6-1']
# ('0957-012', 16, 17)
# ['7-6']
# ('0957-012', 18, 19)
# ['10-8']
# ('0957-013', 14, 16)
# ['6-1', '6-1']
# ('0957-015', 0, 1)
# ['8']
# ('0957-015', 9, 10)
# ['Sidot']
# ('0957-016', 0, 1)
# ['4']
# ('0957-018', 0, 3)
# ['Add', 'Men', "'s"]
# ('0957-018', 5, 6)
# ['second']
# ('0957-018', 7, 8)
# ['16']
# ('0957-018', 21, 22)
# ['6']
# ('0957-018', 25, 26)
# ['6-1']
# ('0957-018', 40, 41)
# ['7']
# ('0957-019', 0, 3)
# ['Add', 'Women', "'s"]
# ('0957-019', 5, 6)
# ['third']
# ('0957-019', 19, 20)
# ['4-6']
# ('0957-019', 20, 25)
# ['7-5', 'Asa', 'Carlsson', '(', 'Sweden']
# ('0957-019', 27, 28)
# ['15']
# ('0957-020', 0, 3)
# ['Add', 'Men', "'s"]
# ('0957-020', 5, 6)
# ['second']
# ('0957-020', 7, 8)
# ['1']
# ('0957-020', 8, 11)
# ['-', 'Pete', 'Sampras']
# ('0957-020', 21, 24)
# ['6-3', '1-6', '6-3']
# ('0957-020', 38, 40)
# ['6', '6-2']
# ('0957-021', 0, 3)
# ['Add', 'Women', "'s"]
# ('0957-021', 5, 6)
# ['third']
# ('0957-021', 18, 20)
# ['6-3', '6-2']
# ('0957-030', 0, 1)
# ['2']
# ('0957-033', 5, 6)
# ['second']
# ('0957-033', 7, 8)
# ['12']
# ('0957-033', 34, 35)
# ['3-6']
# ('0957-033', 35, 37)
# ['6-3', '6-3']
# ('0957-033', 37, 38)
# ['1-0']
# ('0958-000', 0, 5)
# ['BASEBALL', '-', 'MAJOR', 'LEAGUE', 'STANDINGS']
# ('0958-007', 2, 4)
# ['74', '59']
# ('0958-008', 1, 3)
# ['70', '63']
# ('0958-009', 1, 4)
# ['69', '65', '.515']
# ('0958-009', 4, 6)
# ['5', '1/2']
# ('0958-010', 1, 3)
# ['63', '71']
# ('0958-010', 4, 6)
# ['11', '1/2']
# ('0958-011', 1, 3)
# ['48', '86']
# ('0958-011', 4, 6)
# ['26', '1/2']
# ('0958-013', 1, 2)
# ['80']
# ('0958-014', 1, 3)
# ['71', '64']
# ('0958-015', 4, 6)
# ['13', '1/2']
# ('0958-016', 1, 3)
# ['64', '71']
# ('0958-017', 2, 4)
# ['61', '74']
# ('0958-017', 5, 6)
# ['20']
# ('0958-019', 1, 3)
# ['75', '58']
# ('0958-021', 1, 3)
# ['64', '72']
# ('0958-021', 4, 6)
# ['12', '1/2']
# ('0958-022', 1, 3)
# ['62', '72']
# ('0958-022', 4, 6)
# ['13', '1/2']
# ('0958-034', 1, 5)
# ['71', '61', '.538', '12']
# ('0958-037', 1, 3)
# ['54', '80']
# ('0958-037', 4, 5)
# ['30']
# ('0958-039', 1, 3)
# ['72', '63']
# ('0958-040', 2, 5)
# ['69', '65', '.515']
# ('0958-040', 5, 7)
# ['2', '1/2']
# ('0958-041', 1, 2)
# ['66']
# ('0958-041', 4, 5)
# ['5']
# ('0958-042', 1, 3)
# ['65', '66']
# ('0958-042', 4, 5)
# ['5']
# ('0958-043', 1, 3)
# ['56', '77']
# ('0958-043', 4, 5)
# ['15']
# ('0958-045', 3, 4)
# ['60']
# ('0958-047', 1, 4)
# ['70', '65', '.519']
# ('0958-048', 5, 6)
# ['16']
# ('0959-000', 0, 6)
# ['BASEBALL', '-', 'MAJOR', 'LEAGUE', 'RESULTS', 'THURSDAY']
# ('0959-007', 1, 2)
# ['14']
# ('0959-010', 0, 3)
# ['San', 'Diego', '3']
# ('0959-012', 1, 2)
# ['18']
# ('0959-014', 2, 3)
# ['2']
# ('0959-014', 4, 5)
# ['1']
# ('0960-003', 5, 6)
# ['Thursday']
# ('0960-003', 19, 21)
# ['a', 'night']
# ('0960-003', 24, 27)
# ['the', 'U.S.', 'Open']
# ('0960-004', 21, 22)
# ['5-7']
# ('0960-004', 22, 23)
# ['3-6']
# ('0960-004', 23, 24)
# ['6-3']
# ('0960-004', 25, 30)
# ['a', 'two', 'hour', '51', 'minute']
# ('0960-004', 33, 34)
# ['Stadium']
# ('0960-005', 6, 7)
# ['10th']
# ('0960-006', 8, 10)
# ['7-6', '6-2']
# ('0960-007', 0, 2)
# ['The', 'day']
# ('0960-007', 17, 18)
# ['3-6']
# ('0960-007', 22, 23)
# ['18']
# ('0960-007', 26, 27)
# ['19']
# ('0960-009', 7, 8)
# ['1-5']
# ('0960-009', 10, 11)
# ['two']
# ('0960-009', 15, 16)
# ['third']
# ('0960-010', 4, 7)
# ['two', 'weeks', 'ago']
# ('0960-010', 12, 13)
# ['first']
# ('0960-010', 21, 22)
# ['5-4']
# ('0960-010', 24, 25)
# ['third']
# ('0960-011', 34, 35)
# ['65th']
# ('0960-013', 13, 14)
# ['17']
# ('0960-014', 1, 2)
# ['fifth']
# ('0960-014', 8, 9)
# ['sixth']
# ('0960-014', 16, 17)
# ['one']
# ('0960-015', 4, 5)
# ['two']
# ('0960-015', 10, 11)
# ['5-2']
# ('0960-015', 15, 16)
# ['eighth']
# ('0960-015', 29, 30)
# ['40-0']
# ('0960-017', 8, 12)
# ['a', 'couple', 'of', 'moments']
# ('0960-019', 5, 8)
# ['two', 'years', 'ago']
# ('0960-019', 12, 13)
# ['28,000']
# ('0960-019', 18, 19)
# ['year']
# ('0960-019', 22, 25)
# ['the', 'All-England', 'Club']
# ('0960-019', 32, 36)
# ['his', 'lively', 'two', 'hour']
# ('0960-019', 37, 39)
# ['24', 'minute']
# ('0960-023', 12, 13)
# ['7-5']
# ('0960-037', 11, 12)
# ['night']
# ('0961-000', 0, 5)
# ['NFL', 'AMERICAN', 'FOOTBALL-RANDALL', 'CUNNINGHAM', 'RETIRES']
# ('0961-002', 3, 8)
# ['the', 'National', 'Football', 'League', "'s"]
# ('0961-002', 29, 30)
# ['Thursday']
# ('0961-003', 7, 10)
# ['the', 'Philadelphia', 'Eagles']
# ('0961-004', 9, 11)
# ['4,482', 'yards']
# ('0961-004', 12, 13)
# ['677']
# ('0961-008', 1, 4)
# ['his', '11', 'years']
# ('0961-009', 4, 5)
# ['1985']
# ('0961-009', 8, 9)
# ['1,874-of-3,362']
# ('0961-009', 11, 13)
# ['55.7', 'percent']
# ('0961-009', 15, 17)
# ['22,877', 'yards']
# ('0961-009', 18, 19)
# ['150']
# ('0962-003', 1, 4)
# ['$', '1.2', 'million']
# ('0962-003', 4, 6)
# ['Greater', 'Milwaukee']
# ('0962-004', 8, 9)
# ['first']
# ('0962-005', 1, 2)
# ['Thursday']
# ('0962-006', 0, 1)
# ['62']
# ('0962-007', 0, 1)
# ['64']
# ('0962-008', 0, 1)
# ['65']
# ('0962-009', 0, 1)
# ['66']
# ('0962-010', 0, 1)
# ['67']
# ('0963-002', 4, 6)
# ['nine-under-par', '62']
# ('0963-002', 17, 20)
# ['$', '1.2', 'million']
# ('0963-002', 20, 22)
# ['Greater', 'Milwaukee']
# ('0963-002', 23, 24)
# ['Thursday']
# ('0963-002', 25, 26)
# ['20-year-old']
# ('0963-002', 29, 30)
# ['67']
# ('0963-003', 2, 3)
# ['two']
# ('0963-003', 9, 10)
# ['three']
# ('0963-004', 5, 6)
# ['Tuesday']
# ('0963-004', 10, 11)
# ['third']
# ('0963-004', 12, 13)
# ['U.S.']
# ('0963-004', 19, 20)
# ['18th']
# ('0963-006', 1, 2)
# ['Yesterday']
# ('0963-011', 14, 15)
# ['six']
# ('0963-011', 19, 20)
# ['eight']
# ('0963-017', 5, 6)
# ['one']
# ('0963-017', 16, 17)
# ['Wednesday']
# ('0963-017', 21, 22)
# ['three']
# ('0963-017', 31, 32)
# ['1993']
# ('0963-018', 8, 9)
# ['1994']
# ('0963-018', 15, 17)
# ['this', 'year']
# ('0963-018', 22, 25)
# ['the', 'Nortel', 'Open']
# ('0963-018', 26, 27)
# ['January']
# ('0963-018', 31, 32)
# ['fourth']
# ('0963-018', 35, 36)
# ['five']
# ('0963-018', 42, 43)
# ['second']
# ('0963-021', 6, 7)
# ['13']
# ('0963-021', 9, 10)
# ['four']
# ('0963-021', 13, 14)
# ['1993']
# ('0963-021', 21, 22)
# ['second']
# ('0963-021', 23, 26)
# ['last', 'week', "'s"]
# ('0963-021', 33, 34)
# ['U.S.']
# ('0963-022', 7, 8)
# ['68']
# ('0963-022', 10, 11)
# ['six']
# ('0963-023', 8, 11)
# ['the', 'PGA', 'Tour']
# ('0963-023', 17, 22)
# ['the', 'World', 'Series', 'of', 'Golf']
# ('0963-023', 22, 24)
# ['last', 'week']
# ('0963-024', 17, 18)
# ['four']
# ('0963-024', 26, 27)
# ['week']
# ('0964-002', 14, 15)
# ['Saturday']
# ('0964-002', 33, 34)
# ['one']
# ('0964-003', 12, 13)
# ['Wednesday']
# ('0964-003', 15, 16)
# ['Saturday']
# ('0965-000', 0, 1)
# ['ATHLETICS']
# ('0965-003', 0, 3)
# ['American', 'Dennis', 'Mitchell']
# ('0965-003', 5, 7)
# ['100', 'metres']
# ('0965-003', 12, 13)
# ['third']
# ('0965-003', 31, 32)
# ['Friday']
# ('0965-004', 11, 13)
# ['Berlin', 'grand']
# ('0965-004', 22, 25)
# ['the', '100', 'metres']
# ('0965-004', 35, 37)
# ['10.08', 'seconds']
# ('0965-005', 8, 9)
# ['9.84']
# ('0965-005', 28, 29)
# ['third']
# ('0965-006', 5, 6)
# ['second']
# ('0965-006', 7, 8)
# ['10.09']
# ('0965-006', 12, 13)
# ['10.13']
# ('0965-007', 0, 2)
# ['Last', 'Friday']
# ('0965-007', 6, 7)
# ['fourth']
# ('0965-007', 8, 11)
# ['the', 'Atlanta', 'Games']
# ('0965-007', 23, 24)
# ['100']
# ('0965-008', 0, 3)
# ['Earlier', 'this', 'month']
# ('0965-009', 16, 19)
# ['the', 'Golden', 'Four']
# ('0965-010', 4, 5)
# ['Friday']
# ('0965-010', 7, 9)
# ['100', 'metres']
# ('0965-010', 13, 14)
# ['1948']
# ('0965-011', 15, 16)
# ['60th']
# ('0965-011', 18, 21)
# ['Jesse', 'Owens', "'s"]
# ('0965-011', 21, 22)
# ['four']
# ('0965-011', 25, 28)
# ['the', '1936', 'Olympics']
# ('0965-012', 1, 2)
# ['Today']
# ('0965-013', 17, 18)
# ['100']
# ('0965-013', 20, 21)
# ['10.89']
# ('0965-013', 30, 31)
# ['second']
# ('0965-013', 32, 33)
# ['10.94']
# ('0966-000', 0, 6)
# ['ATHLETICS', '-', 'BERLIN', 'GRAND', 'PRIX', 'RESULTS']
# ('0966-002', 3, 7)
# ['the', 'Berlin', 'Grand', 'Prix']
# ('0966-002', 10, 11)
# ['Friday']
# ('0966-004', 0, 1)
# ['1.']
# ('0966-004', 6, 8)
# ['12.71', 'seconds']
# ('0966-005', 0, 1)
# ['2.']
# ('0966-005', 6, 7)
# ['12.74']
# ('0966-006', 0, 1)
# ['3.']
# ('0966-007', 0, 1)
# ['4.']
# ('0966-008', 0, 1)
# ['5.']
# ('0966-009', 0, 1)
# ['6.']
# ('0966-010', 0, 1)
# ['7.']
# ('0966-010', 6, 7)
# ['13.17']
# ('0966-012', 0, 1)
# ['1.']
# ('0966-012', 6, 10)
# ['four', 'minutes', '6.87', 'seconds']
# ('0966-013', 0, 1)
# ['2.']
# ('0966-014', 0, 1)
# ['3.']
# ('0966-015', 0, 1)
# ['4.']
# ('0966-015', 6, 7)
# ['4:09.25']
# ('0966-016', 0, 1)
# ['5.']
# ('0966-016', 1, 4)
# ['Leah', 'Pells', '(']
# ('0966-017', 6, 7)
# ['4:10.38']
# ('0966-018', 0, 1)
# ['7.']
# ('0966-019', 0, 1)
# ['8.']
# ('0966-021', 0, 1)
# ['1.']
# ('0966-021', 6, 8)
# ['13.26', 'seconds']
# ('0966-022', 0, 1)
# ['2.']
# ('0966-022', 6, 7)
# ['13.35']
# ('0966-023', 0, 1)
# ['3.']
# ('0966-023', 1, 2)
# ['Florian']
# ('0966-023', 6, 7)
# ['13.36']
# ('0966-024', 0, 1)
# ['4.']
# ('0966-024', 6, 7)
# ['13.52']
# ('0966-025', 0, 1)
# ['5.']
# ('0966-025', 6, 7)
# ['13.52']
# ('0966-026', 0, 1)
# ['6.']
# ('0966-026', 6, 7)
# ['13.53']
# ('0966-027', 6, 7)
# ['13.58']
# ('0966-028', 6, 7)
# ['13.60']
# ('0966-030', 0, 1)
# ['1.']
# ('0966-030', 6, 8)
# ['19.97', 'seconds']
# ('0966-031', 0, 1)
# ['2.']
# ('0966-031', 6, 7)
# ['20.02']
# ('0966-032', 0, 1)
# ['3.']
# ('0966-032', 6, 7)
# ['20.37']
# ('0966-033', 0, 1)
# ['4.']
# ('0966-033', 6, 7)
# ['20.41']
# ('0966-034', 0, 1)
# ['5.']
# ('0966-034', 6, 7)
# ['20.54']
# ('0966-035', 6, 7)
# ['20.78']
# ('0966-036', 6, 7)
# ['20.90']
# ('0966-037', 6, 7)
# ['20.96']
# ('0966-039', 0, 1)
# ['1.']
# ('0966-039', 6, 8)
# ['19.89', 'metres']
# ('0966-040', 0, 1)
# ['2.']
# ('0966-040', 6, 7)
# ['18.80']
# ('0966-041', 0, 1)
# ['3.']
# ('0966-041', 6, 7)
# ['18.63']
# ('0966-042', 0, 1)
# ['4.']
# ('0966-042', 6, 7)
# ['18.55']
# ('0966-043', 0, 1)
# ['5.']
# ('0966-043', 6, 7)
# ['18.41']
# ('0966-045', 0, 1)
# ['1.']
# ('0966-045', 6, 10)
# ['3', 'minutes', '49.09', 'seconds']
# ('0966-046', 0, 1)
# ['2.']
# ('0966-047', 0, 1)
# ['3.']
# ('0966-047', 6, 7)
# ['3:51.40']
# ('0966-048', 0, 1)
# ['4.']
# ('0966-049', 0, 1)
# ['5.']
# ('0966-050', 6, 7)
# ['3:53.85']
# ('0966-051', 0, 1)
# ['7.']
# ('0966-052', 0, 1)
# ['8.']
# ('0966-052', 6, 7)
# ['3:54.87']
# ('0966-054', 0, 1)
# ['1.']
# ('0966-054', 6, 8)
# ['70.60', 'metres']
# ('0966-055', 0, 1)
# ['2.']
# ('0966-055', 6, 7)
# ['68.44']
# ('0966-056', 0, 1)
# ['3.']
# ('0966-056', 6, 7)
# ['66.24']
# ('0966-057', 0, 1)
# ['4.']
# ('0966-057', 6, 7)
# ['65.30']
# ('0966-058', 0, 1)
# ['5.']
# ('0966-059', 0, 1)
# ['6.']
# ('0966-060', 0, 1)
# ['7.']
# ('0966-060', 6, 7)
# ['62.00']
# ('0966-061', 6, 7)
# ['58.56']
# ('0966-063', 0, 1)
# ['1.']
# ('0966-063', 6, 8)
# ['10.89', 'seconds']
# ('0966-064', 0, 1)
# ['2.']
# ('0966-064', 6, 7)
# ['10.94']
# ('0966-065', 0, 1)
# ['3.']
# ('0966-065', 6, 7)
# ['11.07']
# ('0966-066', 0, 1)
# ['4.']
# ('0966-066', 6, 7)
# ['11.14']
# ('0966-067', 0, 1)
# ['5.']
# ('0966-068', 0, 1)
# ['6.']
# ('0966-068', 6, 7)
# ['11.26']
# ('0966-069', 0, 1)
# ['7.']
# ('0966-069', 6, 7)
# ['11.27']
# ('0966-070', 0, 1)
# ['8.']
# ('0966-070', 6, 7)
# ['11.37']
# ('0966-072', 0, 1)
# ['1.']
# ('0966-072', 6, 10)
# ['15', 'minutes', '04.95', 'seconds']
# ('0966-073', 0, 1)
# ['2.']
# ('0966-073', 6, 7)
# ['15:05.21']
# ('0966-074', 0, 1)
# ['3.']
# ('0966-074', 6, 7)
# ['15:05.41']
# ('0966-075', 0, 1)
# ['4.']
# ('0966-075', 6, 7)
# ['15:06.33']
# ('0966-076', 0, 1)
# ['5.']
# ('0966-076', 6, 7)
# ['15:08.79']
# ('0966-077', 0, 1)
# ['6.']
# ('0966-077', 6, 7)
# ['15:09.00']
# ('0966-078', 0, 1)
# ['7.']
# ('0966-078', 6, 7)
# ['15:09.74']
# ('0966-079', 6, 7)
# ['15:14.34']
# ('0966-081', 0, 1)
# ['1.']
# ('0966-081', 6, 8)
# ['48.23', 'seconds']
# ('0966-082', 0, 1)
# ['2.']
# ('0966-082', 6, 7)
# ['48.34']
# ('0966-083', 0, 1)
# ['3.']
# ('0966-083', 6, 7)
# ['48.62']
# ('0966-084', 0, 1)
# ['4.']
# ('0966-084', 6, 7)
# ['49.21']
# ('0966-085', 0, 1)
# ['5.']
# ('0966-085', 6, 7)
# ['49.22']
# ('0966-087', 0, 1)
# ['7.']
# ('0966-087', 6, 7)
# ['49.36']
# ('0966-088', 0, 1)
# ['8.']
# ('0966-090', 0, 1)
# ['1.']
# ('0966-090', 6, 8)
# ['50.31', 'seconds']
# ('0966-091', 0, 1)
# ['2.']
# ('0966-092', 0, 1)
# ['3.']
# ('0966-092', 6, 7)
# ['51.43']
# ('0966-093', 0, 1)
# ['4.']
# ('0966-093', 6, 7)
# ['51.61']
# ('0966-094', 0, 1)
# ['5.']
# ('0966-094', 6, 7)
# ['51.98']
# ('0966-095', 0, 1)
# ['6.']
# ('0966-095', 6, 7)
# ['52.05']
# ('0966-096', 0, 1)
# ['7.']
# ('0966-096', 6, 7)
# ['52.41']
# ('0966-097', 0, 1)
# ['8.']
# ('0966-097', 6, 7)
# ['53.13']
# ('0966-099', 0, 1)
# ['1.']
# ('0966-099', 6, 7)
# ['10.08']
# ('0966-100', 0, 1)
# ['2.']
# ('0966-100', 6, 7)
# ['10.09']
# ('0966-101', 0, 1)
# ['3.']
# ('0966-101', 6, 7)
# ['10.13']
# ('0966-102', 0, 1)
# ['4.']
# ('0966-102', 6, 7)
# ['10.22']
# ('0966-103', 0, 1)
# ['5.']
# ('0966-103', 6, 7)
# ['10.24']
# ('0966-104', 0, 1)
# ['6.']
# ('0966-104', 6, 7)
# ['10.33']
# ('0966-105', 0, 1)
# ['7.']
# ('0966-105', 6, 7)
# ['10.48']
# ('0966-107', 0, 1)
# ['1.']
# ('0966-107', 6, 7)
# ['1:43.34']
# ('0966-108', 0, 1)
# ['2.']
# ('0966-109', 0, 1)
# ['3.']
# ('0966-110', 0, 1)
# ['4.']
# ('0966-110', 6, 7)
# ['1:45.03']
# ('0966-111', 0, 1)
# ['5.']
# ('0966-112', 0, 1)
# ['6.']
# ('0966-113', 0, 1)
# ['7.']
# ('0966-113', 6, 7)
# ['1:46.45']
# ('0966-116', 6, 7)
# ['5.86']
# ('0966-117', 0, 1)
# ['1=']
# ('0966-117', 6, 7)
# ['5.86']
# ('0966-118', 0, 1)
# ['3.']
# ('0966-118', 6, 7)
# ['5.86']
# ('0966-119', 0, 1)
# ['4.']
# ('0966-119', 6, 7)
# ['5.80']
# ('0966-120', 0, 1)
# ['5.']
# ('0966-120', 6, 7)
# ['5.80']
# ('0966-121', 0, 1)
# ['6.']
# ('0966-121', 6, 7)
# ['5.65']
# ('0966-122', 0, 1)
# ['7.']
# ('0966-122', 6, 7)
# ['5.65']
# ('0966-123', 0, 1)
# ['8.']
# ('0966-123', 6, 7)
# ['5.65']
# ('0966-125', 0, 1)
# ['1.']
# ('0966-125', 6, 7)
# ['2.03']
# ('0966-126', 0, 1)
# ['2.']
# ('0966-126', 6, 8)
# ['2.00', 'metres']
# ('0966-127', 0, 1)
# ['3.']
# ('0966-127', 6, 7)
# ['1.97']
# ('0966-128', 0, 1)
# ['4.']
# ('0966-128', 6, 7)
# ['1.97']
# ('0966-129', 0, 1)
# ['5.']
# ('0966-129', 6, 7)
# ['1.91']
# ('0966-130', 6, 7)
# ['1.91']
# ('0966-131', 6, 7)
# ['1.91']
# ('0966-132', 0, 1)
# ['8.']
# ('0966-132', 6, 7)
# ['1.85']
# ('0966-134', 0, 1)
# ['1.']
# ('0966-134', 6, 10)
# ['13', 'minutes', '2.62', 'seconds']
# ('0966-135', 0, 1)
# ['2.']
# ('0966-136', 0, 1)
# ['3.']
# ('0966-136', 6, 7)
# ['13:06.45']
# ('0966-137', 0, 1)
# ['4.']
# ('0966-137', 7, 8)
# ['13:06.57']
# ('0966-138', 0, 1)
# ['5.']
# ('0966-138', 6, 7)
# ['13:06.65']
# ('0966-139', 6, 7)
# ['13:08.05']
# ('0966-140', 6, 7)
# ['13:20.12']
# ('0966-141', 0, 1)
# ['8.']
# ('0966-141', 6, 7)
# ['13:21.35']
# ('0966-143', 0, 1)
# ['1.']
# ('0966-143', 6, 8)
# ['17.69', 'metres']
# ('0966-144', 0, 1)
# ['2.']
# ('0966-144', 6, 7)
# ['17.44']
# ('0966-145', 0, 1)
# ['3.']
# ('0966-145', 6, 7)
# ['17.16']
# ('0966-146', 0, 1)
# ['4.']
# ('0966-147', 0, 1)
# ['5.']
# ('0966-147', 6, 7)
# ['16.57']
# ('0966-148', 6, 7)
# ['16.41']
# ('0966-149', 6, 7)
# ['16.31']
# ('0966-150', 0, 1)
# ['8.']
# ('0966-150', 6, 7)
# ['16.12']
# ('0966-152', 0, 1)
# ['1.']
# ('0966-152', 6, 8)
# ['66.60', 'metres']
# ('0966-153', 0, 1)
# ['2.']
# ('0966-153', 6, 7)
# ['65.12']
# ('0966-154', 0, 1)
# ['3.']
# ('0966-154', 6, 7)
# ['65.10']
# ('0966-155', 0, 1)
# ['4.']
# ('0966-155', 6, 7)
# ['62.78']
# ('0966-156', 0, 1)
# ['5.']
# ('0966-156', 6, 7)
# ['62.06']
# ('0966-157', 0, 1)
# ['6.']
# ('0966-158', 0, 1)
# ['7.']
# ('0966-158', 1, 2)
# ['Natalya']
# ('0966-158', 6, 7)
# ['60.74']
# ('0966-159', 6, 7)
# ['60.74']
# ('0966-161', 0, 1)
# ['1.']
# ('0966-161', 24, 26)
# ['38.87', 'seconds']
# ('0966-162', 0, 1)
# ['2.']
# ('0966-163', 9, 10)
# ['38.87']
# ('0966-164', 0, 1)
# ['3.']
# ('0966-164', 19, 20)
# ['Florian']
# ('0966-164', 24, 25)
# ['39.93']
# ('0967-000', 3, 4)
# ['STANDARD']
# ('0967-000', 6, 7)
# ['BANNED']
# ('0967-000', 8, 10)
# ['CLUB', 'FINED']
# ('0967-002', 10, 11)
# ['Friday']
# ('0967-003', 5, 8)
# ['25,000', 'Swiss', 'francs']
# ('0967-003', 10, 11)
# ['20,850']
# ('0967-003', 21, 22)
# ['seven']
# ('0967-005', 6, 7)
# ['six']
# ('0967-005', 30, 31)
# ['four']
# ('0967-006', 3, 5)
# ['August', '20']
# ('0967-006', 6, 7)
# ['3-1']
# ('0967-006', 9, 10)
# ['two']
# ('0967-007', 4, 5)
# ['3-2']
# ('0967-007', 10, 13)
# ['the', 'UEFA', 'Cup']
# ('0968-000', 0, 3)
# ['ATHLETICS', '-', 'HARRISON']
# ('0968-002', 21, 22)
# ['Solidarity']
# ('0968-002', 24, 25)
# ['Sarajevo']
# ('0968-002', 26, 28)
# ['September', '9']
# ('0968-003', 0, 5)
# ['The', 'International', 'Amateur', 'Athletic', 'Federation']
# ('0968-003', 7, 8)
# ['Friday']
# ('0968-003', 33, 34)
# ['one']
# ('0968-003', 40, 42)
# ['Kosevo', 'stadium']
# ('0968-004', 35, 37)
# ['two', 'days']
# ('0969-002', 19, 20)
# ['Friday']
# ('0969-003', 20, 21)
# ['Thursday']
# ('0969-004', 9, 10)
# ['four']
# ('0969-004', 13, 15)
# ['this', 'season']
# ('0969-004', 20, 21)
# ['18th']
# ('0970-002', 11, 12)
# ['1992']
# ('0970-002', 32, 34)
# ['a', 'year']
# ('0970-002', 38, 39)
# ['Friday']
# ('0970-003', 1, 2)
# ['Gazzetta']
# ('0970-003', 10, 13)
# ['around', '$', '600,000']
# ('0970-004', 2, 3)
# ['27']
# ('0970-004', 10, 13)
# ['$', '12', 'million']
# ('0970-005', 11, 14)
# ['the', 'following', 'year']
# ('0970-006', 16, 18)
# ['last', 'season']
# ('0971-000', 0, 9)
# ['CRICKET', '-', 'SRI', 'LANKA', 'BEAT', 'AUSTRALIA', 'BY', 'FOUR', 'WICKETS']
# ('0971-002', 5, 6)
# ['four']
# ('0971-002', 9, 10)
# ['third']
# ('0971-002', 12, 16)
# ['the', 'Singer', 'World', 'Series']
# ('0971-002', 16, 17)
# ['one-day']
# ('0971-002', 18, 19)
# ['50']
# ('0971-002', 24, 25)
# ['Friday']
# ('0971-003', 2, 4)
# ['Australia', '228-9']
# ('0971-003', 5, 6)
# ['50']
# ('0971-003', 12, 13)
# ['45.5']
# ('0972-002', 3, 4)
# ['third']
# ('0972-005', 6, 7)
# ['50']
# ('0972-006', 4, 5)
# ['9']
# ('0972-007', 0, 5)
# ['S.', 'Law', 'c', 'Tillekeratne', 'b']
# ('0972-008', 6, 7)
# ['56']
# ('0972-009', 0, 3)
# ['S.', 'Waugh', 'b']
# ('0972-009', 4, 5)
# ['22']
# ('0972-010', 4, 5)
# ['46']
# ('0972-011', 6, 7)
# ['2']
# ('0972-013', 0, 4)
# ['J.', 'Gillespie', 'st', 'Kaluwitharana']
# ('0972-013', 6, 7)
# ['6']
# ('0972-014', 6, 7)
# ['3']
# ('0972-015', 4, 5)
# ['8']
# ('0972-020', 2, 8)
# ['Vass', '7-0-29-0', ',', 'de', 'Silva', '4-0-25-0']
# ('0972-021', 2, 4)
# ['Muralitharan', '10-0-41-2']
# ('0972-021', 6, 7)
# ['10-0-43-2']
# ('0972-024', 3, 6)
# ['Healy', 'b', 'Fleming']
# ('0972-024', 6, 7)
# ['44']
# ('0972-025', 0, 5)
# ['R.', 'Kaluwitharana', 'b', 'S.', 'Waugh']
# ('0972-026', 4, 5)
# ['16']
# ('0972-027', 4, 5)
# ['83']
# ('0972-031', 4, 5)
# ['14']
# ('0972-038', 0, 1)
# ['6-0-26-0']
# ('0972-038', 3, 4)
# ['4-0-18-0']
# ('0972-040', 8, 10)
# ['September', '1']
# ('0973-000', 0, 4)
# ['CRICKET', '-', 'AUSTRALIA', '228-9']
# ('0973-000', 5, 6)
# ['50']
# ('0973-002', 2, 3)
# ['228']
# ('0973-002', 4, 5)
# ['nine']
# ('0973-002', 8, 9)
# ['50']
# ('0973-002', 15, 16)
# ['third']
# ('0973-002', 21, 25)
# ['the', 'Singer', 'World', 'Series']
# ('0973-002', 27, 28)
# ['Friday']
# ('0974-000', 0, 3)
# ['CRICKET', '-', 'AUSTRALIA']
# ('0974-003', 8, 9)
# ['third']
# ('0974-004', 6, 8)
# ['world', 'series']
# ('0975-002', 9, 10)
# ['six-month']
# ('0975-002', 17, 19)
# ['33', 'percent']
# ('0975-002', 20, 23)
# ['1.069', 'billion', 'lei']
# ('0975-004', 2, 3)
# ['six-month']
# ('0975-004', 6, 8)
# ['4,378', 'tonnes']
# ('0975-004', 11, 13)
# ['2,684', 'tonnes']
# ('0975-004', 18, 19)
# ['1995']
# ('0975-004', 24, 28)
# ['the', 'Bucharest', 'stock', 'exchange']
# ('0975-007', 1, 2)
# ['January']
# ('0975-007', 3, 5)
# ['June', 'Comelf']
# ('0975-007', 6, 8)
# ['59', 'percent']
# ('0975-007', 14, 16)
# ['37.3', 'percent']
# ('0975-007', 17, 22)
# ['the', 'same', 'period', 'last', 'year']
# ('0975-012', 0, 4)
# ['--', 'Luli', 'Popescu', ',']
# ('0975-012', 4, 7)
# ['Bucharest', 'Newsroom', '40-1']
# ('0976-002', 0, 5)
# ['The', 'National', 'Bank', 'of', 'Poland']
# ('0976-005', 0, 4)
# ['--', 'Warsaw', 'Newsroom', '+48']
# ('0976-005', 4, 5)
# ['22']
# ('0977-000', 6, 7)
# ['week']
# ('0977-002', 9, 15)
# ['the', 'week', 'that', 'ended', 'August', '28']
# ('0977-002', 16, 20)
# ['the', 'Bank', 'of', 'Canada']
# ('0977-002', 22, 23)
# ['Friday']
# ('0977-007', 2, 3)
# ['152.80']
# ('0977-008', 3, 4)
# ['30.12']
# ('0977-008', 6, 7)
# ['+0.578']
# ('0977-012', 2, 4)
# ['639.55', '639.38']
# ('0977-013', 4, 6)
# ['107.83', '107.24']
# ('0977-019', 5, 6)
# ['613']
# ('0978-002', 5, 6)
# ['Friday']
# ('0978-002', 21, 23)
# ['about', '2,960,000']
# ('0978-003', 4, 5)
# ['1/8']
# ('0978-003', 6, 8)
# ['40', 'Friday']
# ('0978-005', 4, 5)
# ['312']
# ('0979-002', 0, 1)
# ['NYMEX']
# ('0979-002', 23, 26)
# ['Labor', 'Day', 'weekend']
# ('0979-011', 22, 27)
# ['the', 'Labor', 'Day', 'holiday', 'weekend']
# ('0979-012', 0, 1)
# ['NYMEX']
# ('0979-012', 4, 5)
# ['Monday']
# ('0979-013', 0, 4)
# ['--', 'Harry', 'Milling', ',']
# ('0980-002', 23, 30)
# ['the', 'August', 'National', 'Association', 'of', 'Purchasing', 'Management']
# ('0980-003', 1, 2)
# ['August']
# ('0980-003', 5, 6)
# ['8.8']
# ('0980-003', 8, 9)
# ['60.0']
# ('0980-003', 14, 15)
# ['62.6']
# ('0980-003', 16, 18)
# ['February', '1995']
# ('0980-003', 21, 22)
# ['monthly']
# ('0980-003', 24, 26)
# ['December', '1993']
# ('0980-004', 22, 23)
# ['51.9']
# ('0980-004', 24, 25)
# ['July']
# ('0980-004', 26, 27)
# ['51.2']
# ('0980-006', 0, 1)
# ['One']
# ('0980-006', 4, 5)
# ['35,000']
# ('0980-006', 5, 7)
# ['September', '97']
# ('0980-006', 15, 18)
# ['93.25', 'to', '93.30']
# ('0980-006', 21, 22)
# ['two']
# ('0980-006', 29, 30)
# ['4,000']
# ('0980-006', 30, 31)
# ['September']
# ('0980-006', 31, 32)
# ['93.30']
# ('0980-006', 33, 34)
# ['93.32']
# ('0980-009', 3, 6)
# ['the', 'Federal', 'Reserve']
# ('0980-013', 19, 22)
# ['the', 'Federal', 'Reserve']
# ('0980-013', 34, 36)
# ['September', '24']
# ('0980-015', 0, 4)
# ['Earlier', 'in', 'the', 'day']
# ('0980-015', 12, 13)
# ['annual']
# ('0980-015', 13, 15)
# ['Jackson', 'Hole']
# ('0980-016', 13, 14)
# ['July']
# ('0980-017', 15, 16)
# ['one']
# ('0980-019', 7, 8)
# ['December']
# ('0980-019', 11, 12)
# ['27/32']
# ('0980-019', 13, 14)
# ['106-25/32']
# ('0980-019', 18, 19)
# ['21/32']
# ('0980-019', 20, 21)
# ['105-17/32']
# ('0980-019', 24, 25)
# ['17/32']
# ('0980-019', 28, 30)
# ['December', 'Eurodollars']
# ('0980-019', 32, 33)
# ['11']
# ('0980-019', 35, 36)
# ['93.94']
# ('0980-019', 41, 42)
# ['13']
# ('0980-019', 44, 45)
# ['93.72']
# ('0980-019', 46, 47)
# ['March']
# ('0980-019', 50, 51)
# ['12']
# ('0980-019', 53, 54)
# ['94.33']
# ('0981-003', 8, 9)
# ['4-1/2']
# ('0981-003', 11, 12)
# ['Friday']
# ('0981-003', 12, 13)
# ['afternoon']
# ('0981-003', 14, 15)
# ['Thursday']
# ('0981-003', 33, 34)
# ['31']
# ('0981-003', 38, 41)
# ['$', '135', 'million']
# ('0981-004', 3, 4)
# ['1/8']
# ('0981-004', 5, 6)
# ['48-1/4']
# ('0981-004', 7, 12)
# ['the', 'New', 'York', 'Stock', 'Exchange']
# ('0981-005', 4, 6)
# ['4.45', 'million']
# ('0981-005', 26, 27)
# ['31']
# ('0981-007', 7, 8)
# ['1995']
# ('0981-007', 10, 13)
# ['$', '561', 'million']
# ('0981-008', 7, 9)
# ['these', 'days']
# ('0981-008', 11, 14)
# ['$', '500', 'million']
# ('0981-010', 3, 7)
# ['Douglas', '&', 'Lomason', "'s"]
# ('0981-011', 0, 4)
# ['Douglas', '&', 'Lomason', "'s"]
# ('0981-011', 8, 11)
# ['the', 'past', 'year']
# ('0981-013', 7, 8)
# ['2,300']
# ('0981-013', 18, 19)
# ['half']
# ('0981-013', 20, 24)
# ['the', 'next', 'five', 'years']
# ('0982-002', 17, 18)
# ['Friday']
# ('0982-002', 23, 24)
# ['Thursday']
# ('0982-005', 0, 4)
# ['--', 'Jim', 'Ballantyne', ',']
# ('0982-005', 7, 8)
# ['171']
# ('0983-002', 0, 1)
# ['Seven']
# ('0983-002', 8, 9)
# ['199']
# ('0983-002', 20, 21)
# ['Friday']
# ('0983-003', 3, 4)
# ['seven']
# ('0983-003', 19, 20)
# ['Tuesday']
# ('0983-003', 31, 32)
# ['Saturday']
# ('0983-004', 29, 30)
# ['seven']
# ('0983-005', 20, 21)
# ['seven']
# ('0983-006', 4, 5)
# ['Monday']
# ('0984-002', 14, 15)
# ['Friday']
# ('0984-003', 0, 3)
# ['GERMANY', '-', 'Bunds']
# ('0984-004', 1, 2)
# ['September']
# ('0984-004', 5, 13)
# ['the', 'London', 'International', 'Financial', 'Futures', 'and', 'Options', 'Exchange']
# ('0984-004', 19, 20)
# ['97.18']
# ('0984-004', 22, 23)
# ['0.20']
# ('0984-004', 24, 25)
# ['Thursday']
# ('0984-005', 0, 3)
# ['BRITAIN', '-', 'Gilts']
# ('0984-005', 6, 7)
# ['day']
# ('0984-005', 11, 12)
# ['10/32']
# ('0984-005', 14, 16)
# ['the', 'day']
# ('0984-006', 12, 13)
# ['Chicago']
# ('0984-006', 28, 29)
# ['August']
# ('0984-006', 33, 34)
# ['PMI']
# ('0984-006', 37, 38)
# ['Monday']
# ('0984-007', 1, 2)
# ['September']
# ('0984-007', 10, 11)
# ['107-2/32']
# ('0984-007', 13, 14)
# ['8/32']
# ('0984-007', 15, 16)
# ['Thursday']
# ('0984-008', 7, 9)
# ['the', 'day']
# ('0984-009', 1, 2)
# ['September']
# ('0984-009', 12, 13)
# ['123.14']
# ('0984-009', 15, 16)
# ['0.04']
# ('0984-009', 17, 18)
# ['Thursday']
# ('0984-010', 9, 11)
# ['late', 'afternoon']
# ('0984-010', 24, 25)
# ['BTP']
# ('0984-011', 1, 2)
# ['September']
# ('0984-011', 9, 10)
# ['115.45']
# ('0984-011', 12, 13)
# ['0.13']
# ('0984-011', 14, 15)
# ['Thursday']
# ('0984-012', 13, 14)
# ['midday']
# ('0984-012', 18, 22)
# ['Chicago', 'Purchasing', 'Managers', "'"]
# ('0984-012', 28, 33)
# ['the', 'long', 'Labour', 'Day', 'weekend']
# ('0984-013', 1, 2)
# ['September']
# ('0984-013', 6, 11)
# ['the', 'Chicago', 'Board', 'of', 'Trade']
# ('0984-013', 17, 18)
# ['26/32']
# ('0984-013', 19, 20)
# ['Thursday']
# ('0984-015', 5, 6)
# ['182nd']
# ('0984-016', 0, 1)
# ['Japanese']
# ('0984-016', 14, 15)
# ['day']
# ('0984-016', 24, 25)
# ['day']
# ('0984-016', 28, 29)
# ['hours']
# ('0984-016', 31, 32)
# ['September']
# ('0984-016', 38, 39)
# ['122.53']
# ('0984-016', 41, 42)
# ['0.26']
# ('0984-016', 43, 44)
# ['Thursday']
# ('0984-016', 48, 52)
# ['the', 'Tokyo', 'Stock', 'Exchange']
# ('0984-017', 15, 16)
# ['Monday']
# ('0984-017', 22, 25)
# ['next', 'week', "'s"]
# ('0984-018', 4, 7)
# ['A$', '100', 'million']
# ('0984-019', 3, 5)
# ['275', 'million']
# ('0984-020', 4, 6)
# ['110', 'million']
# ('0984-020', 7, 9)
# ['step-up', 'bond']
# ('0984-021', 0, 2)
# ['Next', 'week']
# ('0985-002', 20, 21)
# ['Friday']
# ('0985-003', 13, 14)
# ['one']
# ('0985-004', 17, 18)
# ['March']
# ('0985-006', 3, 5)
# ['years', 'one']
# ('0985-006', 33, 34)
# ['Monday']
# ('0985-009', 2, 3)
# ['three']
# ('0985-009', 24, 26)
# ['September', '1995']
# ('0985-010', 4, 5)
# ['third']
# ('0985-011', 7, 8)
# ['first']
# ('0985-011', 12, 14)
# ['American', 'Tyson']
# ('0985-012', 17, 18)
# ['third']
# ('0986-000', 0, 3)
# ['Soccer', '-', 'McCarthy']
# ('0986-002', 6, 7)
# ['Friday']
# ('0986-002', 14, 15)
# ['Saturday']
# ('0986-003', 14, 15)
# ['18-year-old']
# ('0986-007', 0, 4)
# ['--', 'Dublin', 'Newsroom', '+353']
# ('0986-007', 4, 5)
# ['1']
# ('0987-002', 14, 15)
# ['eight']
# ('0987-002', 22, 26)
# ['the', 'national', 'news', 'agency']
# ('0987-002', 28, 29)
# ['Friday']
# ('0987-003', 12, 17)
# ['the', 'News', 'Agency', 'of', 'Nigeria']
# ('0988-002', 2, 6)
# ['Driefontein', 'Consolidated', 'Ltd', "'s"]
# ('0988-002', 16, 17)
# ['Wednesday']
# ('0988-002', 17, 18)
# ['night']
# ('0988-002', 21, 23)
# ['Gold', 'Fields']
# ('0988-002', 24, 27)
# ['South', 'Africa', 'Ltd']
# ('0988-002', 29, 30)
# ['Friday']
# ('0988-005', 0, 3)
# ['At', 'least', '17']
# ('0988-005', 17, 19)
# ['Driefontein', 'Consolidated']
# ('0988-005', 23, 27)
# ['Kloof', 'Gold', 'Mining', 'Co']
# ('0988-005', 27, 29)
# ['this', 'month']
# ('0988-006', 5, 7)
# ['482', '1003']
# ('0989-002', 9, 11)
# ['two', 'days']
# ('0989-002', 18, 19)
# ['Education']
# ('0989-002', 26, 28)
# ['four', 'hours']
# ('0989-002', 33, 34)
# ['Friday']
# ('0990-000', 2, 4)
# ['Lebed', 'Chechnya']
# ('0990-002', 7, 8)
# ['Friday']
# ('0990-002', 23, 26)
# ['Alexander', 'Lebed', "'s"]
# ('0990-003', 11, 14)
# ['Interfax', 'quoted', 'Chernomyrdin']
# ('0990-005', 9, 10)
# ['yesterday']
# ('0990-006', 18, 20)
# ['last', 'week']
# ('0990-006', 28, 32)
# ['more', 'than', 'a', 'year']
# ('0990-008', 3, 4)
# ['Friday']
# ('0990-008', 15, 17)
# ['the', 'day']
# ('0990-009', 11, 14)
# ['the', 'Russian', 'Federation']
# ('0990-009', 21, 23)
# ['December', '1994']
# ('0990-011', 26, 30)
# ['up', 'to', '10', 'years']
# ('0990-012', 11, 12)
# ['Thursday']
# ('0990-014', 3, 4)
# ['Thursday']
# ('0991-002', 14, 15)
# ['overnight']
# ('0991-002', 27, 31)
# ['December', '31', ',', '2001']
# ('0991-003', 15, 18)
# ['the', 'Russian', 'Federation']
# ('0991-003', 19, 22)
# ['the', 'Chechen', 'Republic']
# ('0991-006', 9, 13)
# ['more', 'than', 'five', 'years']
# ('0991-008', 0, 3)
# ['Tens', 'of', 'thousands']
# ('0991-008', 13, 15)
# ['late', '1994']
# ('0991-011', 6, 7)
# ['Friday']
# ('0992-002', 7, 8)
# ['Friday']
# ('0992-003', 10, 11)
# ['State']
# ('0992-003', 33, 34)
# ['Friday']
# ('0992-006', 0, 2)
# ['Election', 'day']
# ('0992-006', 8, 10)
# ['September', '14']
# ('0992-007', 0, 5)
# ['The', 'Party', 'of', 'Democratic', 'Action']
# ('0992-007', 11, 12)
# ['Wednesday']
# ('0992-008', 0, 8)
# ['The', 'Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('0992-009', 5, 6)
# ['two']
# ('0993-002', 17, 21)
# ['September', '21', 'to', '26']
# ('0993-002', 30, 31)
# ['Friday']
# ('0993-005', 9, 11)
# ['120', 'hours']
# ('0993-005', 14, 16)
# ['20', 'million']
# ('0993-007', 0, 4)
# ['--', 'Amra', 'Kevic', ',']
# ('0993-007', 7, 9)
# ['11', '2224305']
# ('0994-003', 9, 10)
# ['Friday']
# ('0994-003', 20, 22)
# ['Soviet', 'republic']
# ('0994-004', 26, 28)
# ['November', '7']
# ('0994-005', 21, 23)
# ['10', 'million']
# ('0994-010', 2, 3)
# ['41']
# ('0994-010', 8, 9)
# ['1994']
# ('0994-010', 31, 34)
# ['the', 'Soviet', 'Union']
# ('0994-014', 7, 8)
# ['April']
# ('0994-016', 11, 13)
# ['nearly', '200']
# ('0994-017', 0, 3)
# ['The', 'United', 'States']
# ('0994-017', 3, 5)
# ['last', 'week']
# ('0994-017', 9, 10)
# ['two']
# ('0995-003', 29, 30)
# ['Friday']
# ('0995-005', 9, 11)
# ['August', '23']
# ('0995-006', 6, 9)
# ['about', 'three', 'km']
# ('0995-006', 10, 12)
# ['two', 'miles']
# ('0995-007', 2, 4)
# ['200', 'km']
# ('0995-007', 5, 7)
# ['120', 'miles']
# ('0995-011', 0, 3)
# ['Tens', 'of', 'thousands']
# ('0995-019', 0, 1)
# ['One']
# ('0995-019', 12, 13)
# ['two']
# ('0995-019', 24, 25)
# ['two']
# ('0996-002', 10, 14)
# ['September', '3', 'and', '4']
# ('0996-002', 20, 21)
# ['two']
# ('0996-002', 27, 28)
# ['1992']
# ('0996-002', 29, 32)
# ['PAP', 'news', 'agency']
# ('0996-002', 34, 35)
# ['Friday']
# ('0996-003', 5, 6)
# ['two']
# ('0996-004', 0, 5)
# ['The', 'Federal', 'Republic', 'of', 'Yugoslavia']
# ('0996-007', 10, 11)
# ['April']
# ('0997-000', 5, 8)
# ['hospital', '-', 'Interfax']
# ('0997-002', 11, 12)
# ['Friday']
# ('0997-002', 12, 13)
# ['evening']
# ('0997-003', 6, 8)
# ['last', 'Saturday']
# ('0997-004', 15, 16)
# ['first']
# ('0997-006', 18, 20)
# ['last', 'year']
# ('0997-007', 2, 3)
# ['65']
# ('0997-007', 15, 16)
# ['second']
# ('0997-007', 20, 22)
# ['July', '3']
# ('0997-008', 10, 12)
# ['the', 'night']
# ('0997-009', 6, 7)
# ['Saturday']
# ('0997-009', 15, 18)
# ['some', '100', 'km']
# ('0997-009', 19, 21)
# ['60', 'miles']
# ('0998-002', 19, 20)
# ['Friday']
# ('0998-003', 6, 10)
# ['earlier', 'in', 'the', 'day']
# ('0998-003', 29, 32)
# ['tens', 'of', 'thousands']
# ('0999-000', 5, 8)
# ['over', '$', '7']
# ('0999-002', 15, 16)
# ['Friday']
# ('0999-002', 23, 25)
# ['seven', 'dollars']
# ('0999-003', 6, 7)
# ['28']
# ('0999-003', 9, 10)
# ['Thursday']
# ('0999-003', 25, 26)
# ['41']
# ('0999-003', 36, 38)
# ['38,000', 'roubles']
# ('0999-003', 39, 41)
# ['seven', 'dollars']
# ('0999-004', 0, 3)
# ['The', 'next', 'morning']
# ('1000-001', 0, 1)
# ['Emese']
# ('1000-003', 11, 15)
# ['the', 'Budapest', 'Stock', 'Exchange']
# ('1000-003', 19, 20)
# ['Friday']
# ('1000-004', 2, 5)
# ['Global', 'Depositary', 'Receipts']
# ('1000-004', 10, 11)
# ['5,200']
# ('1000-004', 17, 18)
# ['600']
# ('1000-004', 19, 20)
# ['Thursday']
# ('1000-004', 28, 29)
# ['first']
# ('1000-004', 29, 30)
# ['half']
# ('1000-004', 31, 33)
# ['this', 'morning']
# ('1000-005', 13, 14)
# ['Friday']
# ('1000-005', 25, 26)
# ['second']
# ('1000-005', 38, 39)
# ['annual']
# ('1000-006', 7, 11)
# ['37', 'million', 'French', 'franc']
# ('1000-008', 7, 10)
# ['the', 'full', 'year']
# ('1000-008', 17, 19)
# ['next', 'week']
# ('1000-009', 3, 4)
# ['first']
# ('1000-009', 16, 17)
# ['first']
# ('1000-009', 17, 18)
# ['half']
# ('1000-009', 20, 21)
# ['IAS']
# ('1000-009', 22, 24)
# ['this', 'morning']
# ('1000-010', 20, 21)
# ['6,425']
# ('1000-014', 10, 13)
# ['the', 'Czech', 'Republic']
# ('1000-014', 21, 25)
# ['21.8', 'million', 'French', 'francs']
# ('1000-014', 27, 29)
# ['34.1', 'million']
# ('1000-014', 30, 36)
# ['the', 'same', 'six', 'months', 'of', '1995']
# ('1000-015', 5, 6)
# ['1996']
# ('1000-015', 8, 12)
# ['2.1', 'million', 'French', 'francs']
# ('1000-015', 15, 17)
# ['10.3', 'million']
# ('1000-015', 18, 24)
# ['the', 'first', 'six', 'months', 'of', '1995']
# ('1000-015', 38, 39)
# ['one']
# ('1000-019', 4, 6)
# ['36', '1']
# ('1000-019', 7, 8)
# ['327']
# ('1001-000', 7, 8)
# ['50.19']
# ('1001-000', 8, 9)
# ['pct']
# ('1001-002', 0, 5)
# ['The', 'National', 'Bank', 'of', 'Romania']
# ('1001-002', 16, 18)
# ['this', 'week']
# ('1001-002', 19, 21)
# ['50.19', 'percent']
# ('1001-002', 22, 24)
# ['49', 'percent']
# ('1001-002', 25, 26)
# ['two']
# ('1001-002', 33, 34)
# ['Thursday']
# ('1001-003', 1, 2)
# ['two']
# ('1001-003', 6, 8)
# ['497.5', 'billion']
# ('1001-003', 13, 17)
# ['49', 'to', '51', 'percent']
# ('1001-003', 24, 27)
# ['420', 'billion', 'lei']
# ('1001-006', 0, 5)
# ['--', 'Bucharest', 'Newsroom', '40-1', '3120264']
# ('1002-001', 3, 4)
# ['1996-08-30']
# ('1002-002', 0, 1)
# ['Eight']
# ('1002-002', 18, 19)
# ['Friday']
# ('1002-002', 20, 22)
# ['about', 'two']
# ('1002-003', 10, 13)
# ['the', 'Municipal', 'Police']
# ('1003-001', 3, 4)
# ['1996-08-30']
# ('1003-002', 10, 11)
# ['Friday']
# ('1003-003', 7, 9)
# ['10', 'days']
# ('1003-003', 37, 39)
# ['56', 'miles']
# ('1003-003', 40, 42)
# ['90', 'km']
# ('1003-004', 2, 3)
# ['35']
# ('1003-005', 3, 4)
# ['second']
# ('1003-005', 13, 17)
# ['less', 'than', 'two', 'years']
# ('1003-007', 15, 18)
# ['the', 'late', '1980s']
# ('1004-002', 4, 5)
# ['Sihanouk']
# ('1004-002', 6, 7)
# ['Friday']
# ('1004-003', 6, 12)
# ['the', 'Sereipheap', 'Thmei', '(', 'New', 'Liberty']
# ('1004-003', 26, 29)
# ['late', 'Friday', 'afternoon']
# ('1004-004', 0, 3)
# ['The', 'Supreme', 'Court']
# ('1004-004', 5, 7)
# ['August', '23']
# ('1004-004', 31, 34)
# ['five', 'million', 'riels']
# ('1004-004', 36, 37)
# ['2,000']
# ('1004-004', 40, 43)
# ['one', 'year', "'s"]
# ('1004-005', 8, 11)
# ['Hen', 'Vipheak', "'s"]
# ('1004-007', 23, 25)
# ['a', 'week']
# ('1004-007', 31, 32)
# ['June']
# ('1004-008', 8, 11)
# ['earlier', 'this', 'week']
# ('1005-000', 0, 5)
# ['Far', 'East', 'Gold', '-', 'Moribund']
# ('1005-003', 13, 15)
# ['this', 'week']
# ('1005-003', 18, 19)
# ['Friday']
# ('1005-003', 20, 22)
# ['next', 'week']
# ('1005-004', 13, 17)
# ['the', 'previous', 'week', "'s"]
# ('1005-004', 38, 41)
# ['the', 'fourth', 'quarter']
# ('1005-005', 10, 13)
# ['between', '25-45', 'cents']
# ('1005-005', 30, 32)
# ['10-20', 'cents']
# ('1005-006', 28, 30)
# ['recent', 'months']
# ('1005-008', 19, 20)
# ['one']
# ('1005-009', 9, 12)
# ['next', 'year', "'s"]
# ('1005-010', 5, 6)
# ['387.00']
# ('1005-010', 8, 9)
# ['387.50']
# ('1005-010', 15, 16)
# ['Friday']
# ('1005-010', 18, 21)
# ['New', 'York', "'s"]
# ('1005-010', 22, 23)
# ['387.60']
# ('1005-010', 25, 26)
# ['388']
# ('1005-010', 28, 29)
# ['Thursday']
# ('1005-011', 10, 14)
# ['the', 'International', 'Monetary', 'Fund']
# ('1005-014', 4, 5)
# ['September']
# ('1005-014', 7, 10)
# ['New', 'York', "'s"]
# ('1005-014', 10, 11)
# ['Comex']
# ('1005-014', 19, 25)
# ['between', '$', '5.12', '-', '$', '5.15']
# ('1005-014', 32, 33)
# ['5.25']
# ('1005-014', 35, 36)
# ['5.30']
# ('1005-015', 0, 1)
# ['September']
# ('1005-015', 5, 6)
# ['0.004']
# ('1005-015', 10, 11)
# ['Thursday']
# ('1005-015', 13, 14)
# ['5.255']
# ('1006-003', 10, 15)
# ['Sunday', 'of', 'the', '27th', 'anniversary']
# ('1006-004', 5, 9)
# ['the', '"', 'great', 'revolution']
# ('1006-004', 27, 28)
# ['two']
# ('1006-004', 34, 35)
# ['1988']
# ('1006-005', 15, 16)
# ['one']
# ('1006-006', 15, 16)
# ['Sunday']
# ('1006-007', 0, 1)
# ['Three']
# ('1006-007', 18, 22)
# ['September', '1', ',', '1969']
# ('1006-007', 33, 34)
# ['27-year-old']
# ('1006-007', 37, 40)
# ['King', 'Mohammed', 'Idris']
# ('1006-009', 24, 25)
# ['42']
# ('1006-009', 33, 34)
# ['Friday']
# ('1006-011', 11, 12)
# ['July']
# ('1006-013', 0, 3)
# ['At', 'least', '20']
# ('1006-013', 10, 12)
# ['early', 'July']
# ('1006-014', 12, 14)
# ['last', 'year']
# ('1006-014', 15, 16)
# ['thousands']
# ('1007-004', 23, 26)
# ['billions', 'of', 'dollars']
# ('1007-005', 22, 25)
# ['the', 'Federal', 'Reserve']
# ('1007-010', 0, 2)
# ['This', 'week']
# ('1007-010', 15, 17)
# ['15', 'percent']
# ('1007-010', 29, 32)
# ['$', '548', 'billion']
# ('1007-011', 3, 6)
# ['$', '8.4', 'billion']
# ('1007-012', 11, 14)
# ['the', 'White', 'House']
# ('1007-013', 13, 14)
# ['year']
# ('1007-016', 0, 3)
# ['Ronald', 'Reagan', "'s"]
# ('1007-016', 8, 9)
# ['second']
# ('1007-016', 12, 15)
# ['the', 'White', 'House']
# ('1007-016', 16, 17)
# ['1984']
# ('1007-017', 5, 6)
# ['1988']
# ('1007-017', 14, 15)
# ['1992']
# ('1007-018', 33, 39)
# ['between', '4', 'percent', 'and', '5', 'percent']
# ('1007-018', 40, 45)
# ['the', 'end', 'of', 'the', 'decade']
# ('1007-022', 4, 6)
# ['this', 'summer']
# ('1007-022', 17, 18)
# ['5,778.00']
# ('1007-022', 20, 22)
# ['May', '22']
# ('1007-025', 4, 5)
# ['one']
# ('1007-028', 39, 40)
# ['November']
# ('1007-029', 1, 2)
# ['Friday']
# ('1007-029', 9, 10)
# ['31.44']
# ('1007-029', 12, 13)
# ['5,616.21']
# ('1007-031', 5, 6)
# ['3.53']
# ('1007-031', 8, 9)
# ['Friday']
# ('1007-031', 10, 11)
# ['1,141.50']
# ('1007-033', 0, 5)
# ['The', 'Standard', '&', 'Poor', "'s"]
# ('1007-033', 7, 8)
# ['500']
# ('1007-033', 11, 12)
# ['5.41']
# ('1007-033', 14, 15)
# ['651.99']
# ('1007-033', 17, 18)
# ['15.03']
# ('1007-033', 20, 22)
# ['the', 'week']
# ('1007-034', 0, 4)
# ['The', 'American', 'Stock', 'Exchange']
# ('1007-034', 7, 8)
# ['1.66']
# ('1007-034', 10, 11)
# ['559.68']
# ('1007-034', 15, 16)
# ['1.26']
# ('1007-034', 17, 19)
# ['the', 'week']
# ('1008-003', 4, 5)
# ['July']
# ('1008-003', 12, 13)
# ['August']
# ('1008-003', 16, 17)
# ['Friday']
# ('1008-003', 27, 31)
# ['a', 'second', 'straight', 'day']
# ('1008-004', 0, 3)
# ['The', 'Commerce', 'Department']
# ('1008-004', 9, 11)
# ['1.8', 'percent']
# ('1008-004', 12, 13)
# ['July']
# ('1008-004', 15, 16)
# ['seasonally']
# ('1008-004', 17, 20)
# ['$', '317.6', 'billion']
# ('1008-006', 25, 26)
# ['60']
# ('1008-006', 27, 28)
# ['August']
# ('1008-006', 29, 30)
# ['51.2']
# ('1008-006', 31, 32)
# ['July']
# ('1008-009', 12, 15)
# ['the', 'third', 'quarter']
# ('1008-009', 21, 23)
# ['the', 'spring']
# ('1008-009', 29, 33)
# ['late', 'June', 'and', 'July']
# ('1008-010', 4, 5)
# ['August']
# ('1008-011', 20, 22)
# ['next', 'month']
# ('1008-011', 38, 41)
# ['a', 'second', 'day']
# ('1008-012', 23, 25)
# ['7.12', 'percent']
# ('1008-012', 26, 28)
# ['7.04', 'percent']
# ('1008-012', 28, 30)
# ['late', 'Thursday']
# ('1008-013', 6, 7)
# ['31.44']
# ('1008-013', 9, 10)
# ['5,616.21']
# ('1008-013', 12, 13)
# ['64.73-point']
# ('1008-013', 14, 15)
# ['Thursday']
# ('1008-014', 1, 2)
# ['third']
# ('1008-014', 4, 7)
# ['the', 'Commerce', 'Department']
# ('1008-014', 9, 10)
# ['July']
# ('1008-014', 32, 35)
# ['the', 'second', 'half']
# ('1008-018', 4, 7)
# ['First', 'Union', 'bank']
# ('1008-018', 27, 30)
# ['the', 'third', 'quarter']
# ('1008-018', 32, 35)
# ['the', 'first', 'half']
# ('1008-020', 7, 8)
# ['Sept']
# ('1008-023', 9, 10)
# ['Friday']
# ('1008-027', 0, 5)
# ['The', 'University', 'of', 'Michigan', "'s"]
# ('1008-027', 5, 6)
# ['August']
# ('1008-027', 14, 15)
# ['Friday']
# ('1008-027', 21, 22)
# ['95.3']
# ('1008-027', 23, 24)
# ['94.7']
# ('1008-027', 25, 26)
# ['July']
# ('1008-029', 10, 13)
# ['the', '4.8', 'percent']
# ('1008-029', 14, 15)
# ['annual']
# ('1008-029', 21, 24)
# ['the', 'second', 'quarter']
# ('1008-029', 33, 35)
# ['3', 'percent']
# ('1008-029', 42, 45)
# ['the', '2', 'percent']
# ('1008-029', 46, 48)
# ['2-1/4', 'percent']
# ('1009-003', 5, 6)
# ['Friday']
# ('1009-003', 38, 39)
# ['today']
# ('1009-004', 15, 17)
# ['another', 'year']
# ('1009-004', 27, 28)
# ['Agriculture']
# ('1009-005', 6, 7)
# ['tomorrow']
# ('1009-007', 0, 3)
# ['The', 'Agriculture', 'Department']
# ('1009-007', 4, 9)
# ['more', 'than', 'a', 'year', 'ago']
# ('1009-008', 16, 17)
# ['19']
# ('1009-008', 19, 20)
# ['Northeastern']
# ('1009-008', 22, 25)
# ['November', 'through', 'February']
# ('1009-010', 18, 21)
# ['$', '1', 'billion']
# ('1009-011', 23, 27)
# ['the', 'World', 'Trade', 'Organisation']
# ('1009-015', 0, 4)
# ['The', 'California', 'Avocado', 'Commission']
# ('1009-015', 22, 25)
# ['the', 'Agriculture', 'Department']
# ('1009-015', 25, 27)
# ['last', 'spring']
# ('1009-018', 30, 34)
# ['the', 'California', 'avocado', 'group']
# ('1009-020', 10, 14)
# ['the', 'Agriculture', 'Department', "'s"]
# ('1010-002', 16, 17)
# ['Friday']
# ('1010-002', 29, 33)
# ['a', 'year', 'or', 'less']
# ('1010-003', 2, 3)
# ['68']
# ('1010-003', 11, 13)
# ['June', '1995']
# ('1010-003', 15, 16)
# ['months']
# ('1010-005', 13, 17)
# ['one', 'year', 'or', 'less']
# ('1010-006', 1, 3)
# ['14', 'years']
# ('1010-016', 24, 26)
# ['2.3', 'million']
# ('1010-016', 29, 30)
# ['1982']
# ('1010-017', 36, 37)
# ['1993']
# ('1010-017', 46, 48)
# ['the', '1970s']
# ('1010-019', 9, 11)
# ['last', 'year']
# ('1010-020', 8, 9)
# ['1972']
# ('1010-021', 0, 2)
# ['This', 'month']
# ('1011-000', 0, 1)
# ['Boatmen']
# ('1011-003', 1, 4)
# ['$', '9.5', 'billion']
# ('1011-003', 27, 29)
# ['last', 'year']
# ('1011-006', 0, 5)
# ['St.', 'Louis-based', 'Mercantile', 'Bancorp', 'Inc.']
# ('1011-006', 11, 14)
# ['$', '18.04', 'billion']
# ('1011-006', 31, 32)
# ['Boatmen']
# ('1011-007', 9, 12)
# ['$', '9.32', 'billion']
# ('1011-008', 6, 9)
# ['Mercantile', ',', 'Commerce']
# ('1011-009', 6, 9)
# ['$', '9.33', 'billion']
# ('1011-016', 0, 1)
# ['Boatmen']
# ('1011-016', 16, 18)
# ['last', 'year']
# ('1011-019', 9, 11)
# ['40', 'percent']
# ('1011-019', 12, 13)
# ['Boatmen']
# ('1011-020', 3, 4)
# ['Boatmen']
# ('1011-022', 15, 16)
# ['Boatmen']
# ('1012-002', 0, 3)
# ['The', 'State', 'Department']
# ('1012-002', 7, 8)
# ['Friday']
# ('1012-002', 28, 29)
# ['250,000']
# ('1012-006', 0, 4)
# ['The', 'U.S.', 'Treasury', 'Department']
# ('1012-006', 5, 6)
# ['Wednesday']
# ('1012-006', 14, 15)
# ['250,000']
# ('1012-006', 18, 21)
# ['$', '1', 'billion']
# ('1012-006', 38, 40)
# ['last', 'January']
# ('1012-007', 2, 5)
# ['last', 'October', "'s"]
# ('1012-007', 10, 11)
# ['thousands']
# ('1012-008', 0, 3)
# ['The', 'Treasury', 'Department']
# ('1012-008', 30, 31)
# ['1988']
# ('1012-008', 33, 35)
# ['Pan', 'Am']
# ('1012-008', 36, 37)
# ['103']
# ('1013-000', 0, 1)
# ['U.S.']
# ('1013-000', 5, 7)
# ['one', 'to']
# ('1013-000', 7, 8)
# ['162']
# ('1013-000', 9, 10)
# ['week']
# ('1013-002', 2, 3)
# ['162']
# ('1013-002', 7, 10)
# ['the', 'U.S.', 'Gulf']
# ('1013-002', 12, 14)
# ['August', '30']
# ('1013-002', 16, 17)
# ['one']
# ('1013-002', 18, 21)
# ['the', 'prior', 'week']
# ('1013-003', 16, 17)
# ['181']
# ('1013-003', 19, 21)
# ['89.5', 'percent']
# ('1013-004', 6, 9)
# ['European', '/', 'Mediterranean']
# ('1013-004', 11, 13)
# ['this', 'week']
# ('1013-004', 15, 16)
# ['105']
# ('1013-004', 25, 26)
# ['105']
# ('1013-004', 31, 33)
# ['100', 'percent']
# ('1013-006', 5, 6)
# ['212-859-1620']
# ('1014-003', 6, 7)
# ['Friday']
# ('1014-004', 1, 3)
# ...
# ['S.', 'African', 'Afrikaners']
# ('1124-002', 3, 4)
# ['Afrikaners']
# ('1124-002', 5, 6)
# ['Saturday']
# ('1124-003', 5, 9)
# ['the', 'Freedom', 'Front', 'party']
# ('1124-006', 7, 8)
# ['1994']
# ('1124-006', 15, 16)
# ['first']
# ('1124-006', 19, 23)
# ['April', 'of', 'that', 'year']
# ('1124-009', 5, 8)
# ['South', 'Africa', "'s"]
# ('1124-010', 19, 22)
# ['the', 'Northern', 'Cape']
# ('1124-010', 32, 33)
# ['Coloureds']
# ('1125-002', 7, 8)
# ['Saturday']
# ('1125-002', 20, 21)
# ['Sunday']
# ('1125-003', 10, 11)
# ['Rwanda']
# ('1125-006', 3, 6)
# ['more', 'than', '1,000']
# ('1125-006', 15, 16)
# ['Sunday']
# ('1125-006', 17, 18)
# ['Tuesday']
# ('1125-006', 21, 22)
# ['727,000']
# ('1125-006', 27, 29)
# ['eastern', 'Zairean']
# ('1125-007', 0, 3)
# ['Only', 'about', '100']
# ('1125-007', 15, 16)
# ['600']
# ('1125-007', 21, 22)
# ['weekly']
# ('1125-008', 15, 17)
# ['last', 'week']
# ('1125-008', 36, 38)
# ['1.1', 'million']
# ('1125-010', 9, 10)
# ['days']
# ('1125-011', 3, 4)
# ['15,000']
# ('1125-011', 6, 9)
# ['August', 'last', 'year']
# ('1125-012', 3, 5)
# ['1.1', 'million']
# ('1125-012', 5, 7)
# ['Rwandan', 'Hutu']
# ('1125-012', 11, 13)
# ['nearly', '600,000']
# ('1125-012', 26, 27)
# ['1994']
# ('1125-012', 31, 35)
# ['up', 'to', 'a', 'million']
# ('1126-001', 2, 4)
# ['Bosnia', '1996-08-31']
# ('1126-002', 9, 11)
# ['about', '75']
# ('1126-002', 24, 25)
# ['Saturday']
# ('1126-002', 26, 28)
# ['two', 'days']
# ('1126-004', 1, 3)
# ['up', 'to']
# ('1126-004', 16, 19)
# ['Lieutenant-Colonel', 'Max', 'Marriner']
# ('1126-008', 8, 12)
# ['earlier', 'in', 'the', 'week']
# ('1126-009', 12, 13)
# ['Thursday']
# ('1126-010', 7, 8)
# ['Saturday']
# ('1126-010', 8, 9)
# ['morning']
# ('1127-003', 20, 21)
# ['Saturday']
# ('1127-004', 0, 4)
# ['More', 'than', 'a', 'thousand']
# ('1127-004', 22, 23)
# ['Saturday']
# ('1127-004', 37, 39)
# ['25', 'km']
# ('1127-004', 40, 42)
# ['12', 'miles']
# ('1127-006', 17, 18)
# ['1991']
# ('1127-008', 24, 29)
# ['the', 'early', 'hours', 'of', 'Saturday']
# ('1127-009', 11, 13)
# ['December', '1994']
# ('1127-012', 9, 10)
# ['30-year-old']
# ('1127-013', 5, 6)
# ['10-year-old']
# ('1127-018', 4, 8)
# ['his', 'late', '20', "'s"]
# ('1127-019', 1, 2)
# ['Two']
# ('1127-022', 37, 40)
# ['Freedom', 'for', 'Chechnya']
# ('1128-002', 4, 9)
# ['the', 'Bank', 'Rozwoju', 'Exportu', 'SA']
# ('1128-002', 31, 32)
# ['daily']
# ('1128-002', 34, 35)
# ['Saturday']
# ('1128-003', 28, 32)
# ['about', '$', '120', 'million']
# ('1128-004', 3, 5)
# ['40', 'percent']
# ('1128-004', 14, 16)
# ['20', 'percent']
# ('1128-004', 17, 19)
# ['Ruch', 'and']
# ('1128-004', 19, 21)
# ['40', 'percent']
# ('1128-004', 25, 29)
# ['the', 'Warsaw', 'stock', 'exchange']
# ('1128-006', 13, 18)
# ['more', 'than', 'than', '50', 'percent']
# ('1128-006', 36, 37)
# ['September']
# ('1128-006', 39, 40)
# ['daily']
# ('1128-007', 0, 1)
# ['News-stand']
# ('1128-007', 6, 9)
# ['about', '65', 'percent']
# ('1128-007', 21, 24)
# ['16.2', 'million', 'zlotys']
# ('1128-007', 27, 30)
# ['2.7', 'billion', 'zlotys']
# ('1128-007', 31, 32)
# ['1995']
# ('1128-009', 19, 20)
# ['Monday']
# ('1128-010', 4, 7)
# ['$', '200', 'million']
# ('1128-010', 10, 12)
# ['five', 'years']
# ('1128-011', 5, 7)
# ['75', 'percent']
# ('1128-011', 11, 12)
# ['March']
# ('1128-012', 0, 1)
# ['Two']
# ('1128-014', 3, 4)
# ['May']
# ('1128-014', 8, 10)
# ['only', 'one']
# ('1128-014', 24, 28)
# ['up', 'to', '35', 'percent']
# ('1128-015', 0, 4)
# ['--', 'Anthony', 'Barker', '+48']
# ('1128-015', 4, 6)
# ['22', '653']
# ('1129-000', 0, 1)
# ['Three']
# ('1129-002', 0, 1)
# ['Three']
# ('1129-002', 6, 7)
# ['Saturday']
# ('1129-003', 11, 12)
# ['Sergiyev']
# ('1129-003', 13, 15)
# ['70', 'km']
# ('1129-003', 16, 18)
# ['45', 'miles']
# ('1129-004', 7, 8)
# ['two']
# ('1130-000', 7, 8)
# ['79']
# ('1130-002', 0, 1)
# ['One']
# ('1130-002', 14, 18)
# ['the', 'age', 'of', '79']
# ('1130-002', 25, 26)
# ['Saturday']
# ('1130-003', 0, 2)
# ['Puig', "'s"]
# ('1130-003', 2, 3)
# ['first']
# ('1130-003', 13, 14)
# ['1960']
# ('1130-003', 15, 17)
# ['a', 'year']
# ('1130-004', 8, 9)
# ['40']
# ('1130-005', 10, 14)
# ['the', 'Year', 'of', 'January']
# ('1130-005', 16, 17)
# ['1963']
# ('1130-005', 32, 33)
# ['1975']
# ('1130-005', 41, 42)
# ['1977']
# ('1130-005', 51, 52)
# ['1982']
# ('1130-006', 3, 8)
# ['Sleeping', 'Bread', '"', 'Puig', "'s"]
# ('1130-010', 10, 11)
# ['Saturday']
# ('1131-002', 4, 7)
# ['the', 'United', 'Nations']
# ('1131-002', 14, 16)
# ['late', 'Friday']
# ('1131-003', 8, 9)
# ['Monday']
# ('1131-004', 1, 2)
# ['two']
# ('1131-004', 10, 13)
# ['the', 'United', 'States']
# ('1131-005', 11, 13)
# ['the', 'weekend']
# ('1131-006', 6, 7)
# ['Monday']
# ('1131-006', 12, 14)
# ['that', 'day']
# ('1132-001', 0, 1)
# ['MEXICO']
# ('1132-002', 17, 18)
# ['Friday']
# ('1132-002', 20, 21)
# ['one']
# ('1132-002', 24, 25)
# ['two']
# ('1132-003', 13, 15)
# ['80', 'km']
# ('1132-003', 16, 18)
# ['50', 'miles']
# ('1132-003', 28, 31)
# ['40', 'to', '50']
# ('1132-007', 3, 5)
# ['a', 'day']
# ('1132-007', 20, 23)
# ['at', 'least', 'three']
# ('1132-007', 27, 30)
# ['up', 'to', '14']
# ('1132-007', 33, 35)
# ['about', '20']
# ('1133-001', 0, 2)
# ['MANILA', '1996-08-31']
# ('1133-002', 34, 35)
# ['Saturday']
# ('1133-003', 13, 14)
# ['China']
# ('1133-003', 20, 21)
# ['Friday']
# ('1133-003', 36, 37)
# ['thousands']
# ('1133-003', 39, 40)
# ['hundreds']
# ('1133-004', 6, 7)
# ['dozens']
# ('1133-004', 23, 27)
# ['the', 'Communist', 'Party', "'s"]
# ('1133-007', 2, 3)
# ['one']
# ('1133-007', 15, 16)
# ['May']
# ('1133-008', 12, 13)
# ['one']
# ('1133-012', 2, 3)
# ['45']
# ('1133-012', 6, 8)
# ['last', 'month']
# ('1133-012', 9, 12)
# ['one', 'year', "'s"]
# ('1134-001', 0, 2)
# ['MANILA', '1996-08-31']
# ('1134-002', 11, 18)
# ['the', 'Organisation', 'of', 'Islamic', 'Conference', '(', 'OIC']
# ('1134-002', 20, 21)
# ['Saturday']
# ('1134-005', 18, 20)
# ['last', 'Friday']
# ('1134-006', 10, 11)
# ['Monday']
# ('1134-008', 3, 6)
# ['more', 'than', '125,000']
# ('1134-008', 12, 18)
# ['over', 'a', 'quarter', 'of', 'a', 'century']
# ('1135-003', 14, 15)
# ['Saturday']
# ('1135-005', 3, 6)
# ['at', 'least', '61']
# ('1135-005', 12, 13)
# ['May']
# ('1135-005', 15, 17)
# ['about', '30']
# ('1135-006', 1, 2)
# ['May']
# ('1135-006', 15, 16)
# ['260']
# ('1135-006', 18, 21)
# ['Suu', 'Kyi', "'s"]
# ('1135-006', 32, 33)
# ['congress']
# ('1135-008', 3, 5)
# ['last', 'week']
# ('1135-008', 10, 11)
# ['nine']
# ('1135-008', 18, 19)
# ['May']
# ('1135-008', 22, 25)
# ['Suu', 'Kyi', "'s"]
# ('1135-010', 15, 20)
# ['the', 'middle', 'of', 'the', 'night']
# ('1135-013', 19, 21)
# ['six', 'years']
# ('1135-013', 28, 30)
# ['July', '1995']
# ('1135-015', 0, 3)
# ['The', 'NLD', 'party']
# ('1135-015', 9, 10)
# ['1990']
# ('1135-015', 12, 19)
# ['the', 'State', 'Law', 'and', 'Order', 'Restoration', 'Council']
# ('1135-015', 27, 28)
# ['1988']
# ('1135-024', 14, 16)
# ['early', 'August']
# ('1135-024', 21, 23)
# ['six', 'years']
# ('1135-025', 3, 5)
# ['five', 'weeks']
# ('1135-025', 6, 8)
# ['James', 'Leander']
# ('1135-025', 11, 12)
# ['Nichols']
# ('1136-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('1136-002', 0, 4)
# ['The', 'Dow', 'Chemical', 'Co']
# ('1136-002', 5, 8)
# ['the', 'United', 'States']
# ('1136-002', 10, 13)
# ['$', '4', 'billion']
# ('1136-002', 25, 28)
# ['the', 'China', 'Daily']
# ('1136-002', 30, 31)
# ['Saturday']
# ('1136-005', 16, 18)
# ['recent', 'years']
# ('1137-002', 4, 5)
# ['Saturday']
# ('1137-002', 26, 28)
# ['unification', 'ministry']
# ('1137-006', 9, 12)
# ['the', 'Korean', 'War']
# ('1137-006', 16, 20)
# ['more', 'than', '30', 'years']
# ('1137-007', 5, 9)
# ['the', 'International', 'Red', 'Cross']
# ('1137-007', 10, 11)
# ['1993']
# ('1137-008', 32, 35)
# ['the', 'Korean', 'War']
# ('1137-010', 3, 4)
# ['1993']
# ('1137-010', 22, 26)
# ['more', 'than', 'three', 'decades']
# ('1138-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('1138-002', 17, 18)
# ['China']
# ('1138-002', 20, 21)
# ['Saturday']
# ('1138-004', 8, 9)
# ['Friday']
# ('1138-008', 0, 2)
# ['Last', 'month']
# ('1138-008', 5, 6)
# ['45']
# ('1138-008', 12, 13)
# ['1979']
# ('1138-008', 13, 16)
# ['Democracy', 'Wall', 'movement']
# ('1138-008', 21, 23)
# ['one', 'year']
# ('1138-010', 4, 6)
# ['two', 'years']
# ('1138-010', 24, 28)
# ['June', '4', ',', '1989']
# ('1139-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('1139-002', 16, 17)
# ['China']
# ('1139-002', 19, 20)
# ['Saturday']
# ('1139-003', 4, 5)
# ['Friday']
# ('1139-006', 0, 2)
# ['Last', 'month']
# ('1139-006', 5, 6)
# ['45']
# ('1139-006', 12, 13)
# ['1979']
# ('1139-006', 13, 16)
# ['Democracy', 'Wall', 'movement']
# ('1139-006', 21, 23)
# ['one', 'year']
# ('1139-008', 4, 6)
# ['two', 'years']
# ('1139-008', 25, 29)
# ['June', '4', ',', '1989']
# ('1140-000', 3, 4)
# ['88-year-old']
# ('1140-002', 1, 2)
# ['88-year-old']
# ('1140-002', 7, 9)
# ['15', 'years']
# ('1140-002', 32, 33)
# ['Saturday']
# ('1140-003', 8, 9)
# ['five']
# ('1140-003', 15, 18)
# ['the', 'High', 'Court']
# ('1140-003', 21, 22)
# ['Friday']
# ('1140-003', 23, 27)
# ['the', 'Hong', 'Kong', 'Standard']
# ('1140-005', 9, 10)
# ['Nationalist']
# ('1140-005', 19, 20)
# ['1949']
# ('1140-005', 25, 27)
# ['42', 'kg']
# ('1140-005', 28, 30)
# ['92', 'pounds']
# ('1140-005', 39, 41)
# ['25', 'kg']
# ('1140-005', 42, 44)
# ['55', 'pounds']
# ('1141-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('1141-002', 0, 1)
# ['Two']
# ('1141-002', 20, 23)
# ['the', 'China', 'Daily']
# ('1141-002', 25, 26)
# ['Saturday']
# ('1141-003', 23, 25)
# ['September', '1']
# ('1141-006', 2, 6)
# ['more', 'than', '200', 'million']
# ('1141-007', 19, 23)
# ['the', 'end', 'of', '1996']
# ('1141-008', 3, 4)
# ['500,000']
# ('1141-008', 6, 8)
# ['each', 'day']
# ('1142-002', 3, 4)
# ['Saturday']
# ('1142-002', 22, 23)
# ['Iraqi']
# ('1142-002', 23, 24)
# ['Kurdish']
# ('1142-005', 12, 16)
# ['the', 'Kurdistan', 'Democratic', 'Party']
# ('1142-009', 32, 33)
# ['Saturday']
# ('1142-011', 19, 21)
# ['December', '1994']
# ('1142-013', 5, 6)
# ['Iraqi']
# ('1142-013', 6, 7)
# ['Kurdish']
# ('1142-013', 10, 14)
# ['the', '1991', 'Gulf', 'War']
# ('1142-014', 1, 3)
# ['allied', 'planes']
# ('1143-002', 17, 18)
# ['Sunday']
# ('1143-003', 3, 4)
# ['five']
# ('1143-003', 18, 21)
# ['the', 'United', 'States']
# ('1143-003', 25, 27)
# ['11', 'a.m.']
# ('1143-003', 38, 42)
# ['the', 'U.N.', 'Interim', 'Force']
# ('1143-003', 43, 44)
# ['Lebanon']
# ('1143-004', 15, 16)
# ['two']
# ('1143-005', 1, 3)
# ['August', '29']
# ('1143-005', 11, 12)
# ['Saturday']
# ('1143-006', 12, 14)
# ['April', '25']
# ('1143-006', 18, 20)
# ['17', 'days']
# ('1143-008', 0, 2)
# ['Around', '1,000']
# ('1143-008', 6, 8)
# ['15', 'km']
# ('1143-008', 22, 23)
# ['1985']
# ('1145-003', 10, 13)
# ['the', 'early', 'hours']
# ('1145-003', 14, 15)
# ['Saturday']
# ('1145-003', 16, 18)
# ['al-Daih', 'village']
# ('1145-003', 19, 21)
# ['five', 'km']
# ('1145-003', 22, 24)
# ['three', 'miles']
# ('1146-002', 9, 10)
# ['Saturday']
# ('1146-004', 1, 6)
# ['(', 'Patriotic', 'Union', 'of', 'Kurdistan']
# ('1146-005', 8, 9)
# ['first']
# ('1146-005', 20, 21)
# ['Iraqi']
# ('1146-005', 21, 22)
# ['Kurds']
# ('1146-006', 9, 11)
# ['August', '22']
# ('1147-002', 6, 7)
# ['Saturday']
# ('1148-002', 10, 11)
# ['Saturday']
# ('1148-006', 9, 11)
# ['220', 'million']
# ('1148-006', 13, 14)
# ['1995']
# ('1148-008', 6, 9)
# ['the', 'Palestinian', 'Authority']
# ('1148-009', 12, 14)
# ['Zine', 'al-Abidine']
# ('1148-009', 14, 16)
# ['Ben', 'Ali']
# ('1149-005', 1, 2)
# ['first']
# ('1149-005', 25, 29)
# ['the', 'Labor', 'Day', 'weekend']
# ('1149-005', 34, 37)
# ['the', 'East', 'Coast']
# ('1149-005', 39, 40)
# ['80']
# ('1149-011', 2, 8)
# ['the', 'National', 'Highway', 'Traffic', 'Safety', 'Administration']
# ('1149-012', 8, 9)
# ['today']
# ('1149-012', 14, 16)
# ['20', 'million']
# ('1150-000', 0, 1)
# ['Two']
# ('1150-003', 6, 9)
# ['Lilac', 'Falls', 'Motel']
# ('1150-003', 11, 12)
# ['two']
# ('1150-003', 17, 18)
# ['Friday']
# ('1150-005', 10, 11)
# ['four']
# ('1150-005', 24, 28)
# ['the', 'Rochester', 'Fire', 'Department']
# ('1150-006', 12, 16)
# ['the', 'Lilac', 'Falls', 'Motel']
# ('1151-000', 2, 3)
# ['two']
# ('1151-002', 19, 20)
# ['two']
# ('1151-002', 23, 25)
# ['a', 'dozen']
# ('1151-002', 29, 30)
# ['Saturday']
# ('1152-003', 0, 3)
# ['More', 'than', '300']
# ('1152-003', 6, 7)
# ['20']
# ('1152-003', 11, 12)
# ['Saturday']
# ('1152-004', 2, 3)
# ['200']
# ('1152-004', 7, 8)
# ['79']
# ('1152-004', 31, 32)
# ['79']
# ('1152-004', 40, 43)
# ['up', 'to', '40']
# ('1152-004', 49, 52)
# ['the', 'United', 'States']
# ('1152-005', 1, 2)
# ['Yesterday']
# ('1152-005', 5, 9)
# ['the', 'Department', 'of', 'Defense']
# ('1152-007', 3, 4)
# ['Saturday']
# ('1152-010', 19, 21)
# ['the', 'weekend']
# ('1152-011', 16, 17)
# ['1994']
# ('1152-013', 16, 17)
# ['23,000']
# ('1152-014', 4, 5)
# ['158']
# ('1152-014', 29, 32)
# ['30', 'to', '40']
# ('1152-014', 45, 46)
# ['three']
# ('1152-014', 49, 52)
# ['the', 'United', 'States']
# ('1152-015', 5, 7)
# ['nearly', '1,000']
# ('1152-016', 1, 2)
# ['23,000']
# ('1152-016', 11, 12)
# ['15,000']
# ('1152-016', 16, 17)
# ['6,000']
# ('1152-016', 25, 26)
# ['2,000']
# ('1152-017', 6, 7)
# ['three']
# ('1152-017', 9, 14)
# ['the', 'Tarawa', 'Amphibious', 'Readiness', 'Group']
# ('1152-018', 9, 10)
# ['seven']
# ('1152-018', 16, 17)
# ['nine']
# ('1152-018', 27, 28)
# ['20']
# ('1153-000', 0, 1)
# ['Two']
# ('1153-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1153-002', 0, 1)
# ['Two']
# ('1153-002', 6, 7)
# ['Thursday']
# ('1153-002', 15, 16)
# ['Saturday']
# ('1153-006', 2, 3)
# ['Friday']
# ('1153-006', 5, 6)
# ['two']
# ('1153-006', 11, 12)
# ['18']
# ('1153-006', 17, 18)
# ['19']
# ('1153-006', 38, 39)
# ['Thursday']
# ('1153-007', 32, 36)
# ['the', 'past', 'two', 'weeks']
# ('1154-000', 4, 5)
# ['seven']
# ('1154-002', 10, 11)
# ['Friday']
# ('1154-002', 12, 13)
# ['seven']
# ('1154-002', 20, 21)
# ['Saturday']
# ('1154-003', 8, 9)
# ['two']
# ('1154-003', 13, 14)
# ['six']
# ('1154-004', 12, 13)
# ['seven']
# ('1154-004', 16, 17)
# ['20']
# ('1154-006', 0, 3)
# ['A', 'week', 'ago']
# ('1154-006', 19, 21)
# ['65', 'km']
# ('1154-006', 22, 24)
# ['40', 'miles']
# ('1154-008', 3, 8)
# ['the', 'Human', 'Rights', 'National', 'Observatory']
# ('1154-008', 20, 21)
# ['August']
# ('1154-008', 22, 24)
# ['about', '1,400']
# ('1154-008', 36, 40)
# ['the', 'past', 'two', 'years']
# ('1154-009', 0, 3)
# ['An', 'estimated', '50,000']
# ('1154-009', 17, 19)
# ['early', '1992']
# ('1155-002', 14, 17)
# ['a', 'month', 'ago']
# ('1155-002', 30, 31)
# ['Saturday']
# ('1155-003', 12, 13)
# ['weekly']
# ('1155-003', 29, 30)
# ['six']
# ('1155-009', 3, 4)
# ['two']
# ('1155-010', 25, 26)
# ['three']
# ('1155-010', 34, 35)
# ['1992']
# ('1155-011', 16, 18)
# ['next', 'Thursday']
# ('1155-012', 12, 13)
# ['1981']
# ('1156-002', 6, 7)
# ['Saturday']
# ('1156-003', 4, 6)
# ['this', 'week']
# ('1156-003', 25, 30)
# ['the', 'Sant', "'", 'Egidio', 'Community']
# ('1156-004', 30, 32)
# ['July', '25']
# ('1156-006', 15, 21)
# ['the', 'Lay', 'Volunteers', "'", 'International', 'Organisation']
# ('1156-006', 22, 23)
# ['Sunday']
# ('1156-007', 4, 5)
# ['Monday']
# ('1156-008', 0, 4)
# ['The', 'U.N.', 'Security', 'Council']
# ('1156-008', 5, 6)
# ['Friday']
# ('1156-008', 18, 19)
# ['first']
# ('1156-009', 2, 3)
# ['Saturday']
# ('1156-010', 0, 2)
# ['Some', '150,000']
# ('1156-010', 12, 13)
# ['1993']
# ('1156-010', 17, 18)
# ['first']
# ('1157-000', 0, 1)
# ['Nato']
# ('1157-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1157-002', 0, 6)
# ['The', 'North', 'Atlantic', 'Treaty', 'Organisation', "'s"]
# ('1157-002', 8, 9)
# ['Saturday']
# ('1157-004', 0, 3)
# ['Earlier', 'on', 'Saturday']
# ('1157-004', 5, 6)
# ['Iraqi']
# ('1158-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1158-002', 0, 3)
# ['More', 'than', '10']
# ('1158-002', 22, 23)
# ['Saturday']
# ('1158-003', 27, 29)
# ['last', 'night']
# ('1158-005', 1, 2)
# ['Tuesday']
# ('1158-005', 5, 7)
# ['about', '40']
# ('1159-000', 3, 4)
# ['two']
# ('1159-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1159-002', 4, 5)
# ['Saturday']
# ('1159-002', 11, 12)
# ['two']
# ('1159-002', 20, 23)
# ['three', 'days', 'ago']
# ('1159-004', 2, 3)
# ['Friday']
# ('1159-004', 12, 13)
# ['Thursday']
# ('1159-004', 17, 18)
# ['18']
# ('1159-004', 23, 24)
# ['19']
# ('1159-004', 35, 36)
# ['Thursday']
# ('1159-007', 30, 34)
# ['the', 'past', 'two', 'weeks']
# ('1160-002', 0, 1)
# ['VENICE']
# ('1160-002', 3, 4)
# ['1996-08-31']
# ('1160-003', 31, 32)
# ['Saturday']
# ('1160-003', 33, 37)
# ['the', 'Venice', 'Film', 'Festival']
# ('1160-004', 17, 22)
# ['the', 'Irish', 'Republican', 'Army', "'s"]
# ('1160-004', 31, 34)
# ['1919', 'to', '1921']
# ('1160-005', 8, 11)
# ['early', 'next', 'year']
# ('1160-006', 15, 16)
# ['years']
# ('1160-010', 3, 4)
# ['1992']
# ('1160-010', 5, 10)
# ['"', 'The', 'Crying', 'Game', '"']
# ('1160-011', 17, 18)
# ['Mao']
# ('1160-012', 12, 13)
# ['today']
# ('1160-014', 3, 4)
# ['Northern']
# ('1160-016', 13, 14)
# ['thousands']
# ('1160-022', 0, 1)
# ['One']
# ('1160-022', 37, 38)
# ['1922']
# ('1160-023', 18, 21)
# ['Michael', 'Collins', "'"]
# ('1160-024', 5, 6)
# ['one']
# ('1160-024', 23, 24)
# ['today']
# ('1161-002', 2, 6)
# ['the', 'Dhaka', 'Stock', 'Exchange']
# ('1161-002', 38, 40)
# ['Friday', 'weekend']
# ('1161-009', 7, 8)
# ['2.73']
# ('1161-009', 10, 12)
# ['0.22', 'percent']
# ('1161-009', 14, 15)
# ['1,196.35']
# ('1161-009', 19, 21)
# ['133.7', 'million']
# ('1161-009', 23, 24)
# ['Thursday']
# ('1161-010', 0, 4)
# ['--', 'Dhaka', 'Newsroom', '880-2-506363']

# %% [markdown]
# *TODO: Write a short text that discusses the errors that you observed*
#
# *hyphen's, comma's, brackets and numbers are presented as entities. This can be cleaned for better analysis.*

# %% [markdown]
# Now, use the insights from your error analysis to improve the automated prediction that you implemented in Problem&nbsp;2. While the best way to do this would be to [update spaCy&rsquo;s NER model](https://spacy.io/usage/linguistic-features#updating) using domain-specific training data, for this lab it suffices to write code to pre-process the data and/or post-process the output produced by spaCy. You should be able to improve the F1 score from Problem&nbsp;2 by at last 15 percentage points.

# %%
def improved_gold_spans(df):
    previous_sentence_id = 0
    for _,sentence_id, sentence, beg, end, *_ in df.itertuples():
        if previous_sentence_id != sentence_id:
            previous_sentence_id = sentence_id
            doc = nlp(sentence)
            for ent in doc.ents:
                if (len(sentence.split(' ')[ent.start])>2):
                    if ent.label_ not in ["ORDINAL","CARDINAL","TIME", "DATE", "PERCENT", "MONEY","QUANTITY"]:
                        yield sentence_id, ent.start, ent.end
evaluation_report(spans_dev_gold, set(improved_gold_spans(df_dev)))
# Out:
# Precision score is 85.37625239820933 %
# Recall score is 67.68632753084333 %
# f1 score is 75.50904977375565 %

# %%
print("The number of false negatives are",len(spans_dev_gold - set(spans(df_dev))))
false_pos(spans_dev_gold, set(improved_gold_spans(df_dev)), df_dev)
# Out:
# The number of false negatives are 1836
# ('0949-006', 23, 24)
# ['Hoddle']
# ('0957-018', 26, 28)
# ['Alex', 'Corretja']
# ('1054-008', 6, 7)
# ['Rabobank']
# ('0959-013', 2, 3)
# ['PITTSBURGH']
# ('1152-014', 9, 10)
# ['F-14']
# ('0990-005', 7, 8)
# ['Yeltsin']
# ('1123-004', 0, 1)
# ['Ssangbangwool']
# ('1149-001', 0, 1)
# ['DETROIT']
# ('0972-026', 0, 2)
# ['A.', 'Gurusinha']
# ('1068-034', 3, 4)
# ['Hartlepool']
# ('1067-008', 5, 6)
# ['Clydebank']
# ('1011-002', 0, 1)
# ['CHICAGO']
# ('1111-008', 5, 7)
# ['Beryll', 'Remblance']
# ('1145-003', 16, 17)
# ['al-Daih']
# ('1022-007', 21, 22)
# ['C$']
# ('0956-007', 2, 3)
# ['Samsung']
# ('1061-019', 0, 1)
# ['Currie']
# ('1133-004', 24, 26)
# ['Communist', 'Party']
# ('1068-025', 0, 1)
# ['Shrewsbury']
# ('1008-014', 5, 7)
# ['Commerce', 'Department']
# ('1056-014', 1, 3)
# ['Tatian', 'Stiajkina']
# ('1076-038', 0, 4)
# ['Buducnost', '(', 'V', ')']
# ('1045-003', 8, 9)
# ['U.N.']
# ('1046-008', 31, 32)
# ['Real']
# ('1142-012', 4, 5)
# ['KDP']
# ('1143-004', 25, 26)
# ['Sikhin']
# ('0984-005', 0, 1)
# ['BRITAIN']
# ('1065-014', 0, 1)
# ['Stirling']
# ('1056-047', 0, 2)
# ['Antonella', 'Bellutti']
# ('0984-011', 5, 6)
# ['LIFFE']
# ('1093-000', 2, 3)
# ['U.S.']
# ('1067-018', 2, 4)
# ['East', 'Stirling']
# ('1096-013', 3, 5)
# ['Delino', 'DeShields']
# ('0963-011', 0, 1)
# ['Henke']
# ('1152-004', 24, 25)
# ['Enterprise']
# ('1016-001', 0, 1)
# ['BONN']
# ('1160-010', 24, 25)
# ['IRA']
# ('1096-012', 32, 36)
# ['(', 'Jerry', ')', 'Koosman']
# ('1068-014', 7, 8)
# ['Bolton']
# ('0972-000', 4, 6)
# ['SRI', 'LANKA']
# ('1094-040', 0, 2)
# ['ST', 'LOUIS']
# ('1069-011', 4, 5)
# ['Worcestershire']
# ('1094-041', 0, 1)
# ['CHICAGO']
# ('1034-001', 0, 2)
# ['THE', 'HAGUE']
# ('1030-032', 2, 4)
# ['Wall', 'Street']
# ('1075-002', 0, 1)
# ['Mauritania']
# ('1054-005', 4, 5)
# ['Germany']
# ('1058-036', 29, 32)
# ['Kansas', 'City', 'Royals']
# ('0951-004', 2, 4)
# ['Cosmin', 'Contra']
# ('1095-010', 2, 3)
# ['Boston']
# ('1059-000', 4, 5)
# ['KENT']
# ('1006-011', 0, 1)
# ['Tripoli-based']
# ('1095-006', 2, 3)
# ['TORONTO']
# ('1076-014', 0, 1)
# ['Partizan']
# ('1072-000', 6, 8)
# ['ALL', 'BLACK']
# ('1103-016', 22, 24)
# ['Recep', 'Cetin']
# ('1094-014', 0, 1)
# ['CHICAGO']
# ('0958-013', 0, 1)
# ['CLEVELAND']
# ('1068-038', 0, 1)
# ['Wigan']
# ('1098-001', 0, 1)
# ['DUBLIN']
# ('1095-010', 0, 1)
# ['OAKLAND']
# ('1069-006', 5, 6)
# ['Durham']
# ('1058-018', 0, 1)
# ['Pettite']
# ('1116-007', 13, 15)
# ['Charles', 'VI']
# ('1094-018', 0, 2)
# ['WESTERN', 'DIVISION']
# ('0966-002', 4, 7)
# ['Berlin', 'Grand', 'Prix']
# ('0975-000', 1, 2)
# ['COMELF']
# ('1078-007', 0, 1)
# ['Alba']
# ('1089-012', 14, 15)
# ['Parnevik']
# ('1096-001', 0, 1)
# ['CINCINNATI']
# ('1101-012', 65, 68)
# ['Alberto', 'Garcia', 'Aspe']
# ('0989-000', 0, 1)
# ['Chad']
# ('1137-008', 33, 34)
# ['Korean']
# ('0985-004', 10, 11)
# ['WBC']
# ('1152-014', 50, 52)
# ['United', 'States']
# ('1146-001', 0, 1)
# ['BAGHDAD']
# ('1045-006', 42, 45)
# ['Palestinian', 'Liberation', 'Organisation']
# ('1116-016', 6, 8)
# ['Boxer', 'Rising']
# ('1076-015', 0, 4)
# ['Mladost', '(', 'L', ')']
# ('1089-001', 2, 3)
# ['Wisconsin']
# ('1059-005', 0, 1)
# ['Derbyshire']
# ('1111-004', 1, 3)
# ['Miss', 'Stamper']
# ('1130-005', 9, 14)
# ['In', 'the', 'Year', 'of', 'January']
# ('0959-005', 0, 1)
# ['DETROIT']
# ('1069-006', 1, 2)
# ['Chester-le-Street']
# ('1105-001', 0, 1)
# ['MADRID']
# ('1066-061', 0, 1)
# ['Cardiff']
# ('0990-002', 23, 25)
# ['Alexander', 'Lebed']
# ('1016-009', 18, 20)
# ['West', 'Bank']
# ('0966-155', 1, 3)
# ['Heli', 'Rantanen']
# ('0947-006', 0, 1)
# ['Chester-le-Street']
# ('1097-000', 2, 3)
# ['EDBERG']
# ('0991-003', 16, 18)
# ['Russian', 'Federation']
# ('1048-000', 2, 3)
# ['ISRAEL']
# ('1066-022', 0, 1)
# ['Oxford']
# ('1056-006', 4, 5)
# ['Italy']
# ('1068-030', 0, 1)
# ['Colchester']
# ('0960-005', 8, 9)
# ['Rios']
# ('1036-002', 0, 1)
# ['LONGYEAR']
# ('1157-001', 0, 1)
# ['BRUSSELS']
# ('0995-002', 2, 3)
# ['Tajikistan']
# ('0951-001', 0, 1)
# ['BUCHAREST']
# ('1106-000', 4, 5)
# ['TURKEY']
# ('1004-002', 3, 5)
# ['Norodom', 'Sihanouk']
# ('0947-006', 2, 3)
# ['Glamorgan']
# ('0984-004', 14, 15)
# ['LIFFE']
# ('1050-002', 1, 4)
# ['Republic', 'of', 'Ireland']
# ('1125-012', 6, 7)
# ['Hutu']
# ('1083-002', 0, 1)
# ['Benetton']
# ('1014-010', 51, 55)
# ['League', 'of', 'Women', 'Voters']
# ('1068-030', 2, 3)
# ['Hereford']
# ('1076-005', 2, 6)
# ['Proleter', '(', 'Z', ')']
# ('1139-001', 0, 1)
# ['BEIJING']
# ('0948-043', 3, 4)
# ['Somerset']
# ('1069-012', 1, 3)
# ['The', 'Oval']
# ('0947-010', 0, 1)
# ['Portsmouth']
# ('1076-042', 0, 4)
# ['Zeleznik', '(', 'B', ')']
# ('0963-023', 18, 22)
# ['World', 'Series', 'of', 'Golf']
# ('1006-002', 0, 1)
# ['TRIPOLI']
# ('1068-034', 0, 2)
# ['Leyton', 'Orient']
# ('1138-011', 31, 32)
# ['Western']
# ('0991-003', 20, 22)
# ['Chechen', 'Republic']
# ('1091-003', 23, 25)
# ['Martina', 'Hingis']
# ('1066-020', 0, 1)
# ['Reading']
# ('1068-028', 2, 3)
# ['Scunthorpe']
# ('0958-025', 0, 1)
# ['CHICAGO']
# ('1030-027', 1, 3)
# ['Commerce', 'Department']
# ('1157-004', 5, 7)
# ['Iraqi', 'Kurd']
# ('0986-007', 1, 3)
# ['Dublin', 'Newsroom']
# ('0947-003', 0, 1)
# ['Leicester']
# ('0960-039', 21, 22)
# ['Rios']
# ('1135-002', 0, 1)
# ['RANGOON']
# ('1094-021', 0, 1)
# ['OAKLAND']
# ('0950-001', 0, 1)
# ['BELGRADE']
# ('0980-000', 9, 10)
# ['NAPM']
# ('1076-001', 0, 1)
# ['BELGRADE']
# ('1069-010', 5, 7)
# ['K.', 'Spiring']
# ('1077-003', 0, 1)
# ['Ince']
# ('1100-002', 6, 7)
# ['IBF']
# ('1003-003', 14, 15)
# ['Surinamese-born']
# ('1032-001', 0, 1)
# ['AMSTERDAM']
# ('1016-011', 13, 14)
# ['German-Israeli']
# ('1147-003', 1, 2)
# ['KDP']
# ('0968-000', 2, 3)
# ['HARRISON']
# ('1071-000', 7, 9)
# ['WORLD', 'CUP']
# ('1128-011', 8, 9)
# ['Ruch']
# ('1025-006', 3, 5)
# ['West', 'Bank']
# ('0962-008', 7, 9)
# ['Jesper', 'Parnevik']
# ('1030-007', 6, 7)
# ['Brent']
# ('1054-006', 6, 7)
# ['Polti']
# ('0957-020', 9, 11)
# ['Pete', 'Sampras']
# ('1116-014', 10, 13)
# ['Trades', 'Disputes', 'Act']
# ('0959-008', 0, 1)
# ['SEATTLE']
# ('1095-007', 2, 3)
# ['Minnesota']
# ('1059-005', 12, 13)
# ['Warwickshire']
# ('0968-003', 1, 5)
# ['International', 'Amateur', 'Athletic', 'Federation']
# ('1069-004', 14, 16)
# ['P.', 'Tufnell']
# ('0980-013', 20, 22)
# ['Federal', 'Reserve']
# ('0959-000', 2, 4)
# ['MAJOR', 'LEAGUE']
# ('1022-007', 13, 14)
# ['C$']
# ('1125-006', 28, 29)
# ['Zairean']
# ('1055-006', 0, 2)
# ['M.', 'Atherton']
# ('0947-006', 20, 21)
# ['Durham']
# ('1087-018', 0, 1)
# ['Eyles']
# ('0972-005', 0, 2)
# ['M.', 'Waugh']
# ('0948-022', 7, 9)
# ['The', 'Oval']
# ('1052-004', 3, 6)
# ['Jan', 'Allan', 'Mueller']
# ('0952-005', 4, 5)
# ['Rotor']
# ('1007-033', 1, 4)
# ['Standard', '&', 'Poor']
# ('1092-004', 7, 9)
# ['Germany', 'France']
# ('1116-016', 22, 24)
# ['Peking', 'Protocol']
# ('1091-001', 0, 2)
# ['NEW', 'YORK']
# ('0985-003', 6, 7)
# ['Bruno']
# ('1068-026', 4, 5)
# ['Wrexham']
# ('1106-006', 0, 1)
# ['Belgium']
# ('1153-001', 0, 1)
# ['BRUSSELS']
# ('1063-003', 2, 4)
# ['Sergei', 'Rebrov']
# ('1076-028', 0, 1)
# ['Rudar']
# ('1066-033', 0, 1)
# ['Bury']
# ('1067-013', 0, 1)
# ['Dumbarton']
# ('1099-004', 4, 5)
# ['Belarus']
# ('1080-001', 0, 1)
# ['BUCHAREST']
# ('1068-031', 0, 1)
# ['Doncaster']
# ('1078-000', 2, 5)
# ['TROFEJ', 'BEOGRAD', 'TOURNAMENT']
# ('1061-006', 3, 4)
# ['Bristol']
# ('0980-019', 38, 39)
# ['Eurodollars']
# ('1139-002', 9, 11)
# ['New', 'York-based']
# ('1121-003', 1, 2)
# ['London-based']
# ('0951-000', 2, 3)
# ['ROMANIA']
# ('1101-012', 16, 18)
# ['Pavel', 'Pardo']
# ('1132-007', 14, 15)
# ['EPR']
# ('1067-013', 2, 3)
# ['Brechin']
# ('1039-015', 9, 13)
# ['PT', 'Timor', 'Putra', 'Nasional']
# ('0957-009', 9, 11)
# ['Czech', 'Republic']
# ('1129-001', 0, 1)
# ['MOSCOW']
# ('1068-031', 2, 3)
# ['Darlington']
# ('1090-015', 7, 9)
# ['U.S.', 'Open']
# ('0965-011', 18, 20)
# ['Jesse', 'Owens']
# ('0951-000', 4, 5)
# ['LITHUANIA']
# ('0986-000', 2, 3)
# ['McCarthy']
# ('1106-001', 0, 1)
# ['BRUSSELS']
# ('1152-014', 32, 33)
# ['F-15']
# ('1055-026', 0, 1)
# ['Inzamam-ul-Haq']
# ('1065-036', 0, 2)
# ['East', 'Stirling']
# ('1069-017', 27, 29)
# ['K.', 'Evans']
# ('1116-014', 4, 7)
# ['House', 'of', 'Lords']
# ('0972-006', 0, 2)
# ['M.', 'Slater']
# ('1084-000', 4, 5)
# ['LATVIA']
# ('1033-001', 0, 1)
# ['BONN']
# ('1128-000', 5, 6)
# ['Ruch']
# ('1092-002', 16, 18)
# ['U.S.', 'Open']
# ('1039-006', 0, 1)
# ['KOMPAS']
# ('1154-001', 0, 1)
# ['PARIS']
# ('1012-008', 1, 3)
# ['Treasury', 'Department']
# ('1152-014', 34, 35)
# ['F-16']
# ('0981-006', 7, 8)
# ['Ontario-based']
# ('1055-026', 2, 3)
# ['Thorpe']
# ('1030-039', 4, 6)
# ['FTSE', '100']
# ('0976-000', 0, 1)
# ['POLISH']
# ('1150-005', 25, 28)
# ['Rochester', 'Fire', 'Department']
# ('1061-019', 2, 5)
# ['Heriot', "'s", 'F.P.']
# ('0996-004', 1, 5)
# ['Federal', 'Republic', 'of', 'Yugoslavia']
# ('0979-011', 23, 25)
# ['Labor', 'Day']
# ('0981-016', 0, 1)
# ['Magna']
# ('1022-014', 10, 11)
# ['C$']
# ('1055-026', 4, 5)
# ['Croft']
# ('0955-012', 0, 1)
# ['Suwan']
# ('0981-015', 3, 4)
# ['Magna']
# ('1147-001', 0, 1)
# ['BAGHDAD']
# ('1072-018', 5, 7)
# ['Andre', 'Joubert']
# ('1018-001', 0, 1)
# ['BERLIN']
# ('1101-012', 83, 85)
# ['Enrique', 'Alfaro']
# ('0955-011', 0, 1)
# ['Pohang']
# ('1072-019', 56, 58)
# ['Michael', 'Jones']
# ('1068-010', 0, 2)
# ['Port', 'Vale']
# ('1066-032', 0, 1)
# ['Brentford']
# ('1087-015', 4, 7)
# ['Professional', 'Squash', 'Association']
# ('1000-014', 11, 13)
# ['Czech', 'Republic']
# ('1058-042', 18, 19)
# ['Brewers']
# ('0948-004', 8, 13)
# ['Test', 'and', 'County', 'Cricket', 'Board']
# ('1123-001', 0, 1)
# ['SEOUL']
# ('1014-010', 32, 36)
# ['Commission', 'on', 'Presidential', 'Debates']
# ('0948-018', 3, 4)
# ['Worcestershire']
# ('0961-000', 1, 3)
# ['AMERICAN', 'FOOTBALL-RANDALL']
# ('1042-003', 5, 6)
# ['Huize']
# ('1080-000', 4, 5)
# ['LITHUANIA']
# ('1069-017', 19, 21)
# ['C.', 'Hooper']
# ('1055-028', 3, 4)
# ['Knight']
# ('1067-018', 0, 1)
# ['Arbroath']
# ('1055-025', 0, 2)
# ['Ijaz', 'Ahmed']
# ('1011-012', 12, 13)
# ['Minneapolis-based']
# ('0972-037', 6, 8)
# ['M.', 'Waugh']
# ('1033-007', 0, 1)
# ['Pro-Moscow']
# ('0947-011', 10, 12)
# ['J.', 'Adams']
# ('0947-012', 7, 9)
# ['J.', 'Russell']
# ('1101-012', 4, 6)
# ['Osvaldo', 'Sanchez']
# ('1055-027', 5, 6)
# ['Hollioake']
# ('1093-002', 1, 3)
# ['United', 'States']
# ('0968-001', 0, 2)
# ['MONTE', 'CARLO']
# ('0957-019', 29, 31)
# ['Gabriela', 'Sabatini']
# ('1151-001', 0, 1)
# ['DALLAS']
# ('1061-021', 2, 3)
# ['Stirling']
# ('0965-011', 27, 28)
# ['Olympics']
# ('1080-000', 2, 3)
# ['ROMANIA']
# ('1131-001', 0, 1)
# ['SANTIAGO']
# ('0963-003', 18, 20)
# ['Jesper', 'Parnevik']
# ('1092-001', 0, 2)
# ['NEW', 'YORK']
# ('1066-012', 0, 1)
# ['Wolverhampton']
# ('0949-005', 0, 1)
# ['Shearer']
# ('1051-002', 8, 10)
# ['British', 'Masters']
# ('1055-031', 4, 5)
# ['Gough']
# ('0987-002', 6, 7)
# ['Nigeria']
# ('1051-001', 2, 3)
# ['England']
# ('1069-015', 11, 13)
# ['R.', 'Kettleborough']
# ('1115-008', 0, 1)
# ['Ingram']
# ('1087-017', 6, 9)
# ['Hong', 'Kong', 'Open']
# ('1057-006', 0, 1)
# ['England']
# ('0970-000', 2, 3)
# ['MILAN']
# ('1109-007', 2, 3)
# ['Giovanni']
# ('1055-024', 4, 5)
# ['Mullally']
# ('1069-013', 33, 35)
# ['D.', 'Bicknell']
# ('0972-001', 0, 1)
# ['COLOMBO']
# ('1067-011', 2, 3)
# ['Berwick']
# ('0955-013', 0, 1)
# ['Ulsan']
# ('1072-018', 100, 102)
# ['Dawie', 'Theron']
# ('0994-017', 1, 3)
# ['United', 'States']
# ('1116-006', 2, 3)
# ['French']
# ('1060-005', 1, 3)
# ['Ian', 'Woosnam']
# ('1063-000', 2, 3)
# ['UKRAINE']
# ('1096-003', 12, 14)
# ['National', 'League']
# ('0995-016', 22, 23)
# ['Tajik']
# ('1076-017', 0, 1)
# ['Becej']
# ('1090-000', 2, 3)
# ['SPAIN']
# ('0962-004', 1, 6)
# ['Brown', 'Deer', 'Park', 'Golf', 'Course']
# ('1067-011', 0, 1)
# ['Ayr']
# ('1050-002', 5, 6)
# ['Liechtenstein']
# ('1056-032', 1, 3)
# ['Rita', 'Razmaite']
# ('1056-040', 9, 11)
# ['Czech', 'Republic']
# ('0984-006', 12, 14)
# ['Chicago', 'PMI']
# ('1036-014', 0, 1)
# ['Longyear']
# ('1088-000', 2, 5)
# ['HONG', 'KONG', 'OPEN']
# ('1045-003', 7, 8)
# ['Palestinian']
# ('0954-004', 2, 4)
# ['Peter', 'Nicol']
# ('1035-001', 0, 1)
# ['BONN']
# ('1150-001', 2, 3)
# ['N.H.']
# ('1138-002', 14, 18)
# ['Human', 'Rights', 'in', 'China']
# ('1101-012', 71, 73)
# ['Ramon', 'Ramirez']
# ('1045-010', 13, 16)
# ['Burj', 'al-Laqlaq', 'Society']
# ('1066-068', 0, 1)
# ['Exeter']
# ('0957-019', 21, 23)
# ['Asa', 'Carlsson']
# ('1095-018', 2, 3)
# ['PITTSBURGH']
# ('1062-000', 7, 9)
# ['WORLD', 'CUP']
# ('0958-041', 0, 1)
# ['CINCINNATI']
# ('1030-008', 0, 1)
# ['FTSE']
# ('1058-011', 24, 26)
# ['American', 'League']
# ('0972-028', 0, 2)
# ['A.', 'Ranatunga']
# ('1097-004', 7, 8)
# ['Open']
# ('1156-004', 2, 3)
# ['Nyerere']
# ('1065-024', 0, 1)
# ['Clyde']
# ('1011-006', 2, 5)
# ['Mercantile', 'Bancorp', 'Inc.']
# ('1055-018', 6, 8)
# ['Waqar', 'Younis']
# ('1069-015', 19, 21)
# ['P.', 'Such']
# ('1024-008', 2, 7)
# ['Bear', 'Stearns', '&', 'Co', 'Inc']
# ('0966-023', 1, 3)
# ['Florian', 'Schwarthoff']
# ('1061-003', 0, 1)
# ['Welsh']
# ('1090-002', 0, 2)
# ['NEW', 'YORK']
# ('1069-005', 0, 1)
# ['Middlesex']
# ('1128-006', 19, 20)
# ['Ruch']
# ('1054-007', 6, 7)
# ['TVM']
# ('0966-032', 1, 3)
# ['Ato', 'Boldon']
# ('1116-011', 8, 10)
# ['Pedro', 'I']
# ('1009-007', 1, 3)
# ['Agriculture', 'Department']
# ('1123-003', 0, 1)
# ['OB']
# ('1081-001', 0, 1)
# ['YEREVAN']
# ('0963-017', 0, 1)
# ['Henke']
# ('1077-004', 0, 1)
# ['Gascoigne']
# ('1061-013', 2, 4)
# ['Ebbw', 'Vale']
# ('1134-001', 0, 1)
# ['MANILA']
# ('1094-029', 0, 1)
# ['BOSTON']
# ('0947-008', 6, 7)
# ['Warwickshire']
# ('1096-026', 0, 1)
# ['Sanders']
# ('0968-002', 0, 1)
# ['Olympic']
# ('1035-010', 15, 22)
# ['Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('1101-011', 26, 28)
# ['Marcel', 'Desailly']
# ('1039-017', 0, 1)
# ['REPUBLIKA']
# ('1090-018', 8, 9)
# ['King']
# ('0994-003', 20, 21)
# ['Soviet']
# ('1123-003', 2, 3)
# ['Samsung']
# ('1056-043', 0, 2)
# ['Marion', 'Clignet']
# ('1049-005', 18, 20)
# ['Jack', 'Charlton']
# ('1072-018', 42, 46)
# ['Joost', 'van', 'der', 'Westhuizen']
# ('1005-005', 25, 26)
# ['Indonesian-origin']
# ('1146-005', 20, 22)
# ['Iraqi', 'Kurds']
# ('1069-005', 4, 5)
# ['Hampshire']
# ('0986-001', 0, 1)
# ['DUBLIN']
# ('0961-003', 8, 10)
# ['Philadelphia', 'Eagles']
# ('1065-030', 0, 1)
# ['Cowdenbeath']
# ('0984-017', 18, 20)
# ['Labour', 'Day']
# ('0948-000', 3, 4)
# ['ASHES']
# ('1075-000', 2, 3)
# ['MAURITANIA']
# ('1138-005', 20, 23)
# ['1966-76', 'Cultural', 'Revolution']
# ('1130-004', 30, 31)
# ['pre-Castro']
# ('1095-020', 0, 2)
# ['ST', 'LOUIS']
# ('0948-046', 6, 8)
# ['The', 'Oval']
# ('1065-033', 0, 3)
# ['Queen', "'s", 'Park']
# ('1061-010', 0, 1)
# ['Saracens']
# ('0947-004', 5, 7)
# ['P.', 'Simmons']
# ('0984-010', 16, 17)
# ['Treasuries']
# ('1011-011', 0, 1)
# ['Mercantile']
# ('1066-054', 0, 1)
# ['Walsall']
# ('0992-008', 1, 8)
# ['Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('1065-032', 0, 1)
# ['Alloa']
# ('1055-004', 0, 2)
# ['N.', 'Knight']
# ('0972-008', 5, 6)
# ['Chandana']
# ('1069-017', 16, 17)
# ['Kent']
# ('0966-164', 19, 21)
# ['Florian', 'Schwarthoff']
# ('1041-000', 0, 2)
# ['Apic', 'Yamada']
# ('1094-024', 3, 4)
# ['DETROIT']
# ('1054-023', 1, 4)
# ['Maarten', 'den', 'Bakker']
# ('1076-026', 2, 6)
# ['Mladost', '(', 'BJ', ')']
# ('0948-031', 3, 4)
# ['Leicestershire']
# ('1054-005', 1, 3)
# ['Olaf', 'Ludwig']
# ('0956-018', 0, 1)
# ['Samsung']
# ('0967-003', 6, 7)
# ['Swiss']
# ('0952-001', 0, 1)
# ['MOSCOW']
# ('0978-001', 0, 2)
# ['ST.', 'LOUIS']
# ('1086-000', 2, 3)
# ['ENGLAND']
# ('1068-033', 0, 1)
# ['Hull']
# ('1111-000', 3, 5)
# ['TATTERSALLS', 'BREEDERS']
# ('1106-006', 2, 4)
# ['Marc', 'Degryse']
# ('1029-017', 4, 6)
# ['Labour', 'Department']
# ('1131-004', 11, 13)
# ['United', 'States']
# ('1089-008', 14, 17)
# ['U.S.', 'Amateur', 'Championship']
# ('1109-001', 0, 1)
# ['AMSTERDAM']
# ('1055-012', 3, 5)
# ['Waqar', 'Younis']
# ('1076-007', 0, 1)
# ['Borac']
# ('1066-064', 0, 1)
# ['Scarborough']
# ('1055-004', 6, 8)
# ['Saqlain', 'Mushtaq']
# ('1004-001', 0, 2)
# ['PHNOM', 'PENH']
# ('1116-031', 10, 12)
# ['Cape', 'Town']
# ('1026-007', 12, 13)
# ["Gama'a"]
# ('1076-007', 2, 6)
# ['Mladost', '(', 'L', ')']
# ('1052-000', 6, 8)
# ['WORLD', 'CUP']
# ('1072-019', 26, 28)
# ['Frank', 'Bunce']
# ('1086-002', 2, 3)
# ['Moldova']
# ('1096-041', 25, 27)
# ['Houston', 'Astros']
# ('0963-002', 20, 23)
# ['Greater', 'Milwaukee', 'Open']
# ('0947-011', 23, 25)
# ['T.', 'Moody']
# ('1125-012', 5, 6)
# ['Rwandan']
# ('1103-016', 27, 29)
# ['Ogun', 'Temizkanoglu']
# ('1083-000', 2, 3)
# ['BENETTON']
# ('1137-000', 3, 5)
# ['S.', 'Korea']
# ('0965-002', 0, 1)
# ['BERLIN']
# ('1103-003', 4, 7)
# ['1998', 'World', 'Cup']
# ('0947-012', 21, 23)
# ['A.', 'Smith']
# ('0946-002', 12, 13)
# ['Leicestershire']
# ('1052-002', 3, 5)
# ['Faroe', 'Islands']
# ('0958-044', 0, 2)
# ['WESTERN', 'DIVISION']
# ('1068-006', 2, 3)
# ['Portsmouth']
# ('1095-011', 2, 3)
# ['SEATTLE']
# ('1103-010', 32, 34)
# ['De', 'Wilde']
# ('1083-000', 4, 5)
# ['DINAMO']
# ('1037-006', 1, 2)
# ['Stockholm']
# ('1046-004', 26, 27)
# ['Brazilian-born']
# ('0980-009', 4, 6)
# ['Federal', 'Reserve']
# ('1107-000', 2, 3)
# ['AUSTRIA']
# ('0958-018', 0, 2)
# ['WESTERN', 'DIVISION']
# ('1099-011', 0, 2)
# ['SK', 'Rapid']
# ('1088-002', 43, 45)
# ['Peter', 'Nicol']
# ('1103-016', 14, 16)
# ['Sergen', 'Yalcin']
# ('0962-003', 4, 7)
# ['Greater', 'Milwaukee', 'Open']
# ('1077-000', 5, 6)
# ['GASCOIGNE']
# ('1058-002', 13, 15)
# ['Texas', 'Rangers']
# ('1155-004', 0, 1)
# ['Gust']
# ('1136-001', 0, 1)
# ['BEIJING']
# ('1011-022', 15, 17)
# ['Boatmen', "'s"]
# ('0972-011', 3, 4)
# ['Kaluwitharana']
# ('0984-013', 7, 11)
# ['Chicago', 'Board', 'of', 'Trade']
# ('1055-009', 0, 2)
# ['R.', 'Irani']
# ('1090-005', 11, 13)
# ['Czech', 'Republic']
# ('1011-019', 12, 14)
# ['Boatmen', "'s"]
# ('0972-011', 5, 6)
# ['Chandana']
# ('0994-000', 1, 2)
# ['Belarus']
# ('1107-000', 6, 7)
# ['SCOTLAND']
# ('0984-010', 0, 1)
# ['ITALY']
# ('1054-005', 6, 7)
# ['Telekom']
# ('1104-002', 22, 24)
# ['Real', 'Madrid']
# ('1087-000', 6, 7)
# ['JANSHER']
# ('1111-002', 3, 6)
# ['Tattersalls', 'Breeders', 'Stakes']
# ('1059-000', 2, 3)
# ['ESSEX']
# ('0997-008', 14, 15)
# ['Barvikha']
# ('1061-012', 2, 3)
# ['Llanelli']
# ('1094-020', 0, 1)
# ['SEATTLE']
# ('1095-016', 0, 2)
# ['San', 'Diego']
# ('0971-000', 5, 6)
# ['AUSTRALIA']
# ('0963-018', 23, 25)
# ['Nortel', 'Open']
# ('1143-003', 19, 21)
# ['United', 'States']
# ('0972-030', 3, 4)
# ['McGrath']
# ('1052-004', 0, 2)
# ['Faroe', 'Islands']
# ('1055-010', 0, 2)
# ['A.', 'Hollioake']
# ('0993-001', 0, 1)
# ['BELGRADE']
# ('1128-004', 17, 18)
# ['Ruch']
# ('1103-015', 4, 7)
# ['Filip', 'De', 'Wilde']
# ('1090-011', 6, 8)
# ['Fed', 'Cup']
# ('0947-010', 11, 13)
# ['M.', 'Ramprakash']
# ('1076-013', 0, 2)
# ['Red', 'Star']
# ('0955-014', 0, 1)
# ['Anyang']
# ('1149-005', 26, 28)
# ['Labor', 'Day']
# ('0981-006', 8, 9)
# ['Magna']
# ('1087-000', 2, 3)
# ['HILL']
# ('1069-015', 24, 25)
# ['Essex']
# ('0962-000', 5, 8)
# ['GREATER', 'MILWAUKEE', 'OPEN']
# ('1127-022', 39, 40)
# ['Chechnya']
# ('1056-030', 1, 3)
# ['Wendy', 'Everson']
# ('0958-042', 0, 1)
# ['CHICAGO']
# ('1078-002', 3, 6)
# ['Trofej', 'Beograd', '96']
# ('1127-009', 34, 35)
# ['mainly-Moslem']
# ('1068-038', 2, 3)
# ['Chester']
# ('1095-019', 3, 5)
# ['NEW', 'YORK']
# ('1094-056', 0, 1)
# ['COLORADO']
# ('1096-025', 24, 27)
# ['San', 'Diego', 'Padres']
# ('1028-032', 4, 6)
# ['J.J.', 'KENNY']
# ('0985-012', 0, 1)
# ['Bruno']
# ('0948-015', 4, 6)
# ['Lord', "'s"]
# ('1094-047', 0, 1)
# ['COLORADO']
# ('1161-001', 0, 1)
# ['DHAKA']
# ('1052-005', 0, 1)
# ['Slovakia']
# ('0991-000', 2, 3)
# ['Chechens']
# ('0957-030', 11, 12)
# ['Madagascar']
# ('1065-015', 0, 2)
# ['East', 'Fife']
# ('1076-040', 0, 1)
# ['Spartak']
# ('0972-031', 0, 2)
# ['U.', 'Chandana']
# ('1106-000', 2, 3)
# ['BELGIUM']
# ('1058-007', 10, 12)
# ['Ruben', 'Sierra']
# ('1027-002', 0, 1)
# ['AL-RAM']
# ('1061-016', 0, 1)
# ['Swansea']
# ('0948-021', 0, 1)
# ['Leeds']
# ('1044-004', 44, 46)
# ['West', 'Bank']
# ('1113-005', 3, 5)
# ['St', 'Pauli']
# ('1087-019', 0, 1)
# ['Eyles']
# ('0947-012', 14, 15)
# ['Northamptonshire']
# ('1103-016', 9, 11)
# ['Hakan', 'Unsal']
# ('0984-016', 49, 52)
# ['Tokyo', 'Stock', 'Exchange']
# ('1060-011', 1, 3)
# ['Andrew', 'Coltart']
# ('1105-004', 3, 5)
# ['Real', 'Madrid']
# ('0970-006', 3, 4)
# ['Bergamo-based']
# ('1137-000', 0, 2)
# ['N.', 'Korea']
# ('1095-014', 2, 3)
# ['CHICAGO']
# ('0958-009', 0, 1)
# ['BOSTON']
# ('1061-016', 2, 3)
# ['Cardiff']
# ('1027-004', 18, 19)
# ['al-Aqsa']
# ('1090-014', 18, 19)
# ['King']
# ('0963-023', 9, 11)
# ['PGA', 'Tour']
# ('1008-011', 5, 7)
# ['Wall', 'Street']
# ('1027-024', 4, 5)
# ['Arafat']
# ('0957-006', 2, 4)
# ['Goran', 'Ivanisevic']
# ('1022-001', 0, 1)
# ['TORONTO']
# ('1067-021', 4, 5)
# ['Forfar']
# ('1061-009', 0, 1)
# ['Sale']
# ('1083-002', 19, 22)
# ['Trofej', 'Beograd', '96']
# ('1031-015', 5, 7)
# ['Hong', 'Kong-listed']
# ('1083-002', 2, 3)
# ['Italy']
# ('1028-001', 6, 7)
# ['NYC']
# ('1108-001', 0, 1)
# ['DUBLIN']
# ('0947-012', 2, 3)
# ['Gloucestershire']
# ('0963-021', 0, 1)
# ['Woods']
# ('0947-010', 2, 3)
# ['Middlesex']
# ('1066-078', 0, 1)
# ['Rochdale']
# ('1072-018', 90, 92)
# ['Marius', 'Hurter']
# ('1026-002', 12, 14)
# ["al-Gama'a", 'al-Islamiya']
# ('1051-004', 4, 5)
# ['Italy']
# ('0958-025', 2, 3)
# ['TORONTO']
# ('1011-020', 3, 5)
# ['Boatmen', "'s"]
# ('1101-011', 38, 40)
# ['Bixente', 'Lizarazu']
# ('1142-014', 0, 1)
# ['U.S.-led']
# ('1061-008', 2, 3)
# ['Bath']
# ('0970-004', 0, 1)
# ['Lentini']
# ('1058-022', 24, 26)
# ['Seattle', 'Mariners']
# ('0947-003', 2, 3)
# ['Leicestershire']
# ('1138-008', 13, 15)
# ['Democracy', 'Wall']
# ('1103-016', 51, 53)
# ['Arif', 'Erdem']
# ('1058-002', 17, 19)
# ['Cleveland', 'Indians']
# ('0948-016', 3, 8)
# ['Duke', 'of', 'Norfolk', "'s", 'XI']
# ('1113-002', 2, 4)
# ['German', 'Cup']
# ('1069-010', 11, 13)
# ['S.', 'Rhodes']
# ('1072-005', 28, 30)
# ['All', 'Black']
# ('1066-011', 0, 3)
# ['Queens', 'Park', 'Rangers']
# ('1137-003', 24, 26)
# ['Li', 'Song-ho']
# ('1061-000', 3, 4)
# ['ENGLISH']
# ('1156-003', 0, 1)
# ['Nyerere']
# ('1040-009', 2, 5)
# ['Jeans', 'Mate', 'Corp']
# ('1067-019', 3, 4)
# ['Alloa']
# ('1058-027', 32, 35)
# ['Chicago', 'White', 'Sox']
# ('1096-003', 9, 10)
# ['Cardinals']
# ('1127-022', 23, 24)
# ['Chechen']
# ('1119-006', 28, 30)
# ['Iraqi', 'Kurds']
# ('1027-004', 9, 11)
# ['Yasser', 'Arafat']
# ('0980-004', 4, 5)
# ['Eurodollar']
# ('0947-005', 4, 5)
# ['Somerset']
# ('1124-003', 6, 8)
# ['Freedom', 'Front']
# ('0976-005', 1, 3)
# ['Warsaw', 'Newsroom']
# ('0959-008', 2, 3)
# ['Baltimore']
# ('1065-000', 2, 3)
# ['SCOTTISH']
# ('1046-003', 9, 10)
# ['Real']
# ('1109-002', 0, 2)
# ['The', 'Netherlands']
# ('1051-000', 2, 4)
# ['BRITISH', 'MASTERS']
# ('1076-016', 0, 1)
# ['Vojvodina']
# ('1052-001', 0, 1)
# ['TOFTIR']
# ('1018-003', 2, 4)
# ['Nicole', 'Nichterwitz']
# ('1094-051', 2, 3)
# ['PITTSBURGH']
# ('1148-004', 0, 2)
# ['LA', 'PRESSE']
# ('1027-016', 12, 13)
# ['al-Ram']
# ('1085-001', 0, 1)
# ['MINSK']
# ('0953-012', 22, 24)
# ['Puerto', 'Rico']
# ('1077-005', 0, 1)
# ['Hoddle']
# ('1062-000', 2, 3)
# ['WALES']
# ('1025-005', 14, 16)
# ['West', 'Bank']
# ('1036-004', 0, 1)
# ['Longyear']
# ('1101-012', 88, 90)
# ['Francisco', 'Palencia']
# ('1044-005', 2, 5)
# ['Arab', 'East', 'Jerusalem']
# ('1065-002', 0, 1)
# ['Scottish']
# ('1124-000', 2, 3)
# ['Afrikaners']
# ('1128-005', 17, 18)
# ['Ruch']
# ('1007-016', 0, 2)
# ['Ronald', 'Reagan']
# ('1080-004', 2, 4)
# ['Viorel', 'Moldovan']
# ('0956-004', 2, 3)
# ['OB']
# ('1030-040', 6, 7)
# ['Nikkei']
# ('0947-005', 0, 1)
# ['Leicestershire']
# ('1094-051', 0, 1)
# ['HOUSTON']
# ('1116-012', 2, 3)
# ['Scottish']
# ('1077-002', 20, 22)
# ['Paul', 'Ince']
# ('1096-036', 11, 12)
# ['RBI']
# ('1030-038', 13, 17)
# ['New', 'York', 'Cotton', 'Exchange']
# ('0966-000', 2, 5)
# ['BERLIN', 'GRAND', 'PRIX']
# ('0958-056', 0, 1)
# ['COLORADO']
# ('1068-026', 2, 3)
# ['Walsall']
# ('1101-009', 12, 14)
# ['World', 'Cup']
# ('1022-003', 31, 34)
# ['TD', 'Securities', 'Inc']
# ('1072-018', 32, 34)
# ['Pieter', 'Hendriks']
# ('0956-004', 0, 1)
# ['LG']
# ('1068-013', 2, 3)
# ['Birmingham']
# ('1102-001', 0, 1)
# ['PARIS']
# ('1116-009', 2, 3)
# ['Russian']
# ('0990-001', 0, 1)
# ['MOSCOW']
# ('0947-008', 22, 24)
# ['G.', 'Kersey']
# ('1027-024', 1, 3)
# ['Abu', 'Ammar']
# ('1139-002', 13, 17)
# ['Human', 'Rights', 'in', 'China']
# ('1139-006', 13, 15)
# ['Democracy', 'Wall']
# ('0960-003', 25, 27)
# ['U.S.', 'Open']
# ('0984-016', 34, 35)
# ['LIFFE']
# ('0978-003', 0, 1)
# ['Jones']
# ('1115-010', 14, 16)
# ['My', 'Turn']
# ('1096-034', 14, 15)
# ['RBI']
# ('1066-051', 0, 1)
# ['Wrexham']
# ('1065-011', 0, 1)
# ['Falkirk']
# ('1004-003', 0, 2)
# ['Hen', 'Vipheak']
# ('1000-014', 23, 24)
# ['French']
# ('1069-010', 0, 1)
# ['Worcestershire']
# ('1101-012', 58, 60)
# ['Cuauhtemoc', 'Blanco']
# ('1058-037', 14, 15)
# ['Royals']
# ('1160-011', 17, 19)
# ['Mao', 'Tse-Tung']
# ('1084-000', 2, 3)
# ['SWEDEN']
# ('0972-009', 3, 4)
# ['Muralitharan']
# ('0976-002', 1, 5)
# ['National', 'Bank', 'of', 'Poland']
# ('0956-000', 4, 6)
# ['S.', 'KOREAN']
# ('1066-076', 0, 1)
# ['Swansea']
# ('0947-007', 10, 12)
# ['M.', 'McCague']
# ('1085-000', 6, 8)
# ['WORLD', 'CUP']
# ('1045-006', 30, 34)
# ['Holy', 'City', 'of', 'Jerusalem']
# ('1047-000', 3, 4)
# ['WIGAN']
# ('1050-001', 0, 1)
# ['ESCHEN']
# ('1066-015', 0, 1)
# ['Portsmouth']
# ('0958-000', 2, 4)
# ['MAJOR', 'LEAGUE']
# ('1094-050', 2, 3)
# ['CHICAGO']
# ('1056-017', 27, 29)
# ['Heiko', 'Szonn']
# ('1066-009', 0, 1)
# ['Tranmere']
# ('1047-001', 2, 3)
# ['England']
# ('1011-008', 6, 7)
# ['Mercantile']
# ('0957-030', 2, 4)
# ['Monica', 'Seles']
# ('1094-050', 0, 1)
# ['ATLANTA']
# ('1101-012', 76, 78)
# ['Jesus', 'Arellano']
# ('0984-003', 0, 1)
# ['GERMANY']
# ('0971-001', 0, 1)
# ['COLOMBO']
# ('1062-001', 0, 1)
# ['CARDIFF']
# ('1008-027', 1, 4)
# ['University', 'of', 'Michigan']
# ('1071-005', 2, 6)
# ['Jorge', 'Luis', 'Dely', 'Valdes']
# ('1012-007', 5, 8)
# ['Million', 'Man', 'March']
# ('1128-014', 15, 16)
# ['Ruch']
# ('0952-000', 2, 3)
# ['ROTOR']
# ('1142-013', 5, 7)
# ['Iraqi', 'Kurdish']
# ('1112-000', 2, 3)
# ['KLINSMANN']
# ('1088-002', 4, 7)
# ['Hong', 'Kong', 'Open']
# ('1068-009', 2, 3)
# ['Ipswich']
# ('1101-011', 4, 6)
# ['Bernard', 'Lama']
# ('1149-005', 41, 42)
# ['90']
# ('1076-027', 0, 4)
# ['Buducnost', '(', 'V', ')']
# ('0970-001', 0, 1)
# ['MILAN']
# ('1068-008', 0, 1)
# ['Norwich']
# ('1070-013', 1, 3)
# ['Al', 'Unser']
# ('0998-004', 3, 4)
# ['Maskhadov']
# ('1061-015', 0, 1)
# ['Newport']
# ('1104-001', 0, 1)
# ['MADRID']
# ('1066-060', 0, 1)
# ['Torquay']
# ('1061-020', 0, 1)
# ['Jed-Forest']
# ('1111-006', 1, 2)
# ['Pelham']
# ('0990-003', 11, 12)
# ['Interfax']
# ('1061-000', 0, 2)
# ['RUGBY', 'UNION']
# ('1000-004', 14, 15)
# ['BSE']
# ('0984-017', 0, 1)
# ['EUROBONDS']
# ('0972-024', 3, 4)
# ['Healy']
# ('1011-008', 8, 9)
# ['Commerce']
# ('1028-002', 2, 6)
# ['Bay', 'Co', 'Building', 'Authority']
# ('1061-021', 0, 1)
# ['Melrose']
# ('1072-017', 1, 3)
# ['Walter', 'Little']
# ('0964-003', 0, 1)
# ['Silva']
# ('1068-008', 2, 3)
# ['Wolverhampton']
# ('1041-009', 2, 5)
# ['Apic', 'Yamada', 'Corp']
# ('1061-015', 2, 3)
# ['Caerphilly']
# ('1094-024', 0, 2)
# ['KANSAS', 'CITY']
# ('1061-020', 2, 3)
# ['Watsonians']
# ('1054-009', 6, 7)
# ['TVM']
# ('1067-017', 2, 3)
# ['Cowdenbeath']
# ('0972-024', 5, 6)
# ['Fleming']
# ('1103-016', 41, 43)
# ['Tolunay', 'Kafkas']
# ('1066-035', 0, 1)
# ['Millwall']
# ('1092-007', 9, 12)
# ['South', 'Korea', 'Australia']
# ('1116-009', 18, 19)
# ['Borodino']
# ('1068-000', 2, 3)
# ['ENGLISH']
# ('1058-030', 7, 8)
# ['RBI']
# ('1054-009', 4, 5)
# ['Denmark']
# ('0949-000', 2, 3)
# ['SHEARER']
# ('0947-007', 3, 4)
# ['Nottinghamshire']
# ('1115-010', 3, 5)
# ['Ronald', 'Reagan']
# ('0995-000', 0, 1)
# ['Tajik']
# ('1039-018', 18, 19)
# ['PDI']
# ('1067-005', 3, 4)
# ['Falkirk']
# ('1093-005', 3, 5)
# ['Luis', 'Lazo']
# ('1124-001', 0, 2)
# ['CAPE', 'TOWN']
# ('1039-018', 1, 5)
# ['Central', 'Jakarta', 'District', 'Court']
# ('1116-035', 4, 11)
# ['Alan', 'John', 'Percivale', '(', 'A.J.P.', ')', 'Taylor']
# ('1113-006', 0, 1)
# ['Duisburg']
# ('1063-000', 4, 6)
# ['NORTHERN', 'IRELAND']
# ('1072-019', 90, 92)
# ['Craig', 'Dowd']
# ('1067-021', 0, 3)
# ['Queen', "'s", 'Park']
# ('1101-012', 46, 49)
# ['Joaquin', 'del', 'Olmo']
# ('1066-043', 0, 1)
# ['Peterborough']
# ('1045-007', 28, 30)
# ['Old', 'City']
# ('1049-002', 1, 4)
# ['Republic', 'of', 'Ireland']
# ('1007-005', 23, 25)
# ['Federal', 'Reserve']
# ('1094-000', 2, 4)
# ['MAJOR', 'LEAGUE']
# ('1055-012', 0, 2)
# ['R.', 'Croft']
# ('1113-006', 2, 3)
# ['Luebeck']
# ('1069-008', 4, 5)
# ['Durham']
# ('1069-016', 8, 9)
# ['Lancashire']
# ('1099-002', 0, 1)
# ['VIENNA']
# ('1059-006', 0, 1)
# ['Warwickshire']
# ('1066-059', 0, 1)
# ['Hartlepool']
# ('0957-002', 9, 12)
# ['National', 'Tennis', 'Centre']
# ('1067-014', 2, 3)
# ['Hamilton']
# ('1103-015', 76, 79)
# ['Gilles', 'De', 'Bilde']
# ('0972-011', 0, 2)
# ['D.', 'Lehmann']
# ('1087-002', 20, 23)
# ['Hong', 'Kong', 'Open']
# ('1007-027', 3, 5)
# ['Wall', 'Street']
# ('0956-016', 0, 1)
# ['Hanwha']
# ('1101-011', 82, 84)
# ['Patrice', 'Loko']
# ('1100-001', 0, 1)
# ['DUBLIN']
# ('1047-000', 0, 2)
# ['RUGBY', 'LEAGUE']
# ('0965-003', 1, 3)
# ['Dennis', 'Mitchell']
# ('1105-003', 2, 3)
# ['division']
# ('1062-002', 2, 4)
# ['San', 'Marino']
# ('1032-009', 1, 2)
# ['Amsterdam']
# ('1035-010', 0, 1)
# ['Interfax']
# ('1116-015', 11, 12)
# ['Naples']
# ('1068-010', 3, 4)
# ['Oxford']
# ('1094-013', 0, 1)
# ['CLEVELAND']
# ('1141-002', 21, 23)
# ['China', 'Daily']
# ('1072-019', 82, 84)
# ['Sean', 'Fitzpatrick']
# ('1123-000', 2, 4)
# ['S.', 'Korean']
# ('1094-029', 2, 3)
# ['OAKLAND']
# ('1123-013', 0, 1)
# ['LG']
# ('1156-008', 11, 12)
# ['Tutsi']
# ('1069-004', 10, 12)
# ['A.', 'Fraser']
# ('1101-011', 43, 45)
# ['Christian', 'Karembeu']
# ('1067-006', 0, 1)
# ['Partick']
# ('1118-001', 2, 3)
# ['Scotland']
# ('1097-004', 41, 44)
# ['National', 'Tennis', 'Centre']
# ('1094-017', 0, 2)
# ['KANSAS', 'CITY']
# ('1156-006', 16, 21)
# ['Lay', 'Volunteers', "'", 'International', 'Organisation']
# ('1096-002', 10, 12)
# ['Devon', 'White']
# ('0961-000', 0, 1)
# ['NFL']
# ('1076-033', 0, 1)
# ['Obilic']
# ('0981-004', 8, 12)
# ['New', 'York', 'Stock', 'Exchange']
# ('1160-005', 25, 26)
# ['British-ruled']
# ('0958-010', 0, 1)
# ['TORONTO']
# ('1118-001', 0, 1)
# ['STIRLING']
# ('1101-001', 0, 1)
# ['PARIS']
# ('1118-006', 21, 23)
# ['Conservative', 'Party']
# ('1128-002', 5, 9)
# ['Bank', 'Rozwoju', 'Exportu', 'SA']
# ('1155-001', 0, 1)
# ['BONN']
# ('1143-001', 0, 1)
# ['JERUSALEM']
# ('1068-021', 2, 3)
# ['Chesterfield']
# ('1130-005', 71, 73)
# ['A', 'Woman']
# ('1068-037', 0, 1)
# ['Torquay']
# ('1069-003', 1, 2)
# ['Portsmouth']
# ('1066-042', 0, 2)
# ['Bristol', 'Rovers']
# ('1061-010', 2, 3)
# ['Leicester']
# ('1055-032', 4, 5)
# ['Hollioake']
# ('1072-014', 18, 19)
# ['Springboks']
# ('0980-005', 8, 9)
# ['Eurodollar']
# ('1055-038', 5, 6)
# ['Croft']
# ('1137-006', 10, 11)
# ['Korean']
# ('1058-016', 24, 27)
# ['New', 'York', 'Yankees']
# ('1068-021', 0, 1)
# ['Gillingham']
# ('1058-014', 9, 12)
# ['American', 'League', 'Central']
# ('1124-009', 5, 7)
# ['South', 'Africa']
# ('0972-021', 8, 9)
# ['Chandana']
# ('1066-023', 0, 2)
# ['Manchester', 'City']
# ('0952-002', 0, 2)
# ['Rotor', 'Volgograd']
# ('0948-002', 4, 5)
# ['Ashes']
# ('1034-000', 6, 8)
# ['El', 'Al']
# ('0993-007', 1, 3)
# ['Amra', 'Kevic']
# ('1055-032', 2, 3)
# ['Knight']
# ('1113-001', 0, 1)
# ['BONN']
# ('1144-002', 4, 5)
# ['KDP']
# ('0997-001', 0, 1)
# ['MOSCOW']
# ('1123-008', 0, 1)
# ['Ssangbangwool']
# ('1060-003', 4, 6)
# ['British', 'Masters']
# ('1058-029', 0, 1)
# ['Baines']
# ('0971-003', 2, 3)
# ['Australia']
# ('1051-009', 35, 36)
# ['Sweden']
# ('1072-019', 21, 23)
# ['Walter', 'Little']
# ('1068-033', 2, 3)
# ['Barnet']
# ('1137-010', 6, 8)
# ['Li', 'In-mo']
# ('0960-019', 41, 42)
# ['Rios']
# ('1061-005', 0, 1)
# ['Harlequins']
# ('1000-006', 9, 10)
# ['French']
# ('1037-001', 0, 1)
# ['STOCKHOLM']
# ('1065-034', 0, 1)
# ['Montrose']
# ('0958-056', 2, 4)
# ['ST', 'LOUIS']
# ('1058-021', 1, 3)
# ['Randy', 'Velarde']
# ('1116-015', 2, 4)
# ['Giuseppe', 'Garibaldi']
# ('1103-016', 4, 6)
# ['Rustu', 'Recber']
# ('0947-006', 15, 17)
# ['D.', 'Blenkiron']
# ('1008-004', 1, 3)
# ['Commerce', 'Department']
# ('1091-004', 8, 10)
# ['Thomas', 'Enqvist']
# ('1064-004', 23, 25)
# ['Kyran', 'Bracken']
# ('1072-015', 20, 21)
# ['Venter']
# ('0958-051', 2, 3)
# ['CINCINNATI']
# ('1142-002', 5, 6)
# ['Kurdish-controlled']
# ('1005-000', 0, 2)
# ['Far', 'East']
# ('0975-012', 4, 6)
# ['Bucharest', 'Newsroom']
# ('1092-002', 5, 8)
# ['1997', 'Fed', 'Cup']
# ('0972-021', 2, 3)
# ['Muralitharan']
# ('1067-005', 0, 2)
# ['Greenock', 'Morton']
# ('1087-017', 14, 16)
# ['Rodney', 'Eyles']
# ('1101-007', 20, 21)
# ['Espanyol']
# ('1161-002', 3, 6)
# ['Dhaka', 'Stock', 'Exchange']
# ('1066-039', 0, 1)
# ['Burnley']
# ('1009-020', 11, 13)
# ['Agriculture', 'Department']
# ('1076-021', 0, 4)
# ['Rad', '(', 'B', ')']
# ('0969-000', 2, 3)
# ['BARATELLI']
# ('1020-001', 0, 1)
# ['BOMBAY']
# ('0947-006', 11, 13)
# ['H.', 'Morris']
# ('1038-001', 0, 1)
# ['AUCKLAND']
# ('0988-002', 21, 27)
# ['Gold', 'Fields', 'of', 'South', 'Africa', 'Ltd']
# ('0946-008', 13, 14)
# ['Such']
# ('1158-005', 21, 22)
# ['Fal']
# ('1102-000', 4, 5)
# ['MEXICO']
# ('1101-007', 22, 23)
# ['Barcelona']
# ('1101-008', 16, 18)
# ['Internazionale', 'Milan']
# ('1069-000', 2, 5)
# ['ENGLISH', 'COUNTY', 'CHAMPIONSHIP']
# ('0947-011', 2, 3)
# ['Worcestershire']
# ('0966-158', 1, 3)
# ['Natalya', 'Shikolen']
# ('1068-006', 0, 1)
# ['Grimsby']
# ('0958-024', 0, 2)
# ['KANSAS', 'CITY']
# ('0956-009', 2, 3)
# ['Ssangbangwool']
# ('1111-008', 3, 4)
# ['John']
# ('0972-015', 0, 2)
# ['G.', 'McGrath']
# ('1067-019', 0, 2)
# ['Inverness', 'Thistle']
# ('0947-011', 0, 1)
# ['Chesterfield']
# ('0974-001', 0, 1)
# ['COLOMBO']
# ('1055-007', 4, 5)
# ['Ata-ur-Rehman']
# ('0966-066', 4, 5)
# ['Nigeria']
# ('1072-019', 72, 74)
# ['Ian', 'Jones']
# ('1090-000', 10, 13)
# ['1997', 'FED', 'CUP']
# ('0973-002', 22, 25)
# ['Singer', 'World', 'Series']
# ('1058-026', 6, 8)
# ['White', 'Sox']
# ('0947-004', 0, 1)
# ['Somerset']
# ('0973-000', 2, 3)
# ['AUSTRALIA']
# ('1089-008', 2, 3)
# ['Woods']
# ('1004-003', 24, 25)
# ['T3']
# ('0974-004', 5, 6)
# ['Singer']
# ('1069-015', 1, 2)
# ['Headingley']
# ('1069-015', 15, 17)
# ['G.', 'Hamilton']
# ('1069-007', 0, 1)
# ['Glamorgan']
# ('1132-001', 0, 2)
# ['MEXICO', 'CITY']
# ('1068-014', 3, 6)
# ['Queens', 'Park', 'Rangers']
# ('1156-001', 0, 1)
# ['ROME']
# ('0980-016', 14, 15)
# ['FOMC']
# ('0967-001', 0, 1)
# ['GENEVA']
# ('1061-012', 0, 1)
# ['Bridgend']
# ('1046-010', 11, 12)
# ['Silva']
# ('1146-004', 25, 26)
# ['INA']
# ('1091-000', 7, 9)
# ['U.S.', 'OPEN']
# ('1116-006', 17, 18)
# ['Eugene']
# ('1016-007', 23, 25)
# ['Foreign', 'Ministry']
# ('1061-007', 2, 4)
# ['West', 'Hartlepool']
# ('1007-012', 12, 14)
# ['White', 'House']
# ('0972-012', 0, 2)
# ['I.', 'Healy']
# ('1135-015', 13, 19)
# ['State', 'Law', 'and', 'Order', 'Restoration', 'Council']
# ('1069-011', 0, 1)
# ['Derbyshire']
# ('1047-003', 0, 1)
# ['Wigan']
# ('1082-002', 10, 12)
# ['World', 'Cup']
# ('0972-008', 0, 2)
# ['M.', 'Bevan']
# ('0958-050', 0, 1)
# ['ATLANTA']
# ('1072-019', 5, 7)
# ['Christian', 'Cullen']
# ('1095-001', 0, 2)
# ['NEW', 'YORK']
# ('1096-000', 7, 8)
# ['MARLINS']
# ('0947-008', 30, 32)
# ['D.', 'Bicknell']
# ('0987-003', 13, 17)
# ['News', 'Agency', 'of', 'Nigeria']
# ('0965-004', 11, 12)
# ['Berlin']
# ('1004-004', 1, 3)
# ['Supreme', 'Court']
# ('1053-003', 19, 21)
# ['A.', 'Hollioake']
# ('1097-007', 7, 9)
# ['Ivan', 'Lendl']
# ('1000-003', 12, 15)
# ['Budapest', 'Stock', 'Exchange']
# ('0956-008', 0, 1)
# ['Samsung']
# ('1101-012', 21, 23)
# ['Claudio', 'Suarez']
# ('0947-011', 14, 15)
# ["T.O'Gorman"]
# ('1076-022', 0, 1)
# ['Buducnost']
# ('1066-016', 0, 1)
# ['Ipswich']
# ('0946-006', 28, 29)
# ['Headingley']
# ('0955-001', 0, 1)
# ['SEOUL']
# ('0956-008', 2, 3)
# ['Haitai']
# ('1103-000', 2, 3)
# ['BELGIUM']
# ('1065-013', 0, 1)
# ['Partick']
# ('1055-005', 0, 2)
# ['A.', 'Stewart']
# ('1090-019', 22, 23)
# ['King']
# ('1148-008', 7, 9)
# ['Palestinian', 'Authority']
# ('1090-012', 8, 9)
# ['King']
# ('1066-038', 0, 1)
# ['York']
# ('1055-031', 0, 2)
# ['Waqar', 'Younis']
# ('1072-018', 10, 12)
# ['Justin', 'Swart']
# ('1081-000', 8, 10)
# ['WORLD', 'CUP']
# ('1106-007', 2, 4)
# ['Sergen', 'Yalcin']
# ('1101-011', 75, 77)
# ['Florian', 'Maurice']
# ('1072-007', 1, 3)
# ['Andre', 'Joubert']
# ('1056-001', 2, 3)
# ['England']
# ('1089-026', 10, 14)
# ['World', 'Series', 'of', 'Golf']
# ('1037-002', 25, 26)
# ['Guangdong']
# ('1042-001', 0, 1)
# ['BEIJING']
# ('1070-000', 7, 8)
# ['INDYCAR']
# ('1123-011', 0, 1)
# ['Samsung']
# ('1066-077', 0, 1)
# ['Colchester']
# ('1076-041', 0, 4)
# ['Radnicki', '(', 'N', ')']
# ('1034-003', 28, 30)
# ['El', 'Al']
# ('1095-017', 3, 4)
# ['PHILADELPHIA']
# ('1030-023', 14, 17)
# ['Salomon', 'Bros', '.']
# ('1061-009', 2, 3)
# ['Wasps']
# ('1142-012', 1, 2)
# ['PUK']
# ('0979-013', 1, 3)
# ['Harry', 'Milling']
# ('1030-006', 0, 1)
# ['Nikkei']
# ('1065-029', 0, 1)
# ['Forfar']
# ('0973-001', 0, 1)
# ['COLOMBO']
# ('1032-000', 6, 7)
# ['EOE']
# ('1057-007', 14, 15)
# ['Inzamam-ul-Haq']
# ('1066-008', 0, 1)
# ['Norwich']
# ('0972-020', 5, 7)
# ['de', 'Silva']
# ('1034-006', 6, 8)
# ['El', 'Al']
# ('0972-025', 3, 5)
# ['S.', 'Waugh']
# ('1090-012', 0, 1)
# ['Seles']
# ('1055-013', 0, 2)
# ['D.', 'Headley']
# ('1061-008', 0, 1)
# ['Orrell']
# ('1066-000', 2, 3)
# ['ENGLISH']
# ('0946-012', 20, 21)
# ['Derbyshire']
# ('0986-006', 6, 7)
# ['Irwin']
# ('0981-011', 0, 3)
# ['Douglas', '&', 'Lomason']
# ('1121-008', 35, 37)
# ['Iraqi', 'Kurdish']
# ('1015-003', 41, 42)
# ['Boston-based']
# ('0972-007', 0, 2)
# ['S.', 'Law']
# ('1060-023', 1, 3)
# ['Jonathan', 'Lomas']
# ('1116-038', 3, 6)
# ['Stars', 'and', 'Stripes']
# ('0972-024', 0, 2)
# ['S.', 'Jayasuriya']
# ('1011-007', 3, 4)
# ['Mo.-based']
# ('0983-006', 7, 8)
# ['Amman-bound']
# ('1090-003', 12, 14)
# ['United', 'States']
# ('0947-012', 17, 19)
# ['K.', 'Curran']
# ('1103-015', 54, 56)
# ['Frederic', 'Peiremans']
# ('0952-000', 7, 8)
# ['VOLGOGRAD']
# ('0946-006', 0, 1)
# ['Essex']
# ('1002-003', 11, 13)
# ['Municipal', 'Police']
# ('1053-001', 2, 3)
# ['England']
# ('1046-004', 0, 1)
# ['Deportivo']
# ('0992-007', 1, 5)
# ['Party', 'of', 'Democratic', 'Action']
# ('1128-012', 10, 11)
# ['SPC']
# ('1031-014', 33, 35)
# ['Far', 'East']
# ('1049-000', 2, 3)
# ['IRISH']
# ('1092-004', 3, 6)
# ['Netherlands', 'Czech', 'Republic']
# ('1128-006', 10, 11)
# ['UWP']
# ('1009-015', 23, 25)
# ['Agriculture', 'Department']
# ('0966-016', 1, 3)
# ['Leah', 'Pells']
# ('0953-001', 0, 2)
# ['PANAMA', 'CITY']
# ('1069-012', 9, 10)
# ['Warwickshire']
# ('1133-003', 10, 14)
# ['Human', 'Rights', 'in', 'China']
# ('1022-010', 29, 32)
# ['Chicago', 'Purchasing', 'Managers']
# ('0958-016', 0, 1)
# ['MILWAUKEE']
# ('1096-013', 25, 28)
# ['Los', 'Angeles', 'Dodgers']
# ('1054-000', 2, 5)
# ['TOUR', 'OF', 'NETHERLANDS']
# ('0989-001', 0, 1)
# ["N'DJAMENA"]
# ('1096-038', 0, 2)
# ['St', 'Louis']
# ('1068-024', 3, 4)
# ['York']
# ('0958-017', 0, 2)
# ['KANSAS', 'CITY']
# ('0990-000', 3, 4)
# ['Chechnya']
# ('0960-028', 0, 1)
# ['Rios']
# ('1066-073', 0, 2)
# ['Leyton', 'Orient']
# ('1149-005', 38, 40)
# ['Interstates', '80']
# ('1072-000', 3, 4)
# ['SPRINGBOKS']
# ('0947-006', 7, 9)
# ['A.', 'Dale']
# ('1129-003', 11, 13)
# ['Sergiyev', 'Posad']
# ('1051-011', 1, 3)
# ['Iain', 'Pyman']
# ('0947-007', 0, 2)
# ['Tunbridge', 'Wells']
# ('1097-003', 18, 20)
# ['U.S.', 'Open']
# ('1101-011', 63, 65)
# ['Robert', 'Pires']
# ('1066-075', 0, 1)
# ['Hereford']
# ('1068-018', 3, 4)
# ['Stockport']
# ('1156-008', 1, 4)
# ['U.N.', 'Security', 'Council']
# ('0951-005', 0, 1)
# ['Lithuania']
# ('1038-007', 14, 16)
# ['Hong', 'Kong']
# ('1072-018', 68, 70)
# ['Ruben', 'Kruge']
# ('1047-000', 5, 6)
# ['BRADFORD']
# ('0975-000', 0, 1)
# ['ROMANIA']
# ('1064-000', 3, 4)
# ['LYNAGH']
# ('0959-006', 2, 3)
# ['MILWAUKEE']
# ('1057-000', 7, 8)
# ['ENGLAND']
# ('1031-010', 10, 11)
# ['GMT']
# ('1007-000', 3, 5)
# ['Wall', 'Street']
# ('1094-001', 0, 2)
# ['NEW', 'YORK']
# ('0988-002', 2, 5)
# ['Driefontein', 'Consolidated', 'Ltd']
# ('0994-010', 32, 34)
# ['Soviet', 'Union']
# ('1012-006', 1, 4)
# ['U.S.', 'Treasury', 'Department']
# ('1113-004', 2, 4)
# ['Hansa', 'Rostock']
# ('1152-017', 10, 14)
# ['Tarawa', 'Amphibious', 'Readiness', 'Group']
# ('1051-004', 1, 3)
# ['Costantino', 'Rocca']
# ('1112-002', 13, 15)
# ['World', 'Cup']
# ('1064-003', 0, 1)
# ['Lynagh']
# ('0972-020', 2, 3)
# ['Vass']
# ('1125-003', 1, 11)
# ['Rally', 'for', 'the', 'Return', 'of', 'Refugees', 'and', 'Democracy', 'in', 'Rwanda']
# ('0961-002', 4, 7)
# ['National', 'Football', 'League']
# ('0985-011', 12, 13)
# ['American']
# ('1085-000', 4, 5)
# ['ESTONIA']
# ('1030-018', 10, 11)
# ['Dow']
# ('1050-000', 4, 5)
# ['LIECHTENSTEIN']
# ('0957-019', 24, 25)
# ['Sweden']
# ('1069-018', 13, 14)
# ['Northamptonshire']
# ('1101-011', 87, 89)
# ['Zinedine', 'Zidane']
# ('1116-029', 2, 3)
# ['Scottish']
# ('0979-002', 23, 25)
# ['Labor', 'Day']
# ('0953-012', 25, 30)
# ['Hector', '"', 'Macho', '"', 'Camacho']
# ('1101-011', 14, 16)
# ['Sabri', 'Lamouchi']
# ('1055-019', 0, 1)
# ['Ata-ur-Rehman']
# ('1085-000', 2, 3)
# ['BELARUS']
# ('1133-001', 0, 1)
# ['MANILA']
# ('1130-006', 6, 7)
# ['Puig']
# ('0972-000', 2, 3)
# ['AUSTRALIA']
# ('1096-036', 1, 3)
# ['St', 'Louis']
# ('1096-034', 0, 1)
# ['Beck']
# ('1024-003', 0, 1)
# ['Nasdaq']
# ('1066-067', 0, 1)
# ['Barnet']
# ('1073-000', 0, 2)
# ['RUGBY', 'UNION']
# ('0972-025', 0, 2)
# ['R.', 'Kaluwitharana']
# ('1126-001', 2, 3)
# ['Bosnia']
# ('0959-011', 2, 3)
# ['HOUSTON']
# ('1101-012', 9, 11)
# ['Alfonso', 'Rios']
# ('1068-032', 2, 3)
# ['Carlisle']
# ('1114-005', 0, 1)
# ['Lithuania']
# ('0953-000', 2, 3)
# ['PANAMA']
# ('0972-014', 0, 2)
# ['D.', 'Fleming']
# ('1072-011', 0, 1)
# ['Mehrtens']
# ('0962-009', 1, 3)
# ['Neal', 'Lancaster']
# ('1103-015', 10, 12)
# ['Bertrand', 'Crasson']
# ('0947-009', 21, 23)
# ['W.', 'Hegg']
# ('0990-003', 13, 14)
# ['Chernomyrdin']
# ('1095-020', 3, 4)
# ['Colorado']
# ('1079-007', 0, 1)
# ['Alba']
# ('0959-014', 3, 4)
# ['MONTREAL']
# ('0948-027', 6, 7)
# ['Derbyshire']
# ('1156-006', 0, 1)
# ['Nyerere']
# ('0957-002', 3, 7)
# ['U.S.', 'Open', 'Tennis', 'Championships']
# ('1000-003', 16, 17)
# ['BSE']
# ('0988-005', 17, 27)
# ['Driefontein', 'Consolidated', 'and', 'Gold', 'Fields', "'", 'Kloof', 'Gold', 'Mining', 'Co']
# ('1143-009', 2, 5)
# ['Party', 'of', 'God']
# ('1068-009', 0, 1)
# ['Oldham']
# ('1143-003', 29, 30)
# ['GMT']
# ('0985-006', 0, 1)
# ['Bruno']
# ('1144-000', 4, 5)
# ['aid-U.N.']
# ('0995-007', 12, 13)
# ['Dushanbe']
# ('1096-012', 27, 31)
# ['(', 'Tom', ')', 'Seaver']
# ('1090-010', 1, 3)
# ['United', 'States']
# ('1116-013', 1, 2)
# ['Liberal']
# ('1067-020', 2, 4)
# ['Ross', 'County']
# ('1144-001', 0, 1)
# ['BAGHDAD']
# ('0947-006', 23, 25)
# ['S.', 'Watkin']
# ('0956-006', 2, 3)
# ['Lotte']
# ('0955-000', 4, 6)
# ['SOUTH', 'KOREAN']
# ('1152-014', 20, 21)
# ['Enterprise']
# ('1075-000', 7, 10)
# ['AFRICAN', 'NATIONS', 'CUP']
# ('1160-004', 18, 21)
# ['Irish', 'Republican', 'Army']
# ('1128-001', 0, 1)
# ['WARSAW']
# ('1068-012', 0, 1)
# ['Southend']
# ('1067-017', 0, 1)
# ['Albion']
# ('1104-000', 5, 6)
# ['SPANISH']
# ('1033-007', 15, 16)
# ['OSCE']
# ('0981-017', 0, 1)
# ['Magna']
# ('1005-010', 18, 20)
# ['New', 'York']
# ('1046-000', 2, 3)
# ['REAL']
# ('1058-000', 6, 7)
# ['RANGERS']
# ('1094-028', 0, 1)
# ['CLEVELAND']
# ('0964-000', 2, 3)
# ['SILVA']
# ('1068-012', 2, 3)
# ['Swindon']
# ('1046-005', 0, 1)
# ['Real']
# ('1141-001', 0, 1)
# ['BEIJING']
# ('1078-005', 2, 3)
# ['Italy']
# ('1072-016', 2, 4)
# ['All', 'Blacks']
# ('1069-017', 4, 5)
# ['Nottinghamshire']
# ('1065-026', 0, 1)
# ['Berwick']
# ('1016-008', 40, 41)
# ['Arab-Israeli']
# ('0965-010', 6, 7)
# ['Olympic']
# ('0984-007', 6, 7)
# ['LIFFE']
# ('1126-002', 21, 22)
# ['Serb']
# ('1039-011', 24, 28)
# ['Moro', 'National', 'Liberation', 'Front']
# ('1065-009', 0, 2)
# ['St', 'Mirren']
# ('1064-007', 32, 33)
# ['Bath']
# ('1070-003', 2, 3)
# ['Vancouver']
# ('1103-009', 44, 46)
# ['De', 'Wilde']
# ('1058-022', 3, 5)
# ['Pete', 'Incaviglia']
# ('1078-005', 0, 1)
# ['Benetton']
# ('1082-000', 2, 3)
# ['AZERBAIJAN']
# ('1090-013', 14, 15)
# ['King']
# ('1058-000', 2, 3)
# ['GONZALEZ']
# ('1103-002', 0, 1)
# ['BRUSSELS']
# ('1052-005', 2, 4)
# ['Lubomir', 'Moravcik']
# ('1066-025', 0, 1)
# ['Oldham']
# ('0955-005', 0, 1)
# ['Puchon']
# ('1116-019', 18, 21)
# ['On', 'the', 'Waterfront']
# ('1039-010', 6, 7)
# ['Wahono']
# ('1029-003', 9, 11)
# ['Commerce', 'Department']
# ('1055-000', 4, 5)
# ['PAKISTAN']
# ('1007-003', 1, 3)
# ['Wall', 'Street']
# ('1103-016', 64, 66)
# ['Hakan', 'Sukur']
# ('1094-053', 2, 3)
# ['CINCINNATI']
# ('1022-012', 5, 10)
# ['Toronto', 'Bond', 'Traders', "'", 'Association']
# ('0999-001', 0, 1)
# ['MOSCOW']
# ('1030-037', 5, 9)
# ['New', 'York', 'Mercantile', 'Exchange']
# ('1123-007', 0, 1)
# ['Haitai']
# ('1022-014', 13, 14)
# ['C$']
# ('1094-009', 0, 1)
# ['BOSTON']
# ('1043-002', 15, 18)
# ['Central', 'Narcotics', 'Bureau']
# ('1072-019', 77, 79)
# ['Olo', 'Brown']
# ('0985-009', 0, 1)
# ['Bruno']
# ('0955-004', 2, 3)
# ['Ulsan']
# ('0955-005', 2, 3)
# ['Chonbuk']
# ('0972-021', 5, 6)
# ['Jayasuriya']
# ('1136-002', 1, 4)
# ['Dow', 'Chemical', 'Co']
# ('1091-002', 9, 12)
# ['National', 'Tennis', 'Centre']
# ('0948-024', 7, 9)
# ['Lord', "'s"]
# ('1000-009', 0, 1)
# ['Cofinec']
# ('1009-018', 31, 32)
# ['California']
# ('0947-011', 7, 8)
# ['Derbyshire']
# ('0955-004', 0, 1)
# ['Pohang']
# ('0947-009', 5, 7)
# ['W.', 'Athey']
# ('1030-015', 21, 25)
# ['New', 'York', 'Stock', 'Exchange']
# ('1076-005', 0, 1)
# ['Hajduk']
# ('1000-003', 2, 3)
# ['France-registered']
# ('0971-000', 2, 4)
# ['SRI', 'LANKA']
# ('1110-000', 2, 3)
# ['MILLER']
# ('0946-005', 14, 15)
# ['Simmons']
# ('1058-031', 30, 33)
# ['Boston', 'Red', 'Sox']
# ('0959-015', 2, 4)
# ['ST', 'LOUIS']
# ('1094-044', 0, 2)
# ['WESTERN', 'DIVISION']
# ('1082-000', 4, 5)
# ['SWITZERLAND']
# ('1007-007', 45, 47)
# ['Wall', 'Street']
# ('1009-015', 1, 4)
# ['California', 'Avocado', 'Commission']
# ('1157-002', 1, 5)
# ['North', 'Atlantic', 'Treaty', 'Organisation']
# ('0958-030', 0, 1)
# ['BALTIMORE']
# ('1055-000', 2, 3)
# ['ENGLAND']
# ('1040-001', 0, 1)
# ['TOKYO']
# ('1110-000', 4, 5)
# ['WBA']
# ('1136-002', 26, 28)
# ['China', 'Daily']
# ('1068-017', 2, 3)
# ['Peterborough']
# ('1027-007', 33, 35)
# ['West', 'Bank']
# ('1065-008', 0, 2)
# ['St', 'Johnstone']
# ('1143-003', 39, 44)
# ['U.N.', 'Interim', 'Force', 'in', 'Lebanon']
# ('0947-009', 9, 11)
# ['V.', 'Drakes']
# ('1069-009', 3, 4)
# ['Derbyshire']
# ('1161-000', 0, 1)
# ['Dhaka']
# ('0948-010', 7, 9)
# ['Minor', 'Counties']
# ('0998-000', 2, 3)
# ['Chechens']
# ('1068-017', 0, 1)
# ['Bournemouth']
# ('1011-016', 0, 2)
# ['Boatmen', "'s"]
# ('1076-009', 2, 4)
# ['Red', 'Star']
# ('0968-002', 21, 25)
# ['Solidarity', 'Meeting', 'for', 'Sarajevo']
# ('1072-013', 0, 1)
# ['Honiball']
# ('1058-000', 8, 9)
# ['INDIANS']
# ('0997-000', 7, 8)
# ['Interfax']
# ('0990-011', 0, 1)
# ['Itar-Tass']
# ('1067-012', 0, 1)
# ['Clyde']
# ('1128-005', 2, 3)
# ['division']
# ('1160-000', 1, 2)
# ['IRA']
# ('1055-025', 3, 4)
# ['Croft']
# ('1037-002', 3, 6)
# ['LM', 'Ericsson', 'AB']
# ('1014-000', 0, 1)
# ['Dole']
# ('0966-163', 1, 2)
# ['Nigeria']
# ('1055-006', 4, 6)
# ['Mushtaq', 'Ahmed']
# ('1068-037', 2, 3)
# ['Exeter']
# ('1033-003', 22, 23)
# ['Vienna-based']
# ('1076-020', 0, 1)
# ['Zemun']
# ('1015-000', 0, 1)
# ['Titanic']
# ('1076-031', 0, 4)
# ['Radnicki', '(', 'N', ')']
# ('0956-001', 0, 1)
# ['SEOUL']
# ('0979-012', 7, 9)
# ['Labor', 'Day']
# ('0947-009', 13, 15)
# ['I.', 'Austin']
# ('0963-003', 0, 1)
# ['Henke']
# ('1090-017', 8, 9)
# ['Olympic']
# ('1111-001', 0, 1)
# ['DUBLIN']
# ('0963-004', 12, 15)
# ['U.S.', 'Amateur', 'Championship']
# ('1074-004', 1, 3)
# ['North', 'Africans']
# ('1114-000', 4, 5)
# ['LITHUANIA']
# ('1033-003', 7, 14)
# ['Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('0972-012', 5, 6)
# ['Muralitharan']
# ('1000-019', 1, 2)
# ['Budapest']
# ('1055-011', 0, 2)
# ['D.', 'Gough']
# ('1021-001', 0, 1)
# ['HELSINKI']
# ('1069-016', 3, 4)
# ['Sussex']
# ('1069-013', 29, 31)
# ['J.', 'Ratcliffe']
# ('1039-000', 3, 4)
# ['Indonesian']
# ('0957-016', 2, 4)
# ['Conchita', 'Martinez']
# ('1024-010', 23, 25)
# ['United', 'States']
# ('1066-063', 0, 1)
# ['Carlisle']
# ('1011-000', 0, 2)
# ['Boatmen', "'s"]
# ('1022-004', 8, 9)
# ['C$']
# ('1076-027', 5, 7)
# ['OFK', 'Beograd']
# ('0958-040', 0, 2)
# ['ST', 'LOUIS']
# ('0984-012', 30, 32)
# ['Labour', 'Day']
# ('1097-004', 2, 3)
# ['Edberg']
# ('1071-004', 2, 3)
# ['Aunger']
# ('1160-023', 18, 20)
# ['Michael', 'Collins']
# ('1111-005', 1, 3)
# ['Paddy', 'Lad']
# ('0947-008', 12, 14)
# ['C.', 'Lewis']
# ('1061-005', 2, 3)
# ['Gloucester']
# ('0982-005', 1, 3)
# ['Jim', 'Ballantyne']
# ('1066-056', 0, 1)
# ['Wigan']
# ('1076-006', 2, 3)
# ['Rad']
# ('1065-019', 0, 1)
# ['Ayr']
# ('1089-006', 14, 17)
# ['1993', 'BellSouth', 'Classic']
# ('0949-000', 5, 6)
# ['ENGLAND']
# ('1092-007', 2, 4)
# ['Croatia', 'Switzerland']
# ('1069-013', 25, 27)
# ['G.', 'Kersey']
# ('1106-000', 7, 9)
# ['WORLD', 'CUP']
# ('1068-020', 2, 3)
# ['Watford']
# ('1055-023', 5, 6)
# ['Gough']
# ('1114-001', 0, 1)
# ['BUCHAREST']
# ('1046-007', 13, 14)
# ['Real']
# ('1054-009', 1, 3)
# ['Jesper', 'Skibby']
# ('1036-001', 0, 2)
# ['Rolf', 'Soderlind']
# ('1076-006', 0, 1)
# ['Zemun']
# ('1088-002', 18, 20)
# ['Jansher', 'Khan']
# ('1114-000', 2, 3)
# ['ROMANIA']
# ('1015-006', 2, 3)
# ['Titanic']
# ('1089-010', 1, 2)
# ['Parnevik']
# ('1120-006', 12, 13)
# ['Stansted']
# ('0947-009', 0, 1)
# ['Hove']
# ('1011-009', 9, 12)
# ['asset-St', '.', 'Louis']
# ('1039-011', 29, 30)
# ['MNLF']
# ('1053-000', 4, 5)
# ['PAKISTAN']
# ('1096-000', 9, 10)
# ['REDS']
# ('1127-022', 31, 32)
# ['God']
# ('0985-009', 22, 23)
# ['Wembley']
# ('1074-000', 7, 8)
# ['CUP']
# ('1058-027', 42, 44)
# ['Blue', 'Jays']
# ('1104-002', 26, 28)
# ['Roberto', 'Carlos']
# ('1076-039', 0, 1)
# ['Sloboda']
# ('0948-032', 6, 8)
# ['Lord', "'s"]
# ('0946-007', 0, 1)
# ['Hussain']
# ('0953-011', 20, 21)
# ['Panamanian']
# ('1103-012', 10, 12)
# ['De', 'Wilde']
# ('1127-015', 9, 10)
# ['Moscow-backed']
# ('0965-003', 0, 1)
# ['American']
# ('1112-000', 6, 9)
# ['1998', 'WORLD', 'CUP']
# ('1135-015', 1, 2)
# ['NLD']
# ('1067-008', 7, 9)
# ['St', 'Johnstone']
# ('1114-004', 2, 4)
# ['Cosmin', 'Contra']
# ('1069-013', 21, 23)
# ['M.', 'Butcher']
# ('0957-018', 9, 11)
# ['Cedric', 'Pioline']
# ('1076-029', 2, 6)
# ['Zeleznik', '(', 'B', ')']
# ('1076-008', 2, 3)
# ['Vojvodina']
# ('0972-037', 0, 1)
# ['Fleming']
# ('1055-008', 0, 2)
# ['M.', 'Maynard']
# ('1108-000', 4, 5)
# ['MILLER']
# ('0956-009', 0, 1)
# ['Hanwha']
# ('1069-015', 3, 4)
# ['Leeds']
# ('0947-010', 7, 9)
# ['J.', 'Pooley']
# ('1123-009', 0, 1)
# ['Hanwha']
# ('1012-002', 1, 3)
# ['State', 'Department']
# ('1110-001', 0, 1)
# ['DUBLIN']
# ('1036-000', 3, 4)
# ['Arctic']
# ('1076-008', 0, 1)
# ['Cukaricki']
# ('0963-018', 0, 1)
# ['Estes']
# ('0957-000', 7, 9)
# ['U.S.', 'OPEN']
# ('0964-001', 0, 1)
# ['MADRID']
# ('1115-002', 11, 12)
# ['IRA']
# ('0963-000', 2, 3)
# ['HENKE']
# ('1066-027', 0, 1)
# ['Grimsby']
# ('1142-005', 13, 16)
# ['Kurdistan', 'Democratic', 'Party']
# ('1055-028', 5, 6)
# ['Hollioake']
# ('1069-013', 17, 19)
# ['C.', 'Lewis']
# ('1102-000', 2, 3)
# ['FRANCE']
# ('1014-004', 31, 32)
# ['Dole']
# ('1137-001', 0, 1)
# ['SEOUL']
# ('1000-015', 10, 11)
# ['French']
# ('1016-002', 23, 25)
# ['Middle', 'East']
# ('0992-007', 6, 7)
# ['SDA']
# ('1152-004', 50, 52)
# ['United', 'States']
# ('1083-001', 0, 1)
# ['BELGRADE']
# ('1067-007', 0, 1)
# ['Stirling']
# ('1159-001', 0, 1)
# ['BRUSSELS']
# ('1152-005', 6, 9)
# ['Department', 'of', 'Defense']
# ('1066-014', 0, 1)
# ['Bradford']
# ('0972-007', 5, 6)
# ['Dharmasena']
# ('0967-007', 11, 13)
# ['UEFA', 'Cup']
# ('1093-000', 4, 6)
# ['EL', 'SALVADOR']
# ('1073-006', 2, 3)
# ['Honiball']
# ('0947-007', 15, 16)
# ['Kent']
# ('1074-001', 0, 1)
# ['NOUAKCHOTT']
# ('1134-002', 17, 18)
# ['OIC']
# ('1089-019', 0, 1)
# ['Jasper']
# ('1060-000', 6, 8)
# ['EUROPEAN', 'TOUR']
# ('1065-018', 0, 3)
# ['Queen', 'of', 'South']
# ('0953-002', 3, 10)
# ['Roberto', '"', 'Hands', 'of', 'Stone', '"', 'Duran']
# ('1079-005', 2, 3)
# ['Italy']
# ('0983-003', 16, 17)
# ['Stansted']
# ('0958-054', 0, 1)
# ['HOUSTON']
# ('1076-024', 0, 1)
# ['Borac']
# ('0958-050', 2, 3)
# ['CHICAGO']
# ('1145-001', 0, 1)
# ['MANAMA']
# ('1096-000', 5, 6)
# ['ERA']
# ('1031-004', 16, 21)
# ['Wuxi', 'Tong', 'Ling', 'Company', 'Ltd']
# ...
# ('0982-002', 0, 1)
# ['UK']
# ('1079-002', 3, 6)
# ['Trofej', 'Beograd', '96']
# ('1078-001', 0, 1)
# ['BELGRADE']
# ('1148-009', 12, 16)
# ['Zine', 'al-Abidine', 'Ben', 'Ali']
# ('1114-005', 2, 4)
# ['Danius', 'Gleveckas']
# ('1050-000', 2, 3)
# ['IRELAND']
# ('0956-007', 0, 1)
# ['Haitai']
# ('1080-000', 6, 8)
# ['WORLD', 'CUP']
# ('1068-025', 2, 3)
# ['Brentford3']
# ('1116-007', 11, 12)
# ['Roman']
# ('0958-012', 0, 2)
# ['CENTRAL', 'DIVISION']
# ('1094-010', 0, 1)
# ['TORONTO']
# ('0953-000', 4, 6)
# ['ROBERTO', 'DURAN']
# ('1000-000', 0, 1)
# ['Cofinec']
# ('1005-014', 7, 9)
# ['New', 'York']
# ('1039-010', 3, 6)
# ['House', 'of', 'Representatives']
# ('1076-031', 5, 6)
# ['Spartak']
# ('1148-007', 0, 2)
# ['LE', 'TEMPS']
# ('1068-007', 0, 1)
# ['Huddersfield']
# ('0954-005', 2, 4)
# ['Rodney', 'Eyles']
# ('1055-030', 3, 4)
# ['Hollioake']
# ('0955-017', 0, 1)
# ['Chonbuk']
# ('0980-002', 25, 30)
# ['National', 'Association', 'of', 'Purchasing', 'Management']
# ('1101-011', 21, 23)
# ['Laurent', 'Blanc']
# ('1012-005', 0, 1)
# ['Davies']
# ('0966-060', 1, 3)
# ['Andreas', 'Seelig']
# ('1016-007', 22, 23)
# ['German']
# ('1154-008', 4, 8)
# ['Human', 'Rights', 'National', 'Observatory']
# ('0948-033', 3, 5)
# ['British', 'Universities']
# ('1094-043', 0, 1)
# ['PITTSBURGH']
# ('1058-016', 29, 30)
# ['Angels']
# ('1137-007', 6, 9)
# ['International', 'Red', 'Cross']
# ('1012-008', 33, 37)
# ['Pan', 'Am', 'flight', '103']
# ('0974-007', 2, 4)
# ['Ian', 'Healy']
# ('1005-011', 11, 14)
# ['International', 'Monetary', 'Fund']
# ('1049-001', 0, 1)
# ['ESCHEN']
# ('1066-031', 0, 1)
# ['Plymouth']
# ('0966-033', 1, 3)
# ['Geir', 'Moen']
# ('1067-020', 0, 1)
# ['Montrose']
# ('1154-004', 1, 3)
# ['Le', 'Matin']
# ('1116-032', 7, 9)
# ['South', 'Africa']
# ('1091-002', 3, 7)
# ['U.S.', 'Open', 'Tennis', 'Championships']
# ('1134-002', 12, 16)
# ['Organisation', 'of', 'Islamic', 'Conference']
# ('0965-007', 9, 11)
# ['Atlanta', 'Games']
# ('0963-021', 33, 35)
# ['U.S.', 'Open']
# ('1077-003', 13, 15)
# ['Glenn', 'Hoddle']
# ('1071-000', 4, 5)
# ['PANAMA']
# ('1032-002', 31, 32)
# ['EOE']
# ('1049-001', 2, 3)
# ['Liechtenstein']
# ('1026-002', 15, 17)
# ['Islamic', 'Group']
# ('1066-050', 0, 1)
# ['Wycombe']
# ('1066-058', 0, 1)
# ['Hull']
# ('1103-016', 46, 48)
# ['Oguz', 'Cetin']
# ('0955-015', 0, 1)
# ['Chonnam']
# ('0972-027', 0, 2)
# ['A.de', 'Silva']
# ('1072-008', 1, 3)
# ['All', 'Blacks']
# ('1013-000', 0, 2)
# ['U.S.', 'Gulf']
# ('1094-038', 0, 2)
# ['CENTRAL', 'DIVISION']
# ('1071-000', 2, 3)
# ['CANADA']
# ('0990-000', 2, 3)
# ['Lebed']
# ('0946-009', 39, 40)
# ['Warwickshire']
# ('1109-000', 2, 3)
# ['DUTCH']
# ('0977-002', 17, 20)
# ['Bank', 'of', 'Canada']
# ('0957-015', 8, 10)
# ['Anne-Gaelle', 'Sidot']
# ('1058-007', 8, 9)
# ['RBI']
# ('0967-000', 3, 5)
# ['STANDARD', 'LIEGE']
# ('1061-006', 0, 2)
# ['London', 'Irish']
# ('1072-002', 0, 1)
# ['JOHANNESBURG']
# ('0972-013', 3, 4)
# ['Kaluwitharana']
# ('0965-009', 17, 19)
# ['Golden', 'Four']
# ('1131-002', 5, 7)
# ['United', 'Nations']
# ('1158-001', 0, 1)
# ['BRUSSELS']
# ('0975-004', 25, 26)
# ['Bucharest']
# ('1026-004', 0, 1)
# ['Al-Akhbar']
# ('0956-010', 2, 3)
# ['Lotte']
# ('0972-013', 5, 6)
# ['Chandana']
# ('1142-006', 20, 21)
# ['KDP']
# ('1055-037', 2, 3)
# ['Gough']
# ('1092-000', 4, 7)
# ['1997', 'FED', 'CUP']
# ('1095-013', 0, 1)
# ['CHICAGO']
# ('1105-000', 4, 5)
# ['SPANISH']
# ('1094-016', 0, 1)
# ['MILWAUKEE']
# ('1076-023', 0, 4)
# ['Proleter', '(', 'Z', ')']
# ('0953-011', 21, 23)
# ['Boxing', 'Association']
# ('0947-010', 15, 17)
# ['M.', 'Gatting']
# ('1109-000', 6, 7)
# ['BRAZIL']
# ('1065-028', 0, 1)
# ['Albion']
# ('1149-011', 3, 8)
# ['National', 'Highway', 'Traffic', 'Safety', 'Administration']
# ('0947-008', 2, 4)
# ['The', 'Oval']
# ('1069-008', 0, 1)
# ['Glamorgan']
# ('1071-001', 0, 1)
# ['EDMONTON']
# ('1069-009', 5, 6)
# ['Worcestershire']
# ('0979-002', 22, 23)
# ['U.S.']
# ('0972-036', 6, 7)
# ['Law']
# ('0958-038', 0, 2)
# ['CENTRAL', 'DIVISION']
# ('1053-003', 15, 17)
# ['Ijaz', 'Ahmed']
# ('1128-012', 3, 4)
# ['UWP-Hachette']
# ('1072-006', 0, 1)
# ['Springbok']
# ('1123-014', 0, 1)
# ['OB']
# ('1065-035', 0, 2)
# ['Inverness', 'Thistle']
# ('0972-009', 0, 2)
# ['S.', 'Waugh']
# ('1069-006', 3, 4)
# ['Glamorgan']
# ('0959-010', 0, 2)
# ['San', 'Diego']
# ('0985-011', 13, 14)
# ['Tyson']
# ('1075-003', 0, 1)
# ['Benin']
# ('1066-046', 0, 1)
# ['Gillingham']
# ('0947-009', 18, 19)
# ['Lancashire']
# ('1069-014', 0, 1)
# ['Surrey']
# ('1008-018', 4, 6)
# ['First', 'Union']
# ('0969-004', 0, 1)
# ['Nice']
# ('0975-012', 1, 3)
# ['Luli', 'Popescu']
# ('1069-009', 1, 2)
# ['Chesterfield']
# ('1161-010', 1, 3)
# ['Dhaka', 'Newsroom']
# ('1115-009', 5, 7)
# ['Iron', 'Lady']
# ('1099-005', 13, 15)
# ['SC', 'Freiburg']
# ('1140-003', 16, 18)
# ['High', 'Court']
# ('1082-000', 6, 8)
# ['WORLD', 'CUP']
# ('1076-043', 0, 1)
# ['Rudar']
# ('1089-011', 0, 1)
# ['Parnevik']
# ('1133-003', 7, 9)
# ['New', 'York-based']
# ('1076-044', 0, 4)
# ['Mladost', '(', 'BJ', ')']
# ('1068-019', 2, 4)
# ['Bristol', 'City']
# ('1050-000', 7, 9)
# ['WORLD', 'CUP']
# ('1088-002', 35, 37)
# ['Rodney', 'Eyles']
# ('0984-016', 0, 3)
# ['Japanese', 'Goverment', 'Bonds']
# ('0971-002', 13, 16)
# ['Singer', 'World', 'Series']
# ('0946-006', 26, 27)
# ['Yorkshire']
# ('1100-000', 2, 3)
# ['JOHNSON']
# ('0970-000', 7, 8)
# ['ATALANTA']
# ('1082-001', 0, 1)
# ['BAKU']
# ('1069-017', 9, 11)
# ['C.', 'Tolley']
# ('1001-006', 1, 3)
# ['Bucharest', 'Newsroom']
# ('1069-014', 4, 5)
# ['Warwickshire']
# ('1055-028', 0, 2)
# ['Wasim', 'Akram']
# ('1096-031', 26, 29)
# ['San', 'Francisco', 'Giants']
# ('1056-047', 3, 4)
# ['Italy']
# ('1068-023', 2, 3)
# ['Burnley']
# ('1052-002', 12, 14)
# ['World', 'Cup']
# ('1068-036', 2, 3)
# ['Northampton']
# ('1021-000', 0, 1)
# ['MARTELA']
# ('0972-012', 3, 4)
# ['Ranatunga']
# ('1135-008', 22, 24)
# ['Suu', 'Kyi']
# ('1091-003', 8, 10)
# ['Steffi', 'Graf']
# ('1067-008', 2, 4)
# ['East', 'Fife']
# ('1160-003', 34, 37)
# ['Venice', 'Film', 'Festival']
# ('1069-016', 1, 2)
# ['Hove']
# ('1039-013', 0, 2)
# ['MEDIA', 'INDONESIA']
# ('1076-026', 0, 1)
# ['Sloboda']
# ('1055-023', 3, 4)
# ['Croft']
# ('0958-027', 0, 1)
# ['CLEVELAND']
# ('1072-019', 41, 43)
# ['Justin', 'Marshall']
# ('1101-000', 5, 7)
# ['WORLD', 'CUP']
# ('1041-001', 0, 1)
# ['TOKYO']
# ('1068-023', 0, 1)
# ['Millwall']
# ('1068-036', 0, 1)
# ['Scarborough']
# ('1026-001', 0, 1)
# ['CAIRO']
# ('1103-015', 15, 17)
# ['Dirk', 'Medved']
# ('1148-000', 3, 4)
# ['Tunisia']
# ('0972-030', 0, 2)
# ['R.', 'Mahanama']
# ('1064-002', 30, 31)
# ['Leicester']
# ('1109-005', 2, 5)
# ['Ronald', 'de', 'Boer']
# ('1077-001', 2, 3)
# ['Moldova']
# ('0946-000', 2, 3)
# ['LEICESTERSHIRE']
# ('1006-007', 38, 40)
# ['Mohammed', 'Idris']
# ('1069-010', 15, 17)
# ['P.', 'DeFreitas']
# ('1107-001', 0, 1)
# ['VIENNA']
# ('1094-042', 0, 1)
# ['CINCINNATI']
# ('1135-006', 26, 27)
# ['NLD']
# ('1058-038', 8, 9)
# ['ERA']
# ('1030-021', 0, 2)
# ['Wall', 'Street']
# ('1007-013', 29, 31)
# ['Wall', 'Street']
# ('1077-001', 0, 1)
# ['CHISINAU']
# ('1072-019', 46, 48)
# ['Zinzan', 'Brooke']
# ('1121-003', 5, 8)
# ['Iraqi', 'National', 'Congress']
# ('1096-006', 1, 2)
# ['Bolesy']
# ('1095-015', 2, 3)
# ['CINCINNATI']
# ('0947-008', 18, 20)
# ['M.', 'Butcher']
# ('1001-002', 1, 5)
# ['National', 'Bank', 'of', 'Romania']
# ('1148-006', 1, 2)
# ['Tunisia']
# ('0966-123', 4, 5)
# ['Belarus']
# ('1064-000', 9, 10)
# ['LEICESTER']
# ('1032-002', 27, 30)
# ['European', 'Options', 'Exchange']
# ('1066-026', 0, 2)
# ['Sheffield', 'United']
# ('1138-001', 0, 1)
# ['BEIJING']
# ('1070-003', 3, 4)
# ['IndyCar']
# ('1103-015', 62, 64)
# ['Marc', 'Degryse']
# ('1024-002', 1, 2)
# ['Name']
# ('1146-004', 2, 6)
# ['Patriotic', 'Union', 'of', 'Kurdistan']
# ('1094-025', 0, 1)
# ['BALTIMORE']
# ('1043-001', 0, 1)
# ['SINGAPORE']
# ('1054-020', 6, 7)
# ['Rabobank']
# ('1019-001', 2, 3)
# ['Netherlands']
# ('1008-019', 2, 3)
# ['FOMC']
# ('1103-016', 69, 71)
# ['Saffet', 'Sancakli']
# ('0957-017', 10, 11)
# ['Romania']
# ('1056-037', 9, 10)
# ['Latvia']
# ('1025-001', 0, 1)
# ['DAMASCUS']
# ('1055-001', 2, 3)
# ['England']
# ('0947-009', 2, 3)
# ['Sussex']
# ('1076-019', 0, 1)
# ['Cukaricki']
# ('1063-000', 7, 9)
# ['WORLD', 'CUP']
# ('1017-003', 34, 36)
# ['Air', 'France']
# ('0966-094', 1, 3)
# ['Olabisi', 'Afolabi']
# ('0973-000', 8, 10)
# ['SRI', 'LANKA']
# ('1055-005', 3, 5)
# ['Mushtaq', 'Ahmed']
# ('1072-018', 85, 87)
# ['Kobus', 'Wiese']
# ('1116-033', 3, 5)
# ['United', 'States']
# ('1020-008', 1, 3)
# ['Bombay', 'Commodities']
# ('1054-019', 6, 7)
# ['MG-Technogym']
# ('0974-008', 3, 5)
# ['Arjuna', 'Ranatunga']
# ('1101-012', 35, 37)
# ['German', 'Villa']
# ('1065-023', 0, 1)
# ['Brechin']
# ('1072-018', 26, 29)
# ['Danie', 'van', 'Schalkwyk']
# ('1001-001', 0, 1)
# ['BUCHAREST']
# ('0999-003', 0, 1)
# ['Interfax']
# ('1113-004', 0, 1)
# ['Karlsruhe']
# ('1057-001', 2, 3)
# ['England']
# ('1095-005', 0, 1)
# ['DETROIT']
# ('1073-000', 6, 8)
# ['ALL', 'BLACKS']
# ('1067-001', 0, 1)
# ['GLASGOW']
# ('1040-000', 0, 3)
# ['Jeans', 'Mate', 'Corp']
# ('1101-011', 70, 72)
# ['Nicolas', 'Ouedec']
# ('1038-000', 0, 1)
# ['HK']
# ('1089-000', 7, 10)
# ['GREATER', 'MILWAUKEE', 'OPEN']
# ('0961-000', 3, 4)
# ['CUNNINGHAM']
# ('0990-009', 12, 14)
# ['Russian', 'Federation']
# ('1053-000', 2, 3)
# ['ENGLAND']
# ('0947-008', 26, 28)
# ['J.', 'Ratcliffe']
# ('0972-007', 3, 4)
# ['Tillekeratne']
# ('0965-003', 17, 18)
# ['post-Games']
# ('0975-001', 0, 1)
# ['BUCHAREST']
# ('0970-003', 1, 4)
# ['Gazzetta', 'dello', 'Sport']
# ('1070-001', 0, 1)
# ['VANCOUVER']
# ('1092-004', 10, 12)
# ['Japan', 'Spain']
# ('1076-010', 2, 3)
# ['Becej']
# ('1087-007', 0, 1)
# ['Hill']
# ('1116-025', 4, 6)
# ['Baudouin', 'I']
# ('1116-029', 10, 13)
# ['Italian', 'Grand', 'Prix']
# ('0960-000', 2, 3)
# ['TARANGO']
# ('1094-026', 2, 3)
# ['TORONTO']
# ('0946-011', 14, 15)
# ['Worcestershire']
# ('1089-004', 13, 18)
# ['Brown', 'Deer', 'Park', 'Golf', 'Course']
# ('1076-010', 0, 1)
# ['Partizan']
# ('1101-009', 0, 1)
# ['Jacquet']
# ('1066-052', 0, 1)
# ['Stockport']
# ('0956-014', 0, 1)
# ['Haitai']
# ('1067-007', 2, 3)
# ['Dundee']
# ('1037-004', 13, 14)
# ['IN']
# ('1058-015', 7, 8)
# ['West']
# ('1065-007', 0, 1)
# ['Dundee']
# ('1004-003', 10, 12)
# ['New', 'Liberty']
# ('1130-005', 45, 49)
# ['A', 'World', 'of', 'Things']
# ('1094-026', 0, 1)
# ['CHICAGO']
# ('0946-011', 0, 1)
# ['Derbyshire']
# ('1101-012', 26, 28)
# ['Duilio', 'Davino']
# ('0968-003', 40, 41)
# ['Kosevo']
# ('1146-007', 27, 28)
# ['KDP']
# ('0967-002', 18, 19)
# ['Intertoto']
# ('1067-015', 0, 1)
# ['Stenhousemuir']
# ('0947-008', 9, 10)
# ['Surrey']
# ('1094-056', 2, 4)
# ['ST', 'LOUIS']
# ('0958-029', 2, 3)
# ['OAKLAND']
# ('0975-007', 4, 5)
# ['Comelf']
# ('1112-008', 1, 3)
# ['Berti', 'Vogts']
# ('1096-033', 0, 1)
# ['Estes']
# ('0968-005', 18, 22)
# ['IAAF', 'Grand', 'Prix', 'Final']
# ('1038-000', 8, 9)
# ['Tsang']
# ('1079-005', 0, 1)
# ['Benetton']
# ('0958-054', 2, 3)
# ['PITTSBURGH']
# ('1094-012', 0, 2)
# ['CENTRAL', 'DIVISION']
# ('1067-015', 2, 3)
# ['Stranraer']
# ('1068-035', 2, 3)
# ['Rochdale']
# ('1001-002', 6, 7)
# ['BNR']
# ('0958-029', 0, 1)
# ['BOSTON']
# ('0970-000', 4, 5)
# ['LENTINI']
# ('0960-000', 4, 5)
# ["O'BRIEN"]
# ('1116-007', 3, 6)
# ['Treaty', 'of', 'Baden']
# ('0954-002', 4, 7)
# ['Hong', 'Kong', 'Open']
# ('1066-072', 0, 1)
# ['Doncaster']
# ('1047-003', 2, 4)
# ['Bradford', 'Bulls']
# ('1033-007', 16, 17)
# ['Chechnya']
# ('1128-015', 1, 3)
# ['Anthony', 'Barker']
# ('1128-013', 12, 13)
# ['SPC']
# ('1076-000', 2, 3)
# ['YUGOSLAV']
# ('1058-032', 0, 1)
# ['Telgheder']
# ('1101-012', 40, 41)
# ['Gomez']
# ('1055-022', 5, 6)
# ['Gough']
# ('1057-000', 2, 3)
# ['PAKISTAN']
# ('1096-002', 21, 23)
# ['Florida', 'Marlins']
# ('1125-001', 0, 1)
# ['NAIROBI']
# ('1031-004', 39, 40)
# ['Jiangsu']
# ('1142-001', 0, 1)
# ['ISTANBUL']
# ('1007-016', 13, 15)
# ['White', 'House']
# ('1127-000', 0, 1)
# ['Chechens']
# ('1011-006', 0, 2)
# ['St.', 'Louis-based']
# ('1152-014', 5, 8)
# ['F', '/', 'A-18']
# ('0974-000', 2, 3)
# ['AUSTRALIA']
# ('1022-013', 19, 21)
# ['Labour', 'Day']
# ('1056-023', 1, 3)
# ['Magali', 'Faure']
# ('1055-027', 3, 4)
# ['Stewart']
# ('1096-002', 2, 3)
# ['ERA']
# ('1027-014', 4, 6)
# ['Abu', 'Ammar']
# ('0972-005', 5, 6)
# ['Jayasuriya']
# ('1017-001', 0, 1)
# ['PARIS']
# ('1090-003', 37, 39)
# ['U.S.', 'Open']
# ('0984-012', 0, 2)
# ['UNITED', 'STATES']
# ('1054-003', 8, 12)
# ['Tour', 'of', 'the', 'Netherlands']
# ('1027-011', 3, 6)
# ['Arab', 'East', 'Jerusalem']
# ('1156-004', 14, 16)
# ['Great', 'Lakes']
# ('1135-025', 6, 12)
# ['James', 'Leander', '(', 'Leo', ')', 'Nichols']
# ('1028-002', 8, 9)
# ['MI']
# ('1093-004', 2, 4)
# ['Joe-Max', 'Moore']
# ('1103-015', 30, 32)
# ['Gunther', 'Schepens']
# ('1054-011', 6, 7)
# ['Aki']
# ('1096-043', 0, 1)
# ['Wall']
# ('1056-007', 1, 3)
# ['Marion', 'Clignet']
# ('1086-001', 0, 1)
# ['CHISINAU']
# ('1066-071', 0, 1)
# ['Chester']
# ('1055-030', 0, 2)
# ['Saqlain', 'Mushtaq']
# ('0992-001', 0, 1)
# ['SARAJEVO']
# ('1067-006', 2, 4)
# ['St', 'Mirren']
# ('0965-000', 2, 3)
# ['MITCHELL']
# ('0969-000', 5, 6)
# ['NICE']
# ('1079-001', 0, 1)
# ['BELGRADE']
# ('0972-014', 3, 4)
# ['Chandana']
# ('1101-012', 29, 30)
# ['Becerril']
# ('1009-011', 24, 27)
# ['World', 'Trade', 'Organisation']
# ('1073-000', 3, 5)
# ['SOUTH', 'AFRICA']
# ('1128-004', 26, 27)
# ['Warsaw']
# ('1073-009', 2, 3)
# ['Mehrtens']
# ('1061-013', 0, 1)
# ['Dunvant']
# ('1160-010', 6, 9)
# ['The', 'Crying', 'Game']
# ('1069-007', 5, 6)
# ['Durham']
# ('1031-002', 0, 1)
# ['MILAN']
# ('1007-018', 15, 17)
# ['Wall', 'Street']
# ('1101-012', 52, 55)
# ['Raul', 'Rodrigo', 'Lara']
# ('1011-006', 31, 33)
# ['Boatmen', "'s"]
# ('1089-000', 2, 3)
# ['PARNEVIK']
# ('1003-000', 4, 5)
# ['Surinam']
# ('0984-019', 0, 1)
# ['DNIB']
# ('1096-000', 2, 4)
# ['KEVIN', 'BROWN']
# ('1030-004', 0, 2)
# ['NY', 'Dow']
# ('1101-011', 31, 33)
# ['Franck', 'Leboeuf']
# ('1022-012', 28, 29)
# ['GMT']
# ('1015-002', 20, 22)
# ['RMS', 'Titanic']
# ('1137-004', 0, 1)
# ['Li']
# ('1068-019', 0, 1)
# ['Bury']
# ('1122-003', 6, 9)
# ['British', 'Broadcasting', 'Corporation']
# ('0986-006', 2, 3)
# ['Breen']
# ('1089-003', 0, 1)
# ['Parnevik']
# ('0972-029', 0, 2)
# ['H.', 'Tillekeratne']
# ('1096-036', 23, 24)
# ['Cardinals']
# ('1095-000', 2, 4)
# ['MAJOR', 'LEAGUE']
# ('1013-002', 8, 10)
# ['U.S.', 'Gulf']
# ('1037-003', 10, 15)
# ['Guangdong', 'Post', 'and', 'Telecommunications', 'Administration']
# ('1089-004', 0, 1)
# ['Parnevik']
# ('0969-003', 0, 1)
# ['Baratelli']
# ('1064-000', 7, 8)
# ['DWYER']
# ('1096-002', 25, 27)
# ['Cincinnati', 'Reds']
# ('1150-006', 13, 16)
# ['Lilac', 'Falls', 'Motel']
# ('1057-007', 34, 35)
# ['Ata-ur-Rehman']
# ('1067-012', 2, 5)
# ['Queen', 'of', 'South']
# ('1031-000', 0, 1)
# ['Pirelli']
# ('0949-004', 0, 1)
# ['Adams']
# ('1124-010', 20, 22)
# ['Northern', 'Cape']
# ('1126-004', 17, 19)
# ['Max', 'Marriner']
# ('1099-000', 4, 5)
# ['SCOTLAND']
# ('1058-040', 29, 31)
# ['Minnesota', 'Twins']
# ('1013-004', 6, 7)
# ['European']
# ('1068-022', 2, 3)
# ['Rotherham']
# ('1156-000', 6, 7)
# ['Nyerere']
# ('1077-000', 2, 3)
# ['INCE']
# ('1124-000', 0, 2)
# ['S.', 'African']
# ('1066-036', 0, 1)
# ['Shrewsbury']
# ('1069-015', 6, 7)
# ['Yorkshire']
# ('1103-000', 5, 6)
# ['TURKEY']
# ('0972-013', 0, 2)
# ['J.', 'Gillespie']
# ('1069-004', 0, 1)
# ['Middlesex']
# ('1099-000', 2, 3)
# ['AUSTRIA']
# ('1076-009', 0, 1)
# ['Buducnost']
# ('1000-001', 0, 2)
# ['Emese', 'Bartha']
# ('1000-005', 0, 1)
# ['Cofinec']
# ('1052-000', 2, 3)
# ['SLOVAKIA']
# ('1015-003', 42, 44)
# ['Reagan', 'Communications']
# ('1136-002', 6, 8)
# ['United', 'States']
# ('1086-000', 4, 5)
# ['MOLDOVA']
# ('1055-017', 4, 6)
# ['A.', 'Mullally']
# ('1093-005', 0, 2)
# ['El', 'Salvador']
# ('1029-014', 21, 23)
# ['Wall', 'Street']
# ('1036-023', 0, 1)
# ['Barentsburg']
# ('1115-003', 0, 3)
# ['The', 'Sunday', 'Telegraph']
# ('1056-006', 1, 3)
# ['Antonella', 'Bellutti']
# ('1107-000', 8, 10)
# ['WORLD', 'CUP']
# ('0994-002', 0, 1)
# ['MINSK']
# ('1096-036', 26, 28)
# ['Colorado', 'Rockies']
# ('1113-000', 2, 4)
# ['GERMAN', 'CUP']
# ('1072-008', 12, 14)
# ['Walter', 'Little']
# ('1053-003', 7, 9)
# ['N.', 'Knight']
# ('1058-014', 5, 7)
# ['White', 'Sox']
# ('1013-004', 8, 9)
# ['Mediterranean']
# ('1073-001', 0, 1)
# ['JOHANNESBURG']
# ('0947-000', 2, 5)
# ['ENGLISH', 'COUNTY', 'CHAMPIONSHIP']
# ('1065-031', 0, 1)
# ['Arbroath']
# ('1149-005', 35, 37)
# ['East', 'Coast']
# ('1054-014', 4, 5)
# ['Belgium']
# ('1046-001', 0, 2)
# ['LA', 'CORUNA']
# ('0951-005', 2, 4)
# ['Danius', 'Gleveckas']
# ('1158-005', 19, 20)
# ['Uzi']
# ('1112-001', 0, 1)
# ['BONN']
# ('1145-003', 7, 8)
# ["Shul'ala"]
# ('1128-010', 8, 9)
# ['Ruch']
# ('0958-020', 0, 1)
# ['SEATTLE']
# ('1052-000', 4, 5)
# ['FAROES']
# ('1101-011', 48, 50)
# ['Didier', 'Deschamps']
# ('0958-008', 0, 1)
# ['BALTIMORE']
# ('1069-018', 3, 4)
# ['Gloucestershire']
# ('1068-011', 2, 3)
# ['Stoke']
# ('1054-014', 6, 7)
# ['Collstrop']
# ('1108-004', 0, 1)
# ['Heath']
# ('1054-021', 1, 2)
# ['Ludwig']
# ('1023-000', 1, 4)
# ['Computer', 'Systems', 'Inc']
# ('1066-037', 0, 1)
# ['Blackpool']
# ('1066-028', 0, 1)
# ['Southend']
# ('1055-037', 5, 6)
# ['Mullally']
# ('1103-016', 32, 34)
# ['Alpay', 'Ozalan']
# ('1096-037', 0, 1)
# ['Benes']
# ('1034-007', 1, 4)
# ['Air', 'Cargo', 'Newsroom']
# ('1070-000', 6, 7)
# ['VANCOUVER']
# ('1123-012', 0, 1)
# ['Lotte']
# ('1068-011', 0, 1)
# ['Reading']
# ('1069-013', 0, 1)
# ['Warwickshire']
# ('0957-015', 2, 4)
# ['Lindsay', 'Davenport']
# ('1116-003', 3, 5)
# ['Elizabeth', 'I']
# ('1089-002', 0, 2)
# ['Jesper', 'Parnevik']

# %%
print("The number of false positives are",len(set(spans(df_dev))-spans_dev_gold))
false_neg(spans_dev_gold, set(improved_gold_spans(df_dev)), df_dev)
# Out:
# The number of false positives are 3627
# ('1127-022', 37, 40)
# ['Freedom', 'for', 'Chechnya']
# ('1138-008', 13, 16)
# ['Democracy', 'Wall', 'movement']
# ('0953-012', 22, 25)
# ['Puerto', 'Rico', "'s"]
# ('1058-002', 16, 20)
# ['the', 'Cleveland', 'Indians', '5-3']
# ('0966-016', 1, 4)
# ['Leah', 'Pells', '(']
# ('1005-014', 10, 11)
# ['Comex']
# ('1055-032', 2, 6)
# ['Knight', 'b', 'Hollioake', '2']
# ('1106-006', 0, 4)
# ['Belgium', '-', 'Marc', 'Degryse']
# ('0977-002', 16, 20)
# ['the', 'Bank', 'of', 'Canada']
# ('1150-005', 24, 28)
# ['the', 'Rochester', 'Fire', 'Department']
# ('1096-031', 25, 29)
# ['the', 'San', 'Francisco', 'Giants']
# ('1069-007', 5, 7)
# ['Durham', '114']
# ('1058-022', 23, 26)
# ['the', 'Seattle', 'Mariners']
# ('0987-002', 22, 26)
# ['the', 'national', 'news', 'agency']
# ('1067-013', 0, 2)
# ['Dumbarton', '1']
# ('0957-019', 0, 3)
# ['Add', 'Women', "'s"]
# ('1076-000', 3, 7)
# ['LEAGUE', 'RESULTS', '/', 'STANDINGS']
# ('1157-004', 5, 6)
# ['Iraqi']
# ('1104-002', 12, 15)
# ['Deportivo', 'Coruna', '1']
# ('0957-033', 35, 37)
# ['6-3', '6-3']
# ('1051-001', 2, 4)
# ['England', '1996-08-31']
# ('1134-001', 0, 2)
# ['MANILA', '1996-08-31']
# ('0971-003', 2, 4)
# ['Australia', '228-9']
# ('0984-006', 33, 34)
# ['PMI']
# ('1013-004', 6, 9)
# ['European', '/', 'Mediterranean']
# ('1134-002', 11, 18)
# ['the', 'Organisation', 'of', 'Islamic', 'Conference', '(', 'OIC']
# ('1142-014', 1, 3)
# ['allied', 'planes']
# ('0988-005', 17, 19)
# ['Driefontein', 'Consolidated']
# ('0989-002', 18, 19)
# ['Education']
# ('1116-014', 3, 7)
# ['the', 'House', 'of', 'Lords']
# ('1092-002', 6, 8)
# ['Fed', 'Cup']
# ('1058-022', 3, 6)
# ['Pete', 'Incaviglia', "'s"]
# ('1016-002', 22, 25)
# ['the', 'Middle', 'East']
# ('1097-003', 18, 19)
# ['U.S.']
# ('0974-000', 0, 3)
# ['CRICKET', '-', 'AUSTRALIA']
# ('1049-002', 0, 5)
# ['The', 'Republic', 'of', 'Ireland', "'s"]
# ('1035-010', 14, 22)
# ['the', 'Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('0997-000', 5, 8)
# ['hospital', '-', 'Interfax']
# ('0953-000', 0, 4)
# ['BOXING', '-', 'PANAMA', "'S"]
# ('1071-002', 3, 4)
# ['3-1']
# ('1126-004', 16, 19)
# ['Lieutenant-Colonel', 'Max', 'Marriner']
# ('1096-020', 19, 20)
# ['6-2']
# ('1014-010', 50, 55)
# ['the', 'League', 'of', 'Women', 'Voters']
# ('1022-012', 4, 10)
# ['the', 'Toronto', 'Bond', 'Traders', "'", 'Association']
# ('0975-004', 24, 28)
# ['the', 'Bucharest', 'stock', 'exchange']
# ('1090-003', 36, 39)
# ['the', 'U.S.', 'Open']
# ('1142-002', 22, 23)
# ['Iraqi']
# ('1014-010', 31, 36)
# ['the', 'Commission', 'on', 'Presidential', 'Debates']
# ('0967-007', 10, 13)
# ['the', 'UEFA', 'Cup']
# ('1069-013', 14, 16)
# ['Surrey', '468']
# ('1092-004', 11, 12)
# ['Spain']
# ('1027-007', 32, 35)
# ['the', 'West', 'Bank']
# ('1150-006', 12, 16)
# ['the', 'Lilac', 'Falls', 'Motel']
# ('1055-027', 3, 7)
# ['Stewart', 'b', 'Hollioake', '23']
# ('1125-012', 5, 7)
# ['Rwandan', 'Hutu']
# ('1091-000', 7, 8)
# ['U.S.']
# ('1041-000', 0, 4)
# ['Apic', 'Yamada', '-', '6mth']
# ('0986-000', 0, 3)
# ['Soccer', '-', 'McCarthy']
# ('0981-010', 3, 7)
# ['Douglas', '&', 'Lomason', "'s"]
# ('1067-012', 0, 3)
# ['Clyde', '0', 'Queen']
# ('1035-008', 12, 13)
# ['Armenian']
# ('0953-011', 20, 23)
# ['Panamanian', 'Boxing', 'Association']
# ('1138-002', 17, 18)
# ['China']
# ('0965-003', 0, 3)
# ['American', 'Dennis', 'Mitchell']
# ('1096-037', 2, 3)
# ['12-8']
# ('0948-016', 5, 6)
# ['Norfolk']
# ('1079-005', 0, 3)
# ['Benetton', '(', 'Italy']
# ('1053-003', 15, 18)
# ['Ijaz', 'Ahmed', '79']
# ('1004-004', 0, 3)
# ['The', 'Supreme', 'Court']
# ('1116-035', 4, 7)
# ['Alan', 'John', 'Percivale']
# ('1046-000', 7, 10)
# ['SCRAPPY', 'OPENING', 'MATCH']
# ('0984-012', 18, 22)
# ['Chicago', 'Purchasing', 'Managers', "'"]
# ('0984-015', 5, 6)
# ['182nd']
# ('1069-012', 2, 3)
# ['Oval']
# ('1004-003', 6, 12)
# ['the', 'Sereipheap', 'Thmei', '(', 'New', 'Liberty']
# ('1161-002', 2, 6)
# ['the', 'Dhaka', 'Stock', 'Exchange']
# ('1143-003', 38, 42)
# ['the', 'U.N.', 'Interim', 'Force']
# ('1128-004', 25, 29)
# ['the', 'Warsaw', 'stock', 'exchange']
# ('1015-003', 42, 43)
# ['Reagan']
# ('1047-000', 8, 9)
# ['SEMIFINAL']
# ('0959-010', 0, 3)
# ['San', 'Diego', '3']
# ('1061-000', 0, 4)
# ['RUGBY', 'UNION', '-', 'ENGLISH']
# ('1156-008', 0, 4)
# ['The', 'U.N.', 'Security', 'Council']
# ('0957-019', 20, 25)
# ['7-5', 'Asa', 'Carlsson', '(', 'Sweden']
# ('1112-008', 0, 3)
# ['Coach', 'Berti', 'Vogts']
# ('1087-015', 3, 7)
# ['the', 'Professional', 'Squash', 'Association']
# ('1058-002', 12, 15)
# ['the', 'Texas', 'Rangers']
# ('1037-004', 7, 8)
# ['ISDN']
# ('1071-002', 16, 18)
# ['the', '1998']
# ('1085-000', 6, 9)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('0980-009', 3, 6)
# ['the', 'Federal', 'Reserve']
# ('0988-002', 24, 27)
# ['South', 'Africa', 'Ltd']
# ('1092-004', 7, 8)
# ['Germany']
# ('1115-010', 3, 6)
# ['Ronald', 'Reagan', "'s"]
# ('1136-002', 5, 8)
# ['the', 'United', 'States']
# ('1008-018', 4, 7)
# ['First', 'Union', 'bank']
# ('1136-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('1082-000', 6, 9)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1011-022', 15, 16)
# ['Boatmen']
# ('1107-000', 8, 11)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1124-009', 5, 8)
# ['South', 'Africa', "'s"]
# ('1058-011', 23, 26)
# ['the', 'American', 'League']
# ('1137-002', 26, 28)
# ['unification', 'ministry']
# ('1121-008', 36, 37)
# ['Kurdish']
# ('0957-013', 14, 16)
# ['6-1', '6-1']
# ('1069-015', 1, 4)
# ['Headingley', '(', 'Leeds']
# ('1139-006', 13, 16)
# ['Democracy', 'Wall', 'movement']
# ('1061-019', 2, 3)
# ['Heriot']
# ('1002-003', 10, 13)
# ['the', 'Municipal', 'Police']
# ('1009-007', 0, 3)
# ['The', 'Agriculture', 'Department']
# ('1058-014', 8, 12)
# ['the', 'American', 'League', 'Central']
# ('1100-000', 0, 5)
# ['BOXING', '-', 'JOHNSON', 'WINS', 'UNANIMOUS']
# ('0972-020', 2, 8)
# ['Vass', '7-0-29-0', ',', 'de', 'Silva', '4-0-25-0']
# ('1007-033', 0, 5)
# ['The', 'Standard', '&', 'Poor', "'s"]
# ('0971-002', 12, 16)
# ['the', 'Singer', 'World', 'Series']
# ('0970-003', 1, 2)
# ['Gazzetta']
# ('1103-003', 5, 7)
# ['World', 'Cup']
# ('1073-000', 0, 7)
# ['RUGBY', 'UNION', '-', 'SOUTH', 'AFRICA', 'BEAT', 'ALL']
# ('1058-016', 3, 6)
# ['Tino', 'Martinez', "'s"]
# ('1096-020', 27, 28)
# ['13-8']
# ('1126-001', 2, 4)
# ['Bosnia', '1996-08-31']
# ('1138-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('1056-038', 7, 8)
# ['Arrue']
# ('1050-000', 7, 10)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1064-000', 0, 5)
# ['RUGBY', 'UNION', '-', 'LYNAGH', 'SEALS']
# ('1004-002', 4, 5)
# ['Sihanouk']
# ('1054-001', 3, 4)
# ['1996-08-31']
# ('1102-000', 7, 8)
# ['FRIENDLY']
# ('1039-014', 6, 7)
# ['Timor']
# ('1096-031', 4, 7)
# ['Marvin', 'Benard', "'s"]
# ('1000-014', 10, 13)
# ['the', 'Czech', 'Republic']
# ('1104-002', 22, 25)
# ['Real', 'Madrid', '1']
# ('1058-021', 0, 3)
# ['Ex-Yankee', 'Randy', 'Velarde']
# ('1044-004', 43, 46)
# ['the', 'West', 'Bank']
# ('1055-028', 3, 7)
# ['Knight', 'b', 'Hollioake', '21']
# ('1055-025', 0, 5)
# ['Ijaz', 'Ahmed', 'b', 'Croft', '79']
# ('1081-000', 8, 11)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1072-007', 0, 3)
# ['Fullback', 'Andre', 'Joubert']
# ('1128-007', 0, 1)
# ['News-stand']
# ('1033-005', 16, 17)
# ['Cotti']
# ('1050-002', 0, 4)
# ['The', 'Republic', 'of', 'Ireland']
# ('0965-011', 18, 21)
# ['Jesse', 'Owens', "'s"]
# ('1063-000', 7, 10)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1095-016', 0, 3)
# ['San', 'Diego', '6']
# ('0957-033', 34, 35)
# ['3-6']
# ('1076-006', 0, 3)
# ['Zemun', '1', 'Rad']
# ('1135-008', 22, 25)
# ['Suu', 'Kyi', "'s"]
# ('1122-003', 5, 9)
# ['the', 'British', 'Broadcasting', 'Corporation']
# ('1011-006', 0, 5)
# ['St.', 'Louis-based', 'Mercantile', 'Bancorp', 'Inc.']
# ('0957-020', 0, 3)
# ['Add', 'Men', "'s"]
# ('1037-003', 9, 15)
# ['the', 'Guangdong', 'Post', 'and', 'Telecommunications', 'Administration']
# ('1016-013', 21, 24)
# ['the', 'defence', 'ministry']
# ('1054-021', 1, 3)
# ['Ludwig', '1:25']
# ('1076-031', 0, 1)
# ['Radnicki']
# ('1104-002', 27, 29)
# ['Carlos', '79th']
# ('1033-003', 6, 14)
# ['the', 'Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('1055-037', 5, 7)
# ['Mullally', '6-0-30-1']
# ('1101-009', 11, 14)
# ['the', 'World', 'Cup']
# ('1029-003', 8, 11)
# ['the', 'Commerce', 'Department']
# ('1096-012', 33, 34)
# ['Jerry']
# ('0948-022', 8, 9)
# ['Oval']
# ('0992-003', 10, 11)
# ['State']
# ('1056-030', 0, 3)
# ['11.', 'Wendy', 'Everson']
# ('1091-002', 8, 12)
# ['the', 'National', 'Tennis', 'Centre']
# ('1135-006', 32, 33)
# ['congress']
# ('1025-006', 2, 5)
# ['the', 'West', 'Bank']
# ('1069-015', 24, 26)
# ['Essex', '372']
# ('1068-006', 0, 3)
# ['Grimsby', '0', 'Portsmouth']
# ('1060-000', 0, 8)
# ['GOLF', '-', 'LEADING', 'MONEY', 'WINNERS', 'ON', 'EUROPEAN', 'TOUR']
# ('0957-018', 0, 3)
# ['Add', 'Men', "'s"]
# ('1116-006', 16, 18)
# ['Prince', 'Eugene']
# ('1121-003', 4, 8)
# ['the', 'Iraqi', 'National', 'Congress']
# ('0973-002', 21, 25)
# ['the', 'Singer', 'World', 'Series']
# ('1072-017', 0, 3)
# ['Centre', 'Walter', 'Little']
# ('1077-003', 13, 16)
# ['Glenn', 'Hoddle', "'s"]
# ('1000-001', 0, 1)
# ['Emese']
# ('0980-015', 13, 15)
# ['Jackson', 'Hole']
# ('1012-008', 0, 3)
# ['The', 'Treasury', 'Department']
# ('1015-002', 19, 22)
# ['the', 'RMS', 'Titanic']
# ('1135-015', 0, 3)
# ['The', 'NLD', 'party']
# ('1058-022', 19, 22)
# ['the', 'Baltimore', 'Orioles']
# ('0980-002', 23, 30)
# ['the', 'August', 'National', 'Association', 'of', 'Purchasing', 'Management']
# ('1140-003', 15, 18)
# ['the', 'High', 'Court']
# ('0968-003', 0, 5)
# ['The', 'International', 'Amateur', 'Athletic', 'Federation']
# ('0955-004', 0, 2)
# ['Pohang', '3']
# ('1074-002', 28, 33)
# ['the', 'African', 'Nations', "'", 'Cup']
# ('1024-010', 22, 25)
# ['the', 'United', 'States']
# ('1054-023', 3, 4)
# ['Bakker']
# ('1115-003', 2, 3)
# ['Telegraph']
# ('1009-015', 0, 4)
# ['The', 'California', 'Avocado', 'Commission']
# ('1096-025', 23, 27)
# ['the', 'San', 'Diego', 'Padres']
# ('1092-007', 9, 11)
# ['South', 'Korea']
# ('1008-014', 4, 7)
# ['the', 'Commerce', 'Department']
# ('1116-006', 0, 3)
# ['1706', '-', 'French']
# ('1156-003', 25, 30)
# ['the', 'Sant', "'", 'Egidio', 'Community']
# ('0965-011', 25, 28)
# ['the', '1936', 'Olympics']
# ('1089-004', 12, 18)
# ['the', 'Brown', 'Deer', 'Park', 'Golf', 'Course']
# ('1061-019', 0, 2)
# ['Currie', '45']
# ('0957-018', 25, 26)
# ['6-1']
# ('1121-008', 35, 36)
# ['Iraqi']
# ('1039-011', 23, 28)
# ['the', 'Moro', 'National', 'Liberation', 'Front']
# ('1109-000', 8, 10)
# ['FRIENDLY', 'INTERNATIONAL']
# ('1047-001', 2, 4)
# ['England', '1996-08-31']
# ('1154-008', 3, 8)
# ['the', 'Human', 'Rights', 'National', 'Observatory']
# ('1014-010', 13, 16)
# ['the', 'Reform', 'Party']
# ('1030-037', 4, 9)
# ['the', 'New', 'York', 'Mercantile', 'Exchange']
# ('1103-016', 42, 43)
# ['Kafkas']
# ('1148-008', 6, 9)
# ['the', 'Palestinian', 'Authority']
# ('1089-006', 15, 17)
# ['BellSouth', 'Classic']
# ('1006-007', 37, 40)
# ['King', 'Mohammed', 'Idris']
# ('1000-003', 11, 15)
# ['the', 'Budapest', 'Stock', 'Exchange']
# ('1027-004', 9, 12)
# ['Yasser', 'Arafat', "'s"]
# ('1116-004', 15, 17)
# ['England', '1558-1603']
# ('1125-006', 27, 29)
# ['eastern', 'Zairean']
# ('1124-003', 5, 9)
# ['the', 'Freedom', 'Front', 'party']
# ('1113-006', 2, 4)
# ['Luebeck', '0']
# ('1058-003', 9, 10)
# ['7-5']
# ('1042-003', 5, 7)
# ['Huize', 'county']
# ('0957-002', 8, 12)
# ['the', 'National', 'Tennis', 'Centre']
# ('1116-029', 10, 11)
# ['Italian']
# ('1009-018', 30, 34)
# ['the', 'California', 'avocado', 'group']
# ('1116-031', 8, 12)
# ['Archbishop', 'of', 'Cape', 'Town']
# ('0963-018', 22, 25)
# ['the', 'Nortel', 'Open']
# ('0952-002', 1, 2)
# ['Volgograd']
# ('1027-011', 3, 4)
# ['Arab']
# ('1109-002', 1, 2)
# ['Netherlands']
# ('1137-007', 5, 9)
# ['the', 'International', 'Red', 'Cross']
# ('1066-039', 0, 3)
# ['Burnley', '4', '2']
# ('1017-003', 34, 37)
# ['Air', 'France', "'s"]
# ('1112-000', 7, 9)
# ['WORLD', 'CUP']
# ('1009-011', 23, 27)
# ['the', 'World', 'Trade', 'Organisation']
# ('0996-002', 29, 32)
# ['PAP', 'news', 'agency']
# ('1042-001', 0, 2)
# ['BEIJING', '1996-08-30']
# ('1020-008', 1, 2)
# ['Bombay']
# ('1133-004', 23, 27)
# ['the', 'Communist', 'Party', "'s"]
# ('1150-003', 6, 9)
# ['Lilac', 'Falls', 'Motel']
# ('1031-015', 5, 6)
# ['Hong']
# ('1139-002', 16, 17)
# ['China']
# ('1051-002', 8, 9)
# ['British']
# ('1076-041', 0, 1)
# ['Radnicki']
# ('1006-004', 5, 9)
# ['the', '"', 'great', 'revolution']
# ('1133-003', 13, 14)
# ['China']
# ('1013-002', 7, 10)
# ['the', 'U.S.', 'Gulf']
# ('1113-004', 0, 2)
# ['Karlsruhe', '2']
# ('1057-001', 2, 4)
# ['England', '1996-08-31']
# ('0991-003', 15, 18)
# ['the', 'Russian', 'Federation']
# ('1096-013', 24, 28)
# ['the', 'Los', 'Angeles', 'Dodgers']
# ('1152-004', 49, 52)
# ['the', 'United', 'States']
# ('1060-003', 4, 5)
# ['British']
# ('0959-000', 0, 6)
# ['BASEBALL', '-', 'MAJOR', 'LEAGUE', 'RESULTS', 'THURSDAY']
# ('1116-024', 11, 12)
# ['earth']
# ('0966-002', 3, 7)
# ['the', 'Berlin', 'Grand', 'Prix']
# ('0979-002', 0, 1)
# ['NYMEX']
# ('0957-015', 9, 10)
# ['Sidot']
# ('1056-006', 1, 5)
# ['Antonella', 'Bellutti', '(', 'Italy']
# ('1087-017', 6, 8)
# ['Hong', 'Kong']
# ('1129-003', 11, 12)
# ['Sergiyev']
# ('0948-010', 6, 9)
# ['the', 'Minor', 'Counties']
# ('0947-000', 0, 6)
# ['CRICKET', '-', 'ENGLISH', 'COUNTY', 'CHAMPIONSHIP', 'SCORES']
# ('1011-000', 0, 1)
# ['Boatmen']
# ('1011-020', 3, 4)
# ['Boatmen']
# ('1089-000', 0, 4)
# ['GOLF', '-', 'PARNEVIK', 'TAKES']
# ('1118-007', 0, 1)
# ['Conservatives']
# ('1096-012', 35, 36)
# ['Koosman']
# ('1038-007', 14, 17)
# ['Hong', 'Kong', "'s"]
# ('1077-001', 2, 4)
# ['Moldova', '1996-08-31']
# ('0984-020', 7, 9)
# ['step-up', 'bond']
# ('1057-000', 0, 3)
# ['CRICKET', '-', 'PAKISTAN']
# ('1072-005', 28, 31)
# ['All', 'Black', 'series']
# ('0988-002', 21, 23)
# ['Gold', 'Fields']
# ('0961-002', 3, 8)
# ['the', 'National', 'Football', 'League', "'s"]
# ('1050-002', 5, 7)
# ['Liechtenstein', '5-0']
# ('1030-039', 11, 12)
# ['3,8921.1']
# ('1049-005', 27, 28)
# ['0-0']
# ('0948-004', 7, 13)
# ['the', 'Test', 'and', 'County', 'Cricket', 'Board']
# ('1056-040', 9, 10)
# ['Czech']
# ('1042-002', 24, 27)
# ['Xinhua', 'news', 'agency']
# ('0972-021', 2, 4)
# ['Muralitharan', '10-0-41-2']
# ('0988-002', 2, 6)
# ['Driefontein', 'Consolidated', 'Ltd', "'s"]
# ('1096-002', 10, 13)
# ['Devon', 'White', "'s"]
# ('1099-018', 29, 32)
# ['Gordon', 'Durie', '75th']
# ('1106-000', 7, 10)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('0990-002', 23, 26)
# ['Alexander', 'Lebed', "'s"]
# ('0966-000', 0, 6)
# ['ATHLETICS', '-', 'BERLIN', 'GRAND', 'PRIX', 'RESULTS']
# ('0956-014', 0, 2)
# ['Haitai', '64']
# ('0957-000', 0, 4)
# ['TENNIS', '-', 'FRIDAY', "'S"]
# ('1058-027', 6, 7)
# ['12-8']
# ('1055-018', 3, 5)
# ['Akram', '10-0-50-0']
# ('1136-002', 0, 4)
# ['The', 'Dow', 'Chemical', 'Co']
# ('1051-000', 0, 3)
# ['GOLF', '-', 'BRITISH']
# ('1058-037', 3, 4)
# ['3-6']
# ('1111-002', 10, 11)
# ['two-year-olds']
# ('1096-003', 8, 14)
# ['the', 'Cardinals', 'for', 'the', 'National', 'League']
# ('1092-002', 15, 18)
# ['the', 'U.S.', 'Open']
# ('0968-002', 24, 25)
# ['Sarajevo']
# ('0947-006', 28, 29)
# ['81-3']
# ('0965-007', 8, 11)
# ['the', 'Atlanta', 'Games']
# ('1130-006', 3, 8)
# ['Sleeping', 'Bread', '"', 'Puig', "'s"]
# ('1097-004', 40, 44)
# ['the', 'National', 'Tennis', 'Centre']
# ('1097-006', 24, 25)
# ['3-6']
# ('0963-021', 33, 34)
# ['U.S.']
# ('1055-000', 6, 7)
# ['SCOREBOARD']
# ('1076-036', 0, 3)
# ['Loznica', '4', '2']
# ('1045-007', 27, 30)
# ['the', 'Old', 'City']
# ('1018-003', 2, 5)
# ['Nicole', 'Nichterwitz', "'s"]
# ('1088-002', 3, 7)
# ['the', 'Hong', 'Kong', 'Open']
# ('1111-008', 3, 7)
# ['John', 'and', 'Beryll', 'Remblance']
# ('1157-000', 0, 1)
# ['Nato']
# ('1124-010', 19, 22)
# ['the', 'Northern', 'Cape']
# ('1024-008', 1, 7)
# ['Underwriter', 'Bear', 'Stearns', '&', 'Co', 'Inc']
# ('1013-000', 0, 1)
# ['U.S.']
# ('1007-016', 0, 3)
# ['Ronald', 'Reagan', "'s"]
# ('0963-023', 17, 22)
# ['the', 'World', 'Series', 'of', 'Golf']
# ('1007-012', 11, 14)
# ['the', 'White', 'House']
# ('1116-011', 8, 9)
# ['Pedro']
# ('1077-002', 20, 23)
# ['Paul', 'Ince', "'s"]
# ('1116-035', 10, 11)
# ['Taylor']
# ('0967-000', 3, 4)
# ['STANDARD']
# ('1058-027', 41, 44)
# ['the', 'Blue', 'Jays']
# ('1066-073', 0, 1)
# ['Leyton']
# ('1142-005', 12, 16)
# ['the', 'Kurdistan', 'Democratic', 'Party']
# ('1036-000', 3, 5)
# ['Arctic', 'island']
# ('1131-002', 4, 7)
# ['the', 'United', 'Nations']
# ('0968-002', 21, 22)
# ['Solidarity']
# ('0957-000', 7, 8)
# ['U.S.']
# ('1001-000', 8, 9)
# ['pct']
# ('1012-002', 0, 3)
# ['The', 'State', 'Department']
# ('1061-018', 0, 2)
# ['Boroughmuir', '20']
# ('1092-004', 4, 6)
# ['Czech', 'Republic']
# ('1096-002', 21, 22)
# ['Florida']
# ('0994-003', 20, 22)
# ['Soviet', 'republic']
# ('0956-007', 0, 2)
# ['Haitai', '2']
# ('0951-005', 0, 4)
# ['Lithuania', '-', 'Danius', 'Gleveckas']
# ('0961-003', 7, 10)
# ['the', 'Philadelphia', 'Eagles']
# ('1116-035', 8, 9)
# ['A.J.P.']
# ('0960-003', 24, 27)
# ['the', 'U.S.', 'Open']
# ('1092-000', 5, 7)
# ['FED', 'CUP']
# ('1146-005', 20, 21)
# ['Iraqi']
# ('1028-013', 4, 6)
# ['Michigan', 'Corp.']
# ('1021-000', 5, 6)
# ['MLN']
# ('1021-000', 8, 9)
# ['MLN']
# ('1054-003', 7, 12)
# ['the', 'Tour', 'of', 'the', 'Netherlands']
# ('1056-001', 2, 4)
# ['England', '1996-08-31']
# ('1069-005', 4, 6)
# ['Hampshire', '5']
# ('1007-016', 12, 15)
# ['the', 'White', 'House']
# ('1007-034', 0, 4)
# ['The', 'American', 'Stock', 'Exchange']
# ('1043-004', 46, 47)
# ['cannabis']
# ('1118-001', 2, 4)
# ['Scotland', '1996-08-31']
# ('1056-023', 1, 2)
# ['Magali']
# ('0975-012', 4, 7)
# ['Bucharest', 'Newsroom', '40-1']
# ('1039-019', 9, 10)
# ['congress']
# ('1087-002', 19, 23)
# ['the', 'Hong', 'Kong', 'Open']
# ('1058-016', 23, 27)
# ['the', 'New', 'York', 'Yankees']
# ('1027-014', 4, 7)
# ['Abu', 'Ammar', "'s"]
# ('0948-046', 7, 8)
# ['Oval']
# ('0981-011', 0, 4)
# ['Douglas', '&', 'Lomason', "'s"]
# ('1137-008', 32, 35)
# ['the', 'Korean', 'War']
# ('1124-010', 32, 33)
# ['Coloureds']
# ('1160-002', 0, 1)
# ['VENICE']
# ('1071-001', 0, 2)
# ['EDMONTON', '1996-08-31']
# ('1070-000', 0, 6)
# ['MOTOR', 'RACING', '-', 'LEADING', 'QUALIFIERS', 'FOR']
# ('1054-000', 0, 9)
# ['CYCLING', '-', 'TOUR', 'OF', 'NETHERLANDS', 'FINAL', 'RESULTS', '/', 'STANDINGS']
# ('1149-011', 2, 8)
# ['the', 'National', 'Highway', 'Traffic', 'Safety', 'Administration']
# ('1068-022', 0, 3)
# ['Luton', '1', 'Rotherham']
# ('0977-008', 6, 7)
# ['+0.578']
# ('1043-002', 14, 18)
# ['the', 'Central', 'Narcotics', 'Bureau']
# ('0947-008', 3, 4)
# ['Oval']
# ('0992-008', 0, 8)
# ['The', 'Organisation', 'for', 'Security', 'and', 'Cooperation', 'in', 'Europe']
# ('1064-007', 20, 24)
# ['the', 'Rugby', 'Football', 'Union']
# ('1160-011', 17, 18)
# ['Mao']
# ('1072-018', 45, 46)
# ['Westhuizen']
# ('1118-006', 21, 24)
# ['Conservative', 'Party', "'s"]
# ('1011-008', 6, 9)
# ['Mercantile', ',', 'Commerce']
# ('0957-020', 21, 24)
# ['6-3', '1-6', '6-3']
# ('1044-005', 2, 3)
# ['Arab']
# ('1119-006', 28, 29)
# ['Iraqi']
# ('1066-037', 0, 3)
# ['Blackpool', '4', '2']
# ('1044-003', 11, 12)
# ['Palestinian']
# ('1101-012', 53, 55)
# ['Rodrigo', 'Lara']
# ('1052-004', 0, 4)
# ['Faroe', 'Islands', '-', 'Jan']
# ('1157-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1052-002', 2, 5)
# ['the', 'Faroe', 'Islands']
# ('1031-014', 32, 35)
# ['the', 'Far', 'East']
# ('0960-004', 21, 22)
# ['5-7']
# ('0966-164', 19, 20)
# ['Florian']
# ('1030-021', 3, 4)
# ['Sept']
# ('1058-027', 31, 35)
# ['the', 'Chicago', 'White', 'Sox']
# ('0960-006', 8, 10)
# ['7-6', '6-2']
# ('1119-006', 29, 30)
# ['Kurds']
# ('1005-011', 10, 14)
# ['the', 'International', 'Monetary', 'Fund']
# ('1097-007', 7, 10)
# ['Ivan', 'Lendl', "'s"]
# ('1087-019', 9, 12)
# ['the', 'Portuguese', 'Open']
# ('0987-003', 12, 17)
# ['the', 'News', 'Agency', 'of', 'Nigeria']
# ('1149-005', 34, 37)
# ['the', 'East', 'Coast']
# ('1076-016', 0, 2)
# ['Vojvodina', '4']
# ('1039-018', 0, 5)
# ['The', 'Central', 'Jakarta', 'District', 'Court']
# ('0966-158', 1, 2)
# ['Natalya']
# ('1056-037', 6, 10)
# ['Ainars', 'Kiksis', '(', 'Latvia']
# ('1055-030', 0, 3)
# ['Saqlain', 'Mushtaq', 'b']
# ('1005-010', 18, 21)
# ['New', 'York', "'s"]
# ('1056-017', 27, 28)
# ['Heiko']
# ('1139-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('0960-004', 23, 24)
# ['6-3']
# ('1034-007', 7, 8)
# ['8982']
# ('1153-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1058-026', 5, 8)
# ['the', 'White', 'Sox']
# ('1024-003', 0, 2)
# ['Nasdaq', 'Stock']
# ('1065-002', 0, 2)
# ['Scottish', 'league']
# ('1039-010', 2, 7)
# ['the', 'House', 'of', 'Representatives', 'Wahono']
# ('1055-000', 0, 5)
# ['CRICKET', '-', 'ENGLAND', 'V', 'PAKISTAN']
# ('1030-038', 12, 17)
# ['the', 'New', 'York', 'Cotton', 'Exchange']
# ('1011-006', 31, 32)
# ['Boatmen']
# ('1000-004', 2, 5)
# ['Global', 'Depositary', 'Receipts']
# ('1148-009', 14, 16)
# ['Ben', 'Ali']
# ('1053-001', 2, 4)
# ['England', '1996-08-31']
# ('1111-002', 2, 6)
# ['the', 'Tattersalls', 'Breeders', 'Stakes']
# ('0957-007', 11, 12)
# ['6-3']
# ('1114-005', 0, 4)
# ['Lithuania', '-', 'Danius', 'Gleveckas']
# ('1061-006', 0, 1)
# ['London']
# ('0960-023', 12, 13)
# ['7-5']
# ('0947-010', 2, 4)
# ['Middlesex', '199']
# ('1096-041', 28, 31)
# ['the', 'Pirates', '10-0']
# ('1160-004', 17, 22)
# ['the', 'Irish', 'Republican', 'Army', "'s"]
# ('1027-009', 9, 12)
# ['the', 'West', 'Bank']
# ('1116-009', 0, 3)
# ['1812', '-', 'Russian']
# ('1008-029', 46, 48)
# ['2-1/4', 'percent']
# ('1061-006', 1, 2)
# ['Irish']
# ('1027-004', 18, 20)
# ['al-Aqsa', 'mosque']
# ('1142-013', 5, 6)
# ['Iraqi']
# ('1058-016', 28, 31)
# ['the', 'Angels', '6-2']
# ('0957-009', 9, 10)
# ['Czech']
# ('1157-002', 0, 6)
# ['The', 'North', 'Atlantic', 'Treaty', 'Organisation', "'s"]
# ('1116-033', 2, 5)
# ['The', 'United', 'States']
# ('1103-002', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1135-025', 6, 8)
# ['James', 'Leander']
# ('1113-002', 2, 3)
# ['German']
# ('1008-020', 7, 8)
# ['Sept']
# ('0984-005', 0, 3)
# ['BRITAIN', '-', 'Gilts']
# ('0957-021', 0, 3)
# ['Add', 'Women', "'s"]
# ('0963-023', 8, 11)
# ['the', 'PGA', 'Tour']
# ('1132-001', 0, 1)
# ['MEXICO']
# ('1056-047', 0, 4)
# ['Antonella', 'Bellutti', '(', 'Italy']
# ('1029-017', 3, 7)
# ['the', 'Labour', 'Department', "'s"]
# ('1052-002', 11, 14)
# ['their', 'World', 'Cup']
# ('1058-024', 12, 13)
# ['499th']
# ('1005-000', 0, 5)
# ['Far', 'East', 'Gold', '-', 'Moribund']
# ('1160-002', 3, 4)
# ['1996-08-31']
# ('0963-002', 20, 22)
# ['Greater', 'Milwaukee']
# ('1111-006', 1, 3)
# ['Pelham', '10-1']
# ('1004-005', 8, 11)
# ['Hen', 'Vipheak', "'s"]
# ('1071-000', 7, 10)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1039-014', 11, 15)
# ['Kia', 'Motor', 'Corp', 'of']
# ('1123-007', 0, 2)
# ['Haitai', '64']
# ('1143-003', 18, 21)
# ['the', 'United', 'States']
# ('1009-004', 27, 28)
# ['Agriculture']
# ('1082-002', 9, 12)
# ['their', 'World', 'Cup']
# ('0954-002', 3, 7)
# ['the', 'Hong', 'Kong', 'Open']
# ('1058-040', 28, 31)
# ['the', 'Minnesota', 'Twins']
# ('0971-000', 0, 9)
# ['CRICKET', '-', 'SRI', 'LANKA', 'BEAT', 'AUSTRALIA', 'BY', 'FOUR', 'WICKETS']
# ('1097-006', 25, 27)
# ['6-3', '6-3']
# ('1092-004', 3, 4)
# ['Netherlands']
# ('0967-000', 6, 7)
# ['BANNED']
# ('1116-012', 0, 3)
# ['1836', '-', 'Scottish']
# ('0976-002', 0, 5)
# ['The', 'National', 'Bank', 'of', 'Poland']
# ('1030-039', 4, 5)
# ['FTSE']
# ('1135-015', 12, 19)
# ['the', 'State', 'Law', 'and', 'Order', 'Restoration', 'Council']
# ('0981-004', 7, 12)
# ['the', 'New', 'York', 'Stock', 'Exchange']
# ('1055-019', 3, 6)
# ['Saqlain', 'Mushtaq', '10-0-59-1']
# ('0958-000', 0, 5)
# ['BASEBALL', '-', 'MAJOR', 'LEAGUE', 'STANDINGS']
# ('1043-004', 48, 49)
# ['marijuana']
# ('1089-002', 25, 27)
# ['Greater', 'Milwaukee']
# ('1160-003', 33, 37)
# ['the', 'Venice', 'Film', 'Festival']
# ('1009-008', 19, 20)
# ['Northeastern']
# ('0965-004', 11, 13)
# ['Berlin', 'grand']
# ('1008-027', 0, 5)
# ['The', 'University', 'of', 'Michigan', "'s"]
# ('1058-042', 3, 4)
# ['6-1']
# ('1135-006', 18, 21)
# ['Suu', 'Kyi', "'s"]
# ('1076-029', 0, 3)
# ['Obilic', '2', 'Zeleznik']
# ('0965-000', 0, 1)
# ['ATHLETICS']
# ('0975-007', 3, 5)
# ['June', 'Comelf']
# ('1007-005', 22, 25)
# ['the', 'Federal', 'Reserve']
# ('1145-003', 16, 18)
# ['al-Daih', 'village']
# ('0960-004', 33, 34)
# ['Stadium']
# ('0962-003', 4, 6)
# ['Greater', 'Milwaukee']
# ('0968-000', 0, 3)
# ['ATHLETICS', '-', 'HARRISON']
# ('1111-004', 2, 4)
# ['Stamper', '3-1']
# ('1135-025', 11, 12)
# ['Nichols']
# ('1060-023', 1, 4)
# ['Jonathan', 'Lomas', '181,005']
# ('1092-007', 2, 3)
# ['Croatia']
# ('1101-008', 15, 18)
# ['the', 'Internazionale', 'Milan']
# ('1115-003', 33, 36)
# ['the', 'Conservative', 'Party']
# ('1030-027', 0, 3)
# ['The', 'Commerce', 'Department']
# ('1045-006', 29, 34)
# ['the', 'Holy', 'City', 'of', 'Jerusalem']
# ('0955-011', 0, 2)
# ['Pohang', '2']
# ('1141-001', 0, 2)
# ['BEIJING', '1996-08-31']
# ('1069-000', 0, 6)
# ['CRICKET', '-', 'ENGLISH', 'COUNTY', 'CHAMPIONSHIP', 'SCORES']
# ('1136-002', 25, 28)
# ['the', 'China', 'Daily']
# ('1099-004', 4, 6)
# ['Belarus', '5-1']
# ('1045-006', 41, 45)
# ['the', 'Palestinian', 'Liberation', 'Organisation']
# ('0984-013', 6, 11)
# ['the', 'Chicago', 'Board', 'of', 'Trade']
# ('1058-014', 4, 7)
# ['the', 'White', 'Sox']
# ('0980-013', 19, 22)
# ['the', 'Federal', 'Reserve']
# ('1011-019', 12, 13)
# ['Boatmen']
# ('1108-000', 0, 1)
# ['BOXING']
# ('1069-008', 4, 6)
# ['Durham', '4']
# ('0960-019', 22, 25)
# ['the', 'All-England', 'Club']
# ('1090-000', 11, 13)
# ['FED', 'CUP']
# ('1060-011', 1, 4)
# ['Andrew', 'Coltart', '248,142']
# ('1070-003', 2, 4)
# ['Vancouver', 'IndyCar']
# ('1067-015', 0, 4)
# ['Stenhousemuir', '0', 'Stranraer', '1']
# ('0992-007', 0, 5)
# ['The', 'Party', 'of', 'Democratic', 'Action']
# ('0961-000', 0, 5)
# ['NFL', 'AMERICAN', 'FOOTBALL-RANDALL', 'CUNNINGHAM', 'RETIRES']
# ('1093-002', 0, 3)
# ['The', 'United', 'States']
# ('1016-007', 22, 25)
# ['German', 'Foreign', 'Ministry']
# ('1061-000', 7, 9)
# ['WELSH', 'RESULTS']
# ('1044-003', 13, 14)
# ['Authority']
# ('1089-026', 9, 14)
# ['the', 'World', 'Series', 'of', 'Golf']
# ('1131-004', 10, 13)
# ['the', 'United', 'States']
# ('1092-007', 11, 12)
# ['Australia']
# ('1055-028', 1, 2)
# ['Akram']
# ('1055-005', 3, 6)
# ['Mushtaq', 'Ahmed', '46']
# ('1055-006', 4, 7)
# ['Mushtaq', 'Ahmed', '1']
# ('1116-016', 21, 24)
# ['the', 'Peking', 'Protocol']
# ('0955-005', 0, 4)
# ['Puchon', '2', 'Chonbuk', '1']
# ('1012-008', 33, 35)
# ['Pan', 'Am']
# ('1037-002', 25, 27)
# ['Guangdong', 'province']
# ('0965-009', 16, 19)
# ['the', 'Golden', 'Four']
# ('1096-036', 25, 29)
# ['the', 'Colorado', 'Rockies', '7-4']
# ('1028-000', 0, 4)
# ['PRESALE', '-', 'Bay', 'Co']
# ('1106-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1074-004', 0, 3)
# ['The', 'North', 'Africans']
# ('1026-002', 13, 17)
# ['al-Islamiya', '(', 'Islamic', 'Group']
# ('1096-033', 2, 3)
# ['3-4']
# ('1140-005', 9, 10)
# ['Nationalist']
# ('1086-002', 2, 4)
# ['Moldova', '2-0']
# ('0967-006', 6, 7)
# ['3-1']
# ('1128-004', 17, 19)
# ['Ruch', 'and']
# ('1096-022', 40, 41)
# ['6-5']
# ('1090-010', 0, 3)
# ['The', 'United', 'States']
# ('1030-023', 14, 16)
# ['Salomon', 'Bros']
# ('1142-013', 6, 7)
# ['Kurdish']
# ('1096-012', 28, 29)
# ['Tom']
# ('1112-002', 11, 15)
# ['the', '1998', 'World', 'Cup']
# ('1083-002', 0, 3)
# ['Benetton', 'of', 'Italy']
# ('1089-008', 14, 15)
# ['U.S.']
# ('0960-007', 17, 18)
# ['3-6']
# ('1099-000', 6, 9)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1128-002', 4, 9)
# ['the', 'Bank', 'Rozwoju', 'Exportu', 'SA']
# ('1092-004', 8, 9)
# ['France']
# ('0994-017', 0, 3)
# ['The', 'United', 'States']
# ('1141-002', 20, 23)
# ['the', 'China', 'Daily']
# ('0996-004', 0, 5)
# ['The', 'Federal', 'Republic', 'of', 'Yugoslavia']
# ('0988-005', 23, 27)
# ['Kloof', 'Gold', 'Mining', 'Co']
# ('0984-004', 5, 13)
# ['the', 'London', 'International', 'Financial', 'Futures', 'and', 'Options', 'Exchange']
# ('1030-015', 20, 25)
# ['the', 'New', 'York', 'Stock', 'Exchange']
# ('1028-013', 0, 1)
# ['F.A.']
# ('0984-016', 48, 52)
# ['the', 'Tokyo', 'Stock', 'Exchange']
# ('1142-013', 10, 14)
# ['the', '1991', 'Gulf', 'War']
# ('1160-014', 3, 4)
# ['Northern']
# ('1142-002', 23, 24)
# ['Kurdish']
# ('1068-010', 0, 4)
# ['Port', 'Vale', '2', 'Oxford']
# ('1160-023', 18, 21)
# ['Michael', 'Collins', "'"]
# ('1070-001', 0, 2)
# ['VANCOUVER', '1996-08-31']
# ('1092-004', 10, 11)
# ['Japan']
# ('1140-003', 23, 27)
# ['the', 'Hong', 'Kong', 'Standard']
# ('1095-000', 0, 6)
# ['BASEBALL', '-', 'MAJOR', 'LEAGUE', 'RESULTS', 'FRIDAY']
# ('1124-002', 3, 4)
# ['Afrikaners']
# ('1067-006', 0, 2)
# ['Partick', '1']
# ('1053-000', 0, 5)
# ['CRICKET', '-', 'ENGLAND', 'BEAT', 'PAKISTAN']
# ('1068-007', 0, 2)
# ['Huddersfield', '1']
# ('0946-006', 26, 29)
# ['Yorkshire', 'at', 'Headingley']
# ('0967-000', 8, 10)
# ['CLUB', 'FINED']
# ('0953-002', 3, 4)
# ['Roberto']
# ('1089-001', 2, 4)
# ['Wisconsin', '1996-08-31']
# ('0947-009', 18, 20)
# ['Lancashire', '197-8']
# ('1022-010', 28, 32)
# ['the', 'Chicago', 'Purchasing', 'Managers']
# ('1001-002', 0, 5)
# ['The', 'National', 'Bank', 'of', 'Romania']
# ('1113-006', 0, 2)
# ['Duisburg', '1']
# ('0984-006', 12, 13)
# ['Chicago']
# ('0953-002', 9, 10)
# ['Duran']
# ('0991-003', 19, 22)
# ['the', 'Chechen', 'Republic']
# ('1072-008', 11, 14)
# ['centre', 'Walter', 'Little']
# ('0957-021', 18, 20)
# ['6-3', '6-2']
# ('1094-000', 0, 5)
# ['BASEBALL', '-', 'MAJOR', 'LEAGUE', 'STANDINGS']
# ('0974-004', 6, 8)
# ['world', 'series']
# ('0957-006', 17, 18)
# ['6-3']
# ('1058-007', 10, 13)
# ['Ruben', 'Sierra', "'s"]
# ('1068-005', 0, 2)
# ['Bradford', '1']
# ('1072-006', 34, 35)
# ['29-8']
# ('1000-009', 20, 21)
# ['IAS']
# ('1060-009', 1, 2)
# ['Costantino']
# ('1114-000', 7, 8)
# ['QUALIFIER']
# ('1068-008', 0, 3)
# ['Norwich', '1', 'Wolverhampton']
# ('1031-004', 15, 21)
# ['the', 'Wuxi', 'Tong', 'Ling', 'Company', 'Ltd']
# ('1096-013', 3, 6)
# ['Delino', 'DeShields', "'s"]
# ('0984-010', 24, 25)
# ['BTP']
# ('1105-000', 4, 7)
# ['SPANISH', 'FIRST', 'DIVISION']
# ('1130-003', 0, 2)
# ['Puig', "'s"]
# ('0968-003', 40, 42)
# ['Kosevo', 'stadium']
# ('1045-010', 12, 16)
# ['the', 'Burj', 'al-Laqlaq', 'Society']
# ('1011-016', 0, 1)
# ['Boatmen']
# ('0990-003', 11, 14)
# ['Interfax', 'quoted', 'Chernomyrdin']
# ('1090-005', 10, 13)
# ['the', 'Czech', 'Republic']
# ('1032-002', 26, 30)
# ['the', 'European', 'Options', 'Exchange']
# ('0957-012', 14, 15)
# ['6-1']
# ('1066-042', 0, 1)
# ['Bristol']
# ('0972-024', 3, 6)
# ['Healy', 'b', 'Fleming']
# ('0947-008', 9, 11)
# ['Surrey', '429-7']
# ('1146-005', 21, 22)
# ['Kurds']
# ('0955-010', 0, 2)
# ['Chonan', '3']
# ('1087-008', 21, 22)
# ['15-8']
# ('1055-038', 5, 7)
# ['Croft', '8-0-37-2']
# ('1040-000', 0, 5)
# ['Jeans', 'Mate', 'Corp', '-', '6mth']
# ('1055-001', 2, 4)
# ['England', '1996-08-31']
# ('0966-023', 1, 2)
# ['Florian']
# ('1133-001', 0, 2)
# ['MANILA', '1996-08-31']
# ('1069-010', 23, 24)
# ['71-1']
# ('1076-042', 0, 1)
# ['Zeleznik']
# ('1068-034', 0, 1)
# ['Leyton']
# ('1049-000', 8, 9)
# ['WIN']
# ('0994-010', 31, 34)
# ['the', 'Soviet', 'Union']
# ('1056-038', 6, 7)
# ['Christian']
# ('1069-006', 3, 6)
# ['Glamorgan', 'beat', 'Durham']
# ('1009-020', 10, 14)
# ['the', 'Agriculture', 'Department', "'s"]
# ('1040-009', 0, 5)
# ['NOTE', '-', 'Jeans', 'Mate', 'Corp']
# ('0990-000', 2, 4)
# ['Lebed', 'Chechnya']
# ('1060-017', 0, 3)
# ['13.', 'Paul', 'McGinley']
# ('1044-005', 3, 5)
# ['East', 'Jerusalem']
# ('1030-007', 5, 7)
# ['Sept', 'Brent']
# ('1017-004', 25, 26)
# ['unions']
# ('1025-005', 13, 16)
# ['the', 'West', 'Bank']
# ('1008-004', 0, 3)
# ['The', 'Commerce', 'Department']
# ('1158-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1116-014', 9, 13)
# ['his', 'Trades', 'Disputes', 'Act']
# ('1058-036', 28, 32)
# ['the', 'Kansas', 'City', 'Royals']
# ('1049-005', 18, 21)
# ['Jack', 'Charlton', "'s"]
# ('1096-012', 30, 31)
# ['Seaver']
# ('1031-004', 39, 41)
# ['Jiangsu', 'province']
# ('1080-000', 6, 9)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('0973-000', 0, 4)
# ['CRICKET', '-', 'AUSTRALIA', '228-9']
# ('1152-005', 5, 9)
# ['the', 'Department', 'of', 'Defense']
# ('1052-004', 4, 6)
# ['Allan', 'Mueller']
# ('1005-014', 7, 10)
# ['New', 'York', "'s"]
# ('1070-000', 6, 9)
# ['VANCOUVER', 'INDYCAR', 'RACE']
# ('0984-016', 0, 1)
# ['Japanese']
# ('1156-006', 15, 21)
# ['the', 'Lay', 'Volunteers', "'", 'International', 'Organisation']
# ('0984-003', 0, 3)
# ['GERMANY', '-', 'Bunds']
# ('1061-008', 0, 4)
# ['Orrell', '13', 'Bath', '56']
# ('1148-009', 12, 14)
# ['Zine', 'al-Abidine']
# ('1067-005', 0, 3)
# ['Greenock', 'Morton', '1']
# ('1016-009', 17, 20)
# ['the', 'West', 'Bank']
# ('1012-006', 0, 4)
# ['The', 'U.S.', 'Treasury', 'Department']
# ('1116-007', 9, 15)
# ['the', 'Holy', 'Roman', 'Emperor', 'Charles', 'VI']
# ('1152-017', 9, 14)
# ['the', 'Tarawa', 'Amphibious', 'Readiness', 'Group']
# ('1137-006', 9, 12)
# ['the', 'Korean', 'War']
# ('1105-001', 0, 2)
# ['MADRID', '1996-08-31']
# ('1078-005', 0, 3)
# ['Benetton', '(', 'Italy']
# ('0948-033', 3, 4)
# ['British']
# ('1125-003', 10, 11)
# ['Rwanda']
# ('1090-003', 11, 14)
# ['the', 'United', 'States']
# ('0947-007', 15, 17)
# ['Kent', '108-3']
# ('1159-001', 0, 2)
# ['BRUSSELS', '1996-08-31']
# ('1021-000', 0, 3)
# ['MARTELA', 'H1', 'PROFIT']
# ('1113-004', 2, 5)
# ['Hansa', 'Rostock', '0']
# ('1116-022', 20, 22)
# ['Cardinal', 'Wolsey']
# ('1143-003', 43, 44)
# ['Lebanon']
# ('1087-017', 13, 16)
# ['Australian', 'Rodney', 'Eyles']
# ('1027-011', 4, 6)
# ['East', 'Jerusalem']
# ('1046-002', 21, 22)
# ['line-up']
# ('1009-015', 22, 25)
# ['the', 'Agriculture', 'Department']
# ('1152-014', 49, 52)
# ['the', 'United', 'States']
# ('0985-011', 12, 14)
# ['American', 'Tyson']
# ('0947-006', 20, 22)
# ['Durham', '114']
# ('1041-009', 0, 5)
# ['NOTE', '-', 'Apic', 'Yamada', 'Corp']
# ('1062-000', 7, 10)
# ['WORLD', 'CUP', 'QUALIFIER']
# ('1030-006', 2, 3)
# ['CRUDE']
# ('0990-009', 11, 14)
# ['the', 'Russian', 'Federation']
# ('1098-000', 0, 1)
# ['BOXING']
# ('1068-037', 0, 2)
# ['Torquay', '2']
# ('1069-017', 16, 18)
# ['Kent', '244']
# ('1116-032', 7, 10)
# ['South', 'Africa', "'s"]
# ('0963-004', 12, 13)
# ['U.S.']
# ('1101-000', 10, 11)
# ['WIN']
# ('1055-018', 6, 7)
# ['Waqar']
# ('0979-012', 0, 1)
# ['NYMEX']
# ('1049-001', 2, 4)
# ['Liechtenstein', '1996-08-31']

# %% [markdown]
# Show that you achieve the performance goal by reporting the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# Before going on, we ask you to store the outputs of the improved named entity recognizer on the development data in a new data frame. This new frame should have the same layout as the original data frame for the development data that you loaded above, but should contain the predicted start and end positions for each token span. As the `label` of each span, you can use the special value `--NME--`.

# %%
# TODO: Write code here to store the predicted spans in a new data frame
predicted_spans = set(improved_gold_spans(df_dev))
#pred_spans.columns = ['sentence_id','beg','end']
df_predicted = []
for j in predicted_spans:
    df_predicted.append([j[0],df_dev[df_dev.sentence_id == j[0]].sentence.values[0],j[1],j[2],'--NME--'])

# %%
df_predicted = pd.DataFrame(df_predicted, columns = df_dev.columns)
df_predicted.sort_values(by=['sentence_id', 'beg']).reset_index(drop = True)
# Out:
#      sentence_id                                           sentence  beg  end  \
# 0       0946-001                                  LONDON 1996-08-30    0    1
# 1       0946-002  West Indian all-rounder Phil Simmons took four...    0    2
# 2       0946-002  West Indian all-rounder Phil Simmons took four...    3    5
# 3       0946-002  West Indian all-rounder Phil Simmons took four...   14   15
# 4       0946-003  Their stay on top , though , may be short-live...   13   14
# 5       0946-003  Their stay on top , though , may be short-live...   15   16
# 6       0946-003  Their stay on top , though , may be short-live...   17   18
# 7       0946-003  Their stay on top , though , may be short-live...   24   25
# 8       0946-003  Their stay on top , though , may be short-live...   35   36
# 9       0946-004  After bowling Somerset out for 83 on the openi...    2    3
# 10      0946-004  After bowling Somerset out for 83 on the openi...   11   13
# 11      0946-004  After bowling Somerset out for 83 on the openi...   14   15
# 12      0946-004  After bowling Somerset out for 83 on the openi...   29   30
# 13      0946-004  After bowling Somerset out for 83 on the openi...   31   33
# 14      0946-005  Trailing by 213 , Somerset got a solid start t...    4    5
# 15      0946-006  Essex , however , look certain to regain their...   12   14
# 16      0946-006  Essex , however , look certain to regain their...   15   17
# 17      0946-006  Essex , however , look certain to regain their...   26   29
# 18      0946-007  Hussain , considered surplus to England 's one...    5    6
# 19      0946-007  Hussain , considered surplus to England 's one...   22   23
# 20      0946-008  By the close Yorkshire had turned that into a ...    3    4
# 21      0946-009  At the Oval , Surrey captain Chris Lewis , ano...    2    3
# 22      0946-009  At the Oval , Surrey captain Chris Lewis , ano...    4    5
# 23      0946-009  At the Oval , Surrey captain Chris Lewis , ano...    6    8
# 24      0946-009  At the Oval , Surrey captain Chris Lewis , ano...   13   14
# 25      0946-010  He was well backed by England hopeful Mark But...    5    6
# 26      0946-010  He was well backed by England hopeful Mark But...    7    9
# 27      0946-010  He was well backed by England hopeful Mark But...   13   14
# 28      0946-012  Australian Tom Moody took six for 82 but Chris...    0    1
# 29      0946-012  Australian Tom Moody took six for 82 but Chris...    1    3
# ...          ...                                                ...  ...  ...
# 4661    1160-012  " Collins would never be a proponent of contem...    1    2
# 4662    1160-014  Leeson , the Northern Ireland-born actor who w...    0    1
# 4663    1160-014  Leeson , the Northern Ireland-born actor who w...    3    4
# 4664    1160-014  Leeson , the Northern Ireland-born actor who w...   11   12
# 4665    1160-014  Leeson , the Northern Ireland-born actor who w...   20   23
# 4666    1160-014  Leeson , the Northern Ireland-born actor who w...   30   31
# 4667    1160-015  Aidan Quinn portrays Harry Boland , Collins ' ...    0    2
# 4668    1160-015  Aidan Quinn portrays Harry Boland , Collins ' ...    3    5
# 4669    1160-015  Aidan Quinn portrays Harry Boland , Collins ' ...    6    7
# 4670    1160-015  Aidan Quinn portrays Harry Boland , Collins ' ...   17   19
# 4671    1160-015  Aidan Quinn portrays Harry Boland , Collins ' ...   22   23
# 4672    1160-016  Much of the film was shot on location in Dubli...    9   10
# 4673    1160-016  Much of the film was shot on location in Dubli...   11   12
# 4674    1160-018  Noting that information about Collins was " as...    4    5
# 4675    1160-018  Noting that information about Collins was " as...   16   17
# 4676    1160-022  One of the assumptions is his interpretation o...   16   17
# 4677    1160-022  One of the assumptions is his interpretation o...   31   32
# 4678    1160-023  " I have never lost more sleep over the making...   18   21
# 4679    1160-023  " I have never lost more sleep over the making...   33   34
# 4680    1160-024  " In the life of one person you can tell the e...   19   20
# 4681    1161-002  Shares on the Dhaka Stock Exchange ( DSE ) may...    2    6
# 4682    1161-002  Shares on the Dhaka Stock Exchange ( DSE ) may...    7    8
# 4683    1161-002  Shares on the Dhaka Stock Exchange ( DSE ) may...   37   38
# 4684    1161-004  There will be both buying and selling pressure...   12   14
# 4685    1161-005  Broker Khurshid Alam said : " The market senti...    1    3
# 4686    1161-007  Brokers said blue chips like IDLC , Bangladesh...    5    6
# 4687    1161-007  Brokers said blue chips like IDLC , Bangladesh...    7    9
# 4688    1161-007  Brokers said blue chips like IDLC , Bangladesh...   10   12
# 4689    1161-007  Brokers said blue chips like IDLC , Bangladesh...   13   15
# 4690    1161-009  The DSE all share price index closed 2.73 poin...    1    2
#
#         label
# 0     --NME--
# 1     --NME--
# 2     --NME--
# 3     --NME--
# 4     --NME--
# 5     --NME--
# 6     --NME--
# 7     --NME--
# 8     --NME--
# 9     --NME--
# 10    --NME--
# 11    --NME--
# 12    --NME--
# 13    --NME--
# 14    --NME--
# 15    --NME--
# 16    --NME--
# 17    --NME--
# 18    --NME--
# 19    --NME--
# 20    --NME--
# 21    --NME--
# 22    --NME--
# 23    --NME--
# 24    --NME--
# 25    --NME--
# 26    --NME--
# 27    --NME--
# 28    --NME--
# 29    --NME--
# ...       ...
# 4661  --NME--
# 4662  --NME--
# 4663  --NME--
# 4664  --NME--
# 4665  --NME--
# 4666  --NME--
# 4667  --NME--
# 4668  --NME--
# 4669  --NME--
# 4670  --NME--
# 4671  --NME--
# 4672  --NME--
# 4673  --NME--
# 4674  --NME--
# 4675  --NME--
# 4676  --NME--
# 4677  --NME--
# 4678  --NME--
# 4679  --NME--
# 4680  --NME--
# 4681  --NME--
# 4682  --NME--
# 4683  --NME--
# 4684  --NME--
# 4685  --NME--
# 4686  --NME--
# 4687  --NME--
# 4688  --NME--
# 4689  --NME--
# 4690  --NME--
#
# [4691 rows x 5 columns]

# %% [markdown]
# ## Problem 4: Entity linking

# %% [markdown]
# Now that we have a method for predicting mention spans, we turn to the task of **entity linking**, which amounts to predicting the knowledge base entity that is referenced by a given mention. In our case, for each span we want to predict the Wikipedia page that this mention references.
#
# Start by extending the generator function that you implemented in Problem&nbsp;2 to labelled spans.

# %%
def gold_mentions(df):
    """Yield the gold-standard mentions in a data frame.

    Args:
        df: A data frame.

    Yields:
        The gold-standard mention spans in the specified data frame as
        quadruples consisting of the sentence id, start position, end
        position and entity label of each span.
    """
    # TODO: Replace the next line with your own code
    for i in df.itertuples():
        yield (i[1], i[3], i[4], i[5])

# %% [markdown]
# A naive baseline for entity linking on our data set is to link each mention span to the Wikipedia page name that we get when we join the tokens in the span by underscores, as is standard in Wikipedia page names. Suppose, for example, that a span contains the two tokens
#
#     Jimi Hendrix
#
# The baseline Wikipedia page name for this span would be
#
#     Jimi_Hendrix
#
# Implement this naive baseline and evaluate its performance. Print the evaluation measures that you implemented in Problem&nbsp;1.

# %% [markdown]
# <div class="alert alert-warning">
#     Here and in the remainder of this lab, you should base your entity predictions on the predicted spans that you computed in Problem&nbsp;3.
# </div>

# %%
# TODO: Write code here to implement the baseline
def baseline_(data):
    for  row in data.itertuples():
        label = "_".join(row.sentence.split(" ")[int(row.beg):int(row.end)])
        yield row.sentence_id, row.beg, row.end, label     
evaluation_report(set(gold_mentions(df_dev)),set(baseline_(df_predicted.copy() )))
# Out:
# Precision score is 32.61564698358559 %
# Recall score is 25.857698157850262 %
# f1 score is 28.846153846153843 %

# %% [markdown]
# ## Problem 5: Extending the training data using the knowledge base

# %% [markdown]
# State-of-the-art approaches to entity linking exploit information in knowledge bases. In our case, where Wikipedia is the knowledge base, one particularly useful type of information are links to other Wikipedia pages. In particular, we can interpret the anchor texts (the highlighted texts that you click on when you click on a link) as mentions of the entities (pages) that they link to. This allows us to harvest long lists over mention–entity pairings.
#
# The following cell loads a data frame summarizing anchor texts and page references harvested from the first paragraphs of the English Wikipedia. The data frame also contains all entity mentions in the training data (but not the development or the test data).

# %%
with bz2.open("kb.tsv.bz2", 'rt',encoding="utf8") as source:
    df_kb = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# To understand what information is available in this data, the following cell shows the entry for the anchor text `Sweden`.

# %%
df_kb.loc[df_kb["mention"] == "Sweden"]
# Out:
#       mention                                 entity      prob
# 17436  Sweden                                 Sweden  0.985768
# 17437  Sweden          Sweden_national_football_team  0.014173
# 17438  Sweden  Sweden_men's_national_ice_hockey_team  0.000059

# %% [markdown]
# As you can see, each row of the data frame contains a pair $(m, e)$ of a mention $m$ and an entity $e$, as well as the conditional probability $P(e|m)$ for mention $m$ referring to entity $e$. These probabilities were estimated based on the frequencies of mention–entity pairs in the knowledge base. The example shows that the anchor text &lsquo;Sweden&rsquo; is most often used to refer to the entity [Sweden](http://en.wikipedia.org/wiki/Sweden), but in a few cases also to refer to Sweden&rsquo;s national football and ice hockey teams. Note that references are sorted in decreasing order of probability, so that the most probable pairing stands first.
#
# Implement an entity linking method that resolves each mention to the most probable entity in the data frame. If the mention is not included in the data frame, you can predict the generic label `--NME--`. Print the precision, recall, and F1 of your method using the function that you implemented for Problem&nbsp;1.

# %%
# TODO: Write code here to implement the "most probable entity" method.
def most_probable_entity(mention):
    entity = df_kb.loc[df_kb.mention == mention]
    if (len(entity) > 0):
        return entity.iloc[0].entity
    else :
        return "--NME--"

def extender_knowledge_base(data):
    for i in data.itertuples(): 
        label = i.sentence.split(" ")[int(i.beg):int(i.end)]
        label = " ".join(label)
        yield i.sentence_id, i.beg, i.end, most_probable_entity(label)
                    
evaluation_report(set(gold_mentions(df_dev)),set(extender_knowledge_base(df_predicted)))
# Out:
# Precision score is 65.5510552121083 %
# Recall score is 51.96890316038533 %
# f1 score is 57.97511312217195 %

# %% [markdown]
# ## Problem 6: Context-sensitive disambiguation

# %% [markdown]
# Consider the entity mention &lsquo;Lincoln&rsquo;. The most probable entity for this mention turns out to be [Lincoln, Nebraska](http://en.wikipedia.org/Lincoln,_Nebraska); but in pages about American history, we would be better off to predict [Abraham Lincoln](http://en.wikipedia.org/Abraham_Lincoln). This suggests that we should try to disambiguate between different entity references based on the textual context on the page from which the mention was taken. Your task in this last problem is to implement this idea.
#
# Set up a dictionary that contains, for each mention $m$ that can refer to more than one entity $e$, a separate Naive Bayes classifier to predict the correct entity $e$, given the textual context of the mention. As the prior probabilities of the classifier, choose the probabilities $P(e|m)$ that you used in Problem&nbsp;5. To let you estimate the context-specific probabilities, we have compiled a data set with mention contexts:

# %%
with bz2.open("contexts.tsv.bz2") as source:
    df_contexts = pd.read_csv(source, sep='\t', quoting=csv.QUOTE_NONE)

# %% [markdown]
# This data frame contains, for each ambiguous mention $m$ and each knowledge base entity $e$ to which this mention can refer, up to 100 randomly selected contexts in which $m$ is used to refer to $e$. For this data, a **context** is defined as a bag of words containing the mention itself, as well as the 5 tokens to the left and the 5 tokens to the right of the mention. Here are a few examples:

# %%
df_contexts.head()
# Out:
#           mention                 entity  \
# 0            1970  UEFA_Champions_League
# 1            1970         FIFA_World_Cup
# 2  1990 World Cup    1990_FIFA_World_Cup
# 3  1990 World Cup    1990_FIFA_World_Cup
# 4  1990 World Cup    1990_FIFA_World_Cup
#
#                                              context
# 0  Cup twice the first in 1970 and the second in ...
# 1  America 1975 and during the 1970 and 1978 Worl...
# 2     Manolo represented Spain at the 1990 World Cup
# 3  Hašek represented Czechoslovakia at the 1990 W...
# 4  renovations in 1989 for the 1990 World Cup The...

# %% [markdown]
# From this data frame, it is easy to select the data that you need to train the classifiers – the contexts and corresponding entities for all mentions. To illustrate this, the following cell shows how to select all contexts that belong to the mention &lsquo;Lincoln&rsquo;:

# %%
df_contexts.context[df_contexts.mention == "Lincoln"]
# Out:
# 41465    Nebraska Concealed Handgun Permit In Lincoln m...
# 41466    Lazlo restaurants are located in Lincoln and O...
# 41467    California Washington Overland Park Kansas Lin...
# 41468    City Missouri Omaha Nebraska and Lincoln Nebra...
# 41469    by Sandhills Publishing Company in Lincoln Neb...
# 41470    the Humanities NEH based in Lincoln Nebraska H...
# 41471    town Hallam situated halfway between Lincoln a...
# 41472    games in Memorial Stadium in Lincoln The Huske...
# 41473    site and retail store in Lincoln Nebraska and ...
# 41474    The eastern segment begins in Lincoln and ends...
# 41475    1869 with one campus in Lincoln the system now...
# 41476    Ron Kurtenbach is Lincoln Nebraska communist b...
# 41477    state of Nebraska He represented Lincoln distr...
# 41478    national celebrity for his 1908 Lincoln to New...
# 41479    brewery founded in 1990 in Lincoln Nebraska US...
# 41480    state government agency Located in Lincoln the...
# 41481    Omaha Grand Island Kearney and Lincoln Nebrask...
# 41482    TV affiliated television station for Lincoln a...
# 41483    airs in the area on Lincoln KFXL TV which is c...
# 41484    is also included in the Lincoln Beatrice NE Co...
# 41485    the University of Nebraska in Lincoln and was ...
# 41486    peace advocacy organization based in Lincoln N...
# 41487    influence and membership on the Lincoln Board ...
# 41488    Nebraska and grew up in Lincoln She earned bac...
# 41489    official public library system in Lincoln Nebr...
# 41490    Wilson and Irving Chapin of Lincoln Nebraska f...
# 41491    Legislature It is headquartered in Lincoln Neb...
# 41492    the University of Nebraska Lincoln Lincoln Neb...
# 41493    the Nebraska State Penitentiary in Lincoln He ...
# 41494    1923 both to Nebraska in Lincoln before packed...
#                                ...
# 41584    on the night of the Lincoln assassination lawy...
# 41585    He was appointed by President Lincoln and serv...
# 41586    the sleeping quarters for President Lincoln Th...
# 41587    it in exchange for President Lincoln appointin...
# 41588    presents its title character as Lincoln worthy...
# 41589    the campaign song for the Lincoln Johnson tick...
# 41590    Booth the day after President Lincoln assassin...
# 41591    Academy administers the Order of Lincoln the h...
# 41592    Republican Party in Oregon supporting Lincoln ...
# 41593    written by Blakeslee such as Lincoln verse the...
# 41594    after being jailed by the Lincoln administrati...
# 41595    other being the hunt for Lincoln killer It sho...
# 41596    Chester French who also sculpted Lincoln seate...
# 41597    of War Simon Cameron President Lincoln directe...
# 41598    an open critic of the Lincoln administration H...
# 41599    Regiments His Interviews with Presidents Linco...
# 41600    and scored landslide victory for Lincoln and h...
# 41601    the Southern position than to Lincoln acts of ...
# 41602    as the site of the Lincoln log cabin built in ...
# 41603    Congress not the president President Lincoln i...
# 41604                  Lincoln notation on the letter read
# 41605    United States Treasury by President Lincoln He...
# 41606    of the Treasury during the Lincoln administration
# 41607    64 He worked for Presidents Lincoln and Johnso...
# 41608                                      Swansea Lincoln
# 41609                                Lincoln Leyton Orient
# 41610               English division three Swansea Lincoln
# 41611    league membership narrowly edging out Lincoln ...
# 41612                                    Lincoln Cambridge
# 41613                                              Lincoln
# Name: context, Length: 149, dtype: object

# %% [markdown]
# Implement the context-sensitive disambiguation method and evaluate its performance. Here are some more hints that may help you along the way:
#
# **Hint 1:** The prior probabilities for a Naive Bayes classifier can be specified using the `class_prior` option. You will have to provide the probabilities in the same order as the alphabetically sorted class (entity) names.
#
# **Hint 2:** To tune the performance of your method, you can try to tweak the behaviour of the vectorizer (for example, should it apply lowercasing or not?) and the width of the window from which you are extracting context tokens at prediction time.
#
# **Hint 3:** Not all mentions in the knowledge base are ambiguous, and therefore not all mentions have context data. If a mention has only one possible entity, pick that one. If a mention has no entity at all, predict the `--NME--` label.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
entitymentiondict = {}
for m in df_contexts.mention.unique():
    pipeline = Pipeline([('cv', CountVectorizer()),
                     ('mnb', MultinomialNB(class_prior = 
                    list(df_kb[df_kb.mention == m].sort_values(by=["entity"]).prob)))])
    pipeline.fit(df_contexts.context[df_contexts.mention == m], df_contexts.entity[df_contexts.mention == m])
    entitymentiondict[m] = pipeline
    
def probable_entity(mention, sentence, beg, end, n):
    if mention in entity_dict:
        context = sentence.split(" ")
        context = context[max(0, int(beg) - n):min(len(context), int(end) + n)]
        context = ' '.join(context)
        return entitymentiondict[mention].predict([context])[0]
    return most_probable_entity(mention)
    
def mnb_predict(data):
    for i in data.itertuples():
        label = i.sentence.split(" ")[int(i.beg):int(i.end)]
        label = " ".join(label)
        yield i.sentence_id, i.beg, i.end, probable_entity(label, i.sentence, i.beg, i.end, 5)

evaluation_report(set(gold_mentions(df_dev)), set(mnb_predict(df_predicted)))
# Out:
# Precision score is 67.02195693881902 %
# Recall score is 53.13503464593544 %
# f1 score is 59.276018099547514 %

# %%
def nb_predict_mentions(data):
    for i in data.itertuples():
        label = i.sentence.split(" ")[int(i.beg):int(i.end)]
        label = " ".join(label)
        yield i.sentence_id, i.beg, i.end, mnb_entity(label, i.sentence, i.beg, i.end, 10)

evaluation_report(set(gold_mentions(df_dev)), set(nb_predict_mentions(df_predicted)))
# Out:
# Precision score is 67.21381368578129 %
# Recall score is 53.28713875274632 %
# f1 score is 59.44570135746607 %

# %%
def nb_predict_mentions(data):
    for i in data.itertuples():
        label = i.sentence.split(" ")[int(i.beg):int(i.end)]
        label = " ".join(label)
        yield i.sentence_id, i.beg, i.end, mnb_entity(label, i.sentence, i.beg, i.end, 20)

evaluation_report(set(gold_mentions(df_dev)), set(nb_predict_mentions(df_predicted)))
# Out:
# Precision score is 67.32040076742699 %
# Recall score is 53.37164103430793 %
# f1 score is 59.53996983408748 %

# %% [markdown]
# You should expect to see a small (around 1&nbsp;unit) increase in both precision, recall, and F1. Published systems report a larger impact of context-sensitive disambiguation. Feel free to think about what could explain the relatively minor impact that we see here!

# %% [markdown]
# *With a buffer length of 5, we get a precision of 67.02% which is higher than the 65.55% from the knowledge extension done previously, also a 1% approx. increase in recall score and f1 score is observed. It is seen from that when the buffer length is increased , we notice a marginal increase in the precision which shows that an optimum span of context is required to maximise the precision.*

# %% [markdown]
# **This was the last lab in the Text Mining course. Well done!**

# %% [markdown]
# <div class="alert alert-info">
#     Please read the section ‘General information’ on the ‘Labs’ page of the course website before submitting this notebook!
# </div>
